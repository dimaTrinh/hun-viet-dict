# %%
import urllib.request 
from urllib.parse import quote 
from bs4 import BeautifulSoup
import json
import re
import time

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
#Source: https://codezup.com/web-scraping-word-meaning-dictionary-python-beautifulsoup/

# %%
#getting the already scraped dict
import json
with open('/content/gdrive/My Drive/Colab Notebooks/Dictionary Project/vdict VI-EN ver 2.json') as json_file:
     currDict = json.load(json_file)

# %%
#reading the word list produced by wikt2dict:
with open('/content/gdrive/My Drive/Colab Notebooks/Dictionary Project/wiktVietList') as infile:
  wordsData = infile.readlines()

# %%
wordsData[0:5]
# Out:
# ['tài sản\n',
#  'nhiên liệu\n',
#  'bò bía\n',
#  'tôi là người hồi giáo\n',
#  'xe lam\n']

# %%
#generate a list of words from the word list produced by wikt2dict
def generateWordList(): 
  temp = []
  for word in wordsData:
    word = word.strip()
    temp.append(word)
  return temp

# %%
wordList = generateWordList()
len(wordList)
# Out:
# 17357

# %%
#break the word list into batches of 
batches = [wordList[i:i + 10000] for i in range(0, len(wordList), 10000)]

# %%
for batch in batches:
  print(len(batch))
# Out:
# 10000
# 7357

# %%
#The link format for vdict Viet-Eng is: https://vdict.com/m%E1%BB%99t,2,0,0.html

# %%
#Converting IRI to ASCII:
#https://stackoverflow.com/questions/4389572/how-to-fetch-a-non-ascii-url-with-python-urlopen

# %%
def findTranslation(word):
    print("Finding translation for " + word)
    url = "https://vdict.com/" + quote(word) + ",2,0,0.html" #resolving the IRI issue
    
    try: #make sure the link is working
        source = urllib.request.urlopen(url)
    except:
        print("Link broken for " + word)
        return "N/A"
    
    soup = BeautifulSoup(source, 'lxml')

    #make sure the word is in the dictionary
    if (soup.find("div", id = 'result-contents') is None):
        print("Not in the dictionary " + word)
        return "N/A"
    
    translations = {}

    #Getting the first POS tag
    firstPosTag = soup.find("div", class_ = 'phanloai')
    
    if (firstPosTag is None): #empty translation page
        print("Empty translation page " + word)
        return "N/A"
    
    curPos = firstPosTag.string.split(' \xa0')[0]

    #first translation is a tag away from the first POS tag
    curTag = firstPosTag.next_sibling.next_sibling

    #storing the number of translations a word has
    numTrans = 1

    #continue while we are either in a POS tag or a translation tag
    while (curTag != '\n'): 
        if (curTag.attrs["class"] == ["list1"]): #a translation
            temp = {} #temp dict to store each translation of a word

            #getting the raw translation
            if (curTag.find('b').string is not None): #empty translation cell
                temp['translation'] = re.split('[,;]', curTag.find('b').string)
                temp['POS'] = curPos

                #retrieving the examples of each of the translations
                try:
                    examples = curTag.findAll("ul", class_= "list2")
                    temp2 = {} #another dict to store each examples of a translation

                    numExamples = len(list(examples))
                    temp2['nums'] = numExamples

                    for j in range(0, numExamples):
                        temp2['context ' + str(j+1)] = examples[j].find(class_ = "example-original").string

                        #retrieving the usage of each examples
                        try: 
                            tempString = str(examples[j].find("li")) #extracting the usage
                            temp2['usage ' + str(j+1)] = str(examples[j].find("li").contents[-1])
                        except:
                            temp2['usage ' + str(j+1)] = "N/A"

                    temp['examples'] = temp2
                except:
                    temp['examples'] = "N/A"

                translations[numTrans] = temp #adding the translation to the dictionary

                numTrans += 1
            curTag = curTag.next_sibling                
        else: #a tag
            curPos = curTag.string.split(' \xa0')[0]
            curTag = curTag.next_sibling

    #storing the number of translations
    translations['nums'] = numTrans - 1
    return translations

# %%
findTranslation("đòn bẩy")
# Out:
# Finding translation for đòn bẩy
# {1: {'POS': '',
#   'examples': {'context 1': 'Dùng đòn bẩy để bẩy hòn đá',
#    'nums': 1,
#    'usage 1': 'To lift a stone with a lever'},
#   'translation': ['Lever']},
#  'nums': 1}

# %%
url = "https://vdict.com/" + quote("có") + ",2,0,0.html" #resolving the IRI issue

try:
    source = urllib.request.urlopen(url)
except:
    print( "Link broken")
soup = BeautifulSoup(source, 'lxml')

# %%
soup.find("div", class_ = 'phanloai').next_sibling.next_sibling.next_sibling.next_sibling
# Out:
# '\n'

# %%
from google.colab import files
start_time = time.time()

index = 1
batch = batches[index] 

#for (index, batch) in enumerate(batches):
dictionary = {}

#making the dictionary for each batch
for word in batch:

    #if the word is not in already in the dict, find the translation
    if word not in currDict:
      dictionary[word] = findTranslation(word)
      time.sleep(1) #wait for 1 sec between each query
# Out:
# Streaming output truncated to the last 5000 lines.
# Finding translation for xê-ri
# Not in the dictionary xê-ri
# Finding translation for giống trung
# Not in the dictionary giống trung
# Finding translation for tờ quảng cáo
# Not in the dictionary tờ quảng cáo
# Finding translation for tương ớt
# Not in the dictionary tương ớt
# Finding translation for tương hợp
# Not in the dictionary tương hợp
# Finding translation for chuẩn bị
# Finding translation for nằm úp
# Not in the dictionary nằm úp
# Finding translation for cây chia ba
# Not in the dictionary cây chia ba
# Finding translation for giò đĩa
# Not in the dictionary giò đĩa
# Finding translation for thỏa thuật bảo mật thông tin
# Not in the dictionary thỏa thuật bảo mật thông tin
# Finding translation for đất trượt
# Not in the dictionary đất trượt
# Finding translation for xe xích lô
# Not in the dictionary xe xích lô
# Finding translation for đầu gối
# Finding translation for độc diễn
# Not in the dictionary độc diễn
# Finding translation for thiên đàn
# Not in the dictionary thiên đàn
# Finding translation for grenada
# Not in the dictionary grenada
# Finding translation for tuyệt cú mèo
# Not in the dictionary tuyệt cú mèo
# Finding translation for lanh lợi
# Not in the dictionary lanh lợi
# Finding translation for tamoxifen
# Not in the dictionary tamoxifen
# Finding translation for biển marmara
# Not in the dictionary biển marmara
# Finding translation for xlô-ven-ni-a
# Not in the dictionary xlô-ven-ni-a
# Finding translation for cẩm thạch
# Finding translation for chủ nghĩa nam nữ bình quyền
# Not in the dictionary chủ nghĩa nam nữ bình quyền
# Finding translation for mòng két mày trắng
# Not in the dictionary mòng két mày trắng
# Finding translation for bánh thánh
# Not in the dictionary bánh thánh
# Finding translation for nghệ thuật nhún giàn
# Not in the dictionary nghệ thuật nhún giàn
# Finding translation for thiếu tưởng tượng
# Not in the dictionary thiếu tưởng tượng
# Finding translation for hạt nhân
# Finding translation for ba tê
# Not in the dictionary ba tê
# Finding translation for âm u
# Finding translation for parma
# Not in the dictionary parma
# Finding translation for tối thui
# Not in the dictionary tối thui
# Finding translation for búp bê matryoska
# Not in the dictionary búp bê matryoska
# Finding translation for [[màu]] [[sô-cô-la]]
# Not in the dictionary [[màu]] [[sô-cô-la]]
# Finding translation for [[đại lục]] [[âu á]]
# Not in the dictionary [[đại lục]] [[âu á]]
# Finding translation for đuôi bò
# Not in the dictionary đuôi bò
# Finding translation for hoàn ngược
# Not in the dictionary hoàn ngược
# Finding translation for sách nghe
# Not in the dictionary sách nghe
# Finding translation for ô tô
# Finding translation for [[kèn]] baritôn
# Not in the dictionary [[kèn]] baritôn
# Finding translation for chuyến bay
# Finding translation for píp
# Not in the dictionary píp
# Finding translation for tây phương
# Finding translation for tiếng thụy điển
# Not in the dictionary tiếng thụy điển
# Finding translation for người đưa thư
# Not in the dictionary người đưa thư
# Finding translation for khoa nghiên cứu chim
# Not in the dictionary khoa nghiên cứu chim
# Finding translation for bãi đậu xe
# Not in the dictionary bãi đậu xe
# Finding translation for 影
# Not in the dictionary 影
# Finding translation for nhất là
# Finding translation for bồ đào nha
# Not in the dictionary bồ đào nha
# Finding translation for lời nói sáo
# Not in the dictionary lời nói sáo
# Finding translation for so sánh
# Finding translation for phần nhịp điệu
# Not in the dictionary phần nhịp điệu
# Finding translation for cộng hòa hồi giáo iran
# Not in the dictionary cộng hòa hồi giáo iran
# Finding translation for quốc xã
# Finding translation for soup
# Not in the dictionary soup
# Finding translation for yóctô-
# Not in the dictionary yóctô-
# Finding translation for kỹ thuật
# Finding translation for lò phản ứng nước sôi
# Not in the dictionary lò phản ứng nước sôi
# Finding translation for mã lai
# Not in the dictionary mã lai
# Finding translation for cá tính
# Finding translation for sự tham lam
# Not in the dictionary sự tham lam
# Finding translation for tân mão
# Not in the dictionary tân mão
# Finding translation for tuần lộc rudolph mũi đỏ
# Not in the dictionary tuần lộc rudolph mũi đỏ
# Finding translation for nhường bước
# Finding translation for cách mạng pháp
# Not in the dictionary cách mạng pháp
# Finding translation for nguyên sinh vật
# Not in the dictionary nguyên sinh vật
# Finding translation for vinh sơn
# Not in the dictionary vinh sơn
# Finding translation for quần áo
# Finding translation for âm tiết
# Finding translation for tàng hình
# Finding translation for có thể
# Finding translation for lạp hộ
# Not in the dictionary lạp hộ
# Finding translation for vĩ tuyến
# Finding translation for 變聲
# Not in the dictionary 變聲
# Finding translation for pháo hoa
# Finding translation for vườn trẻ
# Not in the dictionary vườn trẻ
# Finding translation for cờ trung quốc
# Not in the dictionary cờ trung quốc
# Finding translation for điều răn
# Not in the dictionary điều răn
# Finding translation for 𠊛傳教
# Not in the dictionary 𠊛傳教
# Finding translation for kim biên
# Not in the dictionary kim biên
# Finding translation for điện thư
# Not in the dictionary điện thư
# Finding translation for thống sử
# Not in the dictionary thống sử
# Finding translation for 物質
# Not in the dictionary 物質
# Finding translation for câu nói đùa
# Not in the dictionary câu nói đùa
# Finding translation for vá mắt
# Not in the dictionary vá mắt
# Finding translation for ăn mật mặt xanh
# Not in the dictionary ăn mật mặt xanh
# Finding translation for hyrokkin
# Not in the dictionary hyrokkin
# Finding translation for xi trum
# Not in the dictionary xi trum
# Finding translation for vi rút
# Not in the dictionary vi rút
# Finding translation for xương sống
# Finding translation for tôi cần ...
# Not in the dictionary tôi cần ...
# Finding translation for hoang mạc
# Finding translation for dẫn chứng
# Finding translation for áo mai ô
# Not in the dictionary áo mai ô
# Finding translation for dạ cỏ
# Not in the dictionary dạ cỏ
# Finding translation for bán nguyên âm
# Finding translation for dương châu
# Not in the dictionary dương châu
# Finding translation for đèn lồng
# Not in the dictionary đèn lồng
# Finding translation for vòi voi
# Finding translation for ra mồ hôi
# Not in the dictionary ra mồ hôi
# Finding translation for mỹ
# Not in the dictionary mỹ
# Finding translation for nhân viên
# Finding translation for ẩn hình
# Not in the dictionary ẩn hình
# Finding translation for cá neon đen
# Not in the dictionary cá neon đen
# Finding translation for buông rơi
# Not in the dictionary buông rơi
# Finding translation for bắp thịt
# Finding translation for người hồi
# Not in the dictionary người hồi
# Finding translation for nước khoáng
# Finding translation for dựng xiên
# Not in the dictionary dựng xiên
# Finding translation for dự trữ
# Finding translation for cờ tam tài
# Not in the dictionary cờ tam tài
# Finding translation for mồ hôi
# Finding translation for sao vĩ
# Not in the dictionary sao vĩ
# Finding translation for vùng kín
# Not in the dictionary vùng kín
# Finding translation for ([[bài]]) [[thi]]
# Not in the dictionary ([[bài]]) [[thi]]
# Finding translation for không gian vectơ
# Not in the dictionary không gian vectơ
# Finding translation for nhân chứng
# Finding translation for xà phu
# Not in the dictionary xà phu
# Finding translation for liên tục
# Not in the dictionary liên tục
# Finding translation for hồng y
# Finding translation for màu ngọc bích
# Not in the dictionary màu ngọc bích
# Finding translation for đồng bằng
# Not in the dictionary đồng bằng
# Finding translation for tốc độ tối đa
# Not in the dictionary tốc độ tối đa
# Finding translation for lịch gregorius
# Not in the dictionary lịch gregorius
# Finding translation for tanzania
# Not in the dictionary tanzania
# Finding translation for điểm giới hạn
# Not in the dictionary điểm giới hạn
# Finding translation for đồng hồ cát
# Not in the dictionary đồng hồ cát
# Finding translation for quang thông
# Not in the dictionary quang thông
# Finding translation for phòng ăn
# Finding translation for sinh quán
# Finding translation for thính giác
# Finding translation for tađêô
# Not in the dictionary tađêô
# Finding translation for buồn bã
# Finding translation for bạch tuộc khổng lồ thái bình dương
# Not in the dictionary bạch tuộc khổng lồ thái bình dương
# Finding translation for nam á
# Not in the dictionary nam á
# Finding translation for hải lí
# Not in the dictionary hải lí
# Finding translation for nỗi nhớ
# Not in the dictionary nỗi nhớ
# Finding translation for săn bắn
# Finding translation for trái ki wi
# Not in the dictionary trái ki wi
# Finding translation for hiệu ứng coriolis
# Not in the dictionary hiệu ứng coriolis
# Finding translation for ngay tức thì
# Finding translation for nhâm ngọ
# Not in the dictionary nhâm ngọ
# Finding translation for âm ti
# Finding translation for [[組織]][[協約]][[安寧]][[集體]]
# Not in the dictionary [[組織]][[協約]][[安寧]][[集體]]
# Finding translation for đại điền
# Not in the dictionary đại điền
# Finding translation for vi thể
# Not in the dictionary vi thể
# Finding translation for tuốc-mê-ni-xtan
# Not in the dictionary tuốc-mê-ni-xtan
# Finding translation for kính lúp
# Finding translation for tầm ma
# Not in the dictionary tầm ma
# Finding translation for người ca-na-đa
# Not in the dictionary người ca-na-đa
# Finding translation for người phật
# Not in the dictionary người phật
# Finding translation for màng bọc thực phẩm
# Not in the dictionary màng bọc thực phẩm
# Finding translation for chân răng
# Not in the dictionary chân răng
# Finding translation for nhắc nhở
# Finding translation for 入家隨俗，入江隨曲
# Not in the dictionary 入家隨俗，入江隨曲
# Finding translation for phăng-tê-di
# Not in the dictionary phăng-tê-di
# Finding translation for chuồi trách nhiệm
# Not in the dictionary chuồi trách nhiệm
# Finding translation for tập kích
# Finding translation for sự suy yếu
# Not in the dictionary sự suy yếu
# Finding translation for tầng xép
# Not in the dictionary tầng xép
# Finding translation for pháp luân công
# Not in the dictionary pháp luân công
# Finding translation for beri
# Not in the dictionary beri
# Finding translation for kính một mắt
# Not in the dictionary kính một mắt
# Finding translation for bánh mì lúa mạch
# Not in the dictionary bánh mì lúa mạch
# Finding translation for nicaragua
# Not in the dictionary nicaragua
# Finding translation for 認識
# Not in the dictionary 認識
# Finding translation for thỉnh thoảng
# Finding translation for chiến lược
# Finding translation for mùa màng
# Finding translation for viễn vọng kính
# Not in the dictionary viễn vọng kính
# Finding translation for thang máy
# Finding translation for thức uống có cồn
# Not in the dictionary thức uống có cồn
# Finding translation for xá lợi tử
# Not in the dictionary xá lợi tử
# Finding translation for thần thoại
# Finding translation for chủng ngừa
# Not in the dictionary chủng ngừa
# Finding translation for đuôi cụt bụng vằn
# Not in the dictionary đuôi cụt bụng vằn
# Finding translation for masjid
# Not in the dictionary masjid
# Finding translation for lưỡng cư
# Finding translation for mulhouse
# Not in the dictionary mulhouse
# Finding translation for cộng hòa hy lạp
# Not in the dictionary cộng hòa hy lạp
# Finding translation for điện trở suất
# Not in the dictionary điện trở suất
# Finding translation for giá lọc
# Not in the dictionary giá lọc
# Finding translation for mặt đất
# Not in the dictionary mặt đất
# Finding translation for máng ăn
# Not in the dictionary máng ăn
# Finding translation for 明斯克
# Not in the dictionary 明斯克
# Finding translation for sử gia
# Finding translation for 安南
# Not in the dictionary 安南
# Finding translation for [[sông]] [[ohio]]
# Not in the dictionary [[sông]] [[ohio]]
# Finding translation for cười khúc khích
# Not in the dictionary cười khúc khích
# Finding translation for vừa đủ
# Not in the dictionary vừa đủ
# Finding translation for 對數
# Not in the dictionary 對數
# Finding translation for oxy hoá
# Not in the dictionary oxy hoá
# Finding translation for câm mồm
# Finding translation for nguyệt thực
# Finding translation for thiên ngôn
# Not in the dictionary thiên ngôn
# Finding translation for nước chè
# Finding translation for 𣛠𢮿
# Not in the dictionary 𣛠𢮿
# Finding translation for lưỡng tính sóng-hạt
# Not in the dictionary lưỡng tính sóng-hạt
# Finding translation for cái chết nóng
# Not in the dictionary cái chết nóng
# Finding translation for chu mỏ
# Not in the dictionary chu mỏ
# Finding translation for cầu môn
# Not in the dictionary cầu môn
# Finding translation for 侵犯
# Not in the dictionary 侵犯
# Finding translation for pha-ra-ông
# Not in the dictionary pha-ra-ông
# Finding translation for sáng mắt
# Finding translation for ưcln
# Not in the dictionary ưcln
# Finding translation for thuốc nổ
# Not in the dictionary thuốc nổ
# Finding translation for oe oe
# Finding translation for suy nghĩ kỹ càng về điều gì đó
# Not in the dictionary suy nghĩ kỹ càng về điều gì đó
# Finding translation for ngọn đuốc
# Not in the dictionary ngọn đuốc
# Finding translation for glasgow
# Not in the dictionary glasgow
# Finding translation for uây khyếm mẹ
# Not in the dictionary uây khyếm mẹ
# Finding translation for wadi
# Not in the dictionary wadi
# Finding translation for đỏ tía
# Finding translation for iapetus
# Not in the dictionary iapetus
# Finding translation for đảo hạ uy di
# Not in the dictionary đảo hạ uy di
# Finding translation for cá voi mũi chai phương nam
# Not in the dictionary cá voi mũi chai phương nam
# Finding translation for phong tỏa
# Finding translation for jun
# Not in the dictionary jun
# Finding translation for xe hơi
# Not in the dictionary xe hơi
# Finding translation for quắc duyên
# Not in the dictionary quắc duyên
# Finding translation for do dự
# Finding translation for phân quang học
# Not in the dictionary phân quang học
# Finding translation for đức quốc xã
# Not in the dictionary đức quốc xã
# Finding translation for kẻ ám sát
# Not in the dictionary kẻ ám sát
# Finding translation for tôi khỏe
# Not in the dictionary tôi khỏe
# Finding translation for chan-xe-đon
# Not in the dictionary chan-xe-đon
# Finding translation for cháu trai
# Not in the dictionary cháu trai
# Finding translation for yaroslavl
# Not in the dictionary yaroslavl
# Finding translation for xu thế
# Finding translation for vương quốc anh
# Not in the dictionary vương quốc anh
# Finding translation for đường dây thuê bao số bất đối xứng
# Not in the dictionary đường dây thuê bao số bất đối xứng
# Finding translation for penny
# Not in the dictionary penny
# Finding translation for thái bình
# Finding translation for mundilfari
# Not in the dictionary mundilfari
# Finding translation for 哲學
# Not in the dictionary 哲學
# Finding translation for âu châu hóa
# Not in the dictionary âu châu hóa
# Finding translation for kẻ khủng bố
# Not in the dictionary kẻ khủng bố
# Finding translation for đại tướng
# Not in the dictionary đại tướng
# Finding translation for ống chỉ
# Finding translation for báng bổ
# Finding translation for bao tên
# Not in the dictionary bao tên
# Finding translation for đầu cột
# Not in the dictionary đầu cột
# Finding translation for bôi mỡ
# Not in the dictionary bôi mỡ
# Finding translation for nadmerné dávenie v ťarchavost
# Not in the dictionary nadmerné dávenie v ťarchavost
# Finding translation for con nhím
# Not in the dictionary con nhím
# Finding translation for hồng hạc
# Not in the dictionary hồng hạc
# Finding translation for lộn ngược
# Not in the dictionary lộn ngược
# Finding translation for tiền nào của đó
# Not in the dictionary tiền nào của đó
# Finding translation for bí quyết
# Finding translation for gối ôm
# Not in the dictionary gối ôm
# Finding translation for con ếch
# Not in the dictionary con ếch
# Finding translation for tiến hóa
# Not in the dictionary tiến hóa
# Finding translation for nhà quàn
# Not in the dictionary nhà quàn
# Finding translation for 英國
# Not in the dictionary 英國
# Finding translation for bói cá
# Finding translation for xưng tội
# Finding translation for thuế thu nhập
# Not in the dictionary thuế thu nhập
# Finding translation for liên doanh
# Finding translation for nhà chiến lược
# Not in the dictionary nhà chiến lược
# Finding translation for thóp
# Not in the dictionary thóp
# Finding translation for phụ thuộc
# Finding translation for quay cóp
# Finding translation for tập tạ
# Not in the dictionary tập tạ
# Finding translation for biến hình
# Finding translation for thịt muối
# Not in the dictionary thịt muối
# Finding translation for mã hai chiều
# Not in the dictionary mã hai chiều
# Finding translation for gấu trúc lớn
# Not in the dictionary gấu trúc lớn
# Finding translation for thằn lằn
# Finding translation for [[bò]] [[đực]] [[thiến]]
# Not in the dictionary [[bò]] [[đực]] [[thiến]]
# Finding translation for sóng ngang
# Not in the dictionary sóng ngang
# Finding translation for đại anh
# Not in the dictionary đại anh
# Finding translation for caliphoócnia
# Not in the dictionary caliphoócnia
# Finding translation for thiên hà vô định hình
# Not in the dictionary thiên hà vô định hình
# Finding translation for gà trống
# Finding translation for phương tiện truyền thông xã hội
# Not in the dictionary phương tiện truyền thông xã hội
# Finding translation for thích nghi
# Finding translation for ô-đờ-cô-lôn
# Not in the dictionary ô-đờ-cô-lôn
# Finding translation for dấu hoa thị
# Finding translation for ống vòi
# Not in the dictionary ống vòi
# Finding translation for thiên xích đạo
# Not in the dictionary thiên xích đạo
# Finding translation for chất bán dẫn
# Not in the dictionary chất bán dẫn
# Finding translation for mọi thứ nào
# Not in the dictionary mọi thứ nào
# Finding translation for thuyền để
# Not in the dictionary thuyền để
# Finding translation for bính âm
# Not in the dictionary bính âm
# Finding translation for đứng núi này trông núi nọ
# Not in the dictionary đứng núi này trông núi nọ
# Finding translation for bón phân
# Not in the dictionary bón phân
# Finding translation for [[熱度]][[肌體]]
# Not in the dictionary [[熱度]][[肌體]]
# Finding translation for đuôi cụt chỏm đen
# Not in the dictionary đuôi cụt chỏm đen
# Finding translation for alberta
# Not in the dictionary alberta
# Finding translation for trần truồng
# Finding translation for huyết áp
# Finding translation for sốt vàng da
# Not in the dictionary sốt vàng da
# Finding translation for [[người]] [[hoa kỳ]]
# Not in the dictionary [[người]] [[hoa kỳ]]
# Finding translation for đũa thần
# Not in the dictionary đũa thần
# Finding translation for viêng chăn
# Not in the dictionary viêng chăn
# Finding translation for lì xì
# Not in the dictionary lì xì
# Finding translation for nunavut
# Not in the dictionary nunavut
# Finding translation for vật đen
# Not in the dictionary vật đen
# Finding translation for platin
# Not in the dictionary platin
# Finding translation for tường lửa
# Not in the dictionary tường lửa
# Finding translation for danh từ loại thể
# Not in the dictionary danh từ loại thể
# Finding translation for đặc ứng
# Not in the dictionary đặc ứng
# Finding translation for học thuyết
# Finding translation for cựu tự thể
# Not in the dictionary cựu tự thể
# Finding translation for ma mút
# Not in the dictionary ma mút
# Finding translation for móng chân
# Not in the dictionary móng chân
# Finding translation for eo lưng
# Finding translation for ở đây
# Not in the dictionary ở đây
# Finding translation for thật sao?
# Not in the dictionary thật sao?
# Finding translation for kỉ cam-bri
# Not in the dictionary kỉ cam-bri
# Finding translation for hấp dẫn tình dục
# Not in the dictionary hấp dẫn tình dục
# Finding translation for ca chuẩn
# Not in the dictionary ca chuẩn
# Finding translation for canxit
# Not in the dictionary canxit
# Finding translation for thừa kế
# Finding translation for khái niệm hóa
# Not in the dictionary khái niệm hóa
# Finding translation for giải pháp
# Finding translation for bướng bỉnh
# Finding translation for hôm qua
# Finding translation for ununocti
# Not in the dictionary ununocti
# Finding translation for belinda
# Not in the dictionary belinda
# Finding translation for nhựa thơm
# Not in the dictionary nhựa thơm
# Finding translation for card điện thoại
# Not in the dictionary card điện thoại
# Finding translation for chondrodit
# Not in the dictionary chondrodit
# Finding translation for động vật không răng
# Not in the dictionary động vật không răng
# Finding translation for thực chứng
# Not in the dictionary thực chứng
# Finding translation for atlat
# Not in the dictionary atlat
# Finding translation for nhũ chấp
# Not in the dictionary nhũ chấp
# Finding translation for 探險
# Not in the dictionary 探險
# Finding translation for lời chúc
# Not in the dictionary lời chúc
# Finding translation for chó rừng
# Not in the dictionary chó rừng
# Finding translation for nghi ngờ
# Finding translation for lẫm lúa
# Not in the dictionary lẫm lúa
# Finding translation for vợ vua
# Not in the dictionary vợ vua
# Finding translation for thiết bị chuyển mạch
# Not in the dictionary thiết bị chuyển mạch
# Finding translation for tinh tinh thông thường
# Not in the dictionary tinh tinh thông thường
# Finding translation for đêca-
# Not in the dictionary đêca-
# Finding translation for bà mụ
# Finding translation for sự liên kết
# Not in the dictionary sự liên kết
# Finding translation for vượn cáo
# Not in the dictionary vượn cáo
# Finding translation for cân nặng
# Finding translation for khối mười hai mặt
# Not in the dictionary khối mười hai mặt
# Finding translation for [[người]] [[dân]] [[du mục]]
# Not in the dictionary [[người]] [[dân]] [[du mục]]
# Finding translation for ý kiến công chúng
# Not in the dictionary ý kiến công chúng
# Finding translation for cá voi mõm khoằm andrews
# Not in the dictionary cá voi mõm khoằm andrews
# Finding translation for socola
# Not in the dictionary socola
# Finding translation for cộng hòa xã hội chủ nghĩa việt nam
# Not in the dictionary cộng hòa xã hội chủ nghĩa việt nam
# Finding translation for pê đê
# Not in the dictionary pê đê
# Finding translation for 字典
# Not in the dictionary 字典
# Finding translation for tiếng đức
# Not in the dictionary tiếng đức
# Finding translation for trình đơn
# Not in the dictionary trình đơn
# Finding translation for nhẫn thuật
# Not in the dictionary nhẫn thuật
# Finding translation for phỏng theo
# Not in the dictionary phỏng theo
# Finding translation for vishnu
# Not in the dictionary vishnu
# Finding translation for đuôi cụt lớn
# Not in the dictionary đuôi cụt lớn
# Finding translation for khoáng sản
# Finding translation for tiếng tăm
# Finding translation for câu thơ tứ bộ vi
# Not in the dictionary câu thơ tứ bộ vi
# Finding translation for cá trích tròn
# Not in the dictionary cá trích tròn
# Finding translation for ôn đới
# Finding translation for 光譜
# Not in the dictionary 光譜
# Finding translation for ngạt thở
# Not in the dictionary ngạt thở
# Finding translation for cháy nắng
# Not in the dictionary cháy nắng
# Finding translation for ống pô
# Not in the dictionary ống pô
# Finding translation for anh quốc
# Not in the dictionary anh quốc
# Finding translation for bài thi
# Not in the dictionary bài thi
# Finding translation for nato
# Not in the dictionary nato
# Finding translation for cộng hòa ireland
# Not in the dictionary cộng hòa ireland
# Finding translation for hannover
# Not in the dictionary hannover
# Finding translation for dùi trống
# Not in the dictionary dùi trống
# Finding translation for dacaria
# Not in the dictionary dacaria
# Finding translation for gió mặt trời
# Not in the dictionary gió mặt trời
# Finding translation for phong cầm
# Finding translation for cò xanh
# Not in the dictionary cò xanh
# Finding translation for đài nam
# Not in the dictionary đài nam
# Finding translation for chứng nghẽn mạch
# Not in the dictionary chứng nghẽn mạch
# Finding translation for quản gia
# Finding translation for shōgun
# Not in the dictionary shōgun
# Finding translation for phân trộn
# Not in the dictionary phân trộn
# Finding translation for mèo túi
# Not in the dictionary mèo túi
# Finding translation for khó khăn
# Finding translation for sói đồng cỏ
# Not in the dictionary sói đồng cỏ
# Finding translation for tiếng hà lan ở kếp
# Not in the dictionary tiếng hà lan ở kếp
# Finding translation for công thức
# Finding translation for jammu và kashmir
# Not in the dictionary jammu và kashmir
# Finding translation for giáo hội latinh
# Not in the dictionary giáo hội latinh
# Finding translation for nam giới
# Finding translation for chanh dây
# Not in the dictionary chanh dây
# Finding translation for a phú hãn
# Not in the dictionary a phú hãn
# Finding translation for chính xác
# Not in the dictionary chính xác
# Finding translation for lây nhiễm
# Not in the dictionary lây nhiễm
# Finding translation for tứ quý
# Finding translation for thanh quản
# Finding translation for guanlong
# Not in the dictionary guanlong
# Finding translation for giới trẻ
# Not in the dictionary giới trẻ
# Finding translation for nam vinh
# Not in the dictionary nam vinh
# Finding translation for duy nhất
# Finding translation for êugêniô
# Not in the dictionary êugêniô
# Finding translation for 會陰
# Not in the dictionary 會陰
# Finding translation for [[tôi]] [[sống]] [[ở]] melbourne
# Not in the dictionary [[tôi]] [[sống]] [[ở]] melbourne
# Finding translation for khỉ aye-aye
# Not in the dictionary khỉ aye-aye
# Finding translation for lãng khách
# Not in the dictionary lãng khách
# Finding translation for tổng giám mục
# Not in the dictionary tổng giám mục
# Finding translation for tiên tri
# Finding translation for mất dạy
# Finding translation for quái gì vậy
# Not in the dictionary quái gì vậy
# Finding translation for kền kền griffon
# Not in the dictionary kền kền griffon
# Finding translation for họ dừa
# Not in the dictionary họ dừa
# Finding translation for làm giả
# Finding translation for bừa cỏ
# Not in the dictionary bừa cỏ
# Finding translation for giặt gỵa
# Not in the dictionary giặt gỵa
# Finding translation for trạm không gian
# Not in the dictionary trạm không gian
# Finding translation for thuyền ba buồm
# Not in the dictionary thuyền ba buồm
# Finding translation for mọt ẩm
# Not in the dictionary mọt ẩm
# Finding translation for phong tục
# Finding translation for mù tạc
# Not in the dictionary mù tạc
# Finding translation for 餅中秋
# Not in the dictionary 餅中秋
# Finding translation for ở bên trái
# Not in the dictionary ở bên trái
# Finding translation for phòng trọ
# Not in the dictionary phòng trọ
# Finding translation for bước cản
# Not in the dictionary bước cản
# Finding translation for đi ngoài
# Finding translation for ttốc độ ánh sáng
# Not in the dictionary ttốc độ ánh sáng
# Finding translation for tí tẹo
# Not in the dictionary tí tẹo
# Finding translation for ước số chung lớn nhất
# Not in the dictionary ước số chung lớn nhất
# Finding translation for hầu hết
# Finding translation for 稅
# Not in the dictionary 稅
# Finding translation for marseille
# Not in the dictionary marseille
# Finding translation for hoa thịnh đốn
# Not in the dictionary hoa thịnh đốn
# Finding translation for khác thường
# Finding translation for núm vú
# Finding translation for chiến thắng
# Finding translation for triết
# Not in the dictionary triết
# Finding translation for hình sáu cạnh
# Not in the dictionary hình sáu cạnh
# Finding translation for quạ gáy xám phương tây
# Not in the dictionary quạ gáy xám phương tây
# Finding translation for [[gỗ]] [[anh đào]]
# Not in the dictionary [[gỗ]] [[anh đào]]
# Finding translation for tương ớt sriracha
# Not in the dictionary tương ớt sriracha
# Finding translation for cũng như
# Not in the dictionary cũng như
# Finding translation for hợp xướng
# Finding translation for hộp thư chung
# Not in the dictionary hộp thư chung
# Finding translation for đến khi
# Not in the dictionary đến khi
# Finding translation for vôn
# Not in the dictionary vôn
# Finding translation for рhù điêu
# Not in the dictionary рhù điêu
# Finding translation for 功夫
# Not in the dictionary 功夫
# Finding translation for 版權
# Not in the dictionary 版權
# Finding translation for âu phục
# Finding translation for bắc hải
# Not in the dictionary bắc hải
# Finding translation for cộng hòa slovakia
# Not in the dictionary cộng hòa slovakia
# Finding translation for triết học
# Finding translation for bào ngư
# Finding translation for nhu cầu
# Finding translation for lợn sữa
# Not in the dictionary lợn sữa
# Finding translation for công-xoóc-xi-om
# Not in the dictionary công-xoóc-xi-om
# Finding translation for diên biên
# Not in the dictionary diên biên
# Finding translation for 油
# Not in the dictionary 油
# Finding translation for 肝
# Not in the dictionary 肝
# Finding translation for phương trình vi phân thường
# Not in the dictionary phương trình vi phân thường
# Finding translation for truyền thống
# Finding translation for ấn độ hóa
# Not in the dictionary ấn độ hóa
# Finding translation for bảng chữ cái
# Not in the dictionary bảng chữ cái
# Finding translation for [[đi]] [[ngủ]]
# Not in the dictionary [[đi]] [[ngủ]]
# Finding translation for ăn ngon nhé
# Not in the dictionary ăn ngon nhé
# Finding translation for bụi bặm
# Finding translation for hê-ghen
# Not in the dictionary hê-ghen
# Finding translation for một chút
# Finding translation for bàn chân
# Finding translation for tàu cánh ngầm
# Not in the dictionary tàu cánh ngầm
# Finding translation for xâm phạm
# Finding translation for dưng cơ mà
# Not in the dictionary dưng cơ mà
# Finding translation for bom thùng
# Not in the dictionary bom thùng
# Finding translation for vương quyền
# Not in the dictionary vương quyền
# Finding translation for 熔岩
# Not in the dictionary 熔岩
# Finding translation for búp bê lồng nhau
# Not in the dictionary búp bê lồng nhau
# Finding translation for nằm trên mặt đất
# Not in the dictionary nằm trên mặt đất
# Finding translation for latte macchiato
# Not in the dictionary latte macchiato
# Finding translation for giời leo
# Not in the dictionary giời leo
# Finding translation for mười giờ
# Not in the dictionary mười giờ
# Finding translation for copenhagen
# Not in the dictionary copenhagen
# Finding translation for ong vẽ
# Finding translation for lão tử
# Not in the dictionary lão tử
# Finding translation for lan can
# Finding translation for chuột chù
# Finding translation for mỹ lợi gia
# Not in the dictionary mỹ lợi gia
# Finding translation for phản ứng tổng hợp hạt nhân
# Not in the dictionary phản ứng tổng hợp hạt nhân
# Finding translation for nổi tiếng
# Finding translation for chỉ thảo
# Not in the dictionary chỉ thảo
# Finding translation for dương cầm
# Finding translation for vô giá trị
# Not in the dictionary vô giá trị
# Finding translation for biểu trưng
# Not in the dictionary biểu trưng
# Finding translation for hỗn hống
# Finding translation for xx nghĩa là gì?
# Not in the dictionary xx nghĩa là gì?
# Finding translation for 氣管
# Not in the dictionary 氣管
# Finding translation for dione
# Not in the dictionary dione
# Finding translation for trân châu
# Finding translation for rađơn
# Not in the dictionary rađơn
# Finding translation for thủ thư
# Finding translation for chủ nghĩa bè phái
# Not in the dictionary chủ nghĩa bè phái
# Finding translation for tiếng [[y pha nho]]
# Not in the dictionary tiếng [[y pha nho]]
# Finding translation for phương trình vi phân riêng phần
# Not in the dictionary phương trình vi phân riêng phần
# Finding translation for hải âu bồ hóng
# Not in the dictionary hải âu bồ hóng
# Finding translation for con tin
# Finding translation for cá sấu orinoco
# Not in the dictionary cá sấu orinoco
# Finding translation for 馭𤝋
# Not in the dictionary 馭𤝋
# Finding translation for thêôđorô
# Not in the dictionary thêôđorô
# Finding translation for gà mờ
# Finding translation for [[陸地]][[歐亞]]
# Not in the dictionary [[陸地]][[歐亞]]
# Finding translation for nút dẹt
# Not in the dictionary nút dẹt
# Finding translation for bao thư
# Not in the dictionary bao thư
# Finding translation for kinh hí
# Not in the dictionary kinh hí
# Finding translation for trải qua
# Finding translation for an sơn
# Not in the dictionary an sơn
# Finding translation for quỳ lạy
# Finding translation for hộp đựng xì gà
# Not in the dictionary hộp đựng xì gà
# Finding translation for tế bào quang điện
# Not in the dictionary tế bào quang điện
# Finding translation for tecnexi
# Not in the dictionary tecnexi
# Finding translation for guadeloupe
# Not in the dictionary guadeloupe
# Finding translation for phòng ở
# Not in the dictionary phòng ở
# Finding translation for rạn san hô vòng midway
# Not in the dictionary rạn san hô vòng midway
# Finding translation for bất định
# Finding translation for không sao
# Finding translation for cuộc khởi nghĩa
# Not in the dictionary cuộc khởi nghĩa
# Finding translation for bồi thẩm
# Finding translation for rohingya
# Not in the dictionary rohingya
# Finding translation for tiếng lóng
# Finding translation for phù hiệu áo giáp
# Not in the dictionary phù hiệu áo giáp
# Finding translation for sức khỏe
# Finding translation for giả vờ
# Finding translation for như thế
# Finding translation for ngăn kéo
# Finding translation for tám giờ
# Not in the dictionary tám giờ
# Finding translation for ò-ó-o-o
# Not in the dictionary ò-ó-o-o
# Finding translation for việt hoá
# Not in the dictionary việt hoá
# Finding translation for dầu xăng
# Finding translation for thức dậy
# Finding translation for tiên vương
# Not in the dictionary tiên vương
# Finding translation for sông donau
# Not in the dictionary sông donau
# Finding translation for califoni
# Not in the dictionary califoni
# Finding translation for hay giúp đỡ
# Not in the dictionary hay giúp đỡ
# Finding translation for 企業
# Not in the dictionary 企業
# Finding translation for in-đô-nê-xi-a
# Not in the dictionary in-đô-nê-xi-a
# Finding translation for nga la tư
# Not in the dictionary nga la tư
# Finding translation for nix
# Not in the dictionary nix
# Finding translation for vụ tai tiếng
# Not in the dictionary vụ tai tiếng
# Finding translation for tân tinh
# Not in the dictionary tân tinh
# Finding translation for cóc tahiti
# Not in the dictionary cóc tahiti
# Finding translation for cái gì
# Not in the dictionary cái gì
# Finding translation for quấy rối tình dục
# Not in the dictionary quấy rối tình dục
# Finding translation for 翁外
# Not in the dictionary 翁外
# Finding translation for phát minh
# Finding translation for phá hoại
# Finding translation for mêtric
# Not in the dictionary mêtric
# Finding translation for liti
# Not in the dictionary liti
# Finding translation for xe lửa
# Not in the dictionary xe lửa
# Finding translation for berlin
# Not in the dictionary berlin
# Finding translation for toyama
# Not in the dictionary toyama
# Finding translation for đại dịch
# Not in the dictionary đại dịch
# Finding translation for đông kinh
# Not in the dictionary đông kinh
# Finding translation for thiên phụ la
# Not in the dictionary thiên phụ la
# Finding translation for đâu vào đấy
# Not in the dictionary đâu vào đấy
# Finding translation for aligot
# Not in the dictionary aligot
# Finding translation for nữ nga hoàng
# Not in the dictionary nữ nga hoàng
# Finding translation for 本質
# Not in the dictionary 本質
# Finding translation for hấp thụ
# Finding translation for thuỷ cư
# Not in the dictionary thuỷ cư
# Finding translation for cordierit
# Not in the dictionary cordierit
# Finding translation for meo meo
# Not in the dictionary meo meo
# Finding translation for niềm vui thích
# Not in the dictionary niềm vui thích
# Finding translation for port-au-prince
# Not in the dictionary port-au-prince
# Finding translation for tiệp khắc
# Not in the dictionary tiệp khắc
# Finding translation for [[có]] [[mùi]]
# Not in the dictionary [[có]] [[mùi]]
# Finding translation for ngôi sao david
# Not in the dictionary ngôi sao david
# Finding translation for thụ tinh
# Finding translation for balalaika
# Not in the dictionary balalaika
# Finding translation for co thuê
# Not in the dictionary co thuê
# Finding translation for đinh ghim
# Finding translation for novokuznetsk
# Not in the dictionary novokuznetsk
# Finding translation for quần đảo mã lai
# Not in the dictionary quần đảo mã lai
# Finding translation for [[tiếng]] [[khơ-me]]
# Not in the dictionary [[tiếng]] [[khơ-me]]
# Finding translation for linh sam
# Not in the dictionary linh sam
# Finding translation for 孫陀利難陀
# Not in the dictionary 孫陀利難陀
# Finding translation for trâu rừng
# Not in the dictionary trâu rừng
# Finding translation for thầy đọc kinh
# Not in the dictionary thầy đọc kinh
# Finding translation for diều thiện
# Not in the dictionary diều thiện
# Finding translation for a dua
# Finding translation for yard
# Not in the dictionary yard
# Finding translation for [[thần]] [[méc-cua]]
# Not in the dictionary [[thần]] [[méc-cua]]
# Finding translation for đồ lót
# Not in the dictionary đồ lót
# Finding translation for hoa sen
# Finding translation for vô thanh
# Not in the dictionary vô thanh
# Finding translation for tavastia
# Not in the dictionary tavastia
# Finding translation for 大學
# Not in the dictionary 大學
# Finding translation for con rể
# Not in the dictionary con rể
# Finding translation for ban đầu
# Finding translation for màu tích
# Not in the dictionary màu tích
# Finding translation for đuôi cụt mặt đen
# Not in the dictionary đuôi cụt mặt đen
# Finding translation for lòng tự trọng
# Not in the dictionary lòng tự trọng
# Finding translation for 氣候
# Not in the dictionary 氣候
# Finding translation for nhiệt đới
# Finding translation for giảo quyệt
# Finding translation for ma-ha-ca-diếp
# Not in the dictionary ma-ha-ca-diếp
# Finding translation for vi-rút corona
# Not in the dictionary vi-rút corona
# Finding translation for hắc long giang
# Not in the dictionary hắc long giang
# Finding translation for ngọc lan
# Finding translation for bạc má mặt vênh
# Not in the dictionary bạc má mặt vênh
# Finding translation for châu úc
# Not in the dictionary châu úc
# Finding translation for coban
# Not in the dictionary coban
# Finding translation for phát triển
# Finding translation for chuột lang
# Finding translation for rõ ràng
# Finding translation for quốc trưởng
# Not in the dictionary quốc trưởng
# Finding translation for áo gi lê
# Not in the dictionary áo gi lê
# Finding translation for giông giống
# Finding translation for phéc-mơ-tuya
# Not in the dictionary phéc-mơ-tuya
# Finding translation for ma-lai-xi-a
# Not in the dictionary ma-lai-xi-a
# Finding translation for axít sữa
# Not in the dictionary axít sữa
# Finding translation for aegirin
# Not in the dictionary aegirin
# Finding translation for lùi bước
# Finding translation for nhà toán học
# Not in the dictionary nhà toán học
# Finding translation for lithi
# Not in the dictionary lithi
# Finding translation for tháng đồng cỏ
# Not in the dictionary tháng đồng cỏ
# Finding translation for 𦷨
# Not in the dictionary 𦷨
# Finding translation for bất cẩn
# Finding translation for dân cư
# Finding translation for simon
# Not in the dictionary simon
# Finding translation for tại sao
# Finding translation for đại bàng
# Finding translation for một giờ rươi
# Not in the dictionary một giờ rươi
# Finding translation for cự giải
# Not in the dictionary cự giải
# Finding translation for 存在
# Not in the dictionary 存在
# Finding translation for tường chung
# Not in the dictionary tường chung
# Finding translation for vàng trắng
# Not in the dictionary vàng trắng
# Finding translation for môn-đô-va
# Not in the dictionary môn-đô-va
# Finding translation for tháng gió
# Not in the dictionary tháng gió
# Finding translation for mai-crô-nê-xi-a
# Not in the dictionary mai-crô-nê-xi-a
# Finding translation for trà trân châu
# Not in the dictionary trà trân châu
# Finding translation for phân chia thời đại
# Not in the dictionary phân chia thời đại
# Finding translation for hình dạng
# Finding translation for số ba
# Not in the dictionary số ba
# Finding translation for cung cấp
# Not in the dictionary cung cấp
# Finding translation for cải thiện
# Finding translation for xơ vữa động mạch
# Not in the dictionary xơ vữa động mạch
# Finding translation for đảo tế châu
# Not in the dictionary đảo tế châu
# Finding translation for ([[màu]]) [[quế]]
# Not in the dictionary ([[màu]]) [[quế]]
# Finding translation for cacbonat
# Not in the dictionary cacbonat
# Finding translation for rộng khắp
# Not in the dictionary rộng khắp
# Finding translation for adam
# Not in the dictionary adam
# Finding translation for thứ hai mươi ba
# Not in the dictionary thứ hai mươi ba
# Finding translation for bệnh suyễn
# Not in the dictionary bệnh suyễn
# Finding translation for trang trại
# Not in the dictionary trang trại
# Finding translation for hoa liên
# Not in the dictionary hoa liên
# Finding translation for thi thử
# Not in the dictionary thi thử
# Finding translation for tây ấn
# Not in the dictionary tây ấn
# Finding translation for đường đến địa ngục được lát bằng thiện tâm
# Not in the dictionary đường đến địa ngục được lát bằng thiện tâm
# Finding translation for chất xám
# Finding translation for chó ngao tây tạng
# Not in the dictionary chó ngao tây tạng
# Finding translation for cầu mây
# Not in the dictionary cầu mây
# Finding translation for síp
# Not in the dictionary síp
# Finding translation for giáo hội
# Finding translation for 重力
# Not in the dictionary 重力
# Finding translation for trình hợp dịch
# Not in the dictionary trình hợp dịch
# Finding translation for sáng ngời
# Finding translation for cây số
# Finding translation for yêu quý
# Not in the dictionary yêu quý
# Finding translation for mayotte
# Not in the dictionary mayotte
# Finding translation for 萬里長城
# Not in the dictionary 萬里長城
# Finding translation for hệ số phản xạ
# Not in the dictionary hệ số phản xạ
# Finding translation for cải cách tin lành
# Not in the dictionary cải cách tin lành
# Finding translation for âm sắc
# Finding translation for clb
# Not in the dictionary clb
# Finding translation for 繃磁
# Not in the dictionary 繃磁
# Finding translation for phanxicô
# Not in the dictionary phanxicô
# Finding translation for khóc thổn thức
# Not in the dictionary khóc thổn thức
# Finding translation for mẫu vật
# Not in the dictionary mẫu vật
# Finding translation for nhập khẩu
# Finding translation for nước dừa
# Not in the dictionary nước dừa
# Finding translation for kinh nguyệt
# Finding translation for nam bán cầu
# Finding translation for tỳ linh
# Not in the dictionary tỳ linh
# Finding translation for rosalind
# Not in the dictionary rosalind
# Finding translation for abkhazia
# Not in the dictionary abkhazia
# Finding translation for tình dục
# Not in the dictionary tình dục
# Finding translation for đào tiên
# Not in the dictionary đào tiên
# Finding translation for ớt cay
# Not in the dictionary ớt cay
# Finding translation for sự thống trị của quần chúng
# Not in the dictionary sự thống trị của quần chúng
# Finding translation for dâu tây
# Finding translation for chế phẩm sữa
# Not in the dictionary chế phẩm sữa
# Finding translation for máy đo tốc độ
# Not in the dictionary máy đo tốc độ
# Finding translation for chuột chù voi
# Not in the dictionary chuột chù voi
# Finding translation for vui mừng
# Not in the dictionary vui mừng
# Finding translation for 中華民國
# Not in the dictionary 中華民國
# Finding translation for 大動脈
# Not in the dictionary 大動脈
# Finding translation for khả hãn
# Not in the dictionary khả hãn
# Finding translation for hà hiếp
# Finding translation for đức giáo tông
# Not in the dictionary đức giáo tông
# Finding translation for nürnberg
# Not in the dictionary nürnberg
# Finding translation for lan hoàng thảo
# Not in the dictionary lan hoàng thảo
# Finding translation for tình yêu đầu tiên
# Not in the dictionary tình yêu đầu tiên
# Finding translation for bằng chân
# Finding translation for pa-pi-ê-ma-sê
# Not in the dictionary pa-pi-ê-ma-sê
# Finding translation for bà phước
# Finding translation for 裝服𬈺
# Not in the dictionary 裝服𬈺
# Finding translation for thu được
# Not in the dictionary thu được
# Finding translation for thực vật một lá mầm
# Not in the dictionary thực vật một lá mầm
# Finding translation for tôi bị les
# Not in the dictionary tôi bị les
# Finding translation for dấu mũ
# Finding translation for cẩu tích
# Not in the dictionary cẩu tích
# Finding translation for ngoại tệ
# Not in the dictionary ngoại tệ
# Finding translation for hải sản
# Finding translation for sens
# Not in the dictionary sens
# Finding translation for đảo anh
# Not in the dictionary đảo anh
# Finding translation for quảng nam
# Not in the dictionary quảng nam
# Finding translation for giản thể tự
# Not in the dictionary giản thể tự
# Finding translation for thiên hoàng
# Not in the dictionary thiên hoàng
# Finding translation for 𠏳
# Not in the dictionary 𠏳
# Finding translation for chi cúc duyên
# Not in the dictionary chi cúc duyên
# Finding translation for quắc đỉnh
# Not in the dictionary quắc đỉnh
# Finding translation for thời đại
# Finding translation for quạ dauria
# Not in the dictionary quạ dauria
# Finding translation for tây nam á
# Not in the dictionary tây nam á
# Finding translation for apec
# Not in the dictionary apec
# Finding translation for bịch ni-lông
# Not in the dictionary bịch ni-lông
# Finding translation for lớp ôzôn
# Not in the dictionary lớp ôzôn
# Finding translation for (sự) [[tăng giá]]
# Not in the dictionary (sự) [[tăng giá]]
# Finding translation for lời hứa
# Finding translation for cộng hòa côte d'ivoire
# Not in the dictionary cộng hòa côte d'ivoire
# Finding translation for ống chân không
# Not in the dictionary ống chân không
# Finding translation for duy ngã
# Finding translation for hàm đan
# Not in the dictionary hàm đan
# Finding translation for [[kinh]] koran
# Not in the dictionary [[kinh]] koran
# Finding translation for chủ nghĩa thế tục
# Not in the dictionary chủ nghĩa thế tục
# Finding translation for quất hồng bì
# Finding translation for lên lịch
# Not in the dictionary lên lịch
# Finding translation for hạ lưu
# Finding translation for madrid
# Not in the dictionary madrid
# Finding translation for bergelmir
# Not in the dictionary bergelmir
# Finding translation for mẹ vợ
# Not in the dictionary mẹ vợ
# Finding translation for bươm bướm
# Finding translation for thằng vc
# Not in the dictionary thằng vc
# Finding translation for 公司
# Not in the dictionary 公司
# Finding translation for điều khiển
# Not in the dictionary điều khiển
# Finding translation for công nữ
# Not in the dictionary công nữ
# Finding translation for thủ công mỹ nghệ
# Not in the dictionary thủ công mỹ nghệ
# Finding translation for nhà thanh
# Not in the dictionary nhà thanh
# Finding translation for cá trích xương
# Not in the dictionary cá trích xương
# Finding translation for bánh sinh nhật
# Not in the dictionary bánh sinh nhật
# Finding translation for hoa oải hương
# Not in the dictionary hoa oải hương
# Finding translation for bồ cắt giả
# Not in the dictionary bồ cắt giả
# Finding translation for trường đua ngựa
# Not in the dictionary trường đua ngựa
# Finding translation for ga xép
# Not in the dictionary ga xép
# Finding translation for lúc đó
# Not in the dictionary lúc đó
# Finding translation for dạ dày
# Finding translation for khí giới
# Finding translation for cơn ác mộng
# Not in the dictionary cơn ác mộng
# Finding translation for cắc kè
# Finding translation for afghanistan
# Not in the dictionary afghanistan
# Finding translation for cộng hòa croatia
# Not in the dictionary cộng hòa croatia
# Finding translation for cương cứng
# Not in the dictionary cương cứng
# Finding translation for kết hợp
# Finding translation for máy tính bảng
# Not in the dictionary máy tính bảng
# Finding translation for an phong
# Not in the dictionary an phong
# Finding translation for thần kinh
# Finding translation for acid deoxyribonucleic
# Not in the dictionary acid deoxyribonucleic
# Finding translation for 敬語
# Not in the dictionary 敬語
# Finding translation for chủ nhật
# Finding translation for xờ nhẹ
# Not in the dictionary xờ nhẹ
# Finding translation for cảm ơn lắm
# Not in the dictionary cảm ơn lắm
# Finding translation for ngoài nước
# Not in the dictionary ngoài nước
# Finding translation for vào đêm nay
# Not in the dictionary vào đêm nay
# Finding translation for kinh độ
# Finding translation for trường giang
# Not in the dictionary trường giang
# Finding translation for [[trời]] [[đang]] [[mưa]]
# Not in the dictionary [[trời]] [[đang]] [[mưa]]
# Finding translation for 極大
# Not in the dictionary 極大
# Finding translation for chìa khóa
# Finding translation for đô
# Finding translation for 猚
# Not in the dictionary 猚
# Finding translation for vô bờ
# Not in the dictionary vô bờ
# Finding translation for cú muỗi mỏ quặp đuôi ngắn
# Not in the dictionary cú muỗi mỏ quặp đuôi ngắn
# Finding translation for địa đồ
# Finding translation for rubik
# Not in the dictionary rubik
# Finding translation for 火葬
# Not in the dictionary 火葬
# Finding translation for tài nguyên
# Finding translation for chủ nghĩa stalin
# Not in the dictionary chủ nghĩa stalin
# Finding translation for giáo hội anh
# Not in the dictionary giáo hội anh
# Finding translation for ōsaka
# Not in the dictionary ōsaka
# Finding translation for bút ký
# Finding translation for thanh điệu
# Not in the dictionary thanh điệu
# Finding translation for siđa
# Not in the dictionary siđa
# Finding translation for xoắn ốc
# Not in the dictionary xoắn ốc
# Finding translation for kroisos
# Not in the dictionary kroisos
# Finding translation for chân gà
# Not in the dictionary chân gà
# Finding translation for công cụ hỗ trợ tình dục
# Not in the dictionary công cụ hỗ trợ tình dục
# Finding translation for tê thấp
# Finding translation for nhà soạn kịch
# Not in the dictionary nhà soạn kịch
# Finding translation for 砲
# Not in the dictionary 砲
# Finding translation for francisco
# Not in the dictionary francisco
# Finding translation for vòng đu quay
# Not in the dictionary vòng đu quay
# Finding translation for khớp xương
# Finding translation for máy đo liều bức xạ
# Not in the dictionary máy đo liều bức xạ
# Finding translation for sơn la
# Not in the dictionary sơn la
# ...
# Not in the dictionary simôn
# Finding translation for gấu bắc cực
# Not in the dictionary gấu bắc cực
# Finding translation for bộ cánh màng
# Not in the dictionary bộ cánh màng
# Finding translation for đất đai
# Not in the dictionary đất đai
# Finding translation for môn học
# Finding translation for bưu thiếp
# Finding translation for phạt tù
# Finding translation for não giữa
# Not in the dictionary não giữa
# Finding translation for bánh gừng
# Not in the dictionary bánh gừng
# Finding translation for dichloro diphenyl trichlorothane
# Not in the dictionary dichloro diphenyl trichlorothane
# Finding translation for siêu cường
# Finding translation for phi hóa
# Not in the dictionary phi hóa
# Finding translation for do thái
# Finding translation for ăn nào
# Not in the dictionary ăn nào
# Finding translation for lạng sơn
# Not in the dictionary lạng sơn
# Finding translation for khái niệm
# Finding translation for người nói chuyện
# Not in the dictionary người nói chuyện
# Finding translation for mệnh lệnh cách
# Not in the dictionary mệnh lệnh cách
# Finding translation for 新疆
# Not in the dictionary 新疆
# Finding translation for siêu đối xứng
# Not in the dictionary siêu đối xứng
# Finding translation for nhạc chủ đề
# Not in the dictionary nhạc chủ đề
# Finding translation for 𪀄天堂
# Not in the dictionary 𪀄天堂
# Finding translation for tự nhiên
# Finding translation for khai hóa
# Finding translation for a-la-hán
# Not in the dictionary a-la-hán
# Finding translation for vệ sĩ
# Not in the dictionary vệ sĩ
# Finding translation for kursk
# Not in the dictionary kursk
# Finding translation for cộng hòa serbia
# Not in the dictionary cộng hòa serbia
# Finding translation for phạm lỗi
# Not in the dictionary phạm lỗi
# Finding translation for đồng hồ nước
# Not in the dictionary đồng hồ nước
# Finding translation for ngày sau
# Finding translation for đàn clavico
# Not in the dictionary đàn clavico
# Finding translation for nội mông
# Not in the dictionary nội mông
# Finding translation for kẻ phản bội
# Not in the dictionary kẻ phản bội
# Finding translation for thổi kèn
# Not in the dictionary thổi kèn
# Finding translation for cầu tiêu
# Finding translation for 無價值
# Not in the dictionary 無價值
# Finding translation for secnôziom
# Not in the dictionary secnôziom
# Finding translation for gaza
# Not in the dictionary gaza
# Finding translation for đất đen
# Not in the dictionary đất đen
# Finding translation for êusêbiô
# Not in the dictionary êusêbiô
# Finding translation for đô la
# Not in the dictionary đô la
# Finding translation for 侍
# Not in the dictionary 侍
# Finding translation for nhà giả kim
# Not in the dictionary nhà giả kim
# Finding translation for cà mau
# Not in the dictionary cà mau
# Finding translation for cửa hàng
# Finding translation for rút phép thông công
# Not in the dictionary rút phép thông công
# Finding translation for người dẫn chương trình
# Not in the dictionary người dẫn chương trình
# Finding translation for mát dần toàn cầu
# Not in the dictionary mát dần toàn cầu
# Finding translation for kim tự tháp cheops
# Not in the dictionary kim tự tháp cheops
# Finding translation for tiếng urdu
# Not in the dictionary tiếng urdu
# Finding translation for cấm chỉ
# Finding translation for xương trụ
# Not in the dictionary xương trụ
# Finding translation for 延邊
# Not in the dictionary 延邊
# Finding translation for tranh biếm hoạ
# Not in the dictionary tranh biếm hoạ
# Finding translation for ác-mê-ni-a
# Not in the dictionary ác-mê-ni-a
# Finding translation for 行書
# Not in the dictionary 行書
# Finding translation for cổ áo
# Not in the dictionary cổ áo
# Finding translation for pháp văn
# Not in the dictionary pháp văn
# Finding translation for được voi đòi tiên
# Not in the dictionary được voi đòi tiên
# Finding translation for lò nướng
# Not in the dictionary lò nướng
# Finding translation for guy-a-na
# Not in the dictionary guy-a-na
# Finding translation for bột nhào nở
# Not in the dictionary bột nhào nở
# Finding translation for chỗ đậu xe
# Not in the dictionary chỗ đậu xe
# Finding translation for ikebana
# Not in the dictionary ikebana
# Finding translation for kiviuq
# Not in the dictionary kiviuq
# Finding translation for im lặng là vàng
# Not in the dictionary im lặng là vàng
# Finding translation for cá voi mũi chai nhiệt đới
# Not in the dictionary cá voi mũi chai nhiệt đới
# Finding translation for đại tân nguyên sinh
# Not in the dictionary đại tân nguyên sinh
# Finding translation for người giữ trẻ
# Not in the dictionary người giữ trẻ
# Finding translation for nhóm nguyên tố 18
# Not in the dictionary nhóm nguyên tố 18
# Finding translation for sénégal
# Not in the dictionary sénégal
# Finding translation for luca
# Not in the dictionary luca
# Finding translation for một mình
# Not in the dictionary một mình
# Finding translation for chiêm tinh học
# Finding translation for hộp đêm
# Finding translation for xương vai
# Not in the dictionary xương vai
# Finding translation for eo biển manche
# Not in the dictionary eo biển manche
# Finding translation for kỹ thuật giấu thư
# Not in the dictionary kỹ thuật giấu thư
# Finding translation for mơ tây
# Not in the dictionary mơ tây
# Finding translation for khôn ngoan
# Finding translation for kỷ devon
# Not in the dictionary kỷ devon
# Finding translation for bạch mã hoàng tử
# Not in the dictionary bạch mã hoàng tử
# Finding translation for parthia
# Not in the dictionary parthia
# Finding translation for chuyện kể
# Not in the dictionary chuyện kể
# Finding translation for con quỷ
# Not in the dictionary con quỷ
# Finding translation for ống nhòm
# Finding translation for gia nghĩa
# Not in the dictionary gia nghĩa
# Finding translation for phép trừ
# Finding translation for 孔子
# Not in the dictionary 孔子
# Finding translation for động mạch
# Finding translation for dương tính giả
# Not in the dictionary dương tính giả
# Finding translation for núi băng trôi
# Not in the dictionary núi băng trôi
# Finding translation for khỏe chứ?
# Not in the dictionary khỏe chứ?
# Finding translation for kẹo mút
# Not in the dictionary kẹo mút
# Finding translation for bru-nây
# Not in the dictionary bru-nây
# Finding translation for 水利
# Not in the dictionary 水利
# Finding translation for mở nắp chai
# Not in the dictionary mở nắp chai
# Finding translation for xe
# Not in the dictionary xe
# Finding translation for bệnh do leishmania
# Not in the dictionary bệnh do leishmania
# Finding translation for 內戰
# Not in the dictionary 內戰
# Finding translation for căm bốt
# Not in the dictionary căm bốt
# Finding translation for đồng minh
# Not in the dictionary đồng minh
# Finding translation for bánh rán
# Finding translation for thái cực
# Finding translation for phó tổng thống
# Not in the dictionary phó tổng thống
# Finding translation for vũ tiên
# Not in the dictionary vũ tiên
# Finding translation for tiếng swahili
# Not in the dictionary tiếng swahili
# Finding translation for bom napan
# Not in the dictionary bom napan
# Finding translation for sa giông
# Not in the dictionary sa giông
# Finding translation for yên tĩnh
# Not in the dictionary yên tĩnh
# Finding translation for đô thị
# Finding translation for bút nguyên tử
# Not in the dictionary bút nguyên tử
# Finding translation for islamabad
# Not in the dictionary islamabad
# Finding translation for hoa kim châm
# Not in the dictionary hoa kim châm
# Finding translation for bệnh nấm da
# Not in the dictionary bệnh nấm da
# Finding translation for phạm tội
# Not in the dictionary phạm tội
# Finding translation for khuyên bảo
# Finding translation for có năng khiếu
# Not in the dictionary có năng khiếu
# Finding translation for người triều tiên
# Not in the dictionary người triều tiên
# Finding translation for trở về
# Finding translation for 理生學
# Not in the dictionary 理生學
# Finding translation for valentinô
# Not in the dictionary valentinô
# Finding translation for zacaria
# Not in the dictionary zacaria
# Finding translation for 水晶
# Not in the dictionary 水晶
# Finding translation for vội lên
# Not in the dictionary vội lên
# Finding translation for sáo nâu
# Not in the dictionary sáo nâu
# Finding translation for thor
# Not in the dictionary thor
# Finding translation for bay mùi
# Finding translation for kỉ tam điệp
# Not in the dictionary kỉ tam điệp
# Finding translation for bộ nhớ đệm
# Not in the dictionary bộ nhớ đệm
# Finding translation for 将軍
# Not in the dictionary 将軍
# Finding translation for các tông
# Not in the dictionary các tông
# Finding translation for căm thù
# Finding translation for nằm ngửa
# Not in the dictionary nằm ngửa
# Finding translation for trà sữa trân châu
# Not in the dictionary trà sữa trân châu
# Finding translation for tí teo
# Finding translation for kim tự tháp
# Finding translation for người ngoại quốc
# Not in the dictionary người ngoại quốc
# Finding translation for giá trị tổng kiểm
# Not in the dictionary giá trị tổng kiểm
# Finding translation for cộng hoà pê-ru
# Not in the dictionary cộng hoà pê-ru
# Finding translation for bữa sáng
# Not in the dictionary bữa sáng
# Finding translation for anh chị em
# Not in the dictionary anh chị em
# Finding translation for bỏ rơi
# Finding translation for múa lại!
# Not in the dictionary múa lại!
# Finding translation for tiêu cực
# Finding translation for sự bầu cử
# Not in the dictionary sự bầu cử
# Finding translation for hốt hoảng
# Finding translation for gioan baotixita
# Not in the dictionary gioan baotixita
# Finding translation for giá sinh hoạt
# Not in the dictionary giá sinh hoạt
# Finding translation for ca hát
# Finding translation for bắc kinh
# Not in the dictionary bắc kinh
# Finding translation for chủ nghĩa hư vô
# Not in the dictionary chủ nghĩa hư vô
# Finding translation for xe đẩy trẻ em
# Not in the dictionary xe đẩy trẻ em
# Finding translation for ghrelin
# Not in the dictionary ghrelin
# Finding translation for nhà ở
# Finding translation for lêô
# Not in the dictionary lêô
# Finding translation for dây chun
# Finding translation for gây ấn tượng
# Not in the dictionary gây ấn tượng
# Finding translation for perdita
# Not in the dictionary perdita
# Finding translation for biển hoa đông
# Not in the dictionary biển hoa đông
# Finding translation for tiếng quốc tế ngữ
# Not in the dictionary tiếng quốc tế ngữ
# Finding translation for thằng cộng sản
# Not in the dictionary thằng cộng sản
# Finding translation for lương hưu
# Not in the dictionary lương hưu
# Finding translation for sultan
# Not in the dictionary sultan
# Finding translation for [[tiếng]] [[do thái]]
# Not in the dictionary [[tiếng]] [[do thái]]
# Finding translation for quấy rầy
# Finding translation for an nam
# Finding translation for ý thức
# Finding translation for nói chuyện phiếm
# Not in the dictionary nói chuyện phiếm
# Finding translation for qaraqalpaqstan
# Not in the dictionary qaraqalpaqstan
# Finding translation for đầu rìu
# Finding translation for nhiệt độ
# Finding translation for thuốc phiện
# Finding translation for sức căng bề mặt
# Not in the dictionary sức căng bề mặt
# Finding translation for pháp hoá
# Not in the dictionary pháp hoá
# Finding translation for ngốc nghếch
# Finding translation for lào cai
# Finding translation for hình thành
# Not in the dictionary hình thành
# Finding translation for chiết giang
# Not in the dictionary chiết giang
# Finding translation for tiểu đường
# Not in the dictionary tiểu đường
# Finding translation for âm học
# Finding translation for djibouti
# Not in the dictionary djibouti
# Finding translation for pa-ri
# Not in the dictionary pa-ri
# Finding translation for kiệt tác
# Finding translation for giéptô-
# Not in the dictionary giéptô-
# Finding translation for hạ cánh
# Finding translation for mặt nạ phòng độc
# Not in the dictionary mặt nạ phòng độc
# Finding translation for sông la plata
# Not in the dictionary sông la plata
# Finding translation for chính thể bô-na-pac
# Not in the dictionary chính thể bô-na-pac
# Finding translation for rường cột
# Finding translation for nâu sẫm
# Not in the dictionary nâu sẫm
# Finding translation for điều khiển từ xa
# Not in the dictionary điều khiển từ xa
# Finding translation for vị trí
# Finding translation for nhà tu
# Finding translation for uỷ ban
# Not in the dictionary uỷ ban
# Finding translation for ngồi thẳng
# Not in the dictionary ngồi thẳng
# Finding translation for người [[do thái]]
# Not in the dictionary người [[do thái]]
# Finding translation for dim-ba-bu-ê
# Not in the dictionary dim-ba-bu-ê
# Finding translation for thứ sáu
# Not in the dictionary thứ sáu
# Finding translation for khỏe mạnh
# Finding translation for truyền miệng
# Not in the dictionary truyền miệng
# Finding translation for bẫy mìn
# Not in the dictionary bẫy mìn
# Finding translation for hiđrua liti
# Not in the dictionary hiđrua liti
# Finding translation for binh khí
# Finding translation for [[quả]] cam
# Not in the dictionary [[quả]] cam
# Finding translation for bằng hiện vật
# Not in the dictionary bằng hiện vật
# Finding translation for tam tinh
# Not in the dictionary tam tinh
# Finding translation for xuống xe
# Not in the dictionary xuống xe
# Finding translation for quán nét
# Not in the dictionary quán nét
# Finding translation for 𩵜鮿
# Not in the dictionary 𩵜鮿
# Finding translation for torino
# Not in the dictionary torino
# Finding translation for ống heo
# Not in the dictionary ống heo
# Finding translation for vấp lưỡi
# Not in the dictionary vấp lưỡi
# Finding translation for bấc đèn
# Not in the dictionary bấc đèn
# Finding translation for tháng chạp
# Not in the dictionary tháng chạp
# Finding translation for tự kỉ
# Not in the dictionary tự kỉ
# Finding translation for fax
# Not in the dictionary fax
# Finding translation for hằng số planck
# Not in the dictionary hằng số planck
# Finding translation for cưỡng dâm
# Finding translation for báo đen
# Not in the dictionary báo đen
# Finding translation for tức thời
# Not in the dictionary tức thời
# Finding translation for châu phi
# Not in the dictionary châu phi
# Finding translation for lời nhạc
# Not in the dictionary lời nhạc
# Finding translation for mèo cá
# Not in the dictionary mèo cá
# Finding translation for hình vẽ
# Not in the dictionary hình vẽ
# Finding translation for nặc danh
# Finding translation for đạo do thái
# Not in the dictionary đạo do thái
# Finding translation for người thường
# Not in the dictionary người thường
# Finding translation for bạn gái
# Not in the dictionary bạn gái
# Finding translation for thì hiện tại
# Not in the dictionary thì hiện tại
# Finding translation for kệ sách
# Not in the dictionary kệ sách
# Finding translation for lực lượng vũ trang ss
# Not in the dictionary lực lượng vũ trang ss
# Finding translation for rửa xe
# Not in the dictionary rửa xe
# Finding translation for nạp điện
# Not in the dictionary nạp điện
# Finding translation for kể lại
# Not in the dictionary kể lại
# Finding translation for 唵
# Not in the dictionary 唵
# Finding translation for trung tâm thương mại thế giới
# Not in the dictionary trung tâm thương mại thế giới
# Finding translation for mặc cảm tự ti
# Not in the dictionary mặc cảm tự ti
# Finding translation for đi đi
# Not in the dictionary đi đi
# Finding translation for dạm ngõ
# Not in the dictionary dạm ngõ
# Finding translation for gái trinh
# Not in the dictionary gái trinh
# Finding translation for dung tích
# Finding translation for áp bức
# Finding translation for lưu huỳnh mù tạt
# Not in the dictionary lưu huỳnh mù tạt
# Finding translation for lượng tử
# Finding translation for khoa mắt
# Not in the dictionary khoa mắt
# Finding translation for nhân dân tệ
# Not in the dictionary nhân dân tệ
# Finding translation for điện báo
# Not in the dictionary điện báo
# Finding translation for thư ký
# Finding translation for cung điện westminster
# Not in the dictionary cung điện westminster
# Finding translation for bằng chứng
# Finding translation for bình thuỷ
# Not in the dictionary bình thuỷ
# Finding translation for lập trình meta
# Not in the dictionary lập trình meta
# Finding translation for hờn dỗi
# Finding translation for 訂婚
# Not in the dictionary 訂婚
# Finding translation for buồng trứng
# Finding translation for tự mình
# Not in the dictionary tự mình
# Finding translation for gađolini
# Not in the dictionary gađolini
# Finding translation for plutoni
# Not in the dictionary plutoni
# Finding translation for ngũ uẩn
# Not in the dictionary ngũ uẩn
# Finding translation for bãi biển
# Finding translation for quạt trần
# Not in the dictionary quạt trần
# Finding translation for borneo
# Not in the dictionary borneo
# Finding translation for piemontit
# Not in the dictionary piemontit
# Finding translation for tỷ giá hối đoái
# Not in the dictionary tỷ giá hối đoái
# Finding translation for chế độ chính trị
# Not in the dictionary chế độ chính trị

# %%
#saving the batch
with open('/content/gdrive/My Drive/Colab Notebooks/Dictionary Project/vdict VI-EN ver 3 batch {}.json'.format(index), 'w') as outfile:
  json.dump(dictionary, outfile)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 9089.936640262604 seconds ---

# %%
len(dictionary.items())
# Out:
# 6493

# %%
findTranslation("cái")
# Out:
# Finding translation for cái
# {1: {'POS': 'noun',
#   'examples': {'context 1': 'con dại cái mang',
#    'nums': 1,
#    'usage 1': 'the mother is responsible for the foolishness of her child'},
#   'translation': ['Mother']},
#  2: {'POS': 'noun',
#   'examples': {'context 1': 'cháu đến rủ cái Hoa đi học',
#    'nums': 1,
#    'usage 1': "I'm calling for Hoa to go to school with her"},
#   'translation': ["khẩu ngữ) (denoting a young girl of one's rank or below)"]},
#  3: {'POS': 'noun',
#   'examples': {'context 1': 'cái giấm',
#    'context 2': 'cái mẻ',
#    'context 3': 'Banker (trong đám bạc)',
#    'context 4': 'ăn cả nước lẫn cái',
#    'nums': 4,
#    'usage 1': 'mother of vinegar',
#    'usage 2': 'mother of fermented cold rice',
#    'usage 3': 'Solid part (of liquid food)',
#    'usage 4': 'to eat both the liquid and the solid part (of a food)'},
#   'translation': ['Mother', ' mother of vinegar']},
#  'nums': 3}
