# %%
import urllib.request 
from urllib.parse import quote 
from bs4 import BeautifulSoup
import json
import re
import time

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import json
with open('/content/gdrive/My Drive/Colab Notebooks/Dictionary Project/bigFreqList.json') as json_file:
     wordsData = json.load(json_file)

# %%
#generate a list of words with frequency higher than the threshold
def generateWordList(threshold): 
  temp = []
  for (word, freq) in wordsData.items():
    if (freq >= threshold):
      temp.append(word)
  return temp

# %%
wordList = generateWordList(40)
print(wordList[-10:])
len(wordList)
# Out:
# ['latikivn', 'imusicvn', 'ycđt', 'greatland', 'lemmevn', 'hoclamgiau', 'hpschoolvn', 'khochiasevn', 'hakiba', 'heisvn']
# 141836

# %%
#break the word list into batches of 
batches = [wordList[i:i + 10000] for i in range(0, len(wordList), 10000)]

# %%
for batch in batches:
  print(len(batch))
# Out:
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 1836

# %%
#The link format for soha Viet-Fran is: http://tratu.soha.vn/dict/vi-fr/C%C3%B3

# %%
url = "http://tratu.soha.vn/dict/vn_fr/" + quote("như") #resolving the IRI issue

try:
    source = urllib.request.urlopen(url)
except:
    print( "Link broken")
soup = BeautifulSoup(source, 'lxml')

# %%
groups = soup.findAll("div", class_ = "section-h3") #soha groups their translations by POS

# %%
containers = soup.findAll("div", class_ = "section-h5")

# %%
containers[0].find("h5").find("span").contents[0]
# Out:
# 'Comme'

# %%
containers[0].find("h5").find("span").contents
# Out:
# ['Comme']

# %%
#detect whether a tag contains a link, if a link is present, the tag contains a context
def hasLink(tag):
    try:
        subTags = tag.findAll('a')
    except:
        return False
    for subTag in subTags:
        if (subTag.get('href')): #found a link
            return True
    return False

# %%
hasLink(containers[0].find("dl").find("dd").find("dl").findAll("dd")[0])
# Out:
# True

# %%
def resolveItalic(parts): #french words use italic to mark an use of "'"
    parts = [str(part) for part in parts]
    if (len(parts) == 1): #nothing special here, just return the string
        return [item.strip() for item in re.split('[.,;]', str(parts[0]))]
    parts = [part.replace("<i>", "'").replace("</i>", "") for part in parts]
    if (parts[-1] == '\n'): #this is an usage, ignore the last part
        return [item.strip() for item in re.split('[.,;]', "".join(parts[:-1]))]
    #this is a translation
    return [item.strip() for item in re.split('[.,;]', "".join(parts))]

# %%
temp = containers[0].find("h5").find("span").contents
temp
# Out:
# ['Comme']

# %%
resolveItalic(temp)
# Out:
# ['Comme']

# %%
temp = containers[0].find("dl").find("dd").find("dl").findAll("dd")[1].contents
temp
# Out:
# ['ils se ressemblent comme deux gouttes d', <i>eau</i>, '\n']

# %%
resolveItalic(temp)
# Out:
# ["ils se ressemblent comme deux gouttes d'eau"]

# %%
def extractContext(tag):
    parts = list(tag.children)
    parts = filter(lambda x: False if x == ' ' or x == '\n' else True, parts) #filter all the non-words out
    parts = [part.contents[0] for part in parts]
    context = " ".join(parts)
    return context

# %%
extractContext(containers[0].find("dl").find("dd").find("dl").findAll("dd")[0])
# Out:
# 'Họ giống nhau như đúc'

# %%
def findTranslation(word):
    print("Finding translation for " + word)
    url = "http://tratu.soha.vn/dict/vn_fr/" + quote(word) #resolving the IRI issue

    try:
        source = urllib.request.urlopen(url)
    except:
        print("Link broken for " + word)
        return "N/A"

    soup = BeautifulSoup(source, 'lxml')
    
    translations = {}
    numTrans = 0
 
    containers = soup.findAll("div", class_ = "section-h5") #getting all the translations for a word
    if (containers is None):
      print("No translations found for " + word)
      return "N/A"

    for trans in containers: #for each translation in this group
        temp = {} #temp dict to store each translation of a word

        #getting the raw translation
        temp['translation'] = resolveItalic(trans.find("h5").find("span").contents)

        try:
            #retrieving the examples and contexts of this translation
            clarifications = trans.find("dl").find("dd").find("dl").findAll("dd")
            temp2 = {} #another dict to store each examples of a translation
            
            numContext = 0;
            numUsage = 0;
            
            for item in clarifications:
                if (hasLink(item)): #this is a context (context contains hyperlink)
                    temp2['context ' + str(numContext+1)] = extractContext(item)
                    numContext += 1
                else: #this is an usage
                    temp2['usage ' + str(numUsage+1)] = resolveItalic(item.contents)
                    numUsage += 1
            
            temp2['nums context'] = numContext
            temp2['nums usage'] = numUsage

            temp['examples'] = temp2
        except:
            temp['examples'] = "N/A"

        translations[numTrans+1] = temp #adding the translation to the dictionary
        numTrans += 1
            
    #storing the number of translations
    translations['nums'] = numTrans
    return translations

# %%
findTranslation("như")
# Out:
# Finding translation for như
# {1: {'examples': {'context 1': 'Họ giống nhau như đúc',
#    'context 2': 'Như tôi đã nói với anh',
#    'context 3': 'Giàu như anh ta',
#    'context 4': 'Như thường lệ',
#    'nums context': 4,
#    'nums usage': 4,
#    'usage 1': ["ils se ressemblent comme deux gouttes d'eau"],
#    'usage 2': ["comme je vous l'ai dit"],
#    'usage 3': ['riche comme il est'],
#    'usage 4': ['comme de coutume', "comme d'habitude"]},
#   'translation': ['Comme']},
#  2: {'examples': {'context 1': 'Tôi cũng vui mừng về điều đó như anh',
#    'nums context': 1,
#    'nums usage': 1,
#    'usage 1': ["je m'en réjouis autant que vous"]},
#   'translation': ['Autant que']},
#  3: {'examples': {'context 1': 'Gia súc như chó mèo',
#    'nums context': 1,
#    'nums usage': 1,
#    'usage 1': ['les animaux domestiques tels que le chien', 'le chat']},
#   'translation': ['Tel que']},
#  4: {'examples': {'context 1': 'Như ông đồng ý tôi sẽ nhường cho ông',
#    'nums context': 1,
#    'nums usage': 1,
#    'usage 1': ["si vous êtes d'accord", 'je vous le céderai']},
#   'translation': ['Si au cas où']},
#  'nums': 4}

# %%
findTranslation("tôi")
# Out:
# Finding translation for tôi
# {1: {'examples': {'context 1': 'Làm tôi người khác',
#    'nums context': 1,
#    'nums usage': 1,
#    'usage 1': ["se faire domestique chez quelqu'un",
#     "être au service de quelqu'un",
#     '']},
#   'translation': ['Serviteur', 'domestique', '']},
#  2: {'examples': {'context 1': 'Vua và tôi',
#    'nums context': 1,
#    'nums usage': 1,
#    'usage 1': ['le roi et ses sujets', '']},
#   'translation': ['Sujet', '']},
#  3: {'examples': {'context 1': 'Em tôi tuổi tôi',
#    'nums context': 1,
#    'nums usage': 1,
#    'usage 1': ['', '']},
#   'translation': ['Je', 'moi', 'memon', 'ma', 'mes', '']},
#  4: {'examples': {'context 1': 'Tôi lưỡi gươm',
#    'nums context': 1,
#    'nums usage': 1,
#    'usage 1': ["��tremper une lame d'épée", '']},
#   'translation': ['Tremper']},
#  5: {'examples': {'context 1': 'Tôi vôi',
#    'context 2': 'Cái tôi',
#    'nums context': 2,
#    'nums usage': 2,
#    'usage 1': ['��éteindre de la chaux', ''],
#    'usage 2': ['(triết học) ego']},
#   'translation': ['Éteindre']},
#  'nums': 5}

# %%
findTranslation("đã")
# Out:
# Finding translation for đã
# {1: {'examples': 'N/A', 'translation': ['Déjà']},
#  2: {'examples': 'N/A', 'translation': ['Non seulement']},
#  3: {'examples': 'N/A', 'translation': ['Voilà']},
#  4: {'examples': 'N/A', 'translation': ['Si']},
#  5: {'examples': 'N/A', 'translation': ['À satiété', "jusqu'à satiété"]},
#  6: {'examples': 'N/A', 'translation': ['(ít dùng) guérir']},
#  'nums': 6}

# %%
from google.colab import files
start_time = time.time()

index = 2
batch = batches[index]

dictionary = {}

#making the dictionary for each batch
for word in batch:
    dictionary[word] = findTranslation(word)
    time.sleep(1) #wait for 1 sec between each query
# Out:
# Finding translation for đtht
# Finding translation for writers
# Finding translation for waxing
# Finding translation for tếthương
# Finding translation for thángbếp
# Finding translation for through
# Finding translation for soóc
# Finding translation for rùm
# Finding translation for rupiah
# Finding translation for polysaccharide
# Finding translation for nấuxuất
# Finding translation for nghệm
# Finding translation for nahnh
# Finding translation for lỗng
# Finding translation for login
# Finding translation for kqxsmn
# Finding translation for know
# Finding translation for khôngdu
# Finding translation for kháchphòng
# Finding translation for khácmức
# Finding translation for kheotaycomvn
# Finding translation for imagerunner
# Finding translation for httpwwwketsatcaocapvn
# Finding translation for hiết
# Finding translation for hihi
# Finding translation for f15
# Finding translation for dẽo
# Finding translation for dơn
# Finding translation for deg
# Finding translation for côt
# Finding translation for côngđây
# Finding translation for chõng
# Finding translation for chuộn
# Finding translation for chogiasicomvn
# Finding translation for betong
# Finding translation for yamaguchigumi
# Finding translation for xc60
# Finding translation for witherspoon
# Finding translation for winline
# Finding translation for winchester
# Finding translation for wed
# Finding translation for webos
# Finding translation for wallet
# Finding translation for wsj
# Finding translation for việtlongviettelecom
# Finding translation for vitavit
# Finding translation for vertical
# Finding translation for venturer
# Finding translation for vtv24
# Finding translation for vpp
# Finding translation for usp
# Finding translation for tyre
# Finding translation for turkmenistan
# Finding translation for trươi
# Finding translation for triomphe
# Finding translation for tikivn
# Finding translation for thank
# Finding translation for tetracycline
# Finding translation for teerasil
# Finding translation for tic
# Finding translation for sớmkhông
# Finding translation for sungroup
# Finding translation for strauss
# Finding translation for steinmeier
# Finding translation for soba
# Finding translation for sisoulith
# Finding translation for serina
# Finding translation for seat
# Finding translation for saga
# Finding translation for saas
# Finding translation for sus316
# Finding translation for sap2000
# Finding translation for s9s9
# Finding translation for s560
# Finding translation for rôma
# Finding translation for ruijie
# Finding translation for rosalia
# Finding translation for relationship
# Finding translation for ramadan
# Finding translation for rbc
# Finding translation for qe
# Finding translation for qcẩm
# Finding translation for pullback
# Finding translation for pregnenolone
# Finding translation for plei
# Finding translation for plank
# Finding translation for pini
# Finding translation for phớc
# Finding translation for pattinson
# Finding translation for parami
# Finding translation for pai
# Finding translation for pcccr
# Finding translation for nđtnn
# Finding translation for nucleus
# Finding translation for nissin
# Finding translation for nemo
# Finding translation for nx300
# Finding translation for nslđ
# Finding translation for naturel
# Finding translation for mycoplasma
# Finding translation for mertens
# Finding translation for mellon
# Finding translation for maru
# Finding translation for marking
# Finding translation for mtd
# Finding translation for mi6
# Finding translation for loangiá
# Finding translation for leto
# Finding translation for lazarus
# Finding translation for lxat
# Finding translation for lntt
# Finding translation for l3
# Finding translation for krista
# Finding translation for kirk
# Finding translation for kazuko
# Finding translation for kanto
# Finding translation for kleague
# Finding translation for jeanne
# Finding translation for jaime
# Finding translation for jaden
# Finding translation for internship
# Finding translation for instruments
# Finding translation for itn
# Finding translation for isocell
# Finding translation for ism
# Finding translation for ippg
# Finding translation for ins
# Finding translation for idi
# Finding translation for hồngthể
# Finding translation for hydration
# Finding translation for holden
# Finding translation for hiêp
# Finding translation for hirayama
# Finding translation for heywel
# Finding translation for hangquangchau
# Finding translation for h5
# Finding translation for h265
# Finding translation for gumiho
# Finding translation for golan
# Finding translation for giabảo
# Finding translation for gerwig
# Finding translation for gemini
# Finding translation for geely
# Finding translation for gtr
# Finding translation for gdcd
# Finding translation for frequency
# Finding translation for frederic
# Finding translation for florian
# Finding translation for equity
# Finding translation for entersoft
# Finding translation for eilish
# Finding translation for ecocity
# Finding translation for ehp
# Finding translation for egf
# Finding translation for einvoice
# Finding translation for dino
# Finding translation for deer
# Finding translation for debit
# Finding translation for dauphine
# Finding translation for danone
# Finding translation for danfoss
# Finding translation for dalattourist
# Finding translation for dxmb
# Finding translation for citisoho
# Finding translation for chernobyl
# Finding translation for charmvit
# Finding translation for chamberlain
# Finding translation for cedric
# Finding translation for ceballos
# Finding translation for careplus
# Finding translation for cd4
# Finding translation for ccna
# Finding translation for cbcnvc
# Finding translation for cbc
# Finding translation for cadisun
# Finding translation for c17
# Finding translation for bulgari
# Finding translation for browne
# Finding translation for britannia
# Finding translation for bravia
# Finding translation for bowie
# Finding translation for boom
# Finding translation for bestway
# Finding translation for berlusconi
# Finding translation for bvs
# Finding translation for bmr
# Finding translation for archi
# Finding translation for aplisens
# Finding translation for apacer
# Finding translation for antifat
# Finding translation for anglia
# Finding translation for allspace
# Finding translation for adata
# Finding translation for attention
# Finding translation for 832014nđcp
# Finding translation for 50ec
# Finding translation for 4n3đ
# Finding translation for 45km
# Finding translation for 35kv
# Finding translation for 313et
# Finding translation for 272012ttbkhcn
# Finding translation for 250mg
# Finding translation for 12m2
# Finding translation for 10kva
# Finding translation for 062010nđcp
# Finding translation for vcca
# Finding translation for nuts
# Finding translation for nut
# Finding translation for μm
# Finding translation for đân
# Finding translation for ýcanhocomvn
# Finding translation for xữ
# Finding translation for wa
# Finding translation for thé
# Finding translation for sốsố
# Finding translation for sector
# Finding translation for quờ
# Finding translation for phưc
# Finding translation for outsource
# Finding translation for mgdl
# Finding translation for lế
# Finding translation for luậnngày
# Finding translation for livescore
# Finding translation for khệ
# Finding translation for hóathể
# Finding translation for hãngoshima
# Finding translation for httpsfactlinkcomvn
# Finding translation for httpscanhocomvn
# Finding translation for hiệuoshima
# Finding translation for giăm
# Finding translation for cầnbán
# Finding translation for cuoi
# Finding translation for cungcầu
# Finding translation for bưc
# Finding translation for based
# Finding translation for aptx
# Finding translation for x10
# Finding translation for wagyu
# Finding translation for wpvc
# Finding translation for voyage
# Finding translation for viruss
# Finding translation for variospeed
# Finding translation for vos
# Finding translation for vnvc
# Finding translation for updo
# Finding translation for universities
# Finding translation for usdchiếc
# Finding translation for ulv
# Finding translation for udf
# Finding translation for twitch
# Finding translation for tottori
# Finding translation for teco
# Finding translation for ttthích
# Finding translation for tns
# Finding translation for soy
# Finding translation for soccer
# Finding translation for smartel
# Finding translation for sinopec
# Finding translation for shopeekhiến
# Finding translation for seongsan
# Finding translation for sakai
# Finding translation for sxtm
# Finding translation for riot
# Finding translation for return
# Finding translation for péo
# Finding translation for pretech
# Finding translation for plastics
# Finding translation for piero
# Finding translation for photography
# Finding translation for peridot
# Finding translation for pattern
# Finding translation for palette
# Finding translation for ptt
# Finding translation for pdc
# Finding translation for p550l
# Finding translation for nukirack
# Finding translation for novartis
# Finding translation for nordlys
# Finding translation for no1
# Finding translation for ngọcthể
# Finding translation for nasri
# Finding translation for namkim
# Finding translation for naked
# Finding translation for nabil
# Finding translation for nnn
# Finding translation for nlg
# Finding translation for nhà14159
# Finding translation for neg
# Finding translation for muammar
# Finding translation for mossman
# Finding translation for mokazana
# Finding translation for miuccia
# Finding translation for mirifica
# Finding translation for mdland
# Finding translation for loren
# Finding translation for lio
# Finding translation for legends
# Finding translation for lanchiều
# Finding translation for lmht
# Finding translation for kra
# Finding translation for kotobuki
# Finding translation for kenhdiaoc24hcomvn
# Finding translation for kp5p
# Finding translation for jzc
# Finding translation for investments
# Finding translation for infantino
# Finding translation for inari
# Finding translation for inec
# Finding translation for imx586
# Finding translation for ibuk
# Finding translation for iba
# Finding translation for huyme
# Finding translation for hurley
# Finding translation for hood
# Finding translation for hiruscar
# Finding translation for hiromi
# Finding translation for heathrow
# Finding translation for hasan
# Finding translation for htg
# Finding translation for hd360
# Finding translation for gallup
# Finding translation for gallagher
# Finding translation for gsxr150
# Finding translation for gmt7
# Finding translation for gms
# Finding translation for gmat
# Finding translation for fractional
# Finding translation for fci
# Finding translation for entry
# Finding translation for emil
# Finding translation for evngenco
# Finding translation for dreamhouse
# Finding translation for dota
# Finding translation for dog
# Finding translation for desk
# Finding translation for davisoft
# Finding translation for daenerys
# Finding translation for creation
# Finding translation for colombo
# Finding translation for chuyennhagiarecomvn
# Finding translation for chok
# Finding translation for chipxinh
# Finding translation for courses
# Finding translation for constar
# Finding translation for cemcolor
# Finding translation for buzz
# Finding translation for brank
# Finding translation for benedict
# Finding translation for bnd
# Finding translation for bf
# Finding translation for ansu
# Finding translation for analyzer
# Finding translation for ambani
# Finding translation for airdrop
# Finding translation for adler
# Finding translation for adlay
# Finding translation for accessories
# Finding translation for accelerator
# Finding translation for ap24
# Finding translation for a850
# Finding translation for 86m2
# Finding translation for 600mg
# Finding translation for 58m2
# Finding translation for 35cttw
# Finding translation for 2dịch
# Finding translation for 138b
# Finding translation for 16at
# Finding translation for irgc
# Finding translation for ợt
# Finding translation for đỏm
# Finding translation for đtv
# Finding translation for vấu
# Finding translation for việctuyển
# Finding translation for tuổi24
# Finding translation for tuẫn
# Finding translation for tryptophan
# Finding translation for tiêc
# Finding translation for ticolor
# Finding translation for themes
# Finding translation for sã
# Finding translation for simplex
# Finding translation for rọt
# Finding translation for redmu
# Finding translation for pof
# Finding translation for octane
# Finding translation for nhiêutrả
# Finding translation for ngầy
# Finding translation for ngàysản
# Finding translation for mix386
# Finding translation for mglít
# Finding translation for itools
# Finding translation for hiphop
# Finding translation for giờkhoảng
# Finding translation for dụcđào
# Finding translation for duyêt
# Finding translation for cươngnâu
# Finding translation for cravat
# Finding translation for coiboicomvn
# Finding translation for chò
# Finding translation for bợm
# Finding translation for bỡn
# Finding translation for bớ
# Finding translation for bé12112018
# Finding translation for bé1302019
# Finding translation for brick
# Finding translation for alkaloid
# Finding translation for yếnthể
# Finding translation for yag
# Finding translation for xshcm
# Finding translation for wai
# Finding translation for w213
# Finding translation for vđh
# Finding translation for vinaxuki
# Finding translation for viettelpay
# Finding translation for vclass
# Finding translation for upod
# Finding translation for uht
# Finding translation for ubqlvnn
# Finding translation for tưthiết
# Finding translation for tourmaline
# Finding translation for toro
# Finding translation for tmallcom
# Finding translation for thiềng
# Finding translation for tpc
# Finding translation for tpthanh
# Finding translation for thxttxvn
# Finding translation for symbian
# Finding translation for streep
# Finding translation for southwest
# Finding translation for slow
# Finding translation for slimane
# Finding translation for skeleton
# Finding translation for sentour
# Finding translation for sembcorp
# Finding translation for scudetto
# Finding translation for scots
# Finding translation for sandbox
# Finding translation for sucmanh
# Finding translation for stp
# Finding translation for steeltruss
# Finding translation for sls
# Finding translation for rupert
# Finding translation for rudy
# Finding translation for rudolf
# Finding translation for robb
# Finding translation for resveratrol
# Finding translation for radial
# Finding translation for qsd
# Finding translation for qlđb
# Finding translation for podolski
# Finding translation for phytophthora
# Finding translation for penny
# Finding translation for parliament
# Finding translation for papas
# Finding translation for pvdf
# Finding translation for ottogi
# Finding translation for otago
# Finding translation for osasuna
# Finding translation for orchestra
# Finding translation for ogawa
# Finding translation for oas
# Finding translation for nitrile
# Finding translation for never
# Finding translation for namhoạt
# Finding translation for nakamoto
# Finding translation for npu
# Finding translation for nema
# Finding translation for munoz
# Finding translation for mechanical
# Finding translation for matisse
# Finding translation for masterchef
# Finding translation for manage
# Finding translation for maia
# Finding translation for magna
# Finding translation for maeda
# Finding translation for mademoiselle
# Finding translation for maddox
# Finding translation for mmi
# Finding translation for mbee
# Finding translation for luigi
# Finding translation for kuvings
# Finding translation for kerala
# Finding translation for keira
# Finding translation for karuizawa
# Finding translation for kanka
# Finding translation for kamaz

# %%
#saving the batch
with open('/content/gdrive/My Drive/Colab Notebooks/Dictionary Project/soha VI-FR batch {}.json'.format(index), 'w') as outfile:
  json.dump(dictionary, outfile)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
dictionary

# %%
findTranslation("insulin")
