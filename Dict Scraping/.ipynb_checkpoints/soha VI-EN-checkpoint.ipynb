# %%
import urllib.request 
from urllib.parse import quote 
from bs4 import BeautifulSoup
import json
import re
import time

# %%
#from google.colab import drive
#drive.mount('/content/gdrive')

# %%
import json
with open('./bigFreqList.json') as json_file:
     wordsData = json.load(json_file)

# %%
#generate a list of words with frequency higher than the threshold
def generateWordList(threshold): 
  temp = []
  for (word, freq) in wordsData.items():
    if (freq >= threshold):
      temp.append(word)
  return temp

# %%
wordList = generateWordList(40)
print(wordList[-10:])
len(wordList)
# Out:
# ['latikivn', 'imusicvn', 'ycđt', 'greatland', 'lemmevn', 'hoclamgiau', 'hpschoolvn', 'khochiasevn', 'hakiba', 'heisvn']
# 141836

# %%
#break the word list into batches of 
batches = [wordList[i:i + 10000] for i in range(0, len(wordList), 10000)]

# %%
for batch in batches:
  print(len(batch))
# Out:
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 1836

# %%
posDict = {} #a dictionary to translate POS words in Vietnamese to English
posDict["Động từ"] = "verb"
posDict["Danh từ"] = "noun"
posDict["Nghĩa chuyên ngành"] = "jargon"
posDict["*"] = "N/A"
posDict["Trạng ngữ"] = "adverb"
posDict["Cảm thán"] = "interjection"
posDict["Phó từ"] = "adverb"
posDict["Từ nối"] = "conjunction"
posDict["Từ đệm"] = "N/A"
posDict["Đại từ"] = "pronoun"

# %%
#The link format for soha Viet-Eng is: http://tratu.soha.vn/dict/vn_en/C%C3%B3

# %%
url = "http://tratu.soha.vn/dict/vn_en/" + quote("như") #resolving the IRI issue

try:
    source = urllib.request.urlopen(url)
except:
    print( "Link broken")
soup = BeautifulSoup(source, 'lxml')

# %%
groups = soup.findAll("div", class_ = "section-h3") #soha groups their translations by POS

# %%
containers = soup.findAll("div", class_ = "section-h5")

# %%
containers[0].parent
# Out:
# <div class="section-h2" id="show-alter"><h2> <span class="mw-headline">Thông dụng</span></h2>
# <a name="As."></a><div class="section-h5" id="content-5"><h5> <span class="mw-headline">As.</span></h5>
# <dl><dd><dl><dd><a href="/dict/vn_en/L%C3%A0m" title="Làm">làm</a> <strong class="selflink">như</strong> <a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a>
# </dd><dd>Do as I do.
# </dd></dl>
# </dd></dl>
# <a name="Like."></a></div><div class="section-h5" id="content-5"><h5> <span class="mw-headline">Like.</span></h5>
# <dl><dd><dl><dd><a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a> <a href="/dict/vn_en/C%C5%A9ng" title="Cũng">cũng</a> <a href="/dict/vn_en/Ngh%C4%A9" title="Nghĩ">nghĩ</a> <strong class="selflink">như</strong> <a href="/dict/vn_en/Anh" title="Anh">anh</a>
# </dd><dd>I think like you.
# </dd><dd>_alike; similar to.
# </dd><dd><a href="/dict/vn_en/Tr%C6%B0%E1%BB%9Dng" title="Trường">trường</a> <a href="/dict/vn_en/H%E1%BB%A3p" title="Hợp">hợp</a> <a href="/dict/vn_en/Anh" title="Anh">anh</a> <a href="/dict/vn_en/Gi%E1%BB%91ng" title="Giống">giống</a> <strong class="selflink">như</strong> <a href="/dict/vn_en/Tr%C6%B0%E1%BB%9Dng" title="Trường">trường</a> <a href="/dict/vn_en/H%E1%BB%A3p" title="Hợp">hợp</a> <a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a>
# </dd><dd>Your case is similar to mine.
# </dd></dl>
# </dd></dl>
# <!-- Saved in parser cache with key wikidbv2-vn_en:pcache:idhash:691271-0!1!0!!vi!2!edit=0 and timestamp 20200612111411 -->
# </div></div>

# %%
containers[0].find("dl").find("dd").find("dl").findAll("dd")
# Out:
# [<dd><a href="/dict/vn_en/L%C3%A0m" title="Làm">làm</a> <strong class="selflink">như</strong> <a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a>
#  </dd>,
#  <dd>Do as I do.
#  </dd>]

# %%
#detect whether a tag contains a link, if a link is present, the tag contains a context
def hasLink(tag):
    try:
        subTags = tag.findAll('a')
    except:
        return False
    for subTag in subTags:
        if (subTag.get('href')): #found a link
            return True
    return False

# %%
hasLink(containers[0].find("dl").find("dd").find("dl").findAll("dd")[1])
# Out:
# False

# %%
def extractContext(tag):
    parts = list(tag.children)
    parts = filter(lambda x: False if x == ' ' or x == '\n' else True, parts) #filter all the non-words out
    parts = [part.contents[0] for part in parts]
    context = " ".join(parts)
    return context

# %%
extractContext(containers[0].find("dl").find("dd").find("dl").findAll("dd")[0])
# Out:
# 'làm như tôi'

# %%
unknownPos = []
def getPos(vietPos): #translating the POS in Viet to English
    vietPos = vietPos.strip(".")
    if (vietPos.find("(") != -1): #the vietPos contains the english equivalent
        return vietPos[vietPos.find("(")+1:vietPos.find(")")].strip()
    elif (vietPos in posDict):
        return posDict[vietPos]
    else:
        unknownPos.append(str(vietPos))
        return "N/A"

# %%
getPos("Động từ")
# Out:
# 'verb'

# %%
getPos("Phó từ ( affirmative particle)")
# Out:
# 'affirmative particle'

# %%
def resolveItalic(parts): #soha use italic to mark an use of "'"
    parts = [str(part) for part in parts]
    if (len(parts) == 1): #nothing special here, just return the string
        return [item.strip() for item in re.split('[.,;]', str(parts[0]))]
    parts = [part.replace("<i>", "'").replace("</i>", "") for part in parts]
    if (parts[-1] == '\n'): #this is an usage, ignore the last part
        return [item.strip() for item in re.split('[.,;]', "".join(parts[:-1]))]
    #this is a translation
    return [item.strip() for item in re.split('[.,;]', "".join(parts))]

# %%
def findTranslation(word):
    print("Finding translation for " + word)
    url = "http://tratu.soha.vn/dict/vn_en/" + quote(word) #resolving the IRI issue

    try:
        source = urllib.request.urlopen(url)
    except:
        print("Link broken for " + word)
        return "N/A"

    soup = BeautifulSoup(source, 'lxml')
    
    translations = {}
    numTrans = 0
 
    containers = soup.findAll("div", class_ = "section-h5") #getting all the translations for a word
    if (containers is None or containers == []):
      print("No translations found for " + word)
      return "N/A"
 
    for trans in containers: #for each translation in this group
        temp = {} #temp dict to store each translation of a word

        #getting the raw translation
        temp['translation'] = resolveItalic(trans.find("h5").find("span").contents)
        
        parentTag = trans.parent
        try:
          if (parentTag.attrs["class"] == "section-h3"): #has POS
            temp['POS'] = getPos(group.find("h3").find("span").string)
          else:
            temp['POS'] = "N/A"
        except: #no POS
            temp['POS'] = "N/A"

        try:
            #retrieving the examples and contexts of this translation
            clarifications = trans.find("dl").find("dd").find("dl").findAll("dd")
            temp2 = {} #another dict to store each examples of a translation
            
            numContext = 0;
            numUsage = 0;
            
            for item in clarifications:
                if (hasLink(item)): #this is a context (context contains hyperlink)
                    temp2['context ' + str(numContext+1)] = extractContext(item)
                    numContext += 1
                else: #this is an usage
                    temp2['usage ' + str(numUsage+1)] = resolveItalic(item.contents)
                    numUsage += 1
            
            temp2['nums context'] = numContext
            temp2['nums usage'] = numUsage

            temp['examples'] = temp2
        except:
            temp['examples'] = "N/A"

        translations[numTrans+1] = temp #adding the translation to the dictionary
        numTrans += 1
            
    #storing the number of translations
    translations['nums'] = numTrans
    return translations

# %%
findTranslation("như")
# Out:
# Finding translation for như
# {1: {'translation': ['As', ''],
#   'POS': 'N/A',
#   'examples': {'context 1': 'làm như tôi',
#    'usage 1': ['Do as I do', ''],
#    'nums context': 1,
#    'nums usage': 1}},
#  2: {'translation': ['Like', ''],
#   'POS': 'N/A',
#   'examples': {'context 1': 'tôi cũng nghĩ như anh',
#    'usage 1': ['I think like you', ''],
#    'usage 2': ['_alike', 'similar to', ''],
#    'context 2': 'trường hợp anh giống như trường hợp tôi',
#    'usage 3': ['Your case is similar to mine', ''],
#    'nums context': 2,
#    'nums usage': 3}},
#  'nums': 2}

# %%
findTranslation("tôi")
# Out:
# Finding translation for tôi
# {1: {'translation': ['Danh từ'],
#   'POS': 'N/A',
#   'examples': {'usage 1': ['subject'],
#    'usage 2': ['servant'],
#    'usage 3': ['self'],
#    'nums context': 0,
#    'nums usage': 3}},
#  2: {'translation': ['Động từ'],
#   'POS': 'N/A',
#   'examples': {'usage 1': ['I', 'me'],
#    'usage 2': ['to temper', 'to slake'],
#    'nums context': 0,
#    'nums usage': 2}},
#  3: {'translation': ['bad'], 'POS': 'N/A', 'examples': 'N/A'},
#  4: {'translation': ['friable'], 'POS': 'N/A', 'examples': 'N/A'},
#  5: {'translation': ['chilling'], 'POS': 'N/A', 'examples': 'N/A'},
#  6: {'translation': ['cure'], 'POS': 'N/A', 'examples': 'N/A'},
#  7: {'translation': ['dip'], 'POS': 'N/A', 'examples': 'N/A'},
#  8: {'translation': ['thoriveitite'], 'POS': 'N/A', 'examples': 'N/A'},
#  9: {'translation': ['advent'], 'POS': 'N/A', 'examples': 'N/A'},
#  10: {'translation': ['arrival'], 'POS': 'N/A', 'examples': 'N/A'},
#  11: {'translation': ['arrive'], 'POS': 'N/A', 'examples': 'N/A'},
#  12: {'translation': ['ingoing'], 'POS': 'N/A', 'examples': 'N/A'},
#  13: {'translation': ['capstan'], 'POS': 'N/A', 'examples': 'N/A'},
#  14: {'translation': ['drawwork'], 'POS': 'N/A', 'examples': 'N/A'},
#  15: {'translation': ['gin'], 'POS': 'N/A', 'examples': 'N/A'},
#  16: {'translation': ['hauler'], 'POS': 'N/A', 'examples': 'N/A'},
#  17: {'translation': ['jack up'], 'POS': 'N/A', 'examples': 'N/A'},
#  18: {'translation': ['purchase'], 'POS': 'N/A', 'examples': 'N/A'},
#  19: {'translation': ['sheave'], 'POS': 'N/A', 'examples': 'N/A'},
#  20: {'translation': ['winch capstan'], 'POS': 'N/A', 'examples': 'N/A'},
#  21: {'translation': ['winding engine'], 'POS': 'N/A', 'examples': 'N/A'},
#  22: {'translation': ['defective'], 'POS': 'N/A', 'examples': 'N/A'},
#  23: {'translation': ['foul'], 'POS': 'N/A', 'examples': 'N/A'},
#  24: {'translation': ['garlicky'], 'POS': 'N/A', 'examples': 'N/A'},
#  25: {'translation': ['crumbly'], 'POS': 'N/A', 'examples': 'N/A'},
#  26: {'translation': ['friable'], 'POS': 'N/A', 'examples': 'N/A'},
#  27: {'translation': ['windlass'], 'POS': 'N/A', 'examples': 'N/A'},
#  28: {'translation': ['wrong'], 'POS': 'N/A', 'examples': 'N/A'},
#  'nums': 28}

# %%
#from google.colab import files
start_time = time.time()

index = 3
batch = batches[index] + batches[index+1]

dictionary = {}
unknownPos = []

#making the dictionary for each batch
for word in batch:
    dictionary[word] = findTranslation(word)
    time.sleep(1) #wait for 1 sec between each query

dictionary['unknownPos'] = unknownPos
# Out:
# Finding translation for dany
# No translations found for dany
# Finding translation for dane
# No translations found for dane
# Finding translation for daejeon
# No translations found for daejeon
# Finding translation for dz
# No translations found for dz
# Finding translation for dmm
# No translations found for dmm
# Finding translation for dhq
# No translations found for dhq
# Finding translation for dh04
# No translations found for dh04
# Finding translation for d20
# No translations found for d20
# Finding translation for d001
# No translations found for d001
# Finding translation for crete
# No translations found for crete
# Finding translation for crafted
# No translations found for crafted
# Finding translation for conversion
# No translations found for conversion
# Finding translation for condoleezza
# No translations found for condoleezza
# Finding translation for cienco4
# No translations found for cienco4
# Finding translation for chôl
# No translations found for chôl
# Finding translation for chnăm
# No translations found for chnăm
# Finding translation for chart
# No translations found for chart
# Finding translation for centec
# No translations found for centec
# Finding translation for carrington
# No translations found for carrington
# Finding translation for carr
# No translations found for carr
# Finding translation for carlmark
# No translations found for carlmark
# Finding translation for canvio
# No translations found for canvio
# Finding translation for cama
# No translations found for cama
# Finding translation for cain
# No translations found for cain
# Finding translation for cvđ
# No translations found for cvđ
# Finding translation for cphi
# No translations found for cphi
# Finding translation for coolerplus
# No translations found for coolerplus
# Finding translation for ciss
# No translations found for ciss
# Finding translation for ch3cooh
# No translations found for ch3cooh
# Finding translation for c49
# No translations found for c49
# Finding translation for butcher
# No translations found for butcher
# Finding translation for braga
# No translations found for braga
# Finding translation for boulder
# No translations found for boulder
# Finding translation for bosselec
# No translations found for bosselec
# Finding translation for bomb
# No translations found for bomb
# Finding translation for bluestacks
# No translations found for bluestacks
# Finding translation for blonde
# No translations found for blonde
# Finding translation for bless
# No translations found for bless
# Finding translation for bjorn
# No translations found for bjorn
# Finding translation for bibby
# No translations found for bibby
# Finding translation for bettencourt
# No translations found for bettencourt
# Finding translation for bergen
# No translations found for bergen
# Finding translation for beedle
# No translations found for beedle
# Finding translation for basics
# No translations found for basics
# Finding translation for barton
# No translations found for barton
# Finding translation for baifern
# No translations found for baifern
# Finding translation for bps
# No translations found for bps
# Finding translation for biệthỗ
# No translations found for biệthỗ
# Finding translation for bigevn
# No translations found for bigevn
# Finding translation for bhp
# No translations found for bhp
# Finding translation for bcvt
# No translations found for bcvt
# Finding translation for bjohnson
# No translations found for bjohnson
# Finding translation for axe
# No translations found for axe
# Finding translation for avram
# No translations found for avram
# Finding translation for augustine
# No translations found for augustine
# Finding translation for associated
# No translations found for associated
# Finding translation for associate
# No translations found for associate
# Finding translation for arvind
# No translations found for arvind
# Finding translation for arlington
# No translations found for arlington
# Finding translation for andiez
# No translations found for andiez
# Finding translation for andhra
# No translations found for andhra
# Finding translation for anaerobic
# No translations found for anaerobic
# Finding translation for amando
# No translations found for amando
# No translations found for koolaid
# Finding translation for konjac
# No translations found for konjac
# Finding translation for kitsune
# No translations found for kitsune
# Finding translation for kingbbq
# No translations found for kingbbq
# Finding translation for kind
# No translations found for kind
# Finding translation for kimberley
# No translations found for kimberley
# Finding translation for kiki
# No translations found for kiki
# Finding translation for kidong
# No translations found for kidong
# Finding translation for kickboxing
# No translations found for kickboxing
# Finding translation for kejriwal
# No translations found for kejriwal
# Finding translation for karlheinz
# No translations found for karlheinz
# Finding translation for kanchanaburi
# No translations found for kanchanaburi
# Finding translation for kana
# No translations found for kana
# Finding translation for kam
# No translations found for kam
# Finding translation for kyowa
# No translations found for kyowa
# Finding translation for ksnb
# No translations found for ksnb
# Finding translation for koko
# No translations found for koko
# Finding translation for klevv
# No translations found for klevv
# Finding translation for kdl40w650d
# No translations found for kdl40w650d
# Finding translation for k72
# No translations found for k72
# Finding translation for juliette
# No translations found for juliette
# Finding translation for jota
# No translations found for jota
# Finding translation for josip
# No translations found for josip
# Finding translation for joshi
# No translations found for joshi
# Finding translation for jingu
# No translations found for jingu
# Finding translation for jimin
# No translations found for jimin
# Finding translation for jess
# No translations found for jess
# Finding translation for jeanmarie
# No translations found for jeanmarie
# Finding translation for jato
# No translations found for jato
# Finding translation for jarrow
# No translations found for jarrow
# Finding translation for janusz
# No translations found for janusz
# Finding translation for jvf
# No translations found for jvf
# Finding translation for jnka
# No translations found for jnka
# Finding translation for jce
# No translations found for jce
# Finding translation for jba
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     553             try:
# --> 554                 chunk_left = self._read_next_chunk_size()
#     555             except ValueError:
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_next_chunk_size(self)
#     520         try:
# --> 521             return int(line, 16)
#     522         except ValueError:
#
# ValueError: invalid literal for int() with base 16: b'\xbb\x9bi Google.com :</div>\r\n'
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/http/client.py in _readall_chunked(self)
#     570             while True:
# --> 571                 chunk_left = self._get_chunk_left()
#     572                 if chunk_left is None:
#
# ~/anaconda3/lib/python3.7/http/client.py in _get_chunk_left(self)
#     555             except ValueError:
# --> 556                 raise IncompleteRead(b'')
#     557             if chunk_left == 0:
#
# IncompleteRead: IncompleteRead(0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# <ipython-input-26-ac58eb2cca9c> in <module>
#      10 #making the dictionary for each batch
#      11 for word in batch:
# ---> 12     dictionary[word] = findTranslation(word)
#      13     time.sleep(1) #wait for 1 sec between each query
#      14
#
# <ipython-input-23-335c7296782c> in findTranslation(word)
#       9         return "N/A"
#      10
# ---> 11     soup = BeautifulSoup(source, 'lxml')
#      12
#      13     translations = {}
#
# ~/anaconda3/lib/python3.7/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     304
#     305         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 306             markup = markup.read()
#     307         elif len(markup) <= 256 and (
#     308                 (isinstance(markup, bytes) and not b'<' in markup)
#
# ~/anaconda3/lib/python3.7/http/client.py in read(self, amt)
#     462
#     463             if self.chunked:
# --> 464                 return self._readall_chunked()
#     465
#     466             if self.length is None:
#
# ~/anaconda3/lib/python3.7/http/client.py in _readall_chunked(self)
#     576             return b''.join(value)
#     577         except IncompleteRead:
# --> 578             raise IncompleteRead(b''.join(value))
#     579
#     580     def _readinto_chunked(self, b):
#
# IncompleteRead: IncompleteRead(14594 bytes read)

# %%
#saving the batch
with open('./soha VI-EN batch {}.json'.format("34"), 'w') as outfile:
  json.dump(dictionary, outfile)
print("--- %s seconds ---" % (time.time() - start_time))

# %%
dictionary

# %%
findTranslation("jba")
# Out:
# Finding translation for jba
# No translations found for jba
# 'N/A'
