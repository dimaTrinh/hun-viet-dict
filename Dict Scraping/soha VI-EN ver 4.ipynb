# %%
import urllib.request 
from urllib.parse import quote 
from bs4 import BeautifulSoup
import json
import re
import time

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#getting the already scraped dict
import json
with open('/content/gdrive/My Drive/Colab Notebooks/Dictionary Project/soha VI-EN ver 3.json') as json_file:
     currDict = json.load(json_file)

# %%
#reading the word list produced by an crubadan:
with open('/content/gdrive/My Drive/Colab Notebooks/Dictionary Project/anCruVietList') as infile:
  wordsData = infile.readlines()

# %%
#generate a list of words from the word list produced by an crubadan
def generateWordList(): 
  temp = []
  for word in wordsData:
    parts = word.strip().split(" ")
    #ignore the frequency
    temp.append(" ".join(parts[1:]))
  return temp

# %%
wordList = generateWordList()
len(wordList)
# Out:
# 34275

# %%
#break the word list into batches of 
batches = [wordList[i:i + 5000] for i in range(0, len(wordList), 5000)]

# %%
for batch in batches:
  print(len(batch))
# Out:
# 5000
# 5000
# 5000
# 5000
# 5000
# 5000
# 4275

# %%
posDict = {} #a dictionary to translate POS words in Vietnamese to English
posDict["Động từ"] = "verb"
posDict["Danh từ"] = "noun"
posDict["Nghĩa chuyên ngành"] = "jargon"
posDict["*"] = "N/A"
posDict["Trạng ngữ"] = "adverb"
posDict["Cảm thán"] = "interjection"
posDict["Phó từ"] = "adverb"
posDict["Từ nối"] = "conjunction"
posDict["Từ đệm"] = "N/A"
posDict["Đại từ"] = "pronoun"

# %%
#The link format for soha Viet-Eng is: http://tratu.soha.vn/dict/vn_en/C%C3%B3

# %%
url = "http://tratu.soha.vn/dict/vn_en/" + quote("như") #resolving the IRI issue

try:
    source = urllib.request.urlopen(url)
except:
    print( "Link broken")
soup = BeautifulSoup(source, 'lxml')

# %%
groups = soup.findAll("div", class_ = "section-h3") #soha groups their translations by POS

# %%
containers = soup.findAll("div", class_ = "section-h5")

# %%
containers[0].parent
# Out:
# <div class="section-h2" id="show-alter"><h2> <span class="mw-headline">Thông dụng</span></h2>
# <a name="As."></a><div class="section-h5" id="content-5"><h5> <span class="mw-headline">As.</span></h5>
# <dl><dd><dl><dd><a href="/dict/vn_en/L%C3%A0m" title="Làm">làm</a> <strong class="selflink">như</strong> <a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a>
# </dd><dd>Do as I do.
# </dd></dl>
# </dd></dl>
# <a name="Like."></a></div><div class="section-h5" id="content-5"><h5> <span class="mw-headline">Like.</span></h5>
# <dl><dd><dl><dd><a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a> <a href="/dict/vn_en/C%C5%A9ng" title="Cũng">cũng</a> <a href="/dict/vn_en/Ngh%C4%A9" title="Nghĩ">nghĩ</a> <strong class="selflink">như</strong> <a href="/dict/vn_en/Anh" title="Anh">anh</a>
# </dd><dd>I think like you.
# </dd><dd>_alike; similar to.
# </dd><dd><a href="/dict/vn_en/Tr%C6%B0%E1%BB%9Dng" title="Trường">trường</a> <a href="/dict/vn_en/H%E1%BB%A3p" title="Hợp">hợp</a> <a href="/dict/vn_en/Anh" title="Anh">anh</a> <a href="/dict/vn_en/Gi%E1%BB%91ng" title="Giống">giống</a> <strong class="selflink">như</strong> <a href="/dict/vn_en/Tr%C6%B0%E1%BB%9Dng" title="Trường">trường</a> <a href="/dict/vn_en/H%E1%BB%A3p" title="Hợp">hợp</a> <a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a>
# </dd><dd>Your case is similar to mine.
# </dd></dl>
# </dd></dl>
# <!-- Saved in parser cache with key wikidbv2-vn_en:pcache:idhash:691271-0!1!0!!vi!2!edit=0 and timestamp 20200724063018 -->
# </div></div>

# %%
containers[0].find("dl").find("dd").find("dl").findAll("dd")
# Out:
# [<dd><a href="/dict/vn_en/L%C3%A0m" title="Làm">làm</a> <strong class="selflink">như</strong> <a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a>
#  </dd>, <dd>Do as I do.
#  </dd>]

# %%
#detect whether a tag contains a link, if a link is present, the tag contains a context
def hasLink(tag):
    try:
        subTags = tag.findAll('a')
    except:
        return False
    for subTag in subTags:
        if (subTag.get('href')): #found a link
            return True
    return False

# %%
hasLink(containers[0].find("dl").find("dd").find("dl").findAll("dd")[1])
# Out:
# False

# %%
def extractContext(tag):
    parts = list(tag.children)
    parts = filter(lambda x: False if x == ' ' or x == '\n' else True, parts) #filter all the non-words out
    parts = [part.contents[0] for part in parts]
    context = " ".join(parts)
    return context

# %%
extractContext(containers[0].find("dl").find("dd").find("dl").findAll("dd")[0])
# Out:
# 'làm như tôi'

# %%
unknownPos = []
def getPos(vietPos): #translating the POS in Viet to English
    vietPos = vietPos.strip(".")
    if (vietPos.find("(") != -1): #the vietPos contains the english equivalent
        return vietPos[vietPos.find("(")+1:vietPos.find(")")].strip()
    elif (vietPos in posDict):
        return posDict[vietPos]
    else:
        unknownPos.append(str(vietPos))
        return "N/A"

# %%
getPos("Động từ")
# Out:
# 'verb'

# %%
getPos("Phó từ ( affirmative particle)")
# Out:
# 'affirmative particle'

# %%
def resolveItalic(parts): #soha use italic to mark an use of "'"
    parts = [str(part) for part in parts]
    if (len(parts) == 1): #nothing special here, just return the string
        return [item.strip() for item in re.split('[.,;]', str(parts[0]))]
    parts = [part.replace("<i>", "'").replace("</i>", "") for part in parts]
    if (parts[-1] == '\n'): #this is an usage, ignore the last part
        return [item.strip() for item in re.split('[.,;]', "".join(parts[:-1]))]
    #this is a translation
    return [item.strip() for item in re.split('[.,;]', "".join(parts))]

# %%
def findTranslation(word):
    print("Finding translation for " + word)
    url = "http://tratu.soha.vn/dict/vn_en/" + quote(word) #resolving the IRI issue

    try:
        source = urllib.request.urlopen(url)
    except:
        print("Link broken for " + word)
        return "N/A"

    soup = BeautifulSoup(source, 'lxml')
    
    translations = {}
    numTrans = 0
 
    containers = soup.findAll("div", class_ = "section-h5") #getting all the translations for a word
    if (containers is None or containers == []):
      print("No translations found for " + word)
      return "N/A"
 
    for trans in containers: #for each translation in this group
        temp = {} #temp dict to store each translation of a word

        #getting the raw translation
        temp['translation'] = resolveItalic(trans.find("h5").find("span").contents)
        
        parentTag = trans.parent
        try:
          if (parentTag.attrs["class"] == "section-h3"): #has POS
            temp['POS'] = getPos(group.find("h3").find("span").string)
          else:
            temp['POS'] = "N/A"
        except: #no POS
            temp['POS'] = "N/A"

        try:
            #retrieving the examples and contexts of this translation
            clarifications = trans.find("dl").find("dd").find("dl").findAll("dd")
            temp2 = {} #another dict to store each examples of a translation
            
            numContext = 0;
            numUsage = 0;
            
            for item in clarifications:
                if (hasLink(item)): #this is a context (context contains hyperlink)
                    temp2['context ' + str(numContext+1)] = extractContext(item)
                    numContext += 1
                else: #this is an usage
                    temp2['usage ' + str(numUsage+1)] = resolveItalic(item.contents)
                    numUsage += 1
            
            temp2['nums context'] = numContext
            temp2['nums usage'] = numUsage

            temp['examples'] = temp2
        except:
            temp['examples'] = "N/A"

        translations[numTrans+1] = temp #adding the translation to the dictionary
        numTrans += 1
            
    #storing the number of translations
    translations['nums'] = numTrans
    return translations

# %%
findTranslation("như")
# Out:
# Finding translation for như
# {1: {'POS': 'N/A',
#   'examples': {'context 1': 'làm như tôi',
#    'nums context': 1,
#    'nums usage': 1,
#    'usage 1': ['Do as I do', '']},
#   'translation': ['As', '']},
#  2: {'POS': 'N/A',
#   'examples': {'context 1': 'tôi cũng nghĩ như anh',
#    'context 2': 'trường hợp anh giống như trường hợp tôi',
#    'nums context': 2,
#    'nums usage': 3,
#    'usage 1': ['I think like you', ''],
#    'usage 2': ['_alike', 'similar to', ''],
#    'usage 3': ['Your case is similar to mine', '']},
#   'translation': ['Like', '']},
#  'nums': 2}

# %%
findTranslation("hờn dỗi")
# Out:
# Finding translation for hờn dỗi
# {1: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['To sulk']}, 'nums': 1}

# %%
findTranslation("thư ký")
# Out:
# Finding translation for thư ký
# {1: {'POS': 'N/A',
#   'examples': {'nums context': 0,
#    'nums usage': 1,
#    'usage 1': ['secretary', 'clerk']},
#   'translation': ['Danh từ']},
#  2: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['secretary']},
#  3: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['clerk']},
#  4: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['secretary']},
#  'nums': 4}

# %%
findTranslation("tôi")
# Out:
# Finding translation for tôi
# {1: {'POS': 'N/A',
#   'examples': {'nums context': 0,
#    'nums usage': 3,
#    'usage 1': ['subject'],
#    'usage 2': ['servant'],
#    'usage 3': ['self']},
#   'translation': ['Danh từ']},
#  10: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['arrival']},
#  11: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['arrive']},
#  12: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['ingoing']},
#  13: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['capstan']},
#  14: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['drawwork']},
#  15: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['gin']},
#  16: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['hauler']},
#  17: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['jack up']},
#  18: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['purchase']},
#  19: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['sheave']},
#  2: {'POS': 'N/A',
#   'examples': {'nums context': 0,
#    'nums usage': 2,
#    'usage 1': ['I', 'me'],
#    'usage 2': ['to temper', 'to slake']},
#   'translation': ['Động từ']},
#  20: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['winch capstan']},
#  21: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['winding engine']},
#  22: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['defective']},
#  23: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['foul']},
#  24: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['garlicky']},
#  25: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['crumbly']},
#  26: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['friable']},
#  27: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['windlass']},
#  28: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['wrong']},
#  3: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['bad']},
#  4: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['friable']},
#  5: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['chilling']},
#  6: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['cure']},
#  7: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['dip']},
#  8: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['thoriveitite']},
#  9: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['advent']},
#  'nums': 28}

# %%
from google.colab import files
start_time = time.time()

index = 6
batch = batches[index]
#for (index, batch) in enumerate(batches):
dictionary = {}

#making the dictionary for each batch
for word in batch:

    #if the word is not in already in the dict, find the translation
    if word not in currDict:
      dictionary[word] = findTranslation(word)
      time.sleep(1) #wait for 1 sec between each query
# Out:
# Streaming output truncated to the last 5000 lines.
# No translations found for tốc hà
# Finding translation for tố quyết
# No translations found for tố quyết
# Finding translation for tố có
# No translations found for tố có
# Finding translation for tỉ phú
# No translations found for tỉ phú
# Finding translation for tế vẫn
# No translations found for tế vẫn
# Finding translation for tế thần
# No translations found for tế thần
# Finding translation for tế nào
# No translations found for tế nào
# Finding translation for tắm chung
# No translations found for tắm chung
# Finding translation for tắm cho
# No translations found for tắm cho
# Finding translation for tắc và
# No translations found for tắc và
# Finding translation for tật hay
# No translations found for tật hay
# Finding translation for tập tốt
# No translations found for tập tốt
# Finding translation for tập sách
# No translations found for tập sách
# Finding translation for tập những
# No translations found for tập những
# Finding translation for tập làm
# No translations found for tập làm
# Finding translation for tầm văn
# No translations found for tầm văn
# Finding translation for tất công
# No translations found for tất công
# Finding translation for tả tơi
# Finding translation for tạo áp
# No translations found for tạo áp
# Finding translation for tạo thêm
# No translations found for tạo thêm
# Finding translation for tạo gel
# No translations found for tạo gel
# Finding translation for tại để
# No translations found for tại để
# Finding translation for tại tỉnh
# No translations found for tại tỉnh
# Finding translation for tại lễ
# No translations found for tại lễ
# Finding translation for tại kỳ
# No translations found for tại kỳ
# Finding translation for tại không
# No translations found for tại không
# Finding translation for tại căn
# No translations found for tại căn
# Finding translation for tại california
# No translations found for tại california
# Finding translation for tại bộ
# No translations found for tại bộ
# Finding translation for tại bình
# No translations found for tại bình
# Finding translation for tượng sâu
# No translations found for tượng sâu
# Finding translation for tượng như
# No translations found for tượng như
# Finding translation for tưởng đã
# No translations found for tưởng đã
# Finding translation for tưởng tốt
# No translations found for tưởng tốt
# Finding translation for tưởng không
# No translations found for tưởng không
# Finding translation for tường thành
# No translations found for tường thành
# Finding translation for tướng của
# No translations found for tướng của
# Finding translation for tước vị
# No translations found for tước vị
# Finding translation for tươi và
# No translations found for tươi và
# Finding translation for tươi mới
# No translations found for tươi mới
# Finding translation for tư tuần
# No translations found for tư tuần
# Finding translation for tơi bời
# Finding translation for tăng đột
# No translations found for tăng đột
# Finding translation for tăng từ
# No translations found for tăng từ
# Finding translation for tăng trong
# No translations found for tăng trong
# Finding translation for tăng theo
# No translations found for tăng theo
# Finding translation for tùng xe
# No translations found for tùng xe
# Finding translation for tù ở
# No translations found for tù ở
# Finding translation for tù ngục
# No translations found for tù ngục
# Finding translation for tù khổ
# No translations found for tù khổ
# Finding translation for tôi đoán
# No translations found for tôi đoán
# Finding translation for tôi xúc
# No translations found for tôi xúc
# Finding translation for tôi vốn
# No translations found for tôi vốn
# Finding translation for tôi tiếp
# No translations found for tôi tiếp
# Finding translation for tôi thôi
# No translations found for tôi thôi
# Finding translation for tôi thu
# No translations found for tôi thu
# Finding translation for tôi tham
# No translations found for tôi tham
# Finding translation for tôi sử
# No translations found for tôi sử
# Finding translation for tôi rồi
# No translations found for tôi rồi
# Finding translation for tôi quên
# No translations found for tôi quên
# Finding translation for tôi nhiều
# No translations found for tôi nhiều
# Finding translation for tôi mở
# No translations found for tôi mở
# Finding translation for tôi lần
# No translations found for tôi lần
# Finding translation for tôi kết
# No translations found for tôi kết
# Finding translation for tôi ghi
# No translations found for tôi ghi
# Finding translation for tôi dùng
# No translations found for tôi dùng
# Finding translation for tôi chịu
# No translations found for tôi chịu
# Finding translation for tôi chia
# No translations found for tôi chia
# Finding translation for tóc nâu
# No translations found for tóc nâu
# Finding translation for tóc bạc
# No translations found for tóc bạc
# Finding translation for tòan cầu
# No translations found for tòan cầu
# Finding translation for tòa xử
# No translations found for tòa xử
# Finding translation for tòa quốc
# No translations found for tòa quốc
# Finding translation for tính xác
# No translations found for tính xác
# Finding translation for tính trung
# No translations found for tính trung
# Finding translation for tính thuyết
# No translations found for tính thuyết
# Finding translation for tính riêng
# Finding translation for tính bằng
# No translations found for tính bằng
# Finding translation for tín dị
# No translations found for tín dị
# Finding translation for tí nào
# No translations found for tí nào
# Finding translation for tình mới
# No translations found for tình mới
# Finding translation for tình khiếu
# No translations found for tình khiếu
# Finding translation for tình bằng
# No translations found for tình bằng
# Finding translation for tìm lời
# No translations found for tìm lời
# Finding translation for tìm câu
# No translations found for tìm câu
# Finding translation for tên tội
# No translations found for tên tội
# Finding translation for tên gì
# No translations found for tên gì
# Finding translation for tên cán
# No translations found for tên cán
# Finding translation for tên bộ
# No translations found for tên bộ
# Finding translation for tâm với
# No translations found for tâm với
# Finding translation for tâm sửa
# No translations found for tâm sửa
# Finding translation for tâm khác
# No translations found for tâm khác
# Finding translation for tâm bảo
# No translations found for tâm bảo
# Finding translation for tái phát
# Finding translation for tác đầu
# No translations found for tác đầu
# Finding translation for tác quản
# No translations found for tác quản
# Finding translation for tác phát
# No translations found for tác phát
# Finding translation for tác nhạc
# No translations found for tác nhạc
# Finding translation for tác gia
# No translations found for tác gia
# Finding translation for tàu hải
# No translations found for tàu hải
# Finding translation for tào lao
# Finding translation for tàn khốc
# Finding translation for tài nhiều
# No translations found for tài nhiều
# Finding translation for ty đã
# No translations found for ty đã
# Finding translation for ty sản
# No translations found for ty sản
# Finding translation for tuỳ theo
# No translations found for tuỳ theo
# Finding translation for tuần để
# No translations found for tuần để
# Finding translation for tuần thứ
# No translations found for tuần thứ
# Finding translation for tuần nữa
# No translations found for tuần nữa
# Finding translation for tuông trong
# No translations found for tuông trong
# Finding translation for tuyệt mỹ
# No translations found for tuyệt mỹ
# Finding translation for tuy rằng
# Finding translation for trực của
# No translations found for trực của
# Finding translation for trữ trong
# No translations found for trữ trong
# Finding translation for trừ các
# No translations found for trừ các
# Finding translation for trụ cột
# Finding translation for trỡ thành
# No translations found for trỡ thành
# Finding translation for trọng thông
# No translations found for trọng thông
# Finding translation for trọng quyết
# No translations found for trọng quyết
# Finding translation for trọng dụng
# Finding translation for trị đau
# No translations found for trị đau
# Finding translation for trị thặng
# No translations found for trị thặng
# Finding translation for trị nước
# No translations found for trị nước
# Finding translation for trị như
# No translations found for trị như
# Finding translation for trị hợp
# No translations found for trị hợp
# Finding translation for trị cảm
# No translations found for trị cảm
# Finding translation for trị con
# No translations found for trị con
# Finding translation for trắng đen
# No translations found for trắng đen
# Finding translation for trắng như
# No translations found for trắng như
# Finding translation for trận hòa
# No translations found for trận hòa
# Finding translation for trận cầu
# No translations found for trận cầu
# Finding translation for trận chung
# No translations found for trận chung
# Finding translation for trải rộng
# No translations found for trải rộng
# Finding translation for trả sau
# No translations found for trả sau
# Finding translation for trạng thiếu
# No translations found for trạng thiếu
# Finding translation for trạm kiểm
# No translations found for trạm kiểm
# Finding translation for trường xung
# No translations found for trường xung
# Finding translation for trường vàng
# No translations found for trường vàng
# Finding translation for trường hiện
# No translations found for trường hiện
# Finding translation for trước ống
# No translations found for trước ống
# Finding translation for trước đám
# No translations found for trước đám
# Finding translation for trước mọi
# No translations found for trước mọi
# Finding translation for trưa ngày
# No translations found for trưa ngày
# Finding translation for trùng trùng
# No translations found for trùng trùng
# Finding translation for trò như
# No translations found for trò như
# Finding translation for trò cười
# No translations found for trò cười
# Finding translation for trích một
# No translations found for trích một
# Finding translation for trí với
# No translations found for trí với
# Finding translation for trìu mến
# Finding translation for trình đặc
# No translations found for trình đặc
# Finding translation for trình đấu
# No translations found for trình đấu
# Finding translation for trình xử
# No translations found for trình xử
# Finding translation for trình với
# No translations found for trình với
# Finding translation for trình viên
# No translations found for trình viên
# Finding translation for trình thanh
# No translations found for trình thanh
# Finding translation for trình không
# No translations found for trình không
# Finding translation for trình cải
# No translations found for trình cải
# Finding translation for trình quốc
# No translations found for trình quốc
# Finding translation for trên lửa
# No translations found for trên lửa
# Finding translation for trên lưng
# No translations found for trên lưng
# Finding translation for trên diện
# No translations found for trên diện
# Finding translation for trên cánh
# No translations found for trên cánh
# Finding translation for trên bầu
# No translations found for trên bầu
# Finding translation for tránh gây
# No translations found for tránh gây
# Finding translation for trào đòi
# No translations found for trào đòi
# Finding translation for trào chống
# No translations found for trào chống
# Finding translation for truyện của
# No translations found for truyện của
# Finding translation for truyền về
# No translations found for truyền về
# Finding translation for truyền nhiễm
# Finding translation for truyền dữ
# No translations found for truyền dữ
# Finding translation for truyền dạy
# No translations found for truyền dạy
# Finding translation for trong đợt
# No translations found for trong đợt
# Finding translation for trong đồn
# No translations found for trong đồn
# Finding translation for trong xứ
# Finding translation for trong vũ
# No translations found for trong vũ
# Finding translation for trong vô
# No translations found for trong vô
# Finding translation for trong tôn
# No translations found for trong tôn
# Finding translation for trong tu
# No translations found for trong tu
# Finding translation for trong trong
# No translations found for trong trong
# Finding translation for trong top
# No translations found for trong top
# Finding translation for trong tai
# No translations found for trong tai
# Finding translation for trong quý
# No translations found for trong quý
# Finding translation for trong qua
# No translations found for trong qua
# Finding translation for trong nha
# No translations found for trong nha
# Finding translation for trong miền
# Finding translation for trong hầu
# No translations found for trong hầu
# Finding translation for trong hành
# No translations found for trong hành
# Finding translation for trong hoạt
# No translations found for trong hoạt
# Finding translation for trong cỏ
# No translations found for trong cỏ
# Finding translation for trong chai
# No translations found for trong chai
# Finding translation for tro lai
# No translations found for tro lai
# Finding translation for triệt sản
# No translations found for triệt sản
# Finding translation for triển như
# No translations found for triển như
# Finding translation for trinh thám
# No translations found for trinh thám
# Finding translation for tranh ở
# No translations found for tranh ở
# Finding translation for thống ngân
# No translations found for thống ngân
# Finding translation for thống bush
# No translations found for thống bush
# Finding translation for thị hóa
# No translations found for thị hóa
# Finding translation for thị hiện
# No translations found for thị hiện
# Finding translation for thể đó
# No translations found for thể đó
# Finding translation for thể uống
# No translations found for thể uống
# Finding translation for thể tận
# No translations found for thể tận
# Finding translation for thể tải
# No translations found for thể tải
# Finding translation for thể tiến
# No translations found for thể tiến
# Finding translation for thể tiêu
# No translations found for thể tiêu
# Finding translation for thể tiên
# No translations found for thể tiên
# Finding translation for thể sửa
# No translations found for thể sửa
# Finding translation for thể sánh
# No translations found for thể sánh
# Finding translation for thể quan
# No translations found for thể quan
# Finding translation for thể phòng
# No translations found for thể phòng
# Finding translation for thể nó
# No translations found for thể nó
# Finding translation for thể hỏi
# No translations found for thể hỏi
# Finding translation for thể diễn
# No translations found for thể diễn
# Finding translation for thể cứ
# No translations found for thể cứ
# Finding translation for thể cầu
# Finding translation for thể cùng
# No translations found for thể cùng
# Finding translation for thế vào
# No translations found for thế vào
# Finding translation for thế những
# No translations found for thế những
# Finding translation for thế khi
# No translations found for thế khi
# Finding translation for thế còn
# No translations found for thế còn
# Finding translation for thế chỉ
# No translations found for thế chỉ
# Finding translation for thẻ tín
# No translations found for thẻ tín
# Finding translation for thẳng ở
# No translations found for thẳng ở
# Finding translation for thẳng thừng
# Finding translation for thắng thế
# Finding translation for thật đúng
# No translations found for thật đúng
# Finding translation for thật này
# No translations found for thật này
# Finding translation for thầy không
# No translations found for thầy không
# Finding translation for thần bất
# No translations found for thần bất
# Finding translation for thấy đất
# No translations found for thấy đất
# Finding translation for thấy ý
# No translations found for thấy ý
# Finding translation for thấy vậy
# No translations found for thấy vậy
# Finding translation for thấy vui
# No translations found for thấy vui
# Finding translation for thấy tên
# No translations found for thấy tên
# Finding translation for thấy thoải
# No translations found for thấy thoải
# Finding translation for thấy phần
# No translations found for thấy phần
# Finding translation for thấy mà
# No translations found for thấy mà
# Finding translation for thấy cảnh
# No translations found for thấy cảnh
# Finding translation for thấy cũng
# No translations found for thấy cũng
# Finding translation for thấy chán
# No translations found for thấy chán
# Finding translation for thấy chiếc
# No translations found for thấy chiếc
# Finding translation for thấy bác
# No translations found for thấy bác
# Finding translation for thất thường
# Finding translation for thấp của
# No translations found for thấp của
# Finding translation for thấm thía
# Finding translation for thượng và
# No translations found for thượng và
# Finding translation for thượng phẩm
# Finding translation for thường để
# No translations found for thường để
# Finding translation for thường xảy
# No translations found for thường xảy
# Finding translation for thường những
# No translations found for thường những
# Finding translation for thường làm
# No translations found for thường làm
# Finding translation for thước và
# No translations found for thước và
# Finding translation for thương như
# No translations found for thương như
# Finding translation for thương binh
# No translations found for thương binh
# Finding translation for thư tuyệt
# No translations found for thư tuyệt
# Finding translation for thư là
# No translations found for thư là
# Finding translation for thư có
# No translations found for thư có
# Finding translation for thơ mà
# No translations found for thơ mà
# Finding translation for thơ hay
# No translations found for thơ hay
# Finding translation for thăm anh
# No translations found for thăm anh
# Finding translation for thúc tại
# Finding translation for quả học
# Finding translation for quê mùa
# Finding translation for quê mình
# No translations found for quê mình
# Finding translation for quân y
# Finding translation for quân mỹ
# No translations found for quân mỹ
# Finding translation for quán bar
# No translations found for quán bar
# Finding translation for quái gì
# No translations found for quái gì
# Finding translation for quá quen
# No translations found for quá quen
# Finding translation for quá nặng
# Finding translation for quá không
# No translations found for quá không
# Finding translation for quyền đối
# No translations found for quyền đối
# Finding translation for quyền quyết
# No translations found for quyền quyết
# Finding translation for quyền khiếu
# No translations found for quyền khiếu
# Finding translation for quyền hay
# No translations found for quyền hay
# Finding translation for quyền chủ
# No translations found for quyền chủ
# Finding translation for quyền bình
# No translations found for quyền bình
# Finding translation for quyền sài
# No translations found for quyền sài
# Finding translation for quen làm
# No translations found for quen làm
# Finding translation for quanh các
# No translations found for quanh các
# Finding translation for quan điều
# No translations found for quan điều
# Finding translation for quan quyền
# No translations found for quan quyền
# Finding translation for quan hơn
# No translations found for quan hơn
# Finding translation for quan chính
# No translations found for quan chính
# Finding translation for quan báo
# No translations found for quan báo
# Finding translation for qua với
# No translations found for qua với
# Finding translation for qua trên
# No translations found for qua trên
# Finding translation for qua rất
# No translations found for qua rất
# Finding translation for qua năm
# No translations found for qua năm
# Finding translation for qua nghị
# No translations found for qua nghị
# Finding translation for qua kinh
# No translations found for qua kinh
# Finding translation for qua hay
# No translations found for qua hay
# Finding translation for qua cơn
# No translations found for qua cơn
# Finding translation for qua công
# No translations found for qua công
# Finding translation for qua câu
# No translations found for qua câu
# Finding translation for qua cái
# No translations found for qua cái
# Finding translation for qua chỗ
# No translations found for qua chỗ
# Finding translation for qua bản
# No translations found for qua bản
# Finding translation for planning ideas
# No translations found for planning ideas
# Finding translation for pin nhiên
# No translations found for pin nhiên
# Finding translation for phức hợp
# Finding translation for phủ mới
# No translations found for phủ mới
# Finding translation for phủ thái
# No translations found for phủ thái
# Finding translation for phủ pháp
# No translations found for phủ pháp
# Finding translation for phủ lào
# No translations found for phủ lào
# Finding translation for phục sự
# No translations found for phục sự
# Finding translation for phục cho
# No translations found for phục cho
# Finding translation for phố đã
# No translations found for phố đã
# Finding translation for phố trong
# No translations found for phố trong
# Finding translation for phố san
# No translations found for phố san
# Finding translation for phố ninh
# No translations found for phố ninh
# Finding translation for phận này
# No translations found for phận này
# Finding translation for phẩm giàu
# No translations found for phẩm giàu
# Finding translation for phần tạo
# No translations found for phần tạo
# Finding translation for phần tham
# No translations found for phần tham
# Finding translation for phần nhiều
# Finding translation for phải đổi
# No translations found for phải đổi
# Finding translation for phải đảm
# No translations found for phải đảm
# Finding translation for phải đơn
# No translations found for phải đơn
# Finding translation for phải xây
# No translations found for phải xây
# Finding translation for phải xác
# No translations found for phải xác
# Finding translation for phải tiêu
# No translations found for phải tiêu
# Finding translation for phải thật
# No translations found for phải thật
# Finding translation for phải tham
# No translations found for phải tham
# Finding translation for phải sợ
# No translations found for phải sợ
# Finding translation for phải phụ
# No translations found for phải phụ
# Finding translation for phải phân
# No translations found for phải phân
# No translations found for nơi họ
# Finding translation for nơi tđ
# No translations found for nơi tđ
# Finding translation for năng thông
# Finding translation for năng khác
# No translations found for năng khác
# Finding translation for năm đến
# No translations found for năm đến
# Finding translation for năm văn
# No translations found for năm văn
# Finding translation for năm tôi
# No translations found for năm tôi
# Finding translation for năm nhưng
# No translations found for năm nhưng
# Finding translation for năm như
# No translations found for năm như
# Finding translation for năm hoạt
# No translations found for năm hoạt
# Finding translation for năm cầm
# No translations found for năm cầm
# Finding translation for nông cạn
# Finding translation for nôn nóng
# Finding translation for nói từ
# No translations found for nói từ
# Finding translation for nói cái
# No translations found for nói cái
# Finding translation for nói chúng
# No translations found for nói chúng
# Finding translation for nói bằng
# No translations found for nói bằng
# Finding translation for nó đến
# No translations found for nó đến
# Finding translation for nó với
# No translations found for nó với
# Finding translation for nó ko
# No translations found for nó ko
# Finding translation for nó chính
# No translations found for nó chính
# Finding translation for nêu ở
# No translations found for nêu ở
# Finding translation for nên đề
# ...
# No translations found for minh giang
# Finding translation for minh chi
# No translations found for minh chi
# Finding translation for mai vàng
# No translations found for mai vàng
# Finding translation for lệnh quân
# No translations found for lệnh quân
# Finding translation for lễ phục
# Finding translation for lượng thuỷ
# No translations found for lượng thuỷ
# Finding translation for lý thường
# No translations found for lý thường
# Finding translation for lúc mới
# No translations found for lúc mới
# Finding translation for lê ngọc
# No translations found for lê ngọc
# Finding translation for lão tử
# No translations found for lão tử
# Finding translation for luật bản
# No translations found for luật bản
# Finding translation for li na
# No translations found for li na
# Finding translation for le chien
# No translations found for le chien
# Finding translation for latvia lithuania
# No translations found for latvia lithuania
# Finding translation for llđb langvei
# No translations found for llđb langvei
# Finding translation for khánh hội
# No translations found for khánh hội
# Finding translation for khánh chi
# No translations found for khánh chi
# Finding translation for khám túi
# No translations found for khám túi
# Finding translation for keangnam hanoi
# No translations found for keangnam hanoi
# Finding translation for karl marx
# No translations found for karl marx
# Finding translation for jong suk
# No translations found for jong suk
# Finding translation for jimmii nguyễn
# No translations found for jimmii nguyễn
# Finding translation for internet và
# No translations found for internet và
# Finding translation for hàng hải
# Finding translation for hà đông
# No translations found for hà đông
# Finding translation for huỳnh thị
# No translations found for huỳnh thị
# Finding translation for huỳnh mỹ
# No translations found for huỳnh mỹ
# Finding translation for huyên chương
# No translations found for huyên chương
# Finding translation for huy cận
# No translations found for huy cận
# Finding translation for hoàng phủ
# No translations found for hoàng phủ
# Finding translation for hoàng ngọc
# No translations found for hoàng ngọc
# Finding translation for hoàng anh
# Finding translation for hoa đông
# No translations found for hoa đông
# Finding translation for ha jong
# No translations found for ha jong
# Finding translation for gửi lúc
# No translations found for gửi lúc
# Finding translation for gò công
# No translations found for gò công
# Finding translation for got talent
# No translations found for got talent
# Finding translation for gopnhat est
# No translations found for gopnhat est
# Finding translation for giải mã
# Finding translation for giêng năm
# No translations found for giêng năm
# Finding translation for giêsu sinh
# No translations found for giêsu sinh
# Finding translation for giáng cũng
# No translations found for giáng cũng
# Finding translation for giá thực
# Finding translation for giá cảeva
# No translations found for reuters
# Finding translation for resort
# No translations found for resort
# Finding translation for rap
# No translations found for rap
# Finding translation for rally
# No translations found for rally
# Finding translation for posted
# No translations found for posted
# Finding translation for play
# No translations found for play
# Finding translation for pirlo
# No translations found for pirlo
# Finding translation for perochan
# No translations found for perochan
# Finding translation for party
# No translations found for party
# Finding translation for pmu
# No translations found for pmu
# Finding translation for oregon
# No translations found for oregon
# Finding translation for onetv
# No translations found for onetv
# Finding translation for novak
# No translations found for novak
# Finding translation for nole
# No translations found for nole
# Finding translation for nibelheim
# No translations found for nibelheim
# Finding translation for nato
# No translations found for nato
# Finding translation for mẽo
# No translations found for mẽo
# Finding translation for missouri
# No translations found for missouri
# Finding translation for maya
# No translations found for maya
# Finding translation for mario
# No translations found for mario
# Finding translation for lumia
# No translations found for lumia
# Finding translation for lancome
# No translations found for lancome
# Finding translation for khmer
# No translations found for khmer
# Finding translation for kemal
# No translations found for kemal
# Finding translation for jimmii
# No translations found for jimmii
# Finding translation for jessica
# No translations found for jessica
# Finding translation for jennifer
# No translations found for jennifer
# Finding translation for jack
# No translations found for jack
# Finding translation for institute
# No translations found for institute
# Finding translation for imf
# No translations found for imf
# Finding translation for hitech
# No translations found for hitech
# Finding translation for hawaii
# No translations found for hawaii
# Finding translation for hae
# No translations found for hae
# Finding translation for hkust
# No translations found for hkust
# Finding translation for hagl
# No translations found for hagl
# Finding translation for greg
# No translations found for greg
# Finding translation for gorbatchev
# No translations found for gorbatchev
# Finding translation for gilbert
# No translations found for gilbert
# Finding translation for friends
# No translations found for friends
# Finding translation for french
# No translations found for french
# Finding translation for first
# No translations found for first
# Finding translation for ericsson
# No translations found for ericsson
# Finding translation for edward
# No translations found for edward
# Finding translation for earth
# No translations found for earth
# Finding translation for ebook
# No translations found for ebook
# Finding translation for easy
# No translations found for easy
# Finding translation for design
# No translations found for design
# Finding translation for default
# No translations found for default
# Finding translation for dance
# No translations found for dance
# Finding translation for côte
# No translations found for côte
# Finding translation for corel
# No translations found for corel
# Finding translation for contostavlos
# No translations found for contostavlos
# Finding translation for command
# No translations found for command
# Finding translation for college
# No translations found for college
# Finding translation for civic
# No translations found for civic
# Finding translation for brisbane
# No translations found for brisbane
# Finding translation for braxil
# No translations found for braxil
# Finding translation for boeing
# No translations found for boeing
# Finding translation for bhaya
# No translations found for bhaya
# Finding translation for benavidez
# No translations found for benavidez
# Finding translation for arthur
# No translations found for arthur
# Finding translation for angelina
# No translations found for angelina
# Finding translation for andrew
# No translations found for andrew
# Finding translation for alzheimer
# No translations found for alzheimer
# Finding translation for albert
# No translations found for albert
# Finding translation for aceh
# No translations found for aceh
# Finding translation for access
# No translations found for access

# %%
#saving the batch
with open('/content/gdrive/My Drive/Colab Notebooks/Dictionary Project/soha VI-EN ver 4 batch {}.json'.format(index), 'w') as outfile:
  json.dump(dictionary, outfile)
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 8525.342663288116 seconds ---

# %%
len(dictionary)
# Out:
# 4156

# %%
findTranslation("lm")
# Out:
# Finding translation for lm
# No translations found for lm
# 'N/A'
