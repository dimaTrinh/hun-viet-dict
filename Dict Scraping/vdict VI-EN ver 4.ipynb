# %%
import urllib.request 
from urllib.parse import quote 
from bs4 import BeautifulSoup
import json
import re
import time

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#Source: https://codezup.com/web-scraping-word-meaning-dictionary-python-beautifulsoup/

# %%
#getting the already scraped dict
import json
with open('/content/gdrive/My Drive/Colab Notebooks/Dictionary Project/vdict VI-EN ver 3.json') as json_file:
     currDict = json.load(json_file)

# %%
#reading the word list produced by an crubadan:
with open('/content/gdrive/My Drive/Colab Notebooks/Dictionary Project/anCruVietList') as infile:
  wordsData = infile.readlines()

# %%
wordsData[0:5]
# Out:
# ['11362 việt\n', '6895 việt nam\n', '5210 có thể\n', '5153 lý\n', '4515 i\n']

# %%
#generate a list of words from the word list produced by an crubadan
def generateWordList(): 
  temp = []
  for word in wordsData:
    parts = word.strip().split(" ")
    #ignore the frequency
    temp.append(" ".join(parts[1:]))
  return temp

# %%
wordList = generateWordList()
len(wordList)
# Out:
# 34275

# %%
#break the word list into batches of 
batches = [wordList[i:i + 10000] for i in range(0, len(wordList), 10000)]

# %%
for batch in batches:
  print(len(batch))
# Out:
# 10000
# 10000
# 10000
# 4275

# %%
#The link format for vdict Viet-Eng is: https://vdict.com/m%E1%BB%99t,2,0,0.html

# %%
#Converting IRI to ASCII:
#https://stackoverflow.com/questions/4389572/how-to-fetch-a-non-ascii-url-with-python-urlopen

# %%
def findTranslation(word):
    print("Finding translation for " + word)
    url = "https://vdict.com/" + quote(word) + ",2,0,0.html" #resolving the IRI issue
    
    try: #make sure the link is working
        source = urllib.request.urlopen(url)
    except:
        print("Link broken for " + word)
        return "N/A"
    
    soup = BeautifulSoup(source, 'lxml')

    #make sure the word is in the dictionary
    if (soup.find("div", id = 'result-contents') is None):
        print("Not in the dictionary " + word)
        return "N/A"
    
    translations = {}

    #Getting the first POS tag
    firstPosTag = soup.find("div", class_ = 'phanloai')
    
    if (firstPosTag is None): #empty translation page
        print("Empty translation page " + word)
        return "N/A"
    
    curPos = firstPosTag.string.split(' \xa0')[0]

    #first translation is a tag away from the first POS tag
    curTag = firstPosTag.next_sibling.next_sibling

    #storing the number of translations a word has
    numTrans = 1

    #continue while we are either in a POS tag or a translation tag
    while (curTag != '\n'): 
        if (curTag.attrs["class"] == ["list1"]): #a translation
            temp = {} #temp dict to store each translation of a word

            #getting the raw translation
            if (curTag.find('b').string is not None): #empty translation cell
                temp['translation'] = re.split('[,;]', curTag.find('b').string)
                temp['POS'] = curPos

                #retrieving the examples of each of the translations
                try:
                    examples = curTag.findAll("ul", class_= "list2")
                    temp2 = {} #another dict to store each examples of a translation

                    numExamples = len(list(examples))
                    temp2['nums'] = numExamples

                    for j in range(0, numExamples):
                        temp2['context ' + str(j+1)] = examples[j].find(class_ = "example-original").string

                        #retrieving the usage of each examples
                        try: 
                            tempString = str(examples[j].find("li")) #extracting the usage
                            temp2['usage ' + str(j+1)] = str(examples[j].find("li").contents[-1])
                        except:
                            temp2['usage ' + str(j+1)] = "N/A"

                    temp['examples'] = temp2
                except:
                    temp['examples'] = "N/A"

                translations[numTrans] = temp #adding the translation to the dictionary

                numTrans += 1
            curTag = curTag.next_sibling                
        else: #a tag
            curPos = curTag.string.split(' \xa0')[0]
            curTag = curTag.next_sibling

    #storing the number of translations
    translations['nums'] = numTrans - 1
    return translations

# %%
findTranslation("đòn bẩy")
# Out:
# Finding translation for đòn bẩy
# {1: {'POS': '',
#   'examples': {'context 1': 'Dùng đòn bẩy để bẩy hòn đá',
#    'nums': 1,
#    'usage 1': 'To lift a stone with a lever'},
#   'translation': ['Lever']},
#  'nums': 1}

# %%
url = "https://vdict.com/" + quote("có") + ",2,0,0.html" #resolving the IRI issue

try:
    source = urllib.request.urlopen(url)
except:
    print( "Link broken")
soup = BeautifulSoup(source, 'lxml')

# %%
soup.find("div", class_ = 'phanloai').next_sibling.next_sibling.next_sibling.next_sibling
# Out:
# '\n'

# %%
from google.colab import files
start_time = time.time()

index = 3
batch = batches[index] 

#for (index, batch) in enumerate(batches):
dictionary = {}

#making the dictionary for each batch
for word in batch:

    #if the word is not in already in the dict, find the translation
    if word not in currDict:
      dictionary[word] = findTranslation(word)
      time.sleep(1) #wait for 1 sec between each query
# Out:
# Streaming output truncated to the last 5000 lines.
# Not in the dictionary tình bằng
# Finding translation for tìm lời
# Not in the dictionary tìm lời
# Finding translation for tìm câu
# Not in the dictionary tìm câu
# Finding translation for tên tội
# Not in the dictionary tên tội
# Finding translation for tên gì
# Not in the dictionary tên gì
# Finding translation for tên cán
# Not in the dictionary tên cán
# Finding translation for tên bộ
# Not in the dictionary tên bộ
# Finding translation for tâm với
# Not in the dictionary tâm với
# Finding translation for tâm sửa
# Not in the dictionary tâm sửa
# Finding translation for tâm khác
# Not in the dictionary tâm khác
# Finding translation for tâm bảo
# Not in the dictionary tâm bảo
# Finding translation for tái phát
# Finding translation for tác đầu
# Not in the dictionary tác đầu
# Finding translation for tác quản
# Not in the dictionary tác quản
# Finding translation for tác phát
# Not in the dictionary tác phát
# Finding translation for tác nhạc
# Not in the dictionary tác nhạc
# Finding translation for tác gia
# Not in the dictionary tác gia
# Finding translation for tàu điện
# Not in the dictionary tàu điện
# Finding translation for tàu hải
# Not in the dictionary tàu hải
# Finding translation for tào lao
# Finding translation for tàn khốc
# Finding translation for tài nhiều
# Not in the dictionary tài nhiều
# Finding translation for ty đã
# Not in the dictionary ty đã
# Finding translation for ty sản
# Not in the dictionary ty sản
# Finding translation for tuỳ theo
# Not in the dictionary tuỳ theo
# Finding translation for tuần để
# Not in the dictionary tuần để
# Finding translation for tuần thứ
# Not in the dictionary tuần thứ
# Finding translation for tuần nữa
# Not in the dictionary tuần nữa
# Finding translation for tuông trong
# Not in the dictionary tuông trong
# Finding translation for tuyệt mỹ
# Not in the dictionary tuyệt mỹ
# Finding translation for tuy rằng
# Finding translation for trực của
# Not in the dictionary trực của
# Finding translation for trữ trong
# Not in the dictionary trữ trong
# Finding translation for trừ các
# Not in the dictionary trừ các
# Finding translation for trụ cột
# Not in the dictionary trụ cột
# Finding translation for trỡ thành
# Not in the dictionary trỡ thành
# Finding translation for trọng thông
# Not in the dictionary trọng thông
# Finding translation for trọng quyết
# Not in the dictionary trọng quyết
# Finding translation for trọng dụng
# Not in the dictionary trọng dụng
# Finding translation for trị đau
# Not in the dictionary trị đau
# Finding translation for trị thặng
# Not in the dictionary trị thặng
# Finding translation for trị nước
# Not in the dictionary trị nước
# Finding translation for trị như
# Not in the dictionary trị như
# Finding translation for trị hợp
# Not in the dictionary trị hợp
# Finding translation for trị cảm
# Not in the dictionary trị cảm
# Finding translation for trị con
# Not in the dictionary trị con
# Finding translation for trắng đen
# Not in the dictionary trắng đen
# Finding translation for trắng như
# Not in the dictionary trắng như
# Finding translation for trận hòa
# Not in the dictionary trận hòa
# Finding translation for trận cầu
# Not in the dictionary trận cầu
# Finding translation for trận chung
# Not in the dictionary trận chung
# Finding translation for trải rộng
# Not in the dictionary trải rộng
# Finding translation for trả sau
# Not in the dictionary trả sau
# Finding translation for trạng thiếu
# Not in the dictionary trạng thiếu
# Finding translation for trạm kiểm
# Not in the dictionary trạm kiểm
# Finding translation for trường xung
# Not in the dictionary trường xung
# Finding translation for trường vàng
# Not in the dictionary trường vàng
# Finding translation for trường hiện
# Not in the dictionary trường hiện
# Finding translation for trước ống
# Not in the dictionary trước ống
# Finding translation for trước đám
# Not in the dictionary trước đám
# Finding translation for trước mọi
# Not in the dictionary trước mọi
# Finding translation for trưa ngày
# Not in the dictionary trưa ngày
# Finding translation for trùng trùng
# Not in the dictionary trùng trùng
# Finding translation for trò như
# Not in the dictionary trò như
# Finding translation for trò cười
# Not in the dictionary trò cười
# Finding translation for trích một
# Not in the dictionary trích một
# Finding translation for trí với
# Not in the dictionary trí với
# Finding translation for trìu mến
# Finding translation for trình đặc
# Not in the dictionary trình đặc
# Finding translation for trình đấu
# Not in the dictionary trình đấu
# Finding translation for trình xử
# Not in the dictionary trình xử
# Finding translation for trình với
# Not in the dictionary trình với
# Finding translation for trình viên
# Not in the dictionary trình viên
# Finding translation for trình thanh
# Not in the dictionary trình thanh
# Finding translation for trình không
# Not in the dictionary trình không
# Finding translation for trình cải
# Not in the dictionary trình cải
# Finding translation for trình quốc
# Not in the dictionary trình quốc
# Finding translation for trên lửa
# Not in the dictionary trên lửa
# Finding translation for trên lưng
# Not in the dictionary trên lưng
# Finding translation for trên diện
# Not in the dictionary trên diện
# Finding translation for trên cánh
# Not in the dictionary trên cánh
# Finding translation for trên bầu
# Not in the dictionary trên bầu
# Finding translation for tránh gây
# Not in the dictionary tránh gây
# Finding translation for trào đòi
# Not in the dictionary trào đòi
# Finding translation for trào chống
# Not in the dictionary trào chống
# Finding translation for truyện của
# Not in the dictionary truyện của
# Finding translation for truyền về
# Not in the dictionary truyền về
# Finding translation for truyền nhiễm
# Not in the dictionary truyền nhiễm
# Finding translation for truyền dữ
# Not in the dictionary truyền dữ
# Finding translation for truyền dạy
# Not in the dictionary truyền dạy
# Finding translation for trong đợt
# Not in the dictionary trong đợt
# Finding translation for trong đồn
# Not in the dictionary trong đồn
# Finding translation for trong xứ
# Not in the dictionary trong xứ
# Finding translation for trong vũ
# Not in the dictionary trong vũ
# Finding translation for trong vô
# Not in the dictionary trong vô
# Finding translation for trong tôn
# Not in the dictionary trong tôn
# Finding translation for trong tu
# Not in the dictionary trong tu
# Finding translation for trong trong
# Not in the dictionary trong trong
# Finding translation for trong top
# Not in the dictionary trong top
# Finding translation for trong tai
# Not in the dictionary trong tai
# Finding translation for trong quý
# Not in the dictionary trong quý
# Finding translation for trong qua
# Not in the dictionary trong qua
# Finding translation for trong nha
# Not in the dictionary trong nha
# Finding translation for trong miền
# Not in the dictionary trong miền
# Finding translation for trong hầu
# Not in the dictionary trong hầu
# Finding translation for trong hành
# Not in the dictionary trong hành
# Finding translation for trong hoạt
# Not in the dictionary trong hoạt
# Finding translation for trong cỏ
# Not in the dictionary trong cỏ
# Finding translation for trong chai
# Not in the dictionary trong chai
# Finding translation for tro lai
# Not in the dictionary tro lai
# Finding translation for triệt sản
# Not in the dictionary triệt sản
# Finding translation for triển như
# Not in the dictionary triển như
# Finding translation for trinh thám
# Not in the dictionary trinh thám
# Finding translation for tranh ở
# Not in the dictionary tranh ở
# Finding translation for tranh ôn
# Not in the dictionary tranh ôn
# Finding translation for tranh vì
# Not in the dictionary tranh vì
# Finding translation for tranh tâm
# Not in the dictionary tranh tâm
# Finding translation for tranh trên
# Not in the dictionary tranh trên
# Finding translation for tranh sinh
# Not in the dictionary tranh sinh
# Finding translation for tranh luan
# Not in the dictionary tranh luan
# Finding translation for tranh có
# Not in the dictionary tranh có
# Finding translation for trang nào
# Not in the dictionary trang nào
# Finding translation for trang công
# Not in the dictionary trang công
# Finding translation for trang hitech
# Not in the dictionary trang hitech
# Finding translation for trai mới
# Not in the dictionary trai mới
# Finding translation for tra của
# Not in the dictionary tra của
# Finding translation for tra các
# Not in the dictionary tra các
# Finding translation for toán nimbus
# Not in the dictionary toán nimbus
# Finding translation for toàn với
# Not in the dictionary toàn với
# Finding translation for toàn tuyệt
# Not in the dictionary toàn tuyệt
# Finding translation for toà soạn
# Not in the dictionary toà soạn
# Finding translation for tour du
# Not in the dictionary tour du
# Finding translation for toi di
# Not in the dictionary toi di
# Finding translation for tiệt trùng
# Finding translation for tiện của
# Not in the dictionary tiện của
# Finding translation for tiệc tùng
# Not in the dictionary tiệc tùng
# Finding translation for tiểu liên
# Not in the dictionary tiểu liên
# Finding translation for tiền được
# Not in the dictionary tiền được
# Finding translation for tiền nhân
# Finding translation for tiền mới
# Not in the dictionary tiền mới
# Finding translation for tiền bán
# Not in the dictionary tiền bán
# Finding translation for tiếp trong
# Not in the dictionary tiếp trong
# Finding translation for tiếng để
# Not in the dictionary tiếng để
# Finding translation for tiếng đã
# Not in the dictionary tiếng đã
# Finding translation for tiếng từ
# Not in the dictionary tiếng từ
# Finding translation for tiếng thì
# Not in the dictionary tiếng thì
# Finding translation for tiếng sau
# Not in the dictionary tiếng sau
# Finding translation for tiếng người
# Not in the dictionary tiếng người
# Finding translation for tiếng cho
# Not in the dictionary tiếng cho
# Finding translation for tiêu trên
# Not in the dictionary tiêu trên
# Finding translation for tiên phải
# Not in the dictionary tiên phải
# Finding translation for tinh voi
# Not in the dictionary tinh voi
# Finding translation for tin ông
# Not in the dictionary tin ông
# Finding translation for tin vip
# Not in the dictionary tin vip
# Finding translation for tin nói
# Not in the dictionary tin nói
# Finding translation for tin hay
# Not in the dictionary tin hay
# Finding translation for tin còn
# Not in the dictionary tin còn
# Finding translation for tieu chi
# Not in the dictionary tieu chi
# Finding translation for thực trong
# Not in the dictionary thực trong
# Finding translation for thực lòng
# Not in the dictionary thực lòng
# Finding translation for thử lại
# Not in the dictionary thử lại
# Finding translation for thừa sức
# Not in the dictionary thừa sức
# Finding translation for thừa hành
# Finding translation for thức đấu
# Not in the dictionary thức đấu
# Finding translation for thức trẻ
# Not in the dictionary thức trẻ
# Finding translation for thức thì
# Not in the dictionary thức thì
# Finding translation for thức những
# Not in the dictionary thức những
# Finding translation for thức làm
# Not in the dictionary thức làm
# Finding translation for thức giấc
# Not in the dictionary thức giấc
# Finding translation for thức cho
# Not in the dictionary thức cho
# Finding translation for thứ thiệt
# Not in the dictionary thứ thiệt
# Finding translation for thứ không
# Not in the dictionary thứ không
# Finding translation for thứ khác
# Not in the dictionary thứ khác
# Finding translation for thủ được
# Not in the dictionary thủ được
# Finding translation for thời đã
# Not in the dictionary thời đã
# Finding translation for thời buổi
# Not in the dictionary thời buổi
# Finding translation for thời chúa
# Not in the dictionary thời chúa
# Finding translation for thờ để
# Not in the dictionary thờ để
# Finding translation for thống ngân
# Not in the dictionary thống ngân
# Finding translation for thống bush
# Not in the dictionary thống bush
# Finding translation for thị hóa
# Not in the dictionary thị hóa
# Finding translation for thị hiện
# Not in the dictionary thị hiện
# Finding translation for thể đó
# Not in the dictionary thể đó
# Finding translation for thể uống
# Not in the dictionary thể uống
# Finding translation for thể tận
# Not in the dictionary thể tận
# Finding translation for thể tải
# Not in the dictionary thể tải
# Finding translation for thể tiến
# Not in the dictionary thể tiến
# Finding translation for thể tiêu
# Not in the dictionary thể tiêu
# Finding translation for thể tiên
# Not in the dictionary thể tiên
# Finding translation for thể sửa
# Not in the dictionary thể sửa
# Finding translation for thể sánh
# Not in the dictionary thể sánh
# Finding translation for thể quan
# Not in the dictionary thể quan
# Finding translation for thể phòng
# Not in the dictionary thể phòng
# Finding translation for thể nó
# Not in the dictionary thể nó
# Finding translation for thể hỏi
# Not in the dictionary thể hỏi
# Finding translation for thể diễn
# Not in the dictionary thể diễn
# Finding translation for thể cứ
# Not in the dictionary thể cứ
# Finding translation for thể cầu
# Not in the dictionary thể cầu
# Finding translation for thể cùng
# Not in the dictionary thể cùng
# Finding translation for thế vào
# Not in the dictionary thế vào
# Finding translation for thế những
# Not in the dictionary thế những
# Finding translation for thế khi
# Not in the dictionary thế khi
# Finding translation for thế còn
# Not in the dictionary thế còn
# Finding translation for thế chỉ
# Not in the dictionary thế chỉ
# Finding translation for thẻ tín
# Not in the dictionary thẻ tín
# Finding translation for thẳng ở
# Not in the dictionary thẳng ở
# Finding translation for thẳng thừng
# Finding translation for thắng thế
# Finding translation for thật đúng
# Not in the dictionary thật đúng
# Finding translation for thật này
# Not in the dictionary thật này
# Finding translation for thầy không
# Not in the dictionary thầy không
# Finding translation for thần tiên
# Not in the dictionary thần tiên
# Finding translation for thần bất
# Not in the dictionary thần bất
# Finding translation for thấy đất
# Not in the dictionary thấy đất
# Finding translation for thấy ý
# Not in the dictionary thấy ý
# Finding translation for thấy vậy
# Not in the dictionary thấy vậy
# Finding translation for thấy vui
# Not in the dictionary thấy vui
# Finding translation for thấy tên
# Not in the dictionary thấy tên
# Finding translation for thấy thoải
# Not in the dictionary thấy thoải
# Finding translation for thấy phần
# Not in the dictionary thấy phần
# Finding translation for thấy mà
# Not in the dictionary thấy mà
# Finding translation for thấy cảnh
# Not in the dictionary thấy cảnh
# Finding translation for thấy cũng
# Not in the dictionary thấy cũng
# Finding translation for thấy chán
# Not in the dictionary thấy chán
# Finding translation for thấy chiếc
# Not in the dictionary thấy chiếc
# Finding translation for thấy bác
# Not in the dictionary thấy bác
# Finding translation for thất thường
# Finding translation for thấp của
# Not in the dictionary thấp của
# Finding translation for thấm thía
# Finding translation for thượng và
# Not in the dictionary thượng và
# Finding translation for thượng phẩm
# Finding translation for thường để
# Not in the dictionary thường để
# Finding translation for thường xảy
# Not in the dictionary thường xảy
# Finding translation for thường những
# Not in the dictionary thường những
# Finding translation for thường làm
# Not in the dictionary thường làm
# Finding translation for thước và
# Not in the dictionary thước và
# Finding translation for thương như
# Not in the dictionary thương như
# Finding translation for thương binh
# Not in the dictionary thương binh
# Finding translation for thư tuyệt
# Not in the dictionary thư tuyệt
# Finding translation for thư là
# Not in the dictionary thư là
# Finding translation for thư có
# Not in the dictionary thư có
# Finding translation for thơ mà
# Not in the dictionary thơ mà
# Finding translation for thơ hay
# Not in the dictionary thơ hay
# Finding translation for thăm anh
# Not in the dictionary thăm anh
# Finding translation for thúc tại
# Not in the dictionary thúc tại
# Finding translation for thù giai
# Not in the dictionary thù giai
# Finding translation for thù chốn
# Not in the dictionary thù chốn
# Finding translation for thông mà
# Not in the dictionary thông mà
# Finding translation for thông công
# Not in the dictionary thông công
# Finding translation for thông chưa
# Not in the dictionary thông chưa
# Finding translation for thô thiển
# Not in the dictionary thô thiển
# Finding translation for thích cái
# Not in the dictionary thích cái
# Finding translation for thích các
# Not in the dictionary thích các
# Finding translation for thì đồng
# Not in the dictionary thì đồng
# Finding translation for thì để
# Not in the dictionary thì để
# Finding translation for thì tớ
# Not in the dictionary thì tớ
# Finding translation for thì tổng
# Not in the dictionary thì tổng
# Finding translation for thì toàn
# Not in the dictionary thì toàn
# Finding translation for thì thời
# Not in the dictionary thì thời
# Finding translation for thì thiếu
# Not in the dictionary thì thiếu
# Finding translation for thì kết
# Not in the dictionary thì kết
# Finding translation for thì hợp
# Not in the dictionary thì hợp
# Finding translation for thì hiện
# Not in the dictionary thì hiện
# Finding translation for thì bắt
# Not in the dictionary thì bắt
# Finding translation for thì mỹ
# Not in the dictionary thì mỹ
# Finding translation for thêm tin
# Not in the dictionary thêm tin
# Finding translation for thêm thời
# Not in the dictionary thêm thời
# Finding translation for thêm mấy
# Not in the dictionary thêm mấy
# Finding translation for thân đã
# Not in the dictionary thân đã
# Finding translation for thân thuộc
# Finding translation for thân hay
# Not in the dictionary thân hay
# Finding translation for thân cũng
# Not in the dictionary thân cũng
# Finding translation for thánh chiến
# Not in the dictionary thánh chiến
# Finding translation for tháng rồi
# Not in the dictionary tháng rồi
# Finding translation for thám thính
# Finding translation for thách nào
# Not in the dictionary thách nào
# Finding translation for thác loạn
# Not in the dictionary thác loạn
# Finding translation for thành thục
# Not in the dictionary thành thục
# Finding translation for thành kính
# Finding translation for thành cổ
# Not in the dictionary thành cổ
# Finding translation for thành có
# Not in the dictionary thành có
# Finding translation for thành thăng
# Not in the dictionary thành thăng
# Finding translation for thuộc đại
# Not in the dictionary thuộc đại
# Finding translation for thuộc nha
# Not in the dictionary thuộc nha
# Finding translation for thuốc hay
# Not in the dictionary thuốc hay
# Finding translation for thuốc cho
# Not in the dictionary thuốc cho
# Finding translation for thuật mà
# Not in the dictionary thuật mà
# Finding translation for thuê căn
# Not in the dictionary thuê căn
# Finding translation for thua thiệt
# Finding translation for thu âm
# Not in the dictionary thu âm
# Finding translation for thu năm
# Not in the dictionary thu năm
# Finding translation for thoại vợ
# Not in the dictionary thoại vợ
# Finding translation for thoa thuan
# Not in the dictionary thoa thuan
# Finding translation for thiệu đến
# Not in the dictionary thiệu đến
# Finding translation for thiệt là
# Not in the dictionary thiệt là
# Finding translation for thiệp với
# Not in the dictionary thiệp với
# Finding translation for thiện cảm
# Finding translation for thiển ý
# Finding translation for thiếu tư
# Not in the dictionary thiếu tư
# Finding translation for thiếu nước
# Not in the dictionary thiếu nước
# Finding translation for thiếu một
# Not in the dictionary thiếu một
# Finding translation for thiết đến
# Not in the dictionary thiết đến
# Finding translation for thiết kêu
# Not in the dictionary thiết kêu
# Finding translation for thieu cho
# Not in the dictionary thieu cho
# Finding translation for thi ảnh
# Not in the dictionary thi ảnh
# Finding translation for thi để
# Not in the dictionary thi để
# Finding translation for thi van
# Not in the dictionary thi van
# Finding translation for thi môn
# Not in the dictionary thi môn
# Finding translation for thi lam
# Not in the dictionary thi lam
# Finding translation for thi do
# Not in the dictionary thi do
# Finding translation for thi ioe
# Not in the dictionary thi ioe
# Finding translation for theo đề
# Not in the dictionary theo đề
# Finding translation for theo đoàn
# Not in the dictionary theo đoàn
# Finding translation for theo tôn
# Not in the dictionary theo tôn
# Finding translation for theo tinh
# Not in the dictionary theo tinh
# Finding translation for theo người
# Not in the dictionary theo người
# Finding translation for theo hoàn
# Not in the dictionary theo hoàn
# Finding translation for theo giờ
# Not in the dictionary theo giờ
# Finding translation for the thao
# Not in the dictionary the thao
# Finding translation for the nay
# Not in the dictionary the nay
# Finding translation for the he
# Not in the dictionary the he
# Finding translation for thanh cao
# Not in the dictionary thanh cao
# Finding translation for thanh bài
# Not in the dictionary thanh bài
# Finding translation for tham chi
# Not in the dictionary tham chi
# Finding translation for tay ông
# Not in the dictionary tay ông
# Finding translation for tay sở
# Not in the dictionary tay sở
# Finding translation for tay cái
# Not in the dictionary tay cái
# Finding translation for tay anh
# Not in the dictionary tay anh
# Finding translation for tap trung
# Not in the dictionary tap trung
# Finding translation for tam guong
# Not in the dictionary tam guong
# Finding translation for tai và
# Not in the dictionary tai và
# Finding translation for tac dung
# Not in the dictionary tac dung
# Finding translation for ta đây
# Not in the dictionary ta đây
# Finding translation for ta đem
# Not in the dictionary ta đem
# Finding translation for ta vừa
# Not in the dictionary ta vừa
# Finding translation for ta thật
# Not in the dictionary ta thật
# Finding translation for ta thi
# Not in the dictionary ta thi
# Finding translation for ta rút
# Not in the dictionary ta rút
# Finding translation for ta những
# Not in the dictionary ta những
# Finding translation for ta mất
# Not in the dictionary ta mất
# Finding translation for ta lấy
# Not in the dictionary ta lấy
# Finding translation for ta khi
# Not in the dictionary ta khi
# Finding translation for ta giúp
# Not in the dictionary ta giúp
# Finding translation for ta dễ
# Not in the dictionary ta dễ
# Finding translation for sự đang
# Not in the dictionary sự đang
# Finding translation for sự áp
# Not in the dictionary sự áp
# Finding translation for sự vụ
# Not in the dictionary sự vụ
# Finding translation for sự viên
# Not in the dictionary sự viên
# Finding translation for sự trừng
# Not in the dictionary sự trừng
# Finding translation for sự trả
# Not in the dictionary sự trả
# Finding translation for sự lưu
# Not in the dictionary sự lưu
# Finding translation for sự kinh
# Not in the dictionary sự kinh
# Finding translation for sự khủng
# Not in the dictionary sự khủng
# Finding translation for sự gắn
# Not in the dictionary sự gắn
# Finding translation for sự giả
# Not in the dictionary sự giả
# Finding translation for sự cũng
# Not in the dictionary sự cũng
# Finding translation for sự chăm
# Not in the dictionary sự chăm
# Finding translation for sự chuẩn
# Not in the dictionary sự chuẩn
# Finding translation for sự bị
# Not in the dictionary sự bị
# Finding translation for sững sờ
# Finding translation for sửa sai
# Not in the dictionary sửa sai
# Finding translation for sử để
# Not in the dictionary sử để
# Finding translation for sử một
# Not in the dictionary sử một
# Finding translation for sử có
# Not in the dictionary sử có
# Finding translation for sức và
# Not in the dictionary sức và
# Finding translation for sức nặng
# Finding translation for sức mua
# Not in the dictionary sức mua
# Finding translation for sức hút
# Not in the dictionary sức hút
# Finding translation for sức cùng
# Not in the dictionary sức cùng
# Finding translation for sợi nấm
# Not in the dictionary sợi nấm
# Finding translation for sở y
# Not in the dictionary sở y
# Finding translation for sống trẻ
# Not in the dictionary sống trẻ
# Finding translation for sống ra
# Not in the dictionary sống ra
# Finding translation for sống lưu
# Not in the dictionary sống lưu
# Finding translation for sống hòa
# Not in the dictionary sống hòa
# Finding translation for sống cùng
# Not in the dictionary sống cùng
# Finding translation for số từ
# Not in the dictionary số từ
# Finding translation for số tác
# Not in the dictionary số tác
# Finding translation for số thống
# Not in the dictionary số thống
# Finding translation for số thân
# Not in the dictionary số thân
# Finding translation for số sự
# Not in the dictionary số sự
# Finding translation for số phiếu
# Not in the dictionary số phiếu
# Finding translation for số nơi
# Not in the dictionary số nơi
# Finding translation for số nguyên
# Not in the dictionary số nguyên
# Finding translation for số lãnh
# Not in the dictionary số lãnh
# Finding translation for số ba
# Not in the dictionary số ba
# Finding translation for số việt
# Not in the dictionary số việt
# Finding translation for số iq
# Not in the dictionary số iq
# Finding translation for sẽ đứng
# Not in the dictionary sẽ đứng
# Finding translation for sẽ tới
# Not in the dictionary sẽ tới
# Finding translation for sẽ tốt
# Not in the dictionary sẽ tốt
# Finding translation for sẽ tập
# Not in the dictionary sẽ tập
# Finding translation for sẽ thắng
# Not in the dictionary sẽ thắng
# Finding translation for sẽ sử
# Not in the dictionary sẽ sử
# Finding translation for sẽ mua
# Not in the dictionary sẽ mua
# Finding translation for sẽ khởi
# Not in the dictionary sẽ khởi
# Finding translation for sẽ giới
# Not in the dictionary sẽ giới
# Finding translation for sẽ cao
# Not in the dictionary sẽ cao
# Finding translation for sẽ bán
# Not in the dictionary sẽ bán
# Finding translation for sẻ cùng
# Not in the dictionary sẻ cùng
# Finding translation for sẻ cho
# Not in the dictionary sẻ cho
# Finding translation for sẵn một
# Not in the dictionary sẵn một
# Finding translation for sắt máu
# Not in the dictionary sắt máu
# Finding translation for sắt hiện
# Not in the dictionary sắt hiện
# Finding translation for sắt của
# Not in the dictionary sắt của
# Finding translation for sắp được
# Not in the dictionary sắp được
# Finding translation for sắc thể
# Not in the dictionary sắc thể
# Finding translation for sản đang
# Not in the dictionary sản đang
# Finding translation for sản âu
# Not in the dictionary sản âu
# Finding translation for sản vô
# Not in the dictionary sản vô
# Finding translation for sản phụ
# Finding translation for sản mại
# Not in the dictionary sản mại
# Finding translation for sản làm
# Not in the dictionary sản làm
# Finding translation for sản cũng
# Not in the dictionary sản cũng
# Finding translation for sư ngô
# Not in the dictionary sư ngô
# Finding translation for sơ để
# Not in the dictionary sơ để
# Finding translation for sơ đẳng
# Finding translation for sơ và
# Not in the dictionary sơ và
# Finding translation for sơ cá
# Not in the dictionary sơ cá
# Finding translation for sĩ về
# Not in the dictionary sĩ về
# Finding translation for sĩ bị
# Not in the dictionary sĩ bị
# Finding translation for sĩ bùi
# Not in the dictionary sĩ bùi
# Finding translation for súng ống
# Not in the dictionary súng ống
# Finding translation for sông bến
# Not in the dictionary sông bến
# Finding translation for sóng thuyền
# Not in the dictionary sóng thuyền
# Finding translation for sâu máy
# Not in the dictionary sâu máy
# Finding translation for sâu hơn
# Not in the dictionary sâu hơn
# Finding translation for sân vườn
# Not in the dictionary sân vườn
# Finding translation for sánh các
# Not in the dictionary sánh các
# Finding translation for sáng trên
# Not in the dictionary sáng trên
# Finding translation for sáng thì
# Not in the dictionary sáng thì
# Finding translation for sách đàn
# Not in the dictionary sách đàn
# Finding translation for sách thuộc
# Not in the dictionary sách thuộc
# Finding translation for sách nói
# Not in the dictionary sách nói
# Finding translation for sách nào
# Not in the dictionary sách nào
# Finding translation for sách nhân
# Not in the dictionary sách nhân
# Finding translation for sách do
# Not in the dictionary sách do
# Finding translation for sách bảo
# Not in the dictionary sách bảo
# Finding translation for sàn nhà
# Not in the dictionary sàn nhà
# Finding translation for suốt từ
# Not in the dictionary suốt từ
# Finding translation for suy tôn
# Finding translation for suy tàn
# Finding translation for suy diễn
# Finding translation for soát các
# Not in the dictionary soát các
# Finding translation for soi đường
# Not in the dictionary soi đường
# Finding translation for siêu rẻ
# Not in the dictionary siêu rẻ
# Finding translation for siêu hình
# Not in the dictionary siêu hình
# Finding translation for sinh trung
# Not in the dictionary sinh trung
# Finding translation for sinh thực
# Finding translation for sinh nở
# Finding translation for sinh linh
# Finding translation for sinh khi
# Not in the dictionary sinh khi
# Finding translation for sinh dự
# Not in the dictionary sinh dự
# Finding translation for sex cao
# Not in the dictionary sex cao
# Finding translation for se la
# Not in the dictionary se la
# Finding translation for say rượu
# Not in the dictionary say rượu
# Finding translation for sau thu
# Not in the dictionary sau thu
# Finding translation for sau nầy
# Not in the dictionary sau nầy
# Finding translation for sau giờ
# Not in the dictionary sau giờ
# Finding translation for sao nổi
# Not in the dictionary sao nổi
# Finding translation for sao ma
# Not in the dictionary sao ma
# Finding translation for sao chỉ
# Not in the dictionary sao chỉ
# Finding translation for sao hoa
# Not in the dictionary sao hoa
# Finding translation for sang pháp
# Not in the dictionary sang pháp
# Finding translation for sa tế
# Not in the dictionary sa tế
# Finding translation for rửa tay
# Not in the dictionary rửa tay
# Finding translation for rời của
# Not in the dictionary rời của
# Finding translation for rớt xuống
# Not in the dictionary rớt xuống
# Finding translation for rồi ông
# Not in the dictionary rồi ông
# Finding translation for rồi cùng
# Not in the dictionary rồi cùng
# Finding translation for rồi các
# Not in the dictionary rồi các
# Finding translation for rỉ video
# Not in the dictionary rỉ video
# Finding translation for rằng ý
# Not in the dictionary rằng ý
# Finding translation for rằng phải
# Not in the dictionary rằng phải
# Finding translation for rất đỗi
# Finding translation for rất xấu
# Not in the dictionary rất xấu
# Finding translation for rất tích
# Not in the dictionary rất tích
# Finding translation for rất to
# Not in the dictionary rất to
# Finding translation for rất thực
# Not in the dictionary rất thực
# Finding translation for rất sáng
# Not in the dictionary rất sáng
# Finding translation for rất rẻ
# Not in the dictionary rất rẻ
# Finding translation for rất nghèo
# Not in the dictionary rất nghèo
# Finding translation for rất hữu
# Not in the dictionary rất hữu
# Finding translation for rất hài
# Not in the dictionary rất hài
# Finding translation for rất hiếm
# Not in the dictionary rất hiếm
# Finding translation for rất ghét
# Not in the dictionary rất ghét
# Finding translation for rất chính
# Not in the dictionary rất chính
# Finding translation for rảnh rỗi
# Finding translation for rạp hát
# Finding translation for rượt đuổi
# Not in the dictionary rượt đuổi
# Finding translation for rơi trúng
# Not in the dictionary rơi trúng
# Finding translation for rút về
# Not in the dictionary rút về
# Finding translation for rõ điều
# Not in the dictionary rõ điều
# Finding translation for ràng trong
# Not in the dictionary ràng trong
# Finding translation for run rẩy
# Finding translation for roi ma
# Not in the dictionary roi ma
# Finding translation for riêng tại
# Not in the dictionary riêng tại
# Finding translation for rau ngót
# Not in the dictionary rau ngót
# Finding translation for rau muống
# Not in the dictionary rau muống
# Finding translation for ra đối
# Not in the dictionary ra đối
# Finding translation for ra đều
# Not in the dictionary ra đều
# Finding translation for ra đảo
# Not in the dictionary ra đảo
# Finding translation for ra đạo
# Not in the dictionary ra đạo
# Finding translation for ra thông
# Not in the dictionary ra thông
# Finding translation for ra nhà
# Not in the dictionary ra nhà
# Finding translation for ra mọi
# Not in the dictionary ra mọi
# Finding translation for ra mấy
# Not in the dictionary ra mấy
# Finding translation for ra hồn
# Finding translation for ra cảnh
# Not in the dictionary ra cảnh
# Finding translation for ra bao
# Not in the dictionary ra bao
# Finding translation for quỷ đỏ
# Not in the dictionary quỷ đỏ
# Finding translation for quận bình
# Not in the dictionary quận bình
# Finding translation for quần trong
# Not in the dictionary quần trong
# Finding translation for quả ở
# Not in the dictionary quả ở
# Finding translation for quả với
# Not in the dictionary quả với
# Finding translation for quả trước
# Not in the dictionary quả trước
# Finding translation for quả học
# Finding translation for quê mùa
# Finding translation for quê mình
# Not in the dictionary quê mình
# Finding translation for quân y
# Finding translation for quân mỹ
# Not in the dictionary quân mỹ
# Finding translation for quán bar
# Not in the dictionary quán bar
# Finding translation for quái gì
# Not in the dictionary quái gì
# Finding translation for quá quen
# Not in the dictionary quá quen
# Finding translation for quá nặng
# Not in the dictionary quá nặng
# Finding translation for quá không
# Not in the dictionary quá không
# Finding translation for quà biếu
# Not in the dictionary quà biếu
# Finding translation for quyền đối
# Not in the dictionary quyền đối
# Finding translation for quyền quyết
# Not in the dictionary quyền quyết
# Finding translation for quyền khiếu
# Not in the dictionary quyền khiếu
# Finding translation for quyền hay
# Not in the dictionary quyền hay
# Finding translation for quyền chủ
# Not in the dictionary quyền chủ
# Finding translation for quyền bình
# Not in the dictionary quyền bình
# Finding translation for quyền sài
# Not in the dictionary quyền sài
# Finding translation for quen làm
# Not in the dictionary quen làm
# Finding translation for quanh các
# Not in the dictionary quanh các
# Finding translation for quan điều
# Not in the dictionary quan điều
# Finding translation for quan quyền
# Not in the dictionary quan quyền
# Finding translation for quan hơn
# Not in the dictionary quan hơn
# Finding translation for quan chính
# Not in the dictionary quan chính
# Finding translation for quan báo
# Not in the dictionary quan báo
# Finding translation for qua với
# Not in the dictionary qua với
# Finding translation for qua trên
# Not in the dictionary qua trên
# Finding translation for qua rất
# Not in the dictionary qua rất
# Finding translation for qua năm
# Not in the dictionary qua năm
# Finding translation for qua nghị
# Not in the dictionary qua nghị
# Finding translation for qua kinh
# Not in the dictionary qua kinh
# Finding translation for qua hay
# Not in the dictionary qua hay
# Finding translation for qua cơn
# Not in the dictionary qua cơn
# Finding translation for qua công
# Not in the dictionary qua công
# Finding translation for qua câu
# Not in the dictionary qua câu
# Finding translation for qua cái
# Not in the dictionary qua cái
# Finding translation for qua chỗ
# Not in the dictionary qua chỗ
# Finding translation for qua bản
# Not in the dictionary qua bản
# Finding translation for planning ideas
# Not in the dictionary planning ideas
# Finding translation for pin nhiên
# Not in the dictionary pin nhiên
# Finding translation for phức hợp
# Not in the dictionary phức hợp
# Finding translation for phủ mới
# Not in the dictionary phủ mới
# Finding translation for phủ thái
# Not in the dictionary phủ thái
# Finding translation for phủ pháp
# Not in the dictionary phủ pháp
# Finding translation for phủ lào
# Not in the dictionary phủ lào
# Finding translation for phục sự
# Not in the dictionary phục sự
# Finding translation for phục cho
# Not in the dictionary phục cho
# Finding translation for phố đã
# Not in the dictionary phố đã
# Finding translation for phố trong
# Not in the dictionary phố trong
# Finding translation for phố san
# Not in the dictionary phố san
# Finding translation for phố ninh
# Not in the dictionary phố ninh
# Finding translation for phận này
# Not in the dictionary phận này
# Finding translation for phẩm giàu
# Not in the dictionary phẩm giàu
# Finding translation for phần tạo
# Not in the dictionary phần tạo
# Finding translation for phần tham
# Not in the dictionary phần tham
# Finding translation for phần nhiều
# Finding translation for phải đổi
# Not in the dictionary phải đổi
# Finding translation for phải đảm
# Not in the dictionary phải đảm
# Finding translation for phải đơn
# Not in the dictionary phải đơn
# Finding translation for phải xây
# Not in the dictionary phải xây
# Finding translation for phải xác
# Not in the dictionary phải xác
# Finding translation for phải tiêu
# Not in the dictionary phải tiêu
# Finding translation for phải thật
# Not in the dictionary phải thật
# Finding translation for phải tham
# Not in the dictionary phải tham
# Finding translation for phải sợ
# Not in the dictionary phải sợ
# Finding translation for phải phụ
# Not in the dictionary phải phụ
# Finding translation for phải phân
# Not in the dictionary phải phân
# Finding translation for phải lập
# Not in the dictionary phải lập
# Finding translation for phải họ
# Not in the dictionary phải họ
# Finding translation for phải dễ
# Not in the dictionary phải dễ
# Finding translation for phải dành
# Not in the dictionary phải dành
# Finding translation for phải cắt
# Not in the dictionary phải cắt
# Finding translation for phải cùng
# Not in the dictionary phải cùng
# Finding translation for phạm một
# Not in the dictionary phạm một
# Finding translation for phút với
# Not in the dictionary phút với
# Finding translation for phút nữa
# Not in the dictionary phút nữa
# Finding translation for phút là
# Not in the dictionary phút là
# Finding translation for phóng thích
# Finding translation for phó biên
# Not in the dictionary phó biên
# Finding translation for phía các
# Not in the dictionary phía các
# Finding translation for phí phạm
# Finding translation for phê và
# Not in the dictionary phê và
# Finding translation for phép chúng
# Not in the dictionary phép chúng
# Finding translation for phép cho
# Not in the dictionary phép cho
# Finding translation for phép bí
# Not in the dictionary phép bí
# Finding translation for pháp quy
# Finding translation for pháp nghiên
# Not in the dictionary pháp nghiên
# Finding translation for pháp làm
# Not in the dictionary pháp làm
# Finding translation for pháp chế
# Finding translation for phán rằng
# Not in the dictionary phán rằng
# Finding translation for phá trong
# Not in the dictionary phá trong
# Finding translation for phong và
# Not in the dictionary phong và
# Finding translation for phong trong
# Not in the dictionary phong trong
# Finding translation for phiếu bầu
# Not in the dictionary phiếu bầu
# Finding translation for phe lãnh
# Not in the dictionary phe lãnh
# Finding translation for phai lam
# Not in the dictionary phai lam
# Finding translation for oán hận
# Finding translation for of vietnam
# Not in the dictionary of vietnam
# Finding translation for oan biểu
# Not in the dictionary oan biểu
# Finding translation for oai hùng
# Finding translation for o nuoc
# Not in the dictionary o nuoc
# Finding translation for o nha
# Not in the dictionary o nha
# Finding translation for o ngoai
# Not in the dictionary o ngoai
# Finding translation for nữa chúng
# Not in the dictionary nữa chúng
# Finding translation for nữ đã
# Not in the dictionary nữ đã
# Finding translation for nữ mang
# Not in the dictionary nữ mang
# Finding translation for nữ khoa
# Not in the dictionary nữ khoa
# Finding translation for nửa tháng
# Not in the dictionary nửa tháng
# Finding translation for nức đọ
# Not in the dictionary nức đọ
# Finding translation for nội của
# Not in the dictionary nội của
# Finding translation for nếu để
# Not in the dictionary nếu để
# Finding translation for nếu ăn
# Not in the dictionary nếu ăn
# Finding translation for nếu tính
# Not in the dictionary nếu tính
# Finding translation for nếu nó
# Not in the dictionary nếu nó
# Finding translation for nếu gặp
# Not in the dictionary nếu gặp
# Finding translation for nếu cứ
# Not in the dictionary nếu cứ
# Finding translation for nặng về
# Not in the dictionary nặng về
# Finding translation for nặng trên
# Not in the dictionary nặng trên
# Finding translation for nằm đó
# Not in the dictionary nằm đó
# Finding translation for nắm chính
# Not in the dictionary nắm chính
# Finding translation for nầy không
# Not in the dictionary nầy không
# Finding translation for nấu chín
# Not in the dictionary nấu chín
# Finding translation for nạn giao
# Not in the dictionary nạn giao
# Finding translation for nước xã
# Not in the dictionary nước xã
# Finding translation for nước vừa
# Not in the dictionary nước vừa
# Finding translation for nước rửa
# Not in the dictionary nước rửa
# Finding translation for nước nầy
# Not in the dictionary nước nầy
# Finding translation for nước người
# Not in the dictionary nước người
# Finding translation for nước do
# Not in the dictionary nước do
# Finding translation for nước công
# Not in the dictionary nước công
# Finding translation for nước chân
# Not in the dictionary nước chân
# Finding translation for nước bảo
# Not in the dictionary nước bảo
# Finding translation for nước bước
# Not in the dictionary nước bước
# Finding translation for nương tựa
# Finding translation for nơi xa
# Not in the dictionary nơi xa
# Finding translation for nơi những
# Not in the dictionary nơi những
# Finding translation for nơi họ
# Not in the dictionary nơi họ
# Finding translation for nơi tđ
# Not in the dictionary nơi tđ
# Finding translation for năng thông
# Not in the dictionary năng thông
# Finding translation for năng khác
# Not in the dictionary năng khác
# Finding translation for năm đến
# Not in the dictionary năm đến
# Finding translation for năm văn
# Not in the dictionary năm văn
# Finding translation for năm tôi
# Not in the dictionary năm tôi
# Finding translation for năm nhưng
# Not in the dictionary năm nhưng
# Finding translation for năm như
# Not in the dictionary năm như
# Finding translation for năm hoạt
# Not in the dictionary năm hoạt
# Finding translation for năm cầm
# Not in the dictionary năm cầm
# Finding translation for nông cạn
# Finding translation for nôn nóng
# Finding translation for nói từ
# Not in the dictionary nói từ
# Finding translation for nói cái
# Not in the dictionary nói cái
# Finding translation for nói chúng
# Not in the dictionary nói chúng
# Finding translation for nói bằng
# Not in the dictionary nói bằng
# Finding translation for nó đến
# Not in the dictionary nó đến
# Finding translation for nó với
# Not in the dictionary nó với
# Finding translation for nó ko
# Not in the dictionary nó ko
# Finding translation for nó chính
# Not in the dictionary nó chính
# Finding translation for nêu ở
# Not in the dictionary nêu ở
# Finding translation for nên đề
# Not in the dictionary nên đề
# Finding translation for nên vẫn
# Not in the dictionary nên vẫn
# Finding translation for nên tất
# Not in the dictionary nên tất
# Finding translation for nên thành
# Not in the dictionary nên thành
# Finding translation for nên phổ
# Not in the dictionary nên phổ
# Finding translation for nên muốn
# Not in the dictionary nên muốn
# Finding translation for nên lấy
# Not in the dictionary nên lấy
# Finding translation for nên khó
# Not in the dictionary nên khó
# Finding translation for nên hay
# Not in the dictionary nên hay
# Finding translation for nên công
# Not in the dictionary nên công
# Finding translation for nên còn
# Not in the dictionary nên còn
# Finding translation for nên cái
# Not in the dictionary nên cái
# Finding translation for nên chú
# Not in the dictionary nên chú
# Finding translation for ném vào
# Not in the dictionary ném vào
# Finding translation for nâng đỡ
# Finding translation for nâng niu
# Finding translation for này ta
# Not in the dictionary này ta
# Finding translation for này hơn
# Not in the dictionary này hơn
# Finding translation for này giải
# Not in the dictionary này giải
# Finding translation for này dẫn
# Not in the dictionary này dẫn
# Finding translation for này dành
# Not in the dictionary này dành
# Finding translation for nào đẹp
# Not in the dictionary nào đẹp
# Finding translation for nào vào
# Not in the dictionary nào vào
# Finding translation for nào trước
# Not in the dictionary nào trước
# Finding translation for nào sai
# Not in the dictionary nào sai
# Finding translation for nào nếu
# Not in the dictionary nào nếu
# Finding translation for nuối tiếc
# Not in the dictionary nuối tiếc
# Finding translation for niệm ngày
# Not in the dictionary niệm ngày
# Finding translation for nhựa alu
# Not in the dictionary nhựa alu
# Finding translation for những ứng
# Not in the dictionary những ứng
# Finding translation for những ảnh
# Not in the dictionary những ảnh
# Finding translation for những đợt
# Not in the dictionary những đợt
# Finding translation for những đoàn
# Not in the dictionary những đoàn
# Finding translation for những điệu
# Not in the dictionary những điệu
# Finding translation for những tuần
# Not in the dictionary những tuần
# Finding translation for những trái
# Not in the dictionary những trái
# Finding translation for những thắng
# Not in the dictionary những thắng
# Finding translation for những sáng
# Not in the dictionary những sáng
# Finding translation for những nhạc
# Not in the dictionary những nhạc
# Finding translation for những mảnh
# Not in the dictionary những mảnh
# Finding translation for những mưu
# Not in the dictionary những mưu
# Finding translation for những khác
# Not in the dictionary những khác
# Finding translation for những cú
# Not in the dictionary những cú
# Finding translation for nhờ tôi
# Not in the dictionary nhờ tôi
# Finding translation for nhờ công
# Not in the dictionary nhờ công
# Finding translation for nhớ ngày
# Not in the dictionary nhớ ngày
# Finding translation for nhớ một
# Not in the dictionary nhớ một
# Finding translation for nhớ hết
# Not in the dictionary nhớ hết
# Finding translation for nhỏ thì
# Not in the dictionary nhỏ thì
# Finding translation for nhỏ nên
# Not in the dictionary nhỏ nên
# Finding translation for nhỏ làm
# Not in the dictionary nhỏ làm
# Finding translation for nhỏ cũng
# Not in the dictionary nhỏ cũng
# Finding translation for nhị nguyên
# Finding translation for nhẹ và
# Not in the dictionary nhẹ và
# Finding translation for nhằm xây
# Not in the dictionary nhằm xây
# Finding translation for nhắn riêng
# Not in the dictionary nhắn riêng
# Finding translation for nhật lần
# Not in the dictionary nhật lần
# Finding translation for nhập để
# Not in the dictionary nhập để
# Finding translation for nhập trường
# Not in the dictionary nhập trường
# Finding translation for nhập ngũ
# Finding translation for nhập các
# Not in the dictionary nhập các
# Finding translation for nhận tội
# Finding translation for nhận thi
# Not in the dictionary nhận thi
# Finding translation for nhận chức
# Not in the dictionary nhận chức
# Finding translation for nhất thị
# Not in the dictionary nhất thị
# Finding translation for nhất như
# Not in the dictionary nhất như
# Finding translation for nhất chỉ
# Not in the dictionary nhất chỉ
# Finding translation for nhạc này
# Not in the dictionary nhạc này
# Finding translation for nhạc trịnh
# Not in the dictionary nhạc trịnh
# Finding translation for nhưng nhìn
# Not in the dictionary nhưng nhìn
# Finding translation for nhưng mọi
# Not in the dictionary nhưng mọi
# Finding translation for nhưng lòng
# Not in the dictionary nhưng lòng
# Finding translation for nhưng ko
# Not in the dictionary nhưng ko
# Finding translation for nhưng cả
# Not in the dictionary nhưng cả
# Finding translation for nhưng chủ
# Not in the dictionary nhưng chủ
# Finding translation for nhưng bà
# Not in the dictionary nhưng bà
# Finding translation for như vừa
# Not in the dictionary như vừa
# Finding translation for như vô
# Not in the dictionary như vô
# Finding translation for như từ
# Not in the dictionary như từ
# Finding translation for như thông
# Not in the dictionary như thông
# Finding translation for như sẽ
# Not in the dictionary như sẽ
# Finding translation for như quá
# Not in the dictionary như quá
# Finding translation for như nhân
# Not in the dictionary như nhân
# Finding translation for như mỗi
# Not in the dictionary như mỗi
# Finding translation for như mơ
# Not in the dictionary như mơ
# Finding translation for như lòng
# Not in the dictionary như lòng
# Finding translation for như cầu
# Not in the dictionary như cầu
# Finding translation for như cơm
# Not in the dictionary như cơm
# Finding translation for như bộ
# Not in the dictionary như bộ
# Finding translation for như báo
# Not in the dictionary như báo
# Finding translation for như hồ
# Not in the dictionary như hồ
# Finding translation for như hoa
# Not in the dictionary như hoa
# Finding translation for nhúng tay
# Finding translation for nhóm đối
# Not in the dictionary nhóm đối
# Finding translation for nhìn sang
# Not in the dictionary nhìn sang
# Finding translation for nhè nhẹ
# Not in the dictionary nhè nhẹ
# Finding translation for nhân ra
# Not in the dictionary nhân ra
# Finding translation for nhân một
# Not in the dictionary nhân một
# Finding translation for nhân luôn
# Not in the dictionary nhân luôn
# Finding translation for nhân dẫn
# Not in the dictionary nhân dẫn
# Finding translation for nhân chỉ
# Not in the dictionary nhân chỉ
# Finding translation for nhân chia
# Not in the dictionary nhân chia
# Finding translation for nhái thành
# Not in the dictionary nhái thành
# ...
# Finding translation for mẹo vặt
# Not in the dictionary mẹo vặt
# Finding translation for mê thuộc
# Not in the dictionary mê thuộc
# Finding translation for mãn nhãn
# Not in the dictionary mãn nhãn
# Finding translation for mini phiên
# Not in the dictionary mini phiên
# Finding translation for minh tiếp
# Not in the dictionary minh tiếp
# Finding translation for minh luôn
# Not in the dictionary minh luôn
# Finding translation for minh còn
# Not in the dictionary minh còn
# Finding translation for minh quốc
# Not in the dictionary minh quốc
# Finding translation for minh giang
# Not in the dictionary minh giang
# Finding translation for minh chi
# Not in the dictionary minh chi
# Finding translation for mai vàng
# Not in the dictionary mai vàng
# Finding translation for lệnh quân
# Not in the dictionary lệnh quân
# Finding translation for lễ phục
# Finding translation for lượng thuỷ
# Not in the dictionary lượng thuỷ
# Finding translation for lý thường
# Not in the dictionary lý thường
# Finding translation for lúc mới
# Not in the dictionary lúc mới
# Finding translation for lê ngọc
# Not in the dictionary lê ngọc
# Finding translation for lão tử
# Not in the dictionary lão tử
# Finding translation for luật bản
# Not in the dictionary luật bản
# Finding translation for li na
# Not in the dictionary li na
# Finding translation for le chien
# Not in the dictionary le chien
# Finding translation for latvia lithuania
# Not in the dictionary latvia lithuania
# Finding translation for llđb langvei
# Not in the dictionary llđb langvei
# Finding translation for kim tuyến
# Not in the dictionary kim tuyến
# Finding translation for khánh hội
# Not in the dictionary khánh hội
# Finding translation for khánh chi
# Not in the dictionary khánh chi
# Finding translation for khám túi
# Not in the dictionary khám túi
# Finding translation for keangnam hanoi
# Not in the dictionary keangnam hanoi
# Finding translation for karl marx
# Not in the dictionary karl marx
# Finding translation for jong suk
# Not in the dictionary jong suk
# Finding translation for jimmii nguyễn
# Not in the dictionary jimmii nguyễn
# Finding translation for internet và
# Not in the dictionary internet và
# Finding translation for hàng hải
# Finding translation for hà đông
# Not in the dictionary hà đông
# Finding translation for huỳnh thị
# Not in the dictionary huỳnh thị
# Finding translation for huỳnh mỹ
# Not in the dictionary huỳnh mỹ
# Finding translation for huyên chương
# Not in the dictionary huyên chương
# Finding translation for huy cận
# Not in the dictionary huy cận
# Finding translation for hoàng phủ
# Not in the dictionary hoàng phủ
# Finding translation for hoàng ngọc
# Not in the dictionary hoàng ngọc
# Finding translation for hoàng anh
# Finding translation for hoa đông
# Not in the dictionary hoa đông
# Finding translation for ha jong
# Not in the dictionary ha jong
# Finding translation for gửi lúc
# Not in the dictionary gửi lúc
# Finding translation for gò công
# Not in the dictionary gò công
# Finding translation for got talent
# Not in the dictionary got talent
# Finding translation for gopnhat est
# Not in the dictionary gopnhat est
# Finding translation for giải mã
# Finding translation for giêng năm
# Not in the dictionary giêng năm
# Finding translation for giêsu sinh
# Not in the dictionary giêsu sinh
# Finding translation for giáng cũng
# Not in the dictionary giáng cũng
# Finding translation for giá thực
# Not in the dictionary giá thực
# Finding translation for giá cảeva
# Not in the dictionary giá cảeva
# Finding translation for giao châu
# Not in the dictionary giao châu
# Finding translation for gia định
# Not in the dictionary gia định
# Finding translation for email báo
# Not in the dictionary email báo
# Finding translation for dương của
# Not in the dictionary dương của
# Finding translation for dũng đã
# Not in the dictionary dũng đã
# Finding translation for dân hành
# Not in the dictionary dân hành
# Finding translation for dong hae
# Not in the dictionary dong hae
# Finding translation for diệm là
# Not in the dictionary diệm là
# Finding translation for du sinh
# Not in the dictionary du sinh
# Finding translation for day tieng
# Not in the dictionary day tieng
# Finding translation for cường để
# Not in the dictionary cường để
# Finding translation for cũng hãy
# Not in the dictionary cũng hãy
# Finding translation for công định
# Not in the dictionary công định
# Finding translation for côran lớn
# Not in the dictionary côran lớn
# Finding translation for có chăng
# Not in the dictionary có chăng
# Finding translation for còn đối
# Not in the dictionary còn đối
# Finding translation for chương quý
# Not in the dictionary chương quý
# Finding translation for chúa con
# Not in the dictionary chúa con
# Finding translation for chín bài
# Not in the dictionary chín bài
# Finding translation for chí linh
# Not in the dictionary chí linh
# Finding translation for châu tự
# Not in the dictionary châu tự
# Finding translation for cam lộc
# Not in the dictionary cam lộc
# Finding translation for cpi hà
# Not in the dictionary cpi hà
# Finding translation for chí thể
# Not in the dictionary chí thể
# Finding translation for bửu quang
# Not in the dictionary bửu quang
# Finding translation for bộ nội
# Not in the dictionary bộ nội
# Finding translation for bắc âu
# Not in the dictionary bắc âu
# Finding translation for bắc kỳ
# Not in the dictionary bắc kỳ
# Finding translation for bấm xem
# Not in the dictionary bấm xem
# Finding translation for bản đã
# Not in the dictionary bản đã
# Finding translation for bản cáo
# Not in the dictionary bản cáo
# Finding translation for bạch đằng
# Not in the dictionary bạch đằng
# Finding translation for bát nhã
# Not in the dictionary bát nhã
# Finding translation for báo giá
# Not in the dictionary báo giá
# Finding translation for bá chi
# Not in the dictionary bá chi
# Finding translation for bush và
# Not in the dictionary bush và
# Finding translation for bui tin
# Not in the dictionary bui tin
# Finding translation for bao da
# Not in the dictionary bao da
# Finding translation for ba má
# Not in the dictionary ba má
# Finding translation for asia clinic
# Not in the dictionary asia clinic
# Finding translation for anh kiểu
# Not in the dictionary anh kiểu
# Finding translation for anh hãy
# Not in the dictionary anh hãy
# Finding translation for an bị
# Not in the dictionary an bị
# Finding translation for đẹpsức
# Not in the dictionary đẹpsức
# Finding translation for đtc
# Not in the dictionary đtc
# Finding translation for éo
# Not in the dictionary éo
# Finding translation for êxêchiên
# Not in the dictionary êxêchiên
# Finding translation for xùm
# Not in the dictionary xùm
# Finding translation for vưà
# Not in the dictionary vưà
# Finding translation for vertebroplasty
# Not in the dictionary vertebroplasty
# Finding translation for uẩn
# Not in the dictionary uẩn
# Finding translation for upload
# Not in the dictionary upload
# Finding translation for ua
# Not in the dictionary ua
# Finding translation for tộilỗi
# Not in the dictionary tộilỗi
# Finding translation for támnhà
# Not in the dictionary támnhà
# Finding translation for tukep
# Not in the dictionary tukep
# Finding translation for trìu
# Not in the dictionary trìu
# Finding translation for trich
# Not in the dictionary trich
# Finding translation for tiếngnói
# Not in the dictionary tiếngnói
# Finding translation for tinhcach
# Not in the dictionary tinhcach
# Finding translation for thổn
# Not in the dictionary thổn
# Finding translation for thướt
# Not in the dictionary thướt
# Finding translation for thuo
# Not in the dictionary thuo
# Finding translation for thizu
# Not in the dictionary thizu
# Finding translation for thangcuoi
# Not in the dictionary thangcuoi
# Finding translation for sy
# Not in the dictionary sy
# Finding translation for silicon
# Not in the dictionary silicon
# Finding translation for robot
# Not in the dictionary robot
# Finding translation for rai
# Not in the dictionary rai
# Finding translation for phờrăng
# Not in the dictionary phờrăng
# Finding translation for phượt
# Not in the dictionary phượt
# Finding translation for order
# Not in the dictionary order
# Finding translation for nylon
# Not in the dictionary nylon
# Finding translation for nop
# Not in the dictionary nop
# Finding translation for nhưong
# Not in the dictionary nhưong
# Finding translation for nhúc
# Not in the dictionary nhúc
# Finding translation for nhuệ
# Not in the dictionary nhuệ
# Finding translation for ngộp
# Not in the dictionary ngộp
# Finding translation for ngổn
# Not in the dictionary ngổn
# Finding translation for ngung
# Not in the dictionary ngung
# Finding translation for nghin
# Not in the dictionary nghin
# Finding translation for mún
# Not in the dictionary mún
# Finding translation for mod
# Not in the dictionary mod
# Finding translation for mix
# Not in the dictionary mix
# Finding translation for methanol
# Not in the dictionary methanol
# Finding translation for menu
# Not in the dictionary menu
# Finding translation for make
# Not in the dictionary make
# Finding translation for lạị
# Not in the dictionary lạị
# Finding translation for list
# Not in the dictionary list
# Finding translation for khoc
# Not in the dictionary khoc
# Finding translation for ion
# Not in the dictionary ion
# Finding translation for hẵn
# Not in the dictionary hẵn
# Finding translation for hảy
# Not in the dictionary hảy
# Finding translation for hìnhthức
# Not in the dictionary hìnhthức
# Finding translation for hoằng
# Not in the dictionary hoằng
# Finding translation for hormone
# Not in the dictionary hormone
# Finding translation for hinhthuc
# Not in the dictionary hinhthuc
# Finding translation for hilux
# Not in the dictionary hilux
# Finding translation for hihihi
# Not in the dictionary hihihi
# Finding translation for hiem
# Not in the dictionary hiem
# Finding translation for hahaha
# Not in the dictionary hahaha
# Finding translation for haha
# Not in the dictionary haha
# Finding translation for hack
# Not in the dictionary hack
# Finding translation for gown
# Not in the dictionary gown
# Finding translation for gas
# Not in the dictionary gas
# Finding translation for emarketing
# Not in the dictionary emarketing
# Finding translation for dình
# Not in the dictionary dình
# Finding translation for dzui
# Not in the dictionary dzui
# Finding translation for doàn
# Not in the dictionary doàn
# Finding translation for dowload
# Not in the dictionary dowload
# Finding translation for diet
# Not in the dictionary diet
# Finding translation for cỏi
# Not in the dictionary cỏi
# Finding translation for cảeva
# Not in the dictionary cảeva
# Finding translation for container
# Not in the dictionary container
# Finding translation for cocktail
# Not in the dictionary cocktail
# Finding translation for chữviệt
# Not in the dictionary chữviệt
# Finding translation for bấp
# Not in the dictionary bấp
# Finding translation for bam
# Not in the dictionary bam
# Finding translation for aygo
# Not in the dictionary aygo
# Finding translation for apps
# Not in the dictionary apps
# Finding translation for zack
# Not in the dictionary zack
# Finding translation for youtube
# Not in the dictionary youtube
# Finding translation for yoga
# Not in the dictionary yoga
# Finding translation for yi
# Not in the dictionary yi
# Finding translation for yale
# Not in the dictionary yale
# Finding translation for wright
# Not in the dictionary wright
# Finding translation for wireless
# Not in the dictionary wireless
# Finding translation for window
# Not in the dictionary window
# Finding translation for wikimedia
# Not in the dictionary wikimedia
# Finding translation for welcome
# Not in the dictionary welcome
# Finding translation for version
# Not in the dictionary version
# Finding translation for têrêsa
# Not in the dictionary têrêsa
# Finding translation for trungsĩ
# Not in the dictionary trungsĩ
# Finding translation for translation
# Not in the dictionary translation
# Finding translation for talent
# Not in the dictionary talent
# Finding translation for symantec
# Not in the dictionary symantec
# Finding translation for suk
# Not in the dictionary suk
# Finding translation for sri
# Not in the dictionary sri
# Finding translation for shinzo
# Not in the dictionary shinzo
# Finding translation for shelby
# Not in the dictionary shelby
# Finding translation for september
# Not in the dictionary september
# Finding translation for schengen
# Not in the dictionary schengen
# Finding translation for sainteny
# Not in the dictionary sainteny
# Finding translation for sara
# Not in the dictionary sara
# Finding translation for reuters
# Not in the dictionary reuters
# Finding translation for resort
# Not in the dictionary resort
# Finding translation for rap
# Not in the dictionary rap
# Finding translation for rally
# Not in the dictionary rally
# Finding translation for posted
# Not in the dictionary posted
# Finding translation for play
# Not in the dictionary play
# Finding translation for pirlo
# Not in the dictionary pirlo
# Finding translation for perochan
# Not in the dictionary perochan
# Finding translation for party
# Not in the dictionary party
# Finding translation for pmu
# Not in the dictionary pmu
# Finding translation for oregon
# Not in the dictionary oregon
# Finding translation for onetv
# Not in the dictionary onetv
# Finding translation for novak
# Not in the dictionary novak
# Finding translation for nole
# Not in the dictionary nole
# Finding translation for nibelheim
# Not in the dictionary nibelheim
# Finding translation for nato
# Not in the dictionary nato
# Finding translation for mẽo
# Not in the dictionary mẽo
# Finding translation for missouri
# Not in the dictionary missouri
# Finding translation for maya
# Not in the dictionary maya
# Finding translation for mario
# Not in the dictionary mario
# Finding translation for lumia
# Not in the dictionary lumia
# Finding translation for lancome
# Not in the dictionary lancome
# Finding translation for khmer
# Not in the dictionary khmer
# Finding translation for kemal
# Not in the dictionary kemal
# Finding translation for jimmii
# Not in the dictionary jimmii
# Finding translation for jessica
# Not in the dictionary jessica
# Finding translation for jennifer
# Not in the dictionary jennifer
# Finding translation for jack
# Not in the dictionary jack
# Finding translation for institute
# Not in the dictionary institute
# Finding translation for imf
# Not in the dictionary imf
# Finding translation for hitech
# Not in the dictionary hitech
# Finding translation for hawaii
# Not in the dictionary hawaii
# Finding translation for hae
# Not in the dictionary hae
# Finding translation for hkust
# Not in the dictionary hkust
# Finding translation for hagl
# Not in the dictionary hagl
# Finding translation for greg
# Not in the dictionary greg
# Finding translation for gorbatchev
# Not in the dictionary gorbatchev
# Finding translation for gilbert
# Not in the dictionary gilbert
# Finding translation for friends
# Not in the dictionary friends
# Finding translation for french
# Not in the dictionary french
# Finding translation for first
# Not in the dictionary first
# Finding translation for ericsson
# Not in the dictionary ericsson
# Finding translation for edward
# Not in the dictionary edward
# Finding translation for earth
# Not in the dictionary earth
# Finding translation for ebook
# Not in the dictionary ebook
# Finding translation for easy
# Not in the dictionary easy
# Finding translation for design
# Not in the dictionary design
# Finding translation for default
# Not in the dictionary default
# Finding translation for dance
# Not in the dictionary dance
# Finding translation for côte
# Not in the dictionary côte
# Finding translation for corel
# Not in the dictionary corel
# Finding translation for contostavlos
# Not in the dictionary contostavlos
# Finding translation for command
# Not in the dictionary command
# Finding translation for college
# Not in the dictionary college
# Finding translation for civic
# Not in the dictionary civic
# Finding translation for brisbane
# Not in the dictionary brisbane
# Finding translation for braxil
# Not in the dictionary braxil
# Finding translation for boeing
# Not in the dictionary boeing
# Finding translation for bhaya
# Not in the dictionary bhaya
# Finding translation for benavidez
# Not in the dictionary benavidez
# Finding translation for arthur
# Not in the dictionary arthur
# Finding translation for angelina
# Not in the dictionary angelina
# Finding translation for andrew
# Not in the dictionary andrew
# Finding translation for alzheimer
# Not in the dictionary alzheimer
# Finding translation for albert
# Not in the dictionary albert
# Finding translation for aceh
# Not in the dictionary aceh
# Finding translation for access
# Not in the dictionary access

# %%
#saving the batch
with open('/content/gdrive/My Drive/Colab Notebooks/Dictionary Project/vdict VI-EN ver 4 batch {}.json'.format(index), 'w') as outfile:
  json.dump(dictionary, outfile)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 5374.28156375885 seconds ---

# %%
len(dictionary.items())
# Out:
# 4201

# %%
findTranslation("cái")
# Out:
# Finding translation for cái
# {1: {'POS': 'noun',
#   'examples': {'context 1': 'con dại cái mang',
#    'nums': 1,
#    'usage 1': 'the mother is responsible for the foolishness of her child'},
#   'translation': ['Mother']},
#  2: {'POS': 'noun',
#   'examples': {'context 1': 'cháu đến rủ cái Hoa đi học',
#    'nums': 1,
#    'usage 1': "I'm calling for Hoa to go to school with her"},
#   'translation': ["khẩu ngữ) (denoting a young girl of one's rank or below)"]},
#  3: {'POS': 'noun',
#   'examples': {'context 1': 'cái giấm',
#    'context 2': 'cái mẻ',
#    'context 3': 'Banker (trong đám bạc)',
#    'context 4': 'ăn cả nước lẫn cái',
#    'nums': 4,
#    'usage 1': 'mother of vinegar',
#    'usage 2': 'mother of fermented cold rice',
#    'usage 3': 'Solid part (of liquid food)',
#    'usage 4': 'to eat both the liquid and the solid part (of a food)'},
#   'translation': ['Mother', ' mother of vinegar']},
#  'nums': 3}
