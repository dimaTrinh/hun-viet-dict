# %%
import urllib.request 
from urllib.parse import quote 
from bs4 import BeautifulSoup
import json
import re
import time

# %%
#Source: https://codezup.com/web-scraping-word-meaning-dictionary-python-beautifulsoup/

# %%
with open('./vi-words.txt', 'r') as infile:
    lines = infile.readlines()
lines = [line.strip().split(" ") for line in lines]
wordList = []
for item in lines:
    if (int(item[1]) >= 2): #words that appeared more than twice is stored
        wordList.append(str(item[0]))
wordList[0:5]
# Out:
# ['của', 'và', 'là', 'có', 'không']

# %%
#The link format for vdict Viet-Fran is: https://vdict.com/m%E1%BB%99t,4,0,0.html

# %%
#Converting IRI to ASCII:
#https://stackoverflow.com/questions/4389572/how-to-fetch-a-non-ascii-url-with-python-urlopen

# %%
def findTranslation(word):
    print("Finding translation for " + word)
    url = "https://vdict.com/" + quote(word) + ",4,0,0.html" #resolving the IRI issue
    
    try: #make sure the link is working
        source = urllib.request.urlopen(url)
    except:
        print("Link broken for " + word)
        return "N/A"
    
    soup = BeautifulSoup(source, 'lxml')

    #make sure the word is in the dictionary
    if (soup.find("div", id = 'result-contents') is None):
        print("Not in the dictionary " + word)
        return "N/A"

    translations = {}

    #Getting the first translation
    curTag = soup.find("ul", class_= "list1")

    if (curTag.find('b') is None): #empty translation page
        print("Empty translation page " + word)
        return "N/A"

    #storing the number of translations a word has
    numTrans = 1

    #continue while we still have more translations
    while(curTag != '\n'): 
        temp = {} #temp dict to store each translation of a word

        #getting the raw translation
        if (curTag.find('b').string is not None): #empty translation cell
            temp['translation'] = re.split('[,;]', curTag.find('b').string)

            #retrieving the examples of each of the translations
            try:
                examples = curTag.findAll("ul", class_= "list2")
                temp2 = {} #another dict to store each examples of a translation

                numExamples = len(list(examples))
                temp2['nums'] = numExamples

                for j in range(0, numExamples):
                    temp2['context ' + str(j+1)] = examples[j].find(class_ = "example-original").string

                    #retrieving the usage of each examples
                    try: 
                        tempString = str(examples[j].find("li")) #extracting the usage
                        temp2['usage ' + str(j+1)] = tempString[tempString.find("<br/>")+5:-5]
                    except:
                        temp2['usage ' + str(j+1)] = "N/A"

                temp['examples'] = temp2
            except:
                temp['examples'] = "N/A"

            translations[numTrans] = temp #adding the translation to the dictionary

            numTrans += 1
        #go to next tag  
        curTag = curTag.next_sibling
    
    translations["nums"] = numTrans - 1
        
    return translations

# %%
url = "https://vdict.com/" + quote("có") + ",4,0,0.html" #resolving the IRI issue

try:
    source = urllib.request.urlopen(url)
except:
    print( "Link broken")
soup = BeautifulSoup(source, 'lxml')

# %%
soup.find("ul", class_= "list1").next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling.next_sibling
# Out:
# '\n'

# %%
containers = soup.findAll("ul", class_= "list1")
containers
# Out:
# [<ul class="list1"><li><b>avoir; posséder</b><ul class="list2"><li><span class="example-original">Tôi có nói câu đó </span><br/>j'ai dit cette phrase</li></ul><ul class="list2"><li><span class="example-original">Có tiền </span><br/>avoir de l'argent</li></ul><ul class="list2"><li><span class="example-original">Có một cái nhà </span><br/>posséder une maison</li></ul></li></ul>,
#  <ul class="list1"><li><b>exister; se trouver</b><ul class="list2"><li><span class="example-original">Cái tục đó còn đó </span><br/>cet usage existe encore</li></ul><ul class="list2"><li><span class="example-original">Loài chim đó không có ở Việt Nam </span><br/>cette espèce d'oiseau n'existe pas au Viet-Nam</li></ul><ul class="list2"><li><span class="example-original">Tên anh không có trong danh sách </span><br/>ton nom ne se trouve pas sur la liste</li></ul></li></ul>,
#  <ul class="list1"><li><b>disposer de</b><ul class="list2"><li><span class="example-original">ông ấy có một cái xe </span><br/>il dispose d'une voiture</li></ul></li></ul>,
#  <ul class="list1"><li><b>être présent</b><ul class="list2"><li><span class="example-original">Một chất khí có rất ít trong không khí </span><br/>un gaz qui est présent dans l'air en proportion infinitésimale</li></ul></li></ul>,
#  <ul class="list1"><li><b>il y a; il est</b><ul class="list2"><li><span class="example-original">Có đông người trong phòng </span><br/>il y a du monde dans la salle</li></ul><ul class="list2"><li><span class="example-original">Trong số các anh có ai trả lời được không ? </span><br/>est-il parmi vous quelqu'un qui puisse répondre ?</li></ul></li></ul>,
#  <ul class="list1"><li><b>oui; si (terme affirmatif pouvant ne pas se traduire)</b><ul class="list2"><li><span class="example-original">Anh đến không ? có tôi đến </span><br/>Venez-vous ? oui , je viens</li></ul><ul class="list2"><li><span class="example-original">Anh không ăn ư ? - Có , tôi ăn </span><br/>Vous ne mangez-pas ? - oui , je mange</li></ul></li></ul>,
#  <ul class="list1"><li><b>(terme de dissuasion non traduit)</b><ul class="list2"><li><span class="example-original">Anh đừng có đi </span><br/>n'y allez pas</li></ul><ul class="list2"><li><span class="example-original">Mày đừng có nói dối </span><br/>ne mens pas</li></ul></li></ul>,
#  <ul class="list1"><li><b>(terme conditionnel se traduisant différemment suivant les contextes)</b><ul class="list2"><li><span class="example-original">Có đi mới đến </span><br/>on ne peut arriver qu'à la condition d'être parti</li></ul><ul class="list2"><li><span class="example-original">Có cứng mới đứng đầu gió (tục ngữ)</span><br/>seule l'énergie vous permettrait de résister à l'adversité</li></ul></li></ul>,
#  <ul class="list1"><li><b>présent ; me voici</b><ul class="list2"><li><span class="example-original">Thiếu uý Hai - Có (mặt)</span><br/>le sous-lieutenant Hai - Présent !</li></ul></li></ul>,
#  <ul class="list1"><li><b>même si</b><ul class="list2"><li><span class="example-original">Mày có chạy đằng trời ! </span><br/>même si tu accourais vers le ciel !</li></ul><ul class="list2"><li><span class="example-original">có bề nào </span><br/>s'il arrivait quelque chose de fâcheux</li></ul><ul class="list2"><li><span class="example-original">có da có thịt </span><br/>s'empâter ; épaissir</li></ul><ul class="list2"><li><span class="example-original">có đi có lại </span><br/>donnant , donnant</li></ul><ul class="list2"><li><span class="example-original">có ít xít ra nhiều </span><br/>exagérer outre mesure</li></ul><ul class="list2"><li><span class="example-original">có máu mặt </span><br/>être dans l'aisance; avoir une vie aisée</li></ul><ul class="list2"><li><span class="example-original">có mới nới cũ </span><br/>délaisser l'ancien quand on a un nouveau ; tout nouveau , tout beau</li></ul><ul class="list2"><li><span class="example-original">có nanh có mỏ </span><br/>avoir bec et ongles</li></ul><ul class="list2"><li><span class="example-original">có tật giật mình </span><br/>qui se sent morveux qu'il se mouche</li></ul><ul class="list2"><li><span class="example-original">có thực mới vực được đạo </span><br/>la soupe fait le soldat</li></ul><ul class="list2"><li><span class="example-original">có tiếng mà không có miếng </span><br/>bonne renommée sans ceinture dorée</li></ul></li></ul>,
#  <ul class="list1">
#  <li>
#  <strong>Những từ phát âm/đánh vần giống như <i>"có"</i>: </strong><br/>
#  <a href="/ca,4,0,0.html">ca</a> <a href="/c%C3%A0,4,0,0.html">cà</a> <a href="/c%E1%BA%A3,4,0,0.html">cả</a> <a href="/c%C3%A1,4,0,0.html">cá</a> <a href="/c%E1%BA%A1,4,0,0.html">cạ</a> <a href="/c%C3%A1c,4,0,0.html">các</a> <a href="/cai,4,0,0.html">cai</a> <a href="/c%C3%A0i,4,0,0.html">cài</a> <a href="/c%E1%BA%A3i,4,0,0.html">cải</a> <a href="/c%C3%A3i,4,0,0.html">cãi</a> <a href="/c%C3%B3,4,0,2.html">more...</a> </li>
#  <li>
#  <strong>Những từ có chứa <i>"có"</i>: </strong><br/>
#  <a href="/%C3%ADt+c%C3%B3,4,0,0.html">ít có</a> <a href="/%E1%BA%AFt+c%C3%B3,4,0,0.html">ắt có</a> <a href="/%C4%91%C3%A2u+c%C3%B3,4,0,0.html">đâu có</a> <a href="/b%C3%A0o+c%C3%B3c,4,0,0.html">bào cóc</a> <a href="/b%C3%AAn+c%C3%B3,4,0,0.html">bên có</a> <a href="/b%E1%BA%AFt+c%C3%B3c,4,0,0.html">bắt cóc</a> <a href="/b%E1%BB%A5ng+c%C3%B3c,4,0,0.html">bụng cóc</a> <a href="/cau+c%C3%B3,4,0,0.html">cau có</a> <a href="/c%C3%B3,4,0,0.html">có</a> <a href="/c%C3%B3+%C3%A1n,4,0,0.html">có án</a> <a href="/c%C3%B3,4,0,1.html">more...</a> </li>
#  </ul>]

# %%
meanings = [item.find('b').string for item in containers[0:4]] #word translation
meanings
# Out:
# ['avoir; posséder', 'exister; se trouver', 'disposer de', 'être présent']

# %%
examples = containers[0].findAll("ul", class_= "list2")
temp = str(examples[1].find("li"))
temp[temp.find("<br/>")+5:-5]
# Out:
# "avoir de l'argent"

# %%
dictionary = {}

# %%
start_time = time.time()
for word in wordList:
    dictionary[word] = findTranslation(word)
    time.sleep(1) #wait for 1 sec between each query
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Finding translation for của
# Finding translation for và
# Finding translation for là
# Finding translation for có
# Finding translation for không
# Finding translation for một
# Finding translation for người
# Finding translation for cho
# Finding translation for trong
# Finding translation for được
# Finding translation for những
# Finding translation for các
# Finding translation for đã
# Finding translation for với
# Finding translation for tôi
# Finding translation for để
# Finding translation for như
# Finding translation for về
# Finding translation for này
# Finding translation for ra
# Finding translation for làm
# Finding translation for Việt
# Not in the dictionary Việt
# Finding translation for thì
# Finding translation for thể
# Finding translation for ở
# Finding translation for cũng
# Finding translation for phải
# Finding translation for khi
# Finding translation for đến
# Finding translation for lại
# Finding translation for sự
# Finding translation for đó
# Finding translation for vào
# Finding translation for mà
# Finding translation for Nam
# Finding translation for công
# Finding translation for năm
# Finding translation for dân
# Finding translation for nước
# Finding translation for bạn
# Finding translation for từ
# Finding translation for bị
# Finding translation for ta
# Finding translation for thế
# Finding translation for chỉ
# Finding translation for học
# Finding translation for thành
# Finding translation for sẽ
# Finding translation for trên
# Finding translation for chính
# Finding translation for nhân
# Finding translation for chúng
# Finding translation for con
# Finding translation for ông
# Finding translation for nhiều
# Finding translation for nhà
# Finding translation for nói
# Finding translation for ngày
# Finding translation for mình
# Finding translation for đi
# Finding translation for còn
# Finding translation for anh
# Finding translation for tại
# Finding translation for vì
# Finding translation for nào
# Finding translation for biết
# Finding translation for cả
# Finding translation for số
# Finding translation for việc
# Finding translation for do
# Finding translation for nhất
# Finding translation for đầu
# Finding translation for gia
# Finding translation for cách
# Finding translation for hay
# Finding translation for mới
# Finding translation for sau
# Finding translation for động
# Finding translation for đồng
# Finding translation for nhưng
# Finding translation for quan
# Finding translation for họ
# Finding translation for theo
# Finding translation for hơn
# Finding translation for gì
# Finding translation for khác
# Finding translation for nên
# Finding translation for thấy
# Finding translation for rất
# Finding translation for sinh
# Finding translation for quyền
# Finding translation for hội
# Finding translation for cái
# Finding translation for qua
# Finding translation for tin
# Finding translation for điều
# Finding translation for sản
# Finding translation for lên
# Finding translation for chủ
# Finding translation for hiện
# Finding translation for nhận
# Finding translation for tự
# Finding translation for viên
# Finding translation for Quốc
# Finding translation for giới
# Finding translation for thời
# Finding translation for quốc
# Finding translation for em
# Finding translation for nay
# Finding translation for định
# Finding translation for đang
# Finding translation for tình
# Finding translation for trước
# Finding translation for o
# Finding translation for bài
# Finding translation for thực
# Finding translation for hàng
# Finding translation for ý
# Finding translation for cùng
# Finding translation for sao
# Finding translation for rằng
# Finding translation for bằng
# Finding translation for sống
# Finding translation for tế
# Finding translation for hai
# Finding translation for Trung
# Finding translation for cuộc
# Finding translation for lý
# Not in the dictionary lý
# Finding translation for hình
# Finding translation for đây
# Finding translation for thông
# Finding translation for trường
# Finding translation for Tôi
# Finding translation for cao
# Finding translation for hành
# Finding translation for đề
# Finding translation for tháng
# Finding translation for trình
# Finding translation for bản
# Finding translation for đường
# Finding translation for giờ
# Finding translation for dụng
# Not in the dictionary dụng
# Finding translation for cần
# Finding translation for báo
# Finding translation for độ
# Finding translation for vẫn
# Finding translation for lời
# Finding translation for đối
# Finding translation for giáo
# Finding translation for hợp
# Finding translation for đại
# Finding translation for bao
# Finding translation for cơ
# Finding translation for tâm
# Finding translation for giá
# Finding translation for ăn
# Finding translation for trị
# Finding translation for rồi
# Finding translation for phát
# Finding translation for văn
# Finding translation for Công
# Finding translation for tính
# Finding translation for thức
# Finding translation for nó
# Finding translation for tư
# Finding translation for vậy
# Finding translation for bộ
# Finding translation for viết
# Finding translation for toàn
# Finding translation for lúc
# Finding translation for Anh
# Finding translation for tiếng
# Finding translation for đất
# Finding translation for vị
# Finding translation for chức
# Finding translation for thường
# Finding translation for muốn
# Finding translation for kinh
# Finding translation for vụ
# Finding translation for cộng
# Finding translation for tác
# Finding translation for ai
# Finding translation for tiếp
# Finding translation for mặt
# Finding translation for thật
# Finding translation for nhau
# Finding translation for tranh
# Finding translation for phần
# Finding translation for chiến
# Finding translation for tài
# Finding translation for cấp
# Finding translation for gian
# Finding translation for bất
# Finding translation for nghĩa
# Finding translation for giải
# Finding translation for quá
# Finding translation for tiền
# Finding translation for lần
# Finding translation for Cộng
# Finding translation for yêu
# Finding translation for nhiên
# Not in the dictionary nhiên
# Finding translation for sử
# Finding translation for Minh
# Finding translation for Trong
# Finding translation for hoặc
# Finding translation for mọi
# Finding translation for Nguyễn
# Not in the dictionary Nguyễn
# Finding translation for Hà
# Finding translation for lớn
# Finding translation for tay
# Finding translation for kết
# Finding translation for thi
# Finding translation for Một
# Finding translation for đều
# Finding translation for đạo
# Finding translation for bắt
# Finding translation for trở
# Finding translation for vấn
# Finding translation for tới
# Finding translation for ảnh
# Finding translation for trọng
# Finding translation for cảm
# Finding translation for Những
# Finding translation for chuyện
# Finding translation for điểm
# Finding translation for ấy
# Finding translation for đời
# Finding translation for Mỹ
# Not in the dictionary Mỹ
# Finding translation for la
# Finding translation for bảo
# Finding translation for dùng
# Finding translation for nữa
# Finding translation for tạo
# Finding translation for sách
# Finding translation for cầu
# Finding translation for tìm
# Finding translation for chế
# Finding translation for quyết
# Finding translation for trang
# Finding translation for nếu
# Finding translation for tham
# Finding translation for thứ
# Finding translation for chưa
# Finding translation for hệ
# Finding translation for Kinh
# Finding translation for lập
# Finding translation for đảng
# Finding translation for hỏi
# Finding translation for n
# Not in the dictionary n
# Finding translation for xem
# Finding translation for lực
# Finding translation for loại
# Finding translation for vô
# Finding translation for Các
# Finding translation for pháp
# Finding translation for chất
# Finding translation for cô
# Finding translation for tập
# Finding translation for quả
# Finding translation for ng
# Not in the dictionary ng
# Finding translation for hết
# Finding translation for Nhưng
# Finding translation for lòng
# Finding translation for an
# Finding translation for sĩ
# Finding translation for i
# Not in the dictionary i
# Finding translation for năng
# Finding translation for minh
# Finding translation for co
# Finding translation for ngoài
# Finding translation for liên
# Not in the dictionary liên
# Finding translation for Hồ
# Finding translation for thống
# Finding translation for giúp
# Finding translation for tổ
# Finding translation for xe
# Finding translation for đổi
# Finding translation for Hoa
# Finding translation for cứu
# Finding translation for tên
# Finding translation for hóa
# Not in the dictionary hóa
# Finding translation for thêm
# Finding translation for Nội
# Finding translation for đẹp
# Finding translation for thương
# Finding translation for thân
# Finding translation for phẩm
# Finding translation for thay
# Finding translation for mẹ
# Finding translation for câu
# Finding translation for máy
# Finding translation for xã
# Finding translation for xuất
# Finding translation for cứ
# Finding translation for phương
# Finding translation for nghĩ
# Finding translation for tưởng
# Finding translation for bình
# Finding translation for ban
# Finding translation for lượng
# Finding translation for Có
# Finding translation for bỏ
# Finding translation for tất
# Finding translation for Nếu
# Finding translation for gọi
# Finding translation for xin
# Finding translation for mục
# Finding translation for chung
# Finding translation for biểu
# Finding translation for nghiệp
# Finding translation for tốt
# Finding translation for đấu
# Finding translation for giả
# Finding translation for nghe
# Finding translation for luận
# Finding translation for nơi
# Finding translation for tiêu
# Finding translation for chết
# Finding translation for da
# Finding translation for trung
# Finding translation for vừa
# Finding translation for cá
# Finding translation for biệt
# Finding translation for mang
# Finding translation for ngay
# Finding translation for độc
# Finding translation for vi
# Finding translation for Pháp
# Finding translation for Người
# Finding translation for mạng
# Finding translation for Đảng
# Not in the dictionary Đảng
# Finding translation for Không
# Finding translation for ba
# Finding translation for bên
# Finding translation for quân
# Finding translation for Chúa
# Finding translation for hiểu
# Finding translation for Thánh
# Finding translation for đưa
# Finding translation for y
# Finding translation for đánh
# Finding translation for Bắc
# Finding translation for bán
# Finding translation for đâu
# Finding translation for Văn
# Finding translation for thuộc
# Finding translation for chí
# Finding translation for địa
# Finding translation for dự
# Finding translation for dẫn
# Finding translation for trí
# Finding translation for tộc
# Finding translation for dịch
# Finding translation for trả
# Finding translation for chị
# Finding translation for truyền
# Finding translation for thu
# Finding translation for sáng
# Finding translation for đọc
# Finding translation for vật
# Finding translation for trẻ
# Finding translation for lãnh
# Finding translation for ca
# Finding translation for tuổi
# Finding translation for khoa
# Finding translation for VN
# Not in the dictionary VN
# Finding translation for hoàn
# Finding translation for Khi
# Finding translation for nhìn
# Finding translation for bệnh
# Finding translation for luôn
# Finding translation for Sau
# Finding translation for Dân
# Finding translation for đình
# Finding translation for bà
# Finding translation for Ông
# Not in the dictionary Ông
# Finding translation for Đại
# Not in the dictionary Đại
# Finding translation for lợi
# Finding translation for Giáo
# Finding translation for va
# Finding translation for sức
# Finding translation for chống
# Finding translation for thích
# Finding translation for Hội
# Finding translation for chứng
# Finding translation for biến
# Finding translation for giữa
# Finding translation for tinh
# Finding translation for danh
# Finding translation for hiệu
# Finding translation for mỗi
# Finding translation for thanh
# Finding translation for chi
# Finding translation for kiến
# Finding translation for kỳ
# Not in the dictionary kỳ
# Finding translation for án
# Finding translation for từng
# Finding translation for thị
# Finding translation for luật
# Finding translation for t
# Not in the dictionary t
# Finding translation for mất
# Finding translation for khách
# Finding translation for điện
# Finding translation for tử
# Finding translation for chân
# Finding translation for lịch
# Finding translation for Nhân
# Finding translation for c
# Not in the dictionary c
# Finding translation for tiên
# Finding translation for đoàn
# Finding translation for hoạt
# Not in the dictionary hoạt
# Finding translation for ngoại
# Finding translation for Liên
# Not in the dictionary Liên
# Finding translation for đồ
# Finding translation for thiết
# Finding translation for nguyên
# Finding translation for đúng
# Finding translation for đủ
# Finding translation for cảnh
# Finding translation for cáo
# Finding translation for thư
# Finding translation for đàn
# Finding translation for kiện
# Finding translation for cung
# Finding translation for diện
# Finding translation for bởi
# Finding translation for diễn
# Finding translation for gần
# Finding translation for nghệ
# Finding translation for phòng
# Finding translation for đặc
# Finding translation for Thanh
# Finding translation for thủ
# Finding translation for cố
# Finding translation for khó
# Finding translation for lấy
# Finding translation for bố
# Finding translation for tục
# Finding translation for nữ
# Finding translation for tiến
# Finding translation for ký
# Not in the dictionary ký
# Finding translation for chọn
# Finding translation for mạnh
# Finding translation for gặp
# Finding translation for Chính
# Finding translation for Chúng
# Finding translation for triệu
# Finding translation for thần
# Finding translation for hướng
# Finding translation for càng
# Finding translation for rõ
# Finding translation for dung
# Finding translation for dưới
# Finding translation for cuối
# Finding translation for nhập
# Finding translation for Vì
# Finding translation for nhỏ
# Finding translation for thuật
# Finding translation for phản
# Finding translation for Đức
# Not in the dictionary Đức
# Finding translation for nội
# Finding translation for chẳng
# Finding translation for dù
# Finding translation for Kỳ
# Not in the dictionary Kỳ
# Finding translation for giao
# Finding translation for mắt
# Finding translation for đặt
# Finding translation for tăng
# Finding translation for Bạn
# Finding translation for gây
# Finding translation for tức
# Finding translation for nhiệm
# Not in the dictionary nhiệm
# Finding translation for phục
# Finding translation for chuyên
# Finding translation for kể
# Finding translation for dài
# Not in the dictionary dài
# Finding translation for triển
# Not in the dictionary triển
# Finding translation for giữ
# Finding translation for xây
# Finding translation for m
# Not in the dictionary m
# Finding translation for phạm
# Finding translation for xác
# Finding translation for phụ
# Finding translation for khoảng
# Finding translation for áp
# Finding translation for tượng
# Finding translation for đơn
# Finding translation for phong
# Finding translation for tích
# Finding translation for mua
# Finding translation for tu
# Finding translation for hoa
# Finding translation for ty
# Not in the dictionary ty
# Finding translation for cua
# Finding translation for xa
# Finding translation for tôn
# Finding translation for thôi
# Finding translation for phủ
# Finding translation for nam
# Finding translation for liệu
# Finding translation for đáng
# Finding translation for hãy
# Finding translation for mấy
# Finding translation for Bình
# Finding translation for sai
# Finding translation for cha
# Finding translation for thơ
# Finding translation for miền
# Finding translation for vệ
# Finding translation for dựng
# Finding translation for đăng
# Finding translation for phân
# Finding translation for vui
# Finding translation for kỷ
# Not in the dictionary kỷ
# Finding translation for Ngày
# Finding translation for nạn
# Finding translation for nổi
# Finding translation for phố
# Finding translation for Chủ
# Finding translation for tương
# Finding translation for ít
# Finding translation for tội
# Finding translation for quý
# Finding translation for sang
# Finding translation for vài
# Finding translation for vùng
# Finding translation for Hoàng
# Finding translation for hôm
# Finding translation for chứ
# Finding translation for Thế
# Finding translation for nhớ
# Finding translation for Chí
# Finding translation for A
# Not in the dictionary A
# Finding translation for bác
# Finding translation for sát
# Finding translation for Thái
# Finding translation for Và
# Finding translation for Theo
# Finding translation for nghiên
# Finding translation for toán
# Finding translation for bàn
# Finding translation for đầy
# Finding translation for chuyển
# Finding translation for Nhà
# Finding translation for sở
# Finding translation for sư
# Finding translation for gửi
# Finding translation for nhu
# Finding translation for chương
# Finding translation for Bộ
# Finding translation for chồng
# Finding translation for khai
# Finding translation for hữu
# Finding translation for kẻ
# Finding translation for Tuy
# Finding translation for du
# Finding translation for CSVN
# Not in the dictionary CSVN
# Finding translation for trời
# Finding translation for chịu
# Finding translation for Hải
# Not in the dictionary Hải
# Finding translation for quy
# Finding translation for đội
# Finding translation for khỏi
# Finding translation for Sản
# Finding translation for Đông
# Not in the dictionary Đông
# Finding translation for chia
# Finding translation for khu
# Finding translation for dễ
# Finding translation for Điều
# Not in the dictionary Điều
# Finding translation for lẽ
# Finding translation for vợ
# Finding translation for đứng
# Finding translation for xử
# Finding translation for bé
# Finding translation for xuống
# Finding translation for hạn
# Finding translation for vọng
# Finding translation for v
# Not in the dictionary v
# Finding translation for ma
# Finding translation for Sự
# Finding translation for Từ
# Finding translation for trợ
# Finding translation for a
# Not in the dictionary a
# Finding translation for Do
# Finding translation for ứng
# Finding translation for yếu
# Finding translation for trưởng
# Finding translation for kế
# Finding translation for gái
# Finding translation for gồm
# Finding translation for cổ
# Finding translation for khí
# Finding translation for hưởng
# Finding translation for cửa
# Finding translation for Nhật
# Not in the dictionary Nhật
# Finding translation for so
# Finding translation for mở
# Finding translation for lâu
# Finding translation for nghị
# Finding translation for lưu
# Finding translation for di
# Finding translation for Châu
# Finding translation for xét
# Finding translation for doanh
# Not in the dictionary doanh
# Finding translation for hộ
# Finding translation for Sơn
# Finding translation for đông
# Finding translation for chắc
# Finding translation for tỉnh
# Finding translation for hải
# Not in the dictionary hải
# Finding translation for tuần
# Finding translation for phép
# Finding translation for phá
# Finding translation for cụ
# Finding translation for âm
# Finding translation for trái
# Finding translation for khả
# Not in the dictionary khả
# Finding translation for cực
# Finding translation for tiết
# Finding translation for đau
# Finding translation for the
# Finding translation for giảm
# Finding translation for vàng
# Finding translation for khổ
# Finding translation for Lý
# Not in the dictionary Lý
# Finding translation for riêng
# Finding translation for Giê-su
# Not in the dictionary Giê-su
# Finding translation for khiến
# Finding translation for chiếc
# Finding translation for Lê
# Finding translation for chấp
# Finding translation for Tây
# Finding translation for nhạc
# Finding translation for duy
# Finding translation for chữ
# Finding translation for chơi
# Finding translation for căn
# Finding translation for nghiệm
# Finding translation for tối
# Finding translation for đoạn
# Finding translation for ngữ
# Finding translation for chạy
# Finding translation for phía
# Finding translation for đóng
# Finding translation for lai
# Finding translation for Trần
# Finding translation for giai
# Finding translation for khong
# Not in the dictionary khong
# Finding translation for to
# Finding translation for de
# Finding translation for bước
# Finding translation for ngành
# Finding translation for hậu
# Finding translation for sợ
# Finding translation for sắc
# Finding translation for Tại
# Finding translation for hòa
# Not in the dictionary hòa
# Finding translation for Xem
# Finding translation for nằm
# Finding translation for dạy
# Finding translation for nhóm
# Finding translation for lo
# Finding translation for bào
# Finding translation for lạc
# Finding translation for trách
# Finding translation for Tổng
# Finding translation for Thành
# Finding translation for trạng
# Finding translation for Âu
# Not in the dictionary Âu
# Finding translation for chuẩn
# Finding translation for Họ
# Finding translation for Hãy
# Finding translation for tù
# Finding translation for nhung
# Finding translation for dục
# Not in the dictionary dục
# Finding translation for cầm
# Finding translation for thiếu
# Finding translation for suy
# Finding translation for Đồng
# Not in the dictionary Đồng
# Finding translation for biển
# Finding translation for linh
# Finding translation for vận
# Finding translation for Tin
# Finding translation for áo
# Finding translation for ghi
# Finding translation for viện
# Finding translation for màu
# Finding translation for lệ
# Finding translation for kiếm
# Finding translation for CS
# Not in the dictionary CS
# Finding translation for tuyên
# Not in the dictionary tuyên
# Finding translation for thoại
# Not in the dictionary thoại
# Finding translation for nền
# Finding translation for Phật
# Not in the dictionary Phật
# Finding translation for tra
# Finding translation for ko
# Not in the dictionary ko
# Finding translation for Trang
# Finding translation for tố
# Finding translation for trò
# Finding translation for đổ
# Finding translation for niệm
# Finding translation for giống
# Finding translation for hồi
# Finding translation for nhanh
# Finding translation for vực
# Finding translation for Tân
# Finding translation for lắm
# Finding translation for Lan
# Finding translation for đa
# Finding translation for coi
# Finding translation for bóng
# Finding translation for Bản
# Finding translation for Xuân
# Finding translation for tín
# Finding translation for phí
# Finding translation for thiên
# Finding translation for may
# Finding translation for đảo
# Finding translation for cây
# Finding translation for châu
# Finding translation for Ban
# Finding translation for tai
# Finding translation for ngồi
# Finding translation for Con
# Finding translation for quản
# Finding translation for ơn
# Finding translation for hại
# Finding translation for kỹ
# Not in the dictionary kỹ
# Finding translation for đêm
# Finding translation for niên
# Finding translation for cập
# Not in the dictionary cập
# Finding translation for vòng
# Finding translation for dành
# Finding translation for buổi
# Finding translation for chỗ
# Finding translation for uống
# Finding translation for u
# Finding translation for thuốc
# Finding translation for mật
# Finding translation for Ba
# Finding translation for trực
# Finding translation for hương
# Finding translation for Bài
# Finding translation for tịch
# Finding translation for nguoi
# Not in the dictionary nguoi
# Finding translation for bay
# Finding translation for lớp
# Finding translation for đôi
# Finding translation for đức
# Finding translation for Tết
# Finding translation for đá
# Finding translation for trai
# Finding translation for quê
# Finding translation for duoc
# Not in the dictionary duoc
# Finding translation for Còn
# Finding translation for đòi
# Finding translation for Như
# Finding translation for tổng
# Finding translation for toi
# Finding translation for rộng
# Finding translation for Em
# Finding translation for lam
# Finding translation for xảy
# Finding translation for máu
# Finding translation for chiều
# Not in the dictionary chiều
# Finding translation for Chỉ
# Finding translation for góp
# Finding translation for cũ
# Finding translation for nguồn
# Finding translation for quảng
# Not in the dictionary quảng
# Finding translation for kiểm
# Finding translation for lễ
# Finding translation for mặc
# Finding translation for mong
# Finding translation for mức
# Finding translation for thuyết
# Finding translation for hồ
# Finding translation for cải
# Finding translation for đem
# Finding translation for An
# Finding translation for thái
# Finding translation for Thiên
# Finding translation for Phương
# Finding translation for Hòa
# Not in the dictionary Hòa
# Finding translation for phi
# Finding translation for Quân
# Finding translation for tuyệt
# Finding translation for ngàn
# Finding translation for Năm
# Finding translation for mot
# Not in the dictionary mot
# Finding translation for hát
# Not in the dictionary hát
# Finding translation for nghi
# Finding translation for lá
# Finding translation for Với
# Finding translation for Trường
# Finding translation for Nga
# Finding translation for ngôn
# Finding translation for nguyện
# Not in the dictionary nguyện
# Finding translation for lương
# Finding translation for hạnh
# Finding translation for ác
# Finding translation for nguy
# Finding translation for Sài
# Finding translation for quần
# Finding translation for lao
# Finding translation for kia
# Finding translation for trận
# Finding translation for chú
# Finding translation for dầu
# Finding translation for sẻ
# Finding translation for khẩu
# Finding translation for can
# Finding translation for lạ
# Finding translation for tướng
# Finding translation for đạt
# Finding translation for D
# Not in the dictionary D
# Finding translation for tỏ
# Finding translation for phim
# Finding translation for tuyển
# Finding translation for thất
# Finding translation for cư
# Not in the dictionary cư
# Finding translation for Gia
# Finding translation for suốt
# Finding translation for cuốn
# Finding translation for mùa
# Finding translation for bi
# Finding translation for cu
# Finding translation for đào
# Finding translation for Thứ
# Finding translation for Giá
# Finding translation for Thời
# Finding translation for Hai
# Finding translation for Cho
# Finding translation for thịt
# Finding translation for Nguyên
# Finding translation for ích
# Finding translation for phúc
# Finding translation for tiện
# Finding translation for ước
# Finding translation for vai
# Finding translation for bây
# Finding translation for Làm
# Finding translation for Để
# Not in the dictionary Để
# Finding translation for Phan
# Not in the dictionary Phan
# Finding translation for tha
# Finding translation for mãi
# Finding translation for mẫu
# Finding translation for khỏe
# Finding translation for Hàn
# Finding translation for xưa
# Finding translation for thiệu
# Not in the dictionary thiệu
# Finding translation for trắng
# Finding translation for sửa
# Finding translation for nhiệt
# Finding translation for thăm
# Finding translation for lộ
# Finding translation for Ngài
# Finding translation for Gòn
# Finding translation for dấu
# Finding translation for đảm
# Finding translation for Tư
# Finding translation for vẻ
# Finding translation for khăn
# Finding translation for B
# Not in the dictionary B
# Finding translation for voi
# Finding translation for nhiêu
# Finding translation for Thị
# Finding translation for tàu
# Finding translation for bày
# Finding translation for vượt
# Finding translation for sơ
# Finding translation for họp
# Finding translation for bức
# Finding translation for tỷ
# Not in the dictionary tỷ
# Finding translation for tờ
# Finding translation for thù
# Finding translation for xong
# Finding translation for lỗi
# Finding translation for cac
# Not in the dictionary cac
# Finding translation for Dương
# Finding translation for kéo
# Finding translation for Về
# Finding translation for hy
# Not in the dictionary hy
# Finding translation for d
# Not in the dictionary d
# Finding translation for thú
# Finding translation for cử
# Finding translation for môn
# Finding translation for Sư
# Finding translation for quanh
# Finding translation for nhờ
# Finding translation for Xin
# Finding translation for Long
# Finding translation for Ở
# Not in the dictionary Ở
# Finding translation for cười
# Finding translation for đích
# Finding translation for Bùi
# Finding translation for Bà
# Finding translation for đô
# Finding translation for h
# Not in the dictionary h
# Finding translation for phận
# Finding translation for khoản
# Finding translation for hôn
# Finding translation for Trước
# Finding translation for trại
# Finding translation for thưởng
# Finding translation for thai
# Finding translation for nha
# Finding translation for hiểm
# Finding translation for bạo
# Finding translation for Đó
# Not in the dictionary Đó
# Finding translation for xấu
# Finding translation for trăm
# Finding translation for dòng
# Finding translation for phóng
# Finding translation for C
# Not in the dictionary C
# Finding translation for đỏ
# Finding translation for lầm
# Finding translation for khá
# Finding translation for phút
# Finding translation for ngài
# Finding translation for hơi
# Finding translation for hoạch
# Not in the dictionary hoạch
# Finding translation for tấm
# Finding translation for thiện
# Finding translation for lối
# Finding translation for ngờ
# Finding translation for Thông
# Finding translation for tránh
# Finding translation for ngu
# Finding translation for thảo
# Finding translation for sẵn
# Finding translation for Tất
# Finding translation for tàn
# Not in the dictionary tàn
# Finding translation for thắng
# Finding translation for Cao
# Finding translation for món
# Finding translation for bánh
# Finding translation for thờ
# Finding translation for thầy
# Finding translation for Cách
# Finding translation for tồn
# Finding translation for tiểu
# Finding translation for biên
# Finding translation for Toàn
# Finding translation for xâm
# Finding translation for Phạm
# Finding translation for Nha
# Finding translation for HCM
# Not in the dictionary HCM
# Finding translation for ve
# Finding translation for bí
# Finding translation for sâu
# Finding translation for quen
# Finding translation for tận
# Finding translation for buồn
# Finding translation for Thủ
# Finding translation for Học
# Finding translation for thử
# Finding translation for lệnh
# Finding translation for dụ
# Finding translation for cạnh
# Finding translation for sông
# Finding translation for dám
# Finding translation for Ngọc
# Finding translation for Đây
# Not in the dictionary Đây
# Finding translation for mời
# Finding translation for Bảo
# Finding translation for Kim
# Finding translation for hạ
# Finding translation for biện
# Finding translation for xúc
# Finding translation for chút
# Finding translation for Tháng
# Finding translation for Ngoài
# Finding translation for nhằm
# Finding translation for Số
# Finding translation for nh
# Not in the dictionary nh
# Finding translation for Tự
# Finding translation for tốc
# Finding translation for kiểu
# Finding translation for cai
# Finding translation for chờ
# Finding translation for cháu
# Finding translation for Việc
# Finding translation for H
# Not in the dictionary H
# Finding translation for nỗi
# Finding translation for bọn
# Finding translation for Giáng
# Finding translation for Quảng
# Not in the dictionary Quảng
# Finding translation for tòa
# Not in the dictionary tòa
# Finding translation for su
# Finding translation for Cô
# Finding translation for tầng
# Finding translation for Nước
# Finding translation for Á
# Not in the dictionary Á
# Finding translation for nặng
# Finding translation for noi
# Finding translation for thánh
# Finding translation for chu
# Finding translation for chiếm
# Finding translation for ly
# Not in the dictionary ly
# Finding translation for ô
# Finding translation for giấy
# Finding translation for Bác
# Finding translation for đừng
# Finding translation for vốn
# Finding translation for T
# Not in the dictionary T
# Finding translation for tặng
# Finding translation for đài
# Finding translation for khủng
# Not in the dictionary khủng
# Finding translation for VND
# Not in the dictionary VND
# Finding translation for Nói
# Finding translation for đỡ
# Finding translation for xanh
# Finding translation for vũ
# Finding translation for nông
# Finding translation for hoá
# Not in the dictionary hoá
# Finding translation for Hồng
# Finding translation for Nhiều
# Finding translation for nghèo
# Finding translation for siêu
# Finding translation for cán
# Finding translation for s
# Not in the dictionary s
# Finding translation for binh
# Finding translation for nóng
# Finding translation for Vũ
# Finding translation for đáp
# Finding translation for kích
# Finding translation for đứa
# Finding translation for tri
# Not in the dictionary tri
# Finding translation for thấp
# Finding translation for môi
# Finding translation for đẳng
# Not in the dictionary đẳng
# Finding translation for nhật
# Not in the dictionary nhật
# Finding translation for thẳng
# Finding translation for mừng
# Finding translation for Ai
# Finding translation for gốc
# Finding translation for Dịch
# Finding translation for cờ
# Finding translation for quay
# Finding translation for xứ
# Finding translation for hồn
# Finding translation for dạng
# Finding translation for cướp
# Finding translation for bổ
# Finding translation for mắc
# Finding translation for hầu
# Finding translation for phái
# Finding translation for Ý
# Not in the dictionary Ý
# Finding translation for ngủ
# Finding translation for Đến
# Not in the dictionary Đến
# Finding translation for rẻ
# Finding translation for lửa
# Finding translation for kêu
# Finding translation for chắn
# Finding translation for Cái
# Finding translation for trào
# Finding translation for dưỡng
# Finding translation for Tâm
# Finding translation for Mặt
# Finding translation for mại
# Finding translation for cong
# Finding translation for Quang
# Finding translation for khắp
# Finding translation for Thầy
# Finding translation for đấy
# Finding translation for nhũng
# Finding translation for giam
# Finding translation for Giang
# Finding translation for huy
# Not in the dictionary huy
# Finding translation for cam
# Finding translation for Vậy
# Finding translation for giết
# Finding translation for Yến
# Finding translation for Vào
# Finding translation for tấn
# Finding translation for tuyến
# Finding translation for tim
# Finding translation for USD
# Not in the dictionary USD
# Finding translation for nghề
# Finding translation for dịp
# Finding translation for thuyền
# Finding translation for buộc
# Finding translation for tầm
# Finding translation for ràng
# Finding translation for bầu
# Finding translation for Thật
# Finding translation for trương
# Finding translation for thoát
# Finding translation for lẫn
# Finding translation for hoàng
# Finding translation for đám
# Finding translation for lược
# Finding translation for kho
# Finding translation for niềm
# Finding translation for diệt
# Finding translation for Cha
# Finding translation for no
# Finding translation for trao
# Finding translation for in
# Finding translation for Sinh
# Finding translation for song
# Finding translation for sắp
# Finding translation for Dù
# Finding translation for mối
# Finding translation for thuận
# Finding translation for phổ
# Finding translation for lạnh
# Finding translation for kính
# Finding translation for Viện
# Finding translation for Phòng
# Finding translation for Đoàn
# Not in the dictionary Đoàn
# Finding translation for phê
# Finding translation for giác
# Finding translation for Cũng
# Finding translation for Chiến
# Finding translation for bè
# Finding translation for TP
# Not in the dictionary TP
# Finding translation for Phi
# Finding translation for ngược
# Finding translation for chữa
# Finding translation for tắc
# Finding translation for quán
# Finding translation for dang
# Finding translation for Vinh
# Finding translation for Chi
# Finding translation for loài
# Finding translation for che
# Finding translation for sân
# Finding translation for mơ
# Finding translation for Nhạc
# Finding translation for phối
# Not in the dictionary phối
# Finding translation for ngon
# Finding translation for Tình
# Finding translation for Giải
# Finding translation for web
# Not in the dictionary web
# Finding translation for vn
# Not in the dictionary vn
# Finding translation for họa
# Not in the dictionary họa
# Finding translation for Ninh
# Finding translation for Hiệp
# Finding translation for nhắc
# Finding translation for hề
# Finding translation for sớm
# Finding translation for quên
# Finding translation for kém
# Finding translation for rút
# Finding translation for đen
# Finding translation for nhé
# Finding translation for Phụ
# Finding translation for Linh
# Finding translation for Điện
# Not in the dictionary Điện
# Finding translation for thủy
# Not in the dictionary thủy
# Finding translation for nuôi
# Finding translation for gắng
# Finding translation for Quan
# Finding translation for Đạo
# Not in the dictionary Đạo
# Finding translation for bang
# Finding translation for se
# Finding translation for lừa
# Finding translation for Y
# Finding translation for đậu
# Finding translation for giản
# Not in the dictionary giản
# Finding translation for xuyên
# Finding translation for Tổ
# Finding translation for Hình
# Finding translation for Cuộc
# Finding translation for ưu
# Finding translation for nửa
# Finding translation for ngôi
# Finding translation for tải
# Finding translation for làng
# Finding translation for cân
# Finding translation for luyện
# Finding translation for ho
# Finding translation for bạc
# Finding translation for Thực
# Finding translation for mô
# Finding translation for dần
# Finding translation for Tiên
# Finding translation for ủng
# Finding translation for thừa
# Finding translation for thúc
# Finding translation for Toán
# Finding translation for trừ
# Finding translation for ninh
# Finding translation for vang
# Finding translation for thập
# Not in the dictionary thập
# Finding translation for tan
# Finding translation for phai
# Finding translation for nhan
# Not in the dictionary nhan
# Finding translation for nghiêm
# Finding translation for Phong
# Finding translation for trích
# Finding translation for mai
# Finding translation for Mẹ
# Finding translation for nầy
# Finding translation for ngăn
# Finding translation for Tế
# Finding translation for moi
# Finding translation for Giới
# Finding translation for giám
# Finding translation for dựa
# Finding translation for La
# Finding translation for tụ
# Finding translation for tuy
# Finding translation for nắm
# Finding translation for cấm
# Finding translation for vua
# Finding translation for Thượng
# Empty translation page Thượng
# Finding translation for Máy
# Finding translation for khắc
# Finding translation for đẩy
# Finding translation for ngân
# Finding translation for lĩnh
# Not in the dictionary lĩnh
# Finding translation for núi
# Finding translation for Chứng
# Finding translation for AM
# Finding translation for giảng
# Finding translation for tien
# Not in the dictionary tien
# Finding translation for thang
# Finding translation for mềm
# Finding translation for Nó
# Finding translation for Hàng
# Finding translation for ấn
# Finding translation for nâng
# Finding translation for Sao
# Finding translation for xếp
# Finding translation for trì
# Finding translation for gió
# Finding translation for già
# Finding translation for gương
# Finding translation for Báo
# Finding translation for ơi
# Finding translation for sạch
# Finding translation for cường
# Finding translation for Xô
# Finding translation for tường
# Finding translation for chiếu
# Finding translation for Phần
# Finding translation for chuyến
# Finding translation for bờ
# Finding translation for tả
# Finding translation for nêu
# Finding translation for Mỗi
# Finding translation for ngắn
# Finding translation for chăm
# Finding translation for Xã
# Finding translation for ngại
# Finding translation for nghỉ
# Finding translation for đón
# Finding translation for Đình
# Not in the dictionary Đình
# Finding translation for truy
# Finding translation for Lúc
# Finding translation for miệng
# Finding translation for tị
# Finding translation for hỗ
# Not in the dictionary hỗ
# Finding translation for VC
# Not in the dictionary VC
# Finding translation for lựa
# Finding translation for Hiện
# Finding translation for đương
# Finding translation for lan
# Finding translation for khởi
# Not in the dictionary khởi
# Finding translation for gi
# Not in the dictionary gi
# Finding translation for Thu
# Finding translation for Điểm
# Not in the dictionary Điểm
# Finding translation for p
# Not in the dictionary p
# Finding translation for liệt
# Finding translation for hắn
# Finding translation for cánh
# Finding translation for bại
# Finding translation for Mục
# Finding translation for Chị
# Finding translation for Được
# Not in the dictionary Được
# Finding translation for phù
# Finding translation for hùng
# Finding translation for đợi
# Finding translation for kim
# Finding translation for xương
# Empty translation page xương
# Finding translation for Cơ
# Finding translation for phó
# Finding translation for hiệp
# Finding translation for quà
# Finding translation for dữ
# Finding translation for b
# Not in the dictionary b
# Finding translation for hẳn
# Finding translation for Luật
# Finding translation for thượng
# Empty translation page thượng
# Finding translation for pha
# Finding translation for sứ
# Finding translation for Thống
# Finding translation for Thơ
# Finding translation for Phú
# Finding translation for ngộ
# Finding translation for lính
# Finding translation for Chương
# Finding translation for san
# Finding translation for tô
# Finding translation for ngang
# Finding translation for hồng
# Finding translation for giàu
# Finding translation for đói
# Finding translation for đoán
# Finding translation for vay
# Finding translation for chụp
# Finding translation for tạm
# Finding translation for tỉ
# Finding translation for tung
# Finding translation for Thư
# Finding translation for rượu
# Finding translation for địch
# Finding translation for đế
# Finding translation for Hương
# Finding translation for Đăng
# Not in the dictionary Đăng
# Finding translation for hào
# Finding translation for Quyền
# Finding translation for hấp
# Finding translation for chục
# Finding translation for sàng
# Finding translation for rừng
# Empty translation page rừng
# Finding translation for chánh
# Finding translation for Tìm
# Finding translation for Bí
# Finding translation for lành
# Finding translation for khảo
# Finding translation for dứt
# Finding translation for nhẹ
# Finding translation for dau
# Not in the dictionary dau
# Finding translation for van
# Finding translation for Tiếng
# Finding translation for Câu
# Finding translation for Chuyện
# Finding translation for dàng
# Not in the dictionary dàng
# Finding translation for Viet
# Not in the dictionary Viet
# Finding translation for VNCH
# Not in the dictionary VNCH
# Finding translation for Thích
# Finding translation for ánh
# Finding translation for nối
# Finding translation for nuoc
# Not in the dictionary nuoc
# Finding translation for miễn
# Finding translation for dậy
# Finding translation for Huy
# Not in the dictionary Huy
# Finding translation for sữa
# Finding translation for Kết
# Finding translation for tóc
# Finding translation for màn
# Finding translation for hút
# Finding translation for thuê
# Finding translation for sóc
# Finding translation for Ngô
# Finding translation for cắt
# Finding translation for Trên
# Finding translation for sắt
# Finding translation for nhieu
# Not in the dictionary nhieu
# Finding translation for biet
# Not in the dictionary biet
# Finding translation for Trưởng
# Finding translation for PM
# Not in the dictionary PM
# Finding translation for đuổi
# Finding translation for th
# Not in the dictionary th
# Finding translation for dây
# Finding translation for Mình
# Finding translation for sung
# Finding translation for soát
# Finding translation for nhảy
# Finding translation for Nhất
# Finding translation for chào
# Finding translation for Chẳng
# Finding translation for phiên
# Finding translation for khô
# Finding translation for Phải
# Finding translation for oan
# Finding translation for Tài
# Finding translation for chứa
# Finding translation for vu
# Finding translation for thảm
# Finding translation for k
# Not in the dictionary k
# Finding translation for dị
# Finding translation for Ta
# Finding translation for Mai
# Finding translation for trụ
# Finding translation for mê
# Finding translation for gà
# Finding translation for Hôm
# Finding translation for dong
# Finding translation for Võ
# Finding translation for Mã
# Finding translation for Lời
# Finding translation for trùng
# Finding translation for mỹ
# Not in the dictionary mỹ
# Finding translation for mưa
# Finding translation for lục
# Finding translation for doi
# Not in the dictionary doi
# Finding translation for băng
# Finding translation for blog
# Not in the dictionary blog
# Finding translation for Hồi
# Finding translation for chỉnh
# Finding translation for rơi
# Finding translation for hài
# Finding translation for hoi
# Finding translation for chợ
# Finding translation for Huế
# Not in the dictionary Huế
# Finding translation for xinh
# Finding translation for rối
# Finding translation for day
# Finding translation for chừng
# Finding translation for khẳng
# Finding translation for dan
# Not in the dictionary dan
# Finding translation for khuyến
# Not in the dictionary khuyến
# Finding translation for Ngay
# Finding translation for Khoa
# Finding translation for thổ
# Finding translation for Tiền
# Finding translation for Sở
# Finding translation for rời
# Finding translation for vững
# Finding translation for Trời
# Finding translation for mộ
# Finding translation for canh
# Finding translation for Vụ
# Finding translation for Mới
# Finding translation for dinh
# Finding translation for tệ
# Finding translation for thậm
# Finding translation for lắng
# Finding translation for Diễn
# Finding translation for tán
# Finding translation for thao
# Finding translation for bo
# Not in the dictionary bo
# Finding translation for Sĩ
# Finding translation for Úc
# Not in the dictionary Úc
# Finding translation for tươi
# Finding translation for mưu
# Finding translation for dõi
# Finding translation for bốn
# Finding translation for Hiến
# Finding translation for vong
# Finding translation for N
# Not in the dictionary N
# Finding translation for xu
# Finding translation for than
# Finding translation for sóng
# Finding translation for rat
# Not in the dictionary rat
# Finding translation for The
# Finding translation for hộp
# Finding translation for e
# Finding translation for Du
# Finding translation for nho
# Finding translation for hạng
# Finding translation for Hữu
# Finding translation for of
# Not in the dictionary of
# Finding translation for cơn
# Finding translation for Nghệ
# Finding translation for vao
# Not in the dictionary vao
# Finding translation for súng
# Finding translation for chua
# Finding translation for Cả
# Finding translation for rửa
# Finding translation for hang
# Finding translation for Qua
# Finding translation for Cần
# Finding translation for Ủy
# Not in the dictionary Ủy
# Finding translation for Đà
# Not in the dictionary Đà
# Finding translation for mo
# Finding translation for Mọi
# Finding translation for website
# Not in the dictionary website
# Finding translation for thí
# Finding translation for khối
# Finding translation for bậc
# Finding translation for Yêu
# Finding translation for Lâm
# Finding translation for dư
# Finding translation for nợ
# Finding translation for cưới
# Finding translation for Hùng
# Finding translation for Bán
# Finding translation for mắn
# Finding translation for kháng
# Finding translation for yên
# Finding translation for tùy
# Not in the dictionary tùy
# Finding translation for thẻ
# Finding translation for liền
# Finding translation for chấm
# Finding translation for khóc
# Finding translation for Trả
# Finding translation for Quý
# Finding translation for Hằng
# Finding translation for hiến
# Finding translation for chay
# Finding translation for buôn
# Finding translation for Tiến
# Finding translation for Hy
# Not in the dictionary Hy
# Finding translation for Bởi
# Finding translation for phán
# Finding translation for chăng
# Finding translation for gởi
# Finding translation for Là
# Finding translation for cựu
# Finding translation for điển
# Finding translation for Đã
# Not in the dictionary Đã
# Finding translation for tr
# Not in the dictionary tr
# Finding translation for mười
# Finding translation for khóa
# Not in the dictionary khóa
# Finding translation for dối
# Finding translation for Sa
# Finding translation for Nữ
# Finding translation for mã
# Finding translation for dương
# Finding translation for Nghe
# Finding translation for Hơn
# Finding translation for roi
# Finding translation for giành
# Finding translation for Quản
# Finding translation for Phát
# Finding translation for Hóa
# Not in the dictionary Hóa
# Finding translation for ẩn
# Finding translation for Độ
# Not in the dictionary Độ
# Finding translation for loạn
# Finding translation for Trận
# Finding translation for Triều
# Finding translation for com
# Not in the dictionary com
# Finding translation for huyện
# Finding translation for triết
# Finding translation for sạn
# Finding translation for mụn
# Finding translation for hon
# Not in the dictionary hon
# Finding translation for cơm
# Finding translation for chúc
# Finding translation for Lịch
# Finding translation for Duy
# Finding translation for thoi
# Finding translation for Tham
# Finding translation for Mác
# Finding translation for tạp
# Finding translation for trần
# Finding translation for điệu
# Finding translation for phạt
# Finding translation for khúc
# Finding translation for cấu
# Finding translation for đốc
# Finding translation for ví
# Finding translation for tây
# Finding translation for trải
# Finding translation for kiên
# Finding translation for Mặc
# Finding translation for nhiễm
# Finding translation for dáng
# Finding translation for Tàu
# Finding translation for Định
# Not in the dictionary Định
# Finding translation for thẩm
# Finding translation for thác
# Finding translation for Cầu
# Finding translation for ổn
# Finding translation for thằng
# Finding translation for quận
# Finding translation for VT
# Not in the dictionary VT
# Finding translation for Tăng
# Finding translation for ấm
# Finding translation for mái
# Finding translation for lặng
# Finding translation for bữa
# Finding translation for bắn
# Finding translation for bảng
# Finding translation for sa
# Finding translation for khen
# Finding translation for hot
# Not in the dictionary hot
# Finding translation for ch
# Not in the dictionary ch
# Finding translation for Tam
# Finding translation for đập
# Finding translation for vinh
# Finding translation for tân
# Finding translation for tái
# Finding translation for thả
# Finding translation for Bây
# Finding translation for Đào
# Not in the dictionary Đào
# Finding translation for trứng
# Finding translation for tao
# Finding translation for phiếu
# Finding translation for nấu
# Finding translation for lão
# Finding translation for hủy
# Not in the dictionary hủy
# Finding translation for hoà
# Not in the dictionary hoà
# Finding translation for Tòa
# Not in the dictionary Tòa
# Finding translation for trông
# Finding translation for thua
# Finding translation for len
# Finding translation for qui
# Not in the dictionary qui
# Finding translation for Miền
# Finding translation for Ảnh
# Not in the dictionary Ảnh
# Finding translation for xuân
# Finding translation for thụ
# Not in the dictionary thụ
# Finding translation for lượt
# Finding translation for ương
# Finding translation for xung
# Finding translation for sánh
# Finding translation for ghe
# Finding translation for Kỹ
# Not in the dictionary Kỹ
# Finding translation for Chung
# Finding translation for Canada
# Not in the dictionary Canada
# Finding translation for rau
# Finding translation for hạt
# Finding translation for bật
# Finding translation for ung
# Finding translation for nàng
# Finding translation for mệnh
# Finding translation for muối
# Finding translation for Tử
# Finding translation for Rồi
# Finding translation for Phúc
# Finding translation for ngã
# Finding translation for VIỆT
# Not in the dictionary VIỆT
# Finding translation for Ngoại
# Finding translation for NAM
# Finding translation for kê
# Finding translation for hãng
# Finding translation for cậu
# Finding translation for ĐCSTQ
# Not in the dictionary ĐCSTQ
# Finding translation for hư
# Finding translation for chinh
# Not in the dictionary chinh
# Finding translation for I
# Not in the dictionary I
# Finding translation for CN
# Not in the dictionary CN
# Finding translation for viet
# Not in the dictionary viet
# Finding translation for Hay
# Finding translation for Đường
# Not in the dictionary Đường
# Finding translation for tiếc
# Finding translation for thiệt
# Finding translation for nổ
# Finding translation for nét
# Finding translation for nao
# Finding translation for cà
# Finding translation for VÀ
# Not in the dictionary VÀ
# Finding translation for M
# Not in the dictionary M
# Finding translation for đua
# Finding translation for den
# Not in the dictionary den
# Finding translation for Vô
# Finding translation for ĐH
# Not in the dictionary ĐH
# Finding translation for trúc
# Finding translation for Phó
# Finding translation for tren
# Not in the dictionary tren
# Finding translation for quang
# Finding translation for email
# Not in the dictionary email
# Finding translation for Danh
# Finding translation for tam

# %%
dictionary

# %%
with open('vdict VI-FR.json', 'w') as outfile:
    json.dump(dictionary, outfile)

# %%
findTranslation("thượng")
