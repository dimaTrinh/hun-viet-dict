# %%
import urllib.request 
from urllib.parse import quote 
from bs4 import BeautifulSoup
import json
import re
import time

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import json
with open('/content/gdrive/My Drive/Colab Notebooks/Dictionary Project/freqlist.json') as json_file:
     wordsData = json.load(json_file)
wordList = list(wordsData.keys())
len(wordList)
# Out:
# 14143

# %%
posDict = {} #a dictionary to translate POS words in Vietnamese to English
posDict["Động từ"] = "verb"
posDict["Danh từ"] = "noun"
posDict["Nghĩa chuyên ngành"] = "jargon"
posDict["*"] = "N/A"
posDict["Trạng ngữ"] = "adverb"
posDict["Cảm thán"] = "interjection"
posDict["Phó từ"] = "adverb"
posDict["Từ nối"] = "conjunction"
posDict["Từ đệm"] = "N/A"
posDict["Đại từ"] = "pronoun"

# %%
#The link format for soha Viet-Eng is: http://tratu.soha.vn/dict/vn_en/C%C3%B3

# %%
url = "http://tratu.soha.vn/dict/vn_en/" + quote("như") #resolving the IRI issue

try:
    source = urllib.request.urlopen(url)
except:
    print( "Link broken")
soup = BeautifulSoup(source, 'lxml')

# %%
groups = soup.findAll("div", class_ = "section-h3") #soha groups their translations by POS

# %%
containers = soup.findAll("div", class_ = "section-h5")

# %%
containers[0].parent
# Out:
# <div class="section-h2" id="show-alter"><h2> <span class="mw-headline">Thông dụng</span></h2>
# <a name="As."></a><div class="section-h5" id="content-5"><h5> <span class="mw-headline">As.</span></h5>
# <dl><dd><dl><dd><a href="/dict/vn_en/L%C3%A0m" title="Làm">làm</a> <strong class="selflink">như</strong> <a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a>
# </dd><dd>Do as I do.
# </dd></dl>
# </dd></dl>
# <a name="Like."></a></div><div class="section-h5" id="content-5"><h5> <span class="mw-headline">Like.</span></h5>
# <dl><dd><dl><dd><a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a> <a href="/dict/vn_en/C%C5%A9ng" title="Cũng">cũng</a> <a href="/dict/vn_en/Ngh%C4%A9" title="Nghĩ">nghĩ</a> <strong class="selflink">như</strong> <a href="/dict/vn_en/Anh" title="Anh">anh</a>
# </dd><dd>I think like you.
# </dd><dd>_alike; similar to.
# </dd><dd><a href="/dict/vn_en/Tr%C6%B0%E1%BB%9Dng" title="Trường">trường</a> <a href="/dict/vn_en/H%E1%BB%A3p" title="Hợp">hợp</a> <a href="/dict/vn_en/Anh" title="Anh">anh</a> <a href="/dict/vn_en/Gi%E1%BB%91ng" title="Giống">giống</a> <strong class="selflink">như</strong> <a href="/dict/vn_en/Tr%C6%B0%E1%BB%9Dng" title="Trường">trường</a> <a href="/dict/vn_en/H%E1%BB%A3p" title="Hợp">hợp</a> <a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a>
# </dd><dd>Your case is similar to mine.
# </dd></dl>
# </dd></dl>
# <!-- Saved in parser cache with key wikidbv2-vn_en:pcache:idhash:691271-0!1!0!!vi!2!edit=0 and timestamp 20150727161032 -->
# </div></div>

# %%
containers[0].find("dl").find("dd").find("dl").findAll("dd")
# Out:
# [<dd><a href="/dict/vn_en/L%C3%A0m" title="Làm">làm</a> <strong class="selflink">như</strong> <a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a>
#  </dd>, <dd>Do as I do.
#  </dd>]

# %%
#detect whether a tag contains a link, if a link is present, the tag contains a context
def hasLink(tag):
    try:
        subTags = tag.findAll('a')
    except:
        return False
    for subTag in subTags:
        if (subTag.get('href')): #found a link
            return True
    return False

# %%
hasLink(containers[0].find("dl").find("dd").find("dl").findAll("dd")[1])
# Out:
# False

# %%
def extractContext(tag):
    parts = list(tag.children)
    parts = filter(lambda x: False if x == ' ' or x == '\n' else True, parts) #filter all the non-words out
    parts = [part.contents[0] for part in parts]
    context = " ".join(parts)
    return context

# %%
extractContext(containers[0].find("dl").find("dd").find("dl").findAll("dd")[0])
# Out:
# 'làm như tôi'

# %%
unknownPos = []
def getPos(vietPos): #translating the POS in Viet to English
    vietPos = vietPos.strip(".")
    if (vietPos.find("(") != -1): #the vietPos contains the english equivalent
        return vietPos[vietPos.find("(")+1:vietPos.find(")")].strip()
    elif (vietPos in posDict):
        return posDict[vietPos]
    else:
        unknownPos.append(vietPos)
        return "N/A"

# %%
getPos("Động từ")
# Out:
# 'verb'

# %%
getPos("Phó từ ( affirmative particle)")
# Out:
# 'affirmative particle'

# %%
def resolveItalic(parts): #soha use italic to mark an use of "'"
    parts = [str(part) for part in parts]
    if (len(parts) == 1): #nothing special here, just return the string
        return [item.strip() for item in re.split('[.,;]', str(parts[0]))]
    parts = [part.replace("<i>", "'").replace("</i>", "") for part in parts]
    if (parts[-1] == '\n'): #this is an usage, ignore the last part
        return [item.strip() for item in re.split('[.,;]', "".join(parts[:-1]))]
    #this is a translation
    return [item.strip() for item in re.split('[.,;]', "".join(parts))]

# %%
def findTranslation(word):
    print("Finding translation for " + word)
    url = "http://tratu.soha.vn/dict/vn_en/" + quote(word) #resolving the IRI issue

    try:
        source = urllib.request.urlopen(url)
    except:
        print("Link broken for " + word)
        return "N/A"

    soup = BeautifulSoup(source, 'lxml')
    
    translations = {}
    numTrans = 0
 
    containers = soup.findAll("div", class_ = "section-h5") #getting all the translations for a word
    if (containers is None or containers == []):
      print("No translations found for " + word)
      return "N/A"
 
    for trans in containers: #for each translation in this group
        temp = {} #temp dict to store each translation of a word

        #getting the raw translation
        temp['translation'] = resolveItalic(trans.find("h5").find("span").contents)
        
        parentTag = trans.parent
        try:
          if (parentTag.attrs["class"] == "section-h3"): #has POS
            temp['POS'] = getPos(group.find("h3").find("span").string)
          else:
            temp['POS'] = "N/A"
        except: #no POS
            temp['POS'] = "N/A"

        try:
            #retrieving the examples and contexts of this translation
            clarifications = trans.find("dl").find("dd").find("dl").findAll("dd")
            temp2 = {} #another dict to store each examples of a translation
            
            numContext = 0;
            numUsage = 0;
            
            for item in clarifications:
                if (hasLink(item)): #this is a context (context contains hyperlink)
                    temp2['context ' + str(numContext+1)] = extractContext(item)
                    numContext += 1
                else: #this is an usage
                    temp2['usage ' + str(numUsage+1)] = resolveItalic(item.contents)
                    numUsage += 1
            
            temp2['nums context'] = numContext
            temp2['nums usage'] = numUsage

            temp['examples'] = temp2
        except:
            temp['examples'] = "N/A"

        translations[numTrans+1] = temp #adding the translation to the dictionary
        numTrans += 1
            
    #storing the number of translations
    translations['nums'] = numTrans
    return translations

# %%
findTranslation("như")
# Out:
# Finding translation for như
# {1: {'POS': 'N/A',
#   'examples': {'context 1': 'làm như tôi',
#    'nums context': 1,
#    'nums usage': 1,
#    'usage 1': ['Do as I do', '']},
#   'translation': ['As', '']},
#  2: {'POS': 'N/A',
#   'examples': {'context 1': 'tôi cũng nghĩ như anh',
#    'context 2': 'trường hợp anh giống như trường hợp tôi',
#    'nums context': 2,
#    'nums usage': 3,
#    'usage 1': ['I think like you', ''],
#    'usage 2': ['_alike', 'similar to', ''],
#    'usage 3': ['Your case is similar to mine', '']},
#   'translation': ['Like', '']},
#  'nums': 2}

# %%
findTranslation("tôi")
# Out:
# Finding translation for tôi
# {1: {'POS': 'N/A',
#   'examples': {'nums context': 0,
#    'nums usage': 3,
#    'usage 1': ['subject'],
#    'usage 2': ['servant'],
#    'usage 3': ['self']},
#   'translation': ['Danh từ']},
#  10: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['arrival']},
#  11: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['arrive']},
#  12: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['ingoing']},
#  13: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['capstan']},
#  14: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['drawwork']},
#  15: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['gin']},
#  16: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['hauler']},
#  17: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['jack up']},
#  18: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['purchase']},
#  19: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['sheave']},
#  2: {'POS': 'N/A',
#   'examples': {'nums context': 0,
#    'nums usage': 2,
#    'usage 1': ['I', 'me'],
#    'usage 2': ['to temper', 'to slake']},
#   'translation': ['Động từ']},
#  20: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['winch capstan']},
#  21: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['winding engine']},
#  22: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['defective']},
#  23: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['foul']},
#  24: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['garlicky']},
#  25: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['crumbly']},
#  26: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['friable']},
#  27: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['windlass']},
#  28: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['wrong']},
#  3: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['bad']},
#  4: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['friable']},
#  5: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['chilling']},
#  6: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['cure']},
#  7: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['dip']},
#  8: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['thoriveitite']},
#  9: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['advent']},
#  'nums': 28}

# %%
dictionary = {}
start_time = time.time()
for word in wordList:
    dictionary[word] = findTranslation(word)
    time.sleep(1) #wait for 1 sec between each query
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Streaming output truncated to the last 5000 lines.
# Finding translation for andromakhe
# No translations found for andromakhe
# Finding translation for briseis
# No translations found for briseis
# Finding translation for aiolian
# No translations found for aiolian
# Finding translation for korinth
# No translations found for korinth
# Finding translation for kalchas
# No translations found for kalchas
# Finding translation for antenor
# No translations found for antenor
# Finding translation for alexandros
# No translations found for alexandros
# Finding translation for euneos
# No translations found for euneos
# Finding translation for sarpedon
# No translations found for sarpedon
# Finding translation for aineias
# No translations found for aineias
# Finding translation for pandaros
# No translations found for pandaros
# Finding translation for meleagros
# No translations found for meleagros
# Finding translation for bellerophontes
# No translations found for bellerophontes
# Finding translation for laomedon
# No translations found for laomedon
# Finding translation for ida
# No translations found for ida
# Finding translation for aulis
# No translations found for aulis
# Finding translation for ổ.
# No translations found for ổ.
# Finding translation for tóp
# No translations found for tóp
# Finding translation for tép
# Finding translation for ngặm
# No translations found for ngặm
# Finding translation for hekabe
# No translations found for hekabe
# Finding translation for thersites
# No translations found for thersites
# Finding translation for dardanos
# No translations found for dardanos
# Finding translation for glaukos
# No translations found for glaukos
# Finding translation for lykia
# No translations found for lykia
# Finding translation for roman
# No translations found for roman
# Finding translation for chryses
# No translations found for chryses
# Finding translation for chryse
# No translations found for chryse
# Finding translation for chryseis
# No translations found for chryseis
# Finding translation for simoeisios
# Finding translation for smollet
# No translations found for smollet
# Finding translation for snelling
# No translations found for snelling
# Finding translation for mein
# No translations found for mein
# Finding translation for tt
# No translations found for tt
# Finding translation for goldaming
# No translations found for goldaming
# Finding translation for paddington
# No translations found for paddington
# Finding translation for sóat
# No translations found for sóat
# Finding translation for arminius
# No translations found for arminius
# Finding translation for bermondsey
# No translations found for bermondsey
# Finding translation for bloxam
# No translations found for bloxam
# Finding translation for candy
# No translations found for candy
# Finding translation for mitchel
# No translations found for mitchel
# Finding translation for enoch
# No translations found for enoch
# Finding translation for mile
# No translations found for mile
# Finding translation for czarina
# No translations found for czarina
# Finding translation for winchester
# No translations found for winchester
# Finding translation for kukri
# No translations found for kukri
# Finding translation for galatz
# No translations found for galatz
# Finding translation for roumanian
# No translations found for roumanian
# Finding translation for hildesheim
# No translations found for hildesheim
# Finding translation for skinsky
# No translations found for skinsky
# Finding translation for pruth
# No translations found for pruth
# Finding translation for sereth
# No translations found for sereth
# Finding translation for fundu
# No translations found for fundu
# Finding translation for bistritza
# No translations found for bistritza
# --- 31347.70158815384 seconds ---

# %%
dictionary
# Out:
# {'thông': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0, 'nums usage': 1, 'usage 1': ['pine']},
#    'translation': ['Danh từ']},
#   2: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 1,
#     'usage 1': ['through', 'clear', 'unchocked']},
#    'translation': ['Tính từ']},
#   3: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 2,
#     'usage 1': ['to clear off', 'to unchock', 'to unclog'],
#     'usage 2': ['to open', 'to allow', 'traffic through']},
#    'translation': ['Động từ']},
#   4: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['clear-to-send']},
#   5: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['hamlet']},
#   'nums': 5},
#  'tin': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 1,
#     'usage 1': ['news', 'information']},
#    'translation': ['Danh từ']},
#   2: {'POS': 'N/A',
#    'examples': {'nums context': 0, 'nums usage': 1, 'usage 1': ['to believe']},
#    'translation': ['Động từ']},
#   'nums': 2},
#  'ebook': 'N/A',
#  'tên': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 3,
#     'usage 1': ['arrow'],
#     'usage 2': ['name'],
#     'usage 3': ['chap', 'bloke']},
#    'translation': ['Danh từ']},
#   2: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['descriptor']},
#   3: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['missile']},
#   4: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['nominal']},
#   5: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['appellation']},
#   6: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['style']},
#   7: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['title']},
#   'nums': 7},
#  'truyện': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0, 'nums usage': 1, 'usage 1': ['story']},
#    'translation': ['Danh từ']},
#   'nums': 1},
#  'nguyên': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'dầu nguyên chất',
#     'context 2': 'quặng nguyên',
#     'context 3': 'quặng nguyên khai',
#     'nums context': 3,
#     'nums usage': 3,
#     'usage 1': ['crude oil'],
#     'usage 2': ['crude oil storage tank'],
#     'usage 3': ['crude ore']},
#    'translation': ['crude']},
#   10: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['whole']},
#   11: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 2,
#     'usage 1': ['former president'],
#     'usage 2': ['nguyên tổng thống']},
#    'translation': ['former']},
#   2: {'POS': 'N/A',
#    'examples': {'context 1': 'cấp tăng của một hàm nguyên',
#     'context 2': 'chỉ tìm nguyên ô',
#     'context 3': 'giống của một hàm nguyên',
#     'context 4': 'hàm hữu tỷ nguyên',
#     'context 5': 'hàm nguyên',
#     'context 6': 'hàm nguyên loại cực tiểu',
#     'context 7': 'hàm phần nguyên',
#     'nums context': 7,
#     'nums usage': 7,
#     'usage 1': ['growth of an entire function'],
#     'usage 2': ['find entire cell only'],
#     'usage 3': ['genre of an entire function'],
#     'usage 4': ['entire rational function'],
#     'usage 5': ['entire function'],
#     'usage 6': ['entire function of zero type'],
#     'usage 7': ['function of entire part']},
#    'translation': ['entire']},
#   3: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['integer']},
#   4: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['integral']},
#   5: {'POS': 'N/A',
#    'examples': {'context 1': 'dầm nguyên',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['ordinary beam']},
#    'translation': ['ordinary']},
#   6: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['prot (o)']},
#   7: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['raw']},
#   8: {'POS': 'N/A',
#    'examples': {'context 1': 'bậc nguyên',
#     'context 10': 'trục gá nguyên',
#     'context 11': 'được chế tạo nguyên khối',
#     'context 2': 'cột nguyên',
#     'context 3': 'gạch nguyên',
#     'context 4': 'mài bằng thỏi nguyên',
#     'context 5': 'nhịp cầu thang nguyên khối',
#     'context 6': 'ổ trục nguyên khối',
#     'context 7': 'tarô nguyên',
#     'context 8': 'thân cầu thang nguyên khối',
#     'context 9': 'trụ nguyên',
#     'nums context': 11,
#     'nums usage': 11,
#     'usage 1': ['solid tread'],
#     'usage 10': ['solid mandrel'],
#     'usage 11': ['made solid with'],
#     'usage 2': ['solid post'],
#     'usage 3': ['solid brick'],
#     'usage 4': ['solid-ground'],
#     'usage 5': ['solid flight of stairs'],
#     'usage 6': ['solid bearing'],
#     'usage 7': ['solid tap'],
#     'usage 8': ['solid flight of stairs'],
#     'usage 9': ['solid post']},
#    'translation': ['solid']},
#   9: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['sound']},
#   'nums': 11},
#  'tác': 'N/A',
#  'tiếng': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 4,
#     'usage 1': ['sound', 'voice'],
#     'usage 2': ['language'],
#     'usage 3': ['name', 'reputation'],
#     'usage 4': ['hour']},
#    'translation': ['Danh từ']},
#   2: {'POS': 'N/A',
#    'examples': {'context 1': 'ấn bản tiếng Nhật',
#     'context 2': 'phiên bản tiếng Nhật',
#     'context 3': 'sự hiểu rõ tiếng nói',
#     'nums context': 3,
#     'nums usage': 3,
#     'usage 1': ['Japanese (language) version', 'edition'],
#     'usage 2': ['Japanese (language) version', 'edition'],
#     'usage 3': ['language understanding']},
#    'translation': ['language']},
#   3: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['sound']},
#   4: {'POS': 'N/A',
#    'examples': {'context 1': 'bảng mạch tiếng nói',
#     'context 10': 'công nghệ nhận dạng tiếng nói',
#     'context 11': 'công nghệ xử lý tiếng nói',
#     'context 12': 'dải tần số tiếng nói',
#     'context 13': 'dải tần tiếng nói',
#     'context 14': 'dải tiếng nói',
#     'context 15': 'dữ liệu dưới tiếng nói',
#     'context 16': 'dữ liệu tiếng mã xung',
#     'context 17': 'dữ liệu tiếng mã xung',
#     'context 18': 'dữ liệu trên tiếng nói',
#     'context 19': 'hộp thư có tiếng nói',
#     'context 2': 'bộ dò tiếng nói',
#     'context 20': 'hộp thư tiếng nói',
#     'context 21': 'kênh báo hiệu tiếng nói',
#     'context 22': 'kênh tiếng',
#     'context 23': 'kênh tiếng nói',
#     'context 24': 'Khuyến nghị G.711 của ITU về điểm xung mã các tần số tiếng nói',
#     'context 25': 'kỹ thuật nhận dạng tiếng nói',
#     'context 26': 'kỹ thuật xử lý tiếng nói',
#     'context 27': 'mã hóa tiếng nói',
#     'context 28': 'mã tiếng nói',
#     'context 29': 'mạng tiếng nói',
#     'context 3': 'bộ mã hóa tiếng nói',
#     'context 30': 'máy ghi tiếng nói',
#     'context 31': 'máy tính và sự trả lời bằng tiếng nói tương tác',
#     'context 32': 'mức tiếng nói',
#     'context 33': 'nén tiếng',
#     'context 34': 'nhận biết tiếng nói không phụ thuộc người nói',
#     'context 35': 'nhận biết tiếng nói tự động',
#     'context 36': 'nhận dạng tiếng nói',
#     'context 37': 'nhập tiếng nói',
#     'context 38': 'rãnh tiếng nói',
#     'context 39': 'sự chuyển gói tiếng nói/dữ liệu',
#     'context 4': 'bộ mã hóa tiếng nói',
#     'context 40': 'sự nhập dữ liệu tiếng nói',
#     'context 41': 'sự nhập dữ liệu tiếng nói',
#     'context 42': 'sự phát tiếng nói đã thu',
#     'context 43': 'sự phát tiếng nói đã thu',
#     'context 44': 'sự thử mức tiếng nói',
#     'context 45': 'sự truyền tiếng nói',
#     'context 46': 'sự xử lý tiếng nói',
#     'context 47': 'tần số tiếng nói',
#     'context 48': 'tần số tiếng nói',
#     'context 49': 'tần số tiếng nói',
#     'context 5': 'bộ mã hóa tiếng nói',
#     'context 50': 'thiết bị nhận biết tiếng nói',
#     'context 51': 'thiết bị nhận biết tiếng nói',
#     'context 52': 'thiết bị nhận tiếng nói',
#     'context 53': 'thiết bị phát tiếng nói đã thu',
#     'context 54': 'thiết bị xuất tiếng nói',
#     'context 55': 'thiết bị xuất tiếng nói',
#     'context 56': 'thông báo tiếng nói',
#     'context 57': 'thông tin bằng tiếng nói',
#     'context 58': 'thông điệp tiếng nói',
#     'context 59': 'thư tiếng nói',
#     'context 6': 'bộ nhận biết tiếng nói',
#     'context 60': 'tiếng an toàn',
#     'context 61': 'tiếng nói và số liệu đồng thời kiểu số',
#     'context 62': 'tiếng nói và số liệu đồng thời tương tự',
#     'context 63': 'Tiếng nói và truyền thoại qua ATM',
#     'context 64': 'tiếng thổi hang',
#     'context 65': 'tổng hợp tiếng nói',
#     'context 66': 'trả lời bằng tiếng nói',
#     'context 67': 'trả lời bằng tiếng nói',
#     'context 68': 'trả lời bằng tiếng nói',
#     'context 69': 'truyền thông tiếng nói',
#     'context 7': 'bộ nhiễu số loại tiếng nói',
#     'context 70': 'vi mạch tiếng nói',
#     'context 71': 'đáp ứng tiếng nói',
#     'context 72': 'đầu ra tiếng nói',
#     'context 73': 'điều biến tiếng nói dải hẹp',
#     'context 74': 'điều biến tiếng nói dải hẹp',
#     'context 75': 'đơn vị tiếng nói',
#     'context 76': 'đơn vị tiếng nói',
#     'context 8': 'bộ tổng hợp tiếng nói',
#     'context 9': 'bộ đáp ứng tiếng nói',
#     'nums context': 76,
#     'nums usage': 76,
#     'usage 1': ['voice board'],
#     'usage 10': ['voice recognition technology'],
#     'usage 11': ['voice processing technology'],
#     'usage 12': ['voice frequency band'],
#     'usage 13': ['voice-band'],
#     'usage 14': ['voice band'],
#     'usage 15': ['data under voice'],
#     'usage 16': ['PCVD (pulsecode voice data)'],
#     'usage 17': ['pulse code voice data (PCVD)'],
#     'usage 18': ['data above voice'],
#     'usage 19': ['voice mailbox'],
#     'usage 2': ['voice detector'],
#     'usage 20': ['voice mailbox'],
#     'usage 21': ['Signalling Voice Channel (SVC)'],
#     'usage 22': ['voice channel'],
#     'usage 23': ['voice channel'],
#     'usage 24': ['G',
#      '711 - Pulse code modulation of voice frequencies ITU Recommendation (G',
#      '711)'],
#     'usage 25': ['voice recognition technology'],
#     'usage 26': ['voice processing technology'],
#     'usage 27': ['voice encoding'],
#     'usage 28': ['voice code'],
#     'usage 29': ['voice network'],
#     'usage 3': ['vocoder (voicecoder)'],
#     'usage 30': ['voice recorder'],
#     'usage 31': ['Computer and Interactive Voice Response (CIVR)'],
#     'usage 32': ['voice level'],
#     'usage 33': ['voice compression'],
#     'usage 34': ['Speaker independent voice recognition (SIVR)'],
#     'usage 35': ['Automatic Voice Recognition (AVR)'],
#     'usage 36': ['voice recognition'],
#     'usage 37': ['voice data entry'],
#     'usage 38': ['voice track'],
#     'usage 39': ['voice/data packet switch'],
#     'usage 4': ['voice coder'],
#     'usage 40': ['VDE (voicedata entry)'],
#     'usage 41': ['voice data entry'],
#     'usage 42': ['recorded voice announcement'],
#     'usage 43': ['RVA (recordedvoice announcement)'],
#     'usage 44': ['voice level test'],
#     'usage 45': ['voice transmission'],
#     'usage 46': ['voice processing'],
#     'usage 47': ['VF (voicefrequency)'],
#     'usage 48': ['voice frequency'],
#     'usage 49': ['voice frequency (VF)'],
#     'usage 5': ['voice coder (vocoder)'],
#     'usage 50': ['voice recognition device (VRD)'],
#     'usage 51': ['VRD (voice-recognition device)'],
#     'usage 52': ['VID (voiceinput device)'],
#     'usage 53': ['recorded voice announcement unit'],
#     'usage 54': ['VOD (voice-output device)'],
#     'usage 55': ['voice-output device (VOD)'],
#     'usage 56': ['voice message'],
#     'usage 57': ['voice communication'],
#     'usage 58': ['voice message'],
#     'usage 59': ['voice mail'],
#     'usage 6': ['voice-recognition unit'],
#     'usage 60': ['secure voice'],
#     'usage 61': ['Digital Simultaneous Voice and Data (DSVD)'],
#     'usage 62': ['Analogue Simultaneous Voice and Data (ASVD)'],
#     'usage 63': ['Voice and Telephony Over ATM (VTOA)'],
#     'usage 64': ['cavernous voice'],
#     'usage 65': ['voice synthesis'],
#     'usage 66': ['VAB (voiceanswer-back)'],
#     'usage 67': ['voice answer back (VAB)'],
#     'usage 68': ['voice response'],
#     'usage 69': ['voice communication'],
#     'usage 7': ['linear digital voice scrambler'],
#     'usage 70': ['voice chip'],
#     'usage 71': ['voice response'],
#     'usage 72': ['voice output'],
#     'usage 73': ['narrow-band voice modulation'],
#     'usage 74': ['NBVM (narrowband voice modulation)'],
#     'usage 75': ['voice synthesizer'],
#     'usage 76': ['VU (voiceunit)'],
#     'usage 8': ['voice synthesizer'],
#     'usage 9': ['VRU (voiceresponse unit)']},
#    'translation': ['voice']},
#   'nums': 4},
#  'pháp': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0, 'nums usage': 1, 'usage 1': ['France', '']},
#    'translation': ['Danh từ', '']},
#   2: {'POS': 'N/A',
#    'examples': {'nums context': 0, 'nums usage': 1, 'usage 1': ['French', '']},
#    'translation': ['Tính từ', '']},
#   3: {'POS': 'N/A',
#    'examples': {'context 1': 'Công ty Hàng không Pháp',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['Air France']},
#    'translation': ['france']},
#   'nums': 3},
#  'eugénie': 'N/A',
#  'giả': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'răng giả',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['false teeth', '']},
#    'translation': ['False', 'artificial', 'forged', '']},
#   2: {'POS': 'N/A',
#    'examples': {'context 1': 'giả đau',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['To pretend to be ill', '']},
#    'translation': ['To pretend', 'to feign', '']},
#   3: {'POS': 'N/A',
#    'examples': {'context 1': 'nó giả làm công an',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['He disguised himself as a policeman', '']},
#    'translation': ['To disguise', '']},
#   'nums': 3},
#  'de': {1: {'POS': 'N/A',
#    'examples': 'N/A',
#    'translation': ['(thực vật) Cinnamon', '']},
#   'nums': 1},
#  'balzac': 'N/A',
#  'dịch': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'dịch từ tiếng Anh ra tiếng Việt',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['to translate from English into Vietnamese']},
#    'translation': ['To translate', 'to turn']},
#   10: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['transitivity']},
#   11: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['translate']},
#   12: {'POS': 'N/A',
#    'examples': {'context 1': 'hệ thống dịch',
#     'context 2': 'mạch dịch',
#     'context 3': 'sự dịch',
#     'context 4': 'thời gian dịch',
#     'nums context': 4,
#     'nums usage': 4,
#     'usage 1': ['translating system'],
#     'usage 2': ['translating circuit'],
#     'usage 3': ['translating system'],
#     'usage 4': ['translating time']},
#    'translation': ['translating']},
#   13: {'POS': 'N/A',
#    'examples': {'context 1': 'bảng dịch',
#     'context 10': 'cổng thông dịch địa chỉ',
#     'context 11': 'dịch chương trình',
#     'context 12': 'dịch ký tự',
#     'context 13': 'dịch máy',
#     'context 14': 'dịch máy tự động',
#     'context 15': 'dịch ngôn ngữ tự động',
#     'context 16': 'dịch nhờ máy tính',
#     'context 17': 'dịch tiếng Nhật',
#     'context 18': 'Dịch tiêu đề toàn cầu/Truyền dẫn tiêu đề toàn cầu',
#     'context 19': 'dịch từ có lệnh kênh',
#     'context 2': 'bảng dịch ký tự',
#     'context 20': 'dịch tự động',
#     'context 21': 'dịch vụ thông dịch mã số',
#     'context 22': 'dịch địa chỉ khối',
#     'context 23': 'dịch địa chỉ mạng',
#     'context 24': 'dịch địa chỉ động',
#     'context 25': 'dịch địa chỉ động',
#     'context 26': 'hệ thống dịch thuộc tính',
#     'context 27': 'hệ thống dịch thuộc tính',
#     'context 28': 'lỗi biên dịch tần số SSB',
#     'context 29': 'mã điểm dịch',
#     'context 3': 'bảng dịch mã tham chiếu',
#     'context 30': 'máy dịch',
#     'context 31': 'ngoại lệ dịch trang',
#     'context 32': 'ngoại lệ dịch đoạn',
#     'context 33': 'ngoại lệ trong dịch trang',
#     'context 34': 'Nhận biết/Thông dịch gói tự động',
#     'context 35': 'phương tiện dịch bí danh',
#     'context 36': 'sai lệch dịch chuyển tần số',
#     'context 37': 'sự dịch',
#     'context 38': 'sự dịch bằng máy tính',
#     'context 39': 'sự dịch bằng máy tính',
#     'context 4': 'bảng thông dịch địa chỉ đồ họa',
#     'context 40': 'sự dịch chuyển tần số',
#     'context 41': 'sự dịch cơ',
#     'context 42': 'sự dịch có máy tính hỗ trợ',
#     'context 43': 'sự dịch công thức',
#     'context 44': 'sự dịch ký tự',
#     'context 45': 'sự dịch mã',
#     'context 46': 'sự dịch máy',
#     'context 47': 'sự dịch máy',
#     'context 48': 'sự dịch máy',
#     'context 49': 'sự dịch một đối một',
#     'context 5': 'bộ nhớ đệm dịch địa chỉ',
#     'context 50': 'sự dịch riêng rẽ',
#     'context 51': 'sự dịch tách biệt',
#     'context 52': 'sự dịch tần số laser',
#     'context 53': 'sự dịch tập tin',
#     'context 54': 'sự dịch tên',
#     'context 55': 'sự dịch thuật toán',
#     'context 56': 'sự dịch địa chỉ',
#     'context 57': 'sự dịch địa chỉ mạng',
#     'context 58': 'sự dịch địa chỉ động',
#     'context 59': 'tâm diễn dịch phím mã',
#     'context 6': 'bộ đệm dịch',
#     'context 60': 'thiết bị dịch kênh',
#     'context 61': 'thời gian biên dịch',
#     'context 62': 'thuật toán dịch',
#     'context 63': 'tốc độ chuyển dịch',
#     'context 64': 'trung tâm diễn dịch mật mã',
#     'context 65': 'đặc điểm dịch ngôn ngữ',
#     'context 7': 'bộ đệm dịch dữ liệu',
#     'context 8': 'chương trình dịch',
#     'context 9': 'chương trình dịch ngôn ngữ',
#     'nums context': 65,
#     'nums usage': 67,
#     'usage 1': ['translation table'],
#     'usage 10': ['Address Translation Gateway (ATG)'],
#     'usage 11': ['program translation'],
#     'usage 12': ['character translation'],
#     'usage 13': ['machine translation'],
#     'usage 14': ['automatic', 'machine translation'],
#     'usage 15': ['automatic language translation'],
#     'usage 16': ['computer aided translation'],
#     'usage 17': ['Japanese translation'],
#     'usage 18': ['Global Title Translation/Global Title Transmission (GTT)'],
#     'usage 19': ['channel command word translation'],
#     'usage 2': ['character translation table'],
#     'usage 20': ['machine translation'],
#     'usage 21': ['Number Translation Service (NTS)'],
#     'usage 22': ['Block Address Translation (BAT)'],
#     'usage 23': ['Network Address Translation (NAT)'],
#     'usage 24': ['DAT (DynamicAddress Translation)'],
#     'usage 25': ['Dynamic Address Translation (DAT)'],
#     'usage 26': ['ATS (attributetranslation system)'],
#     'usage 27': ['attribute translation system (ATS)'],
#     'usage 28': ['SSB frequency translation error'],
#     'usage 29': ['Translation Point Code (TPC)'],
#     'usage 3': ['reference code translation table'],
#     'usage 30': ['translation surface'],
#     'usage 31': ['page translation exception'],
#     'usage 32': ['segment translation exception'],
#     'usage 33': ['page translation exception'],
#     'usage 34': ['Automated Packet Recognition/Translation (APART)'],
#     'usage 35': ['alias name translation facility'],
#     'usage 36': ['frequency translation error'],
#     'usage 37': ['translation (vs)'],
#     'usage 38': ['CAT (computerassisted translation)'],
#     'usage 39': ['computer-aided translation (CAT)'],
#     'usage 4': ['Graphics Address Translation Table (GATT)'],
#     'usage 40': ['frequency translation'],
#     'usage 41': ['mechanical translation'],
#     'usage 42': ['CAT (computerassisted translation)'],
#     'usage 43': ['formula translation'],
#     'usage 44': ['character translation'],
#     'usage 45': ['code translation'],
#     'usage 46': ['machine translation'],
#     'usage 47': ['machine translation (MT)'],
#     'usage 48': ['MT (machinetranslation)'],
#     'usage 49': ['one-for-one translation'],
#     'usage 5': ['address translation cache'],
#     'usage 50': ['separate translation'],
#     'usage 51': ['separate translation'],
#     'usage 52': ['laser frequency translation'],
#     'usage 53': ['file translation'],
#     'usage 54': ['name translation'],
#     'usage 55': ['algorithm translation'],
#     'usage 56': ['address translation'],
#     'usage 57': ['network address translation (NAT)'],
#     'usage 58': ['DAT (dynamicaddress translation)'],
#     'usage 59': ['CKTC (crypto-graphic key translation center)'],
#     'usage 6': ['translation buffer'],
#     'usage 60': ['Channel Translation Equipment (CTE)'],
#     'usage 61': ['translation time'],
#     'usage 62': ['translation algorithm'],
#     'usage 63': ['translation speed'],
#     'usage 64': ['cryptographic key translation center (CKT)'],
#     'usage 65': ['trước khi dịch'],
#     'usage 66': ['pre-translation (abbr)'],
#     'usage 67': ['language translation feature'],
#     'usage 7': ['data translation buffer'],
#     'usage 8': ['translation program'],
#     'usage 9': ['language translation program']},
#    'translation': ['translation']},
#   2: {'POS': 'N/A',
#    'examples': {'context 1': 'dịch bức điện từ mật mã',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['to decode a telegram']},
#    'translation': ['To decode']},
#   3: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['To move a little']},
#   4: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 2,
#     'usage 1': ['bệnh dịch - (rud) epidemic'],
#     'usage 2': ['dung dịch', 'chất lỏng - juice', 'liquid', 'fluid']},
#    'translation': ['Danh từ']},
#   5: {'POS': 'N/A',
#    'examples': {'context 1': 'bảng hoặc mảng thời gian biên dịch',
#     'context 10': 'thời khoảng biên dịch',
#     'context 2': 'biên dịch',
#     'context 3': 'biên dịch byte',
#     'context 4': 'biên dịch không lỗi',
#     'context 5': 'khoảng thời gian dịch',
#     'context 6': 'mảng thời gian biên dịch',
#     'context 7': 'pha biên dịch',
#     'context 8': 'thời gian biên dịch',
#     'context 9': 'thời gian biên dịch',
#     'nums context': 10,
#     'nums usage': 10,
#     'usage 1': ['compile-time table or array'],
#     'usage 10': ['compile duration'],
#     'usage 2': ['compile (vs)'],
#     'usage 3': ['byte-compile'],
#     'usage 4': ['clean compile'],
#     'usage 5': ['compile duration'],
#     'usage 6': ['compile time array'],
#     'usage 7': ['compile phase'],
#     'usage 8': ['compile duration'],
#     'usage 9': ['compile time']},
#    'translation': ['compile']},
#   6: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['convert']},
#   7: {'POS': 'N/A',
#    'examples': {'context 1': 'bảng diễn dịch',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['interpret table']},
#    'translation': ['interpret']},
#   8: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['shift']},
#   9: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['transform']},
#   'nums': 13},
#  'huỳnh': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'bên tường thấp thoáng bóng huỳnh Nguyễn Gia Thiều',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['Near the wall', 'there flickered fire-flies', '']},
#    'translation': ['(văn chương) Fire-fly', 'glow-worm', '']},
#   'nums': 1},
#  'lý': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'hợp lý',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['reasonable', '']},
#    'translation': ['Reason', 'ground', '']},
#   2: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['mile']},
#   'nums': 2},
#  'thể': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 3,
#     'usage 1': ['state'],
#     'usage 2': ['genre'],
#     'usage 3': ['aspect']},
#    'translation': ['Danh từ']},
#   'nums': 1},
#  'loại': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 1,
#     'usage 1': ['sort', 'category', 'gemos']},
#    'translation': ['Danh từ']},
#   2: {'POS': 'N/A',
#    'examples': {'context 1': 'loại những kẻ bất tài',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['to weed out the inefficients']},
#    'translation': ['To eliminate', 'to weed out']},
#   'nums': 2},
#  'văn': 'N/A',
#  'học': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'anh học tiếng Anh đã bao lâu',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['How long have you been learning English?']},
#    'translation': ['To study', 'to learn', 'to read']},
#   'nums': 1},
#  'nước': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'không thấm nước',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['waterproof', '']},
#    'translation': ['Water', '']},
#   10: {'POS': 'N/A',
#    'examples': {'context 1': 'dịch súp nước cá',
#     'context 2': 'dung dịch nước màu',
#     'context 3': 'phần cô nước cà phê',
#     'context 4': 'thuốc rửa nước',
#     'nums context': 4,
#     'nums usage': 4,
#     'usage 1': ['liquid fish'],
#     'usage 2': ['liquid colour'],
#     'usage 3': ['liquid coffee concentrate'],
#     'usage 4': ['liquid detergent']},
#    'translation': ['liquid']},
#   11: {'POS': 'N/A',
#    'examples': {'context 1': 'sự làm tan đông bằng nước',
#     'context 2': 'vòi phun nước muối',
#     'nums context': 2,
#     'nums usage': 2,
#     'usage 1': ['defrosting by water spray'],
#     'usage 2': ['brine spray']},
#    'translation': ['spray']},
#   12: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['stove']},
#   2: {'POS': 'N/A',
#    'examples': {'context 1': 'nước bắt đầu lớn',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['the tide is setting in', '']},
#    'translation': ['Tide', '']},
#   3: {'POS': 'N/A',
#    'examples': 'N/A',
#    'translation': ['Coat', 'layer (of paint)', '']},
#   4: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['aqua']},
#   5: {'POS': 'N/A',
#    'examples': {'context 1': 'dầu tan trong nước',
#     'context 10': 'pha nước',
#     'context 11': 'sự phân tán nước',
#     'context 12': 'trầm tích do nước',
#     'context 13': 'đá do nước tạo thành',
#     'context 14': 'đất ngậm nước',
#     'context 2': 'dung dịch chứa nước',
#     'context 3': 'dung dịch nước',
#     'context 4': 'dung dịch nước muối',
#     'context 5': 'không có nước',
#     'context 6': 'không nước',
#     'context 7': 'nhũ tương nước',
#     'context 8': 'nhũ tương trong nước',
#     'context 9': 'pha nước',
#     'nums context': 14,
#     'nums usage': 14,
#     'usage 1': ['aqueous soluble oil'],
#     'usage 10': ['aqueous phase'],
#     'usage 11': ['aqueous dispersion'],
#     'usage 12': ['aqueous deposit'],
#     'usage 13': ['aqueous rock'],
#     'usage 14': ['aqueous soil'],
#     'usage 2': ['aqueous solution'],
#     'usage 3': ['aqueous solution'],
#     'usage 4': ['aqueous salt solution'],
#     'usage 5': ['non-aqueous'],
#     'usage 6': ['non-aqueous'],
#     'usage 7': ['aqueous amulsion'],
#     'usage 8': ['aqueous emulsion'],
#     'usage 9': ['aqueous pH']},
#    'translation': ['aqueous']},
#   6: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['gum']},
#   7: {'POS': 'N/A',
#    'examples': {'context 1': 'lanolin ngậm nước',
#     'context 2': 'muối ngậm nước',
#     'context 3': 'silicat ngậm nước',
#     'nums context': 3,
#     'nums usage': 3,
#     'usage 1': ['hydrous wool fat'],
#     'usage 2': ['hydrous salt'],
#     'usage 3': ['hydrous silicate']},
#    'translation': ['hydrous']},
#   8: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['water']},
#   9: {'POS': 'N/A',
#    'examples': {'context 1': 'dung dịch nước',
#     'context 2': 'nhũ tương nước',
#     'context 3': 'pha nước',
#     'nums context': 3,
#     'nums usage': 3,
#     'usage 1': ['aqueous solution'],
#     'usage 2': ['aqueous emulsion'],
#     'usage 3': ['aqueous phase']},
#    'translation': ['aqueous']},
#   'nums': 12},
#  'ngoài': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'ở ngoài thành phố',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['outside the town', '']},
#    'translation': ['Out', 'outside', 'without', 'exterior', 'external', '']},
#   10: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['outside']},
#   11: {'POS': 'N/A',
#    'examples': {'context 1': 'chức vị ngoài ngân sách',
#     'context 10': 'tiền trả thêm ngoài giờ',
#     'context 11': 'trợ cấp ngoại ngạch',
#     'context 12': 'trương mục ngoài ngân sách',
#     'context 13': 'vận phí ngoại ngạch',
#     'context 14': 'vốn ngoài ngân sách',
#     'context 2': 'chương mục ngoài ngân sách',
#     'context 3': 'ngoại ngạch',
#     'context 4': 'ngoại ngân sách',
#     'context 5': 'nguồn vốn ngoài ngân sách',
#     'context 6': 'phí dụng ngoại ngạch',
#     'context 7': 'phí tổn ngoại ngạch',
#     'context 8': 'sự châm chước ngoài pháp luật',
#     'context 9': 'tài khoản ngoài ngân sách',
#     'nums context': 14,
#     'nums usage': 14,
#     'usage 1': ['extra-budgetary post'],
#     'usage 10': ['extra time to pay'],
#     'usage 11': ['extra allowance'],
#     'usage 12': ['extra-budgetary accounts'],
#     'usage 13': ['extra freight'],
#     'usage 14': ['extra-budgetary funds'],
#     'usage 2': ['extra-budgetary accounts'],
#     'usage 3': ['extra premium'],
#     'usage 4': ['extra-budgetary'],
#     'usage 5': ['extra-budgetary resources'],
#     'usage 6': ['extra charges'],
#     'usage 7': ['extra cost'],
#     'usage 8': ['extra statutory concession'],
#     'usage 9': ['extra-budgetary accounts']},
#    'translation': ['extra']},
#   12: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['foreign']},
#   2: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['apparent']},
#   3: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['external']},
#   4: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['external (a-no)']},
#   5: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['outer']},
#   6: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['exterior']},
#   7: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['foreign']},
#   8: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['exocarp']},
#   9: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['foreign']},
#   'nums': 12},
#  '--': 'N/A',
#  'nguồn': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'nguồn sáng',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['light source', '']},
#    'translation': ['Source', 'spring', '']},
#   10: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['source']},
#   11: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['spring']},
#   12: {'POS': 'N/A',
#    'examples': {'context 1': 'bộ đảo nguồn điện áp',
#     'context 2': 'nguồn cao thế',
#     'context 3': 'nguồn điện áp bên ngoài',
#     'context 4': 'nguồn điện áp không đổi',
#     'context 5': 'nguồn điện áp một chiều',
#     'nums context': 5,
#     'nums usage': 5,
#     'usage 1': ['voltage source inverter'],
#     'usage 2': ['high voltage source'],
#     'usage 3': ['external voltage source'],
#     'usage 4': ['constant-voltage source'],
#     'usage 5': ['DC voltage source']},
#    'translation': ['voltage source']},
#   13: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['mine']},
#   14: {'POS': 'N/A',
#    'examples': {'context 1': 'nguồn nước muối',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['brine spring']},
#    'translation': ['spring']},
#   2: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['current source']},
#   3: {'POS': 'N/A',
#    'examples': {'context 1': 'đầu nguồn',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['fountain head']},
#    'translation': ['fountain']},
#   4: {'POS': 'N/A',
#    'examples': {'context 1': 'giấy chứng nhận nguồn gốc',
#     'context 10': 'nguồn gốc đứt gãy',
#     'context 11': 'nguồn địa chấn',
#     'context 2': 'kiểm tra chứng thực nguồn gốc tin báo',
#     'context 3': 'nguồn dữ liệu',
#     'context 4': 'nguồn gốc của quang sai',
#     'context 5': 'nguồn gốc cuộc gọi',
#     'context 6': 'nguồn gốc hữu cơ',
#     'context 7': 'nguồn gốc sự ô nhiễm môi trường',
#     'context 8': 'nguồn gốc sự phá hoại',
#     'context 9': 'nguồn gốc động đất',
#     'nums context': 11,
#     'nums usage': 11,
#     'usage 1': ['certificate of origin'],
#     'usage 10': ['fracture origin'],
#     'usage 11': ['seismic origin'],
#     'usage 2': ['Message Origin Authentication Check (MOAC)'],
#     'usage 3': ['data origin'],
#     'usage 4': ['origin of aberration'],
#     'usage 5': ['call origin'],
#     'usage 6': ['organic origin'],
#     'usage 7': ['origin of the environment pollution'],
#     'usage 8': ['origin of the failure'],
#     'usage 9': ['seismic origin']},
#    'translation': ['origin']},
#   5: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['power source']},
#   6: {'POS': 'N/A',
#    'examples': {'context 1': 'bộ nguồn',
#     'context 10': 'bộ nguồn khả lập trình',
#     'context 11': 'bộ nguồn không biến áp',
#     'context 12': 'bộ nguồn liên tục',
#     'context 13': 'bộ nguồn lưỡng cực',
#     'context 14': 'bộ nguồn micrô',
#     'context 15': 'bộ nguồn một đầu ra',
#     'context 16': 'bộ nguồn OEM tuyến tính',
#     'context 17': 'bộ nguồn ổn định',
#     'context 18': 'bộ nguồn ổn định điện áp',
#     'context 19': 'bộ nguồn ra đơn',
#     'context 2': 'bộ nguồn',
#     'context 20': 'bộ nguồn tần số vô tuyến',
#     'context 21': 'bộ nguồn tạo dòng biến thiên',
#     'context 22': 'bộ nguồn từ xa',
#     'context 23': 'bộ nguồn điện áp cao',
#     'context 24': 'bộ nguồn điện kép',
#     'context 25': 'bộ nguồn điện không bị gián đoạn',
#     'context 26': 'bộ nguồn điện tử',
#     'context 27': 'bộ nguồn điều chỉnh bằng tyristo',
#     'context 28': 'bộ nguồn được điều chỉnh',
#     'context 29': 'cấp nguồn ở chế độ chuyển mạch',
#     'context 3': 'bộ nguồn ắcqui dự phòng',
#     'context 30': 'cung cấp nguồn liên tục',
#     'context 31': 'cung cấp nguồn ổn định',
#     'context 32': 'dây nguồn',
#     'context 33': 'mạch nguồn',
#     'context 34': 'môđun nguồn',
#     'context 35': 'nguồn cấp cho lò sưởi',
#     'context 36': 'nguồn cấp điện',
#     'context 37': 'nguồn cấp điện',
#     'context 38': 'nguồn cấp điện',
#     'context 39': 'nguồn cấp điện áp cao',
#     'context 4': 'bộ nguồn âm',
#     'context 40': 'nguồn cấp điện áp cao',
#     'context 41': 'nguồn cấp điện dư dự phòng',
#     'context 42': 'nguồn cấp điện không ngắt',
#     'context 43': 'nguồn cấp điện lập trình được',
#     'context 44': 'nguồn cấp điện liên tục',
#     'context 45': 'nguồn cấp điện liên tục-UPS',
#     'context 46': 'nguồn cấp điện một chiều',
#     'context 47': 'nguồn cấp điện điện áp cao',
#     'context 48': 'nguồn cung cấp cao thế',
#     'context 49': 'nguồn cung cấp năng lượng',
#     'context 5': 'bộ nguồn chương trình hóa được',
#     'context 50': 'nguồn cung cấp tần số điện áp không đổi',
#     'context 51': 'nguồn cung cấp từ xa',
#     'context 52': 'nguồn cung cấp điện dự phòng',
#     'context 53': 'nguồn năng lượng được điều chỉnh',
#     'context 54': 'nguồn nuôi ắcqui dự phòng',
#     'context 55': 'nguồn nuôi không ngắt',
#     'context 56': 'nguồn điện chia tải',
#     'context 57': 'nguồn điện dòng chính',
#     'context 58': 'nguồn điện dự bị',
#     'context 59': 'nguồn điện dự phòng',
#     'context 6': 'bộ nguồn chuyển mạch',
#     'context 60': 'nguồn điện dự phòng khẩn cấp',
#     'context 61': 'nguồn điện năng lượng hạt nhân',
#     'context 62': 'nguồn điện phụ',
#     'context 63': 'nguồn điện phụ',
#     'context 64': 'nguồn điện thứ cấp',
#     'context 65': 'nguồn điện đa năng',
#     'context 66': 'nguồn điện điều chỉnh nối tiếp',
#     'context 67': 'sự cấp nguồn nung',
#     'context 68': 'sự cấp nguồn điện dự phòng',
#     'context 69': 'sự chập chờn của nguồn điện',
#     'context 7': 'bộ nguồn dòng một chiều',
#     'context 70': 'sự ngắt nguồn nuôi',
#     'context 71': 'tắt nguồn điện',
#     'context 72': 'thiết bị nguồn',
#     'context 8': 'bộ nguồn dòng xoay chiều',
#     'context 9': 'bộ nguồn dương',
#     'nums context': 72,
#     'nums usage': 72,
#     'usage 1': ['electronic power supply'],
#     'usage 10': ['programmable power supply'],
#     'usage 11': ['transformerless power supply'],
#     'usage 12': ['UPS (uninterruptiblepower supply)'],
#     'usage 13': ['bipolar power supply'],
#     'usage 14': ['microphone power supply'],
#     'usage 15': ['single output switching power supply'],
#     'usage 16': ['linear OEM power supply'],
#     'usage 17': ['regulated power supply'],
#     'usage 18': ['voltage-stabilized power supply'],
#     'usage 19': ['single output switching power supply'],
#     'usage 2': ['power supply unit'],
#     'usage 20': ['radio-frequency power supply'],
#     'usage 21': ['vibrator power supply'],
#     'usage 22': ['remote power supply'],
#     'usage 23': ['high-tension power supply'],
#     'usage 24': ['dual power supply'],
#     'usage 25': ['uninterruptible power supply system'],
#     'usage 26': ['electronic power supply'],
#     'usage 27': ['SCR-regulated power supply'],
#     'usage 28': ['regulated power supply'],
#     'usage 29': ['Switching Mode Power Supply (SMPS)'],
#     'usage 3': ['stand-by battery power supply'],
#     'usage 30': ['Uninterruptible Power Supply (UPS)'],
#     'usage 31': ['regulated power supply'],
#     'usage 32': ['power supply cord'],
#     'usage 33': ['power supply circuit'],
#     'usage 34': ['power supply module'],
#     'usage 35': ['heater power supply'],
#     'usage 36': ['electric power supply'],
#     'usage 37': ['electronic power supply'],
#     'usage 38': ['power supply source'],
#     'usage 39': ['high-tension power supply'],
#     'usage 4': ['negative power supply'],
#     'usage 40': ['high-voltage power supply'],
#     'usage 41': ['redundant power supply'],
#     'usage 42': ['UPS (uninterruptiblepower supply)'],
#     'usage 43': ['programmable power supply'],
#     'usage 44': ['uninterruptible power supply'],
#     'usage 45': ['Uninterruptible Power Supply (B71UPS)'],
#     'usage 46': ['DC power supply'],
#     'usage 47': ['HT power supply'],
#     'usage 48': ['high-tension power supply'],
#     'usage 49': ['power supply source'],
#     'usage 5': ['programmable power supply'],
#     'usage 50': ['CVCF (ConstantVoltage Frequency Power Supply)'],
#     'usage 51': ['remote power supply'],
#     'usage 52': ['standby power supply'],
#     'usage 53': ['regulated power supply'],
#     'usage 54': ['stand-by battery power supply'],
#     'usage 55': ['no-break power supply'],
#     'usage 56': ['load sharing power supply'],
#     'usage 57': ['series-regulated power supply'],
#     'usage 58': ['standby power supply'],
#     'usage 59': ['emergency power supply'],
#     'usage 6': ['switching power supply'],
#     'usage 60': ['emergence power supply'],
#     'usage 61': ['nuclear power supply'],
#     'usage 62': ['auxiliary electric power supply'],
#     'usage 63': ['secondary power (supply)'],
#     'usage 64': ['secondary power (supply)'],
#     'usage 65': ['universal power supply'],
#     'usage 66': ['series-regulated power supply'],
#     'usage 67': ['heater power supply'],
#     'usage 68': ['backup power supply'],
#     'usage 69': ['power supply voltage fluctuation'],
#     'usage 7': ['direct-current power supply'],
#     'usage 70': ['power supply interrupt'],
#     'usage 71': ['power (supply) cutoff'],
#     'usage 72': ['power supply unit'],
#     'usage 8': ['alternating-current power supply'],
#     'usage 9': ['positive power supply']},
#    'translation': ['power supply']},
#   7: {'POS': 'N/A',
#    'examples': {'context 1': 'nguồn phát chất thải',
#     'context 2': 'nguồn sinh chất thải',
#     'nums context': 2,
#     'nums usage': 2,
#     'usage 1': ['waste producer'],
#     'usage 2': ['waste producer']},
#    'translation': ['producer']},
#   8: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['repository']},
#   9: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['resources']},
#   'nums': 14},
#  'http': 'N/A',
#  '//vnthuquan.net': 'N/A',
#  'đánh': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'đánh vào mặt người nào',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['to strike someone in the face']},
#    'translation': ['To beat', 'to strike', 'to fight', 'to combat']},
#   2: {'POS': 'N/A',
#    'examples': 'N/A',
#    'translation': ["To play (one's card)"]},
#   'nums': 2},
#  'máy': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 1,
#     'usage 1': ['machine', 'engine', '']},
#    'translation': ['Danh từ', '']},
#   'nums': 1},
#  'chuyển': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'chuyển đi ở nơi khác',
#     'context 2': 'chuyển quân',
#     'context 3': 'chuyển sang nhà mới',
#     'context 4': 'chuyển công tác',
#     'context 5': 'chuyển tiền',
#     'context 6': 'chuyển bại thành thắng',
#     'context 7': 'lay chẳng chuyển',
#     'context 8': 'nói mãi mà hắn vẫn không chuyển',
#     'context 9': 'tư tưởng không chuyển kịp với tình hình',
#     'nums context': 9,
#     'nums usage': 9,
#     'usage 1': ['to move to another place'],
#     'usage 2': ['to move troops'],
#     'usage 3': ['to move in'],
#     'usage 4': ['to get a transfer'],
#     'usage 5': ['to transfer money'],
#     'usage 6': ['to change defeat into victory'],
#     'usage 7': ['to shake (a stone', '', ') without being able to move it'],
#     'usage 8': ['despite our admonishing', 'he did not change'],
#     'usage 9': ['the thinking did not change (evolve) at the same pace as the situation',
#      'the ideological evolution did not keep pace with the development of the situation']},
#    'translation': ['To move',
#     'to transfer',
#     'to shift',
#     'to switch over',
#     'to change']},
#   10: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['remit']},
#   11: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['transfer']},
#   12: {'POS': 'N/A',
#    'examples': {'context 1': 'bánh xe chuyển động',
#     'context 2': 'mạch chuyển mã',
#     'context 3': 'tầng chuyển đổi',
#     'nums context': 3,
#     'nums usage': 3,
#     'usage 1': ['translating wheel'],
#     'usage 2': ['translating circuit'],
#     'usage 3': ['translating stage']},
#    'translation': ['translating']},
#   13: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['trip']},
#   14: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['transfer']},
#   2: {'POS': 'N/A',
#    'examples': {'context 1': 'chuyển bức thư của bạn gửi về cho gia đình',
#     'context 2': 'chuyển lời cám ơn',
#     'context 3': 'chuyển một món tiền',
#     'nums context': 3,
#     'nums usage': 3,
#     'usage 1': ["to forward a friend's letter to his family"],
#     'usage 2': ["to convey someone's thanks"],
#     'usage 3': ['to forward a sum of money']},
#    'translation': ['To forward', 'to convey', 'to pass on']},
#   3: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['switch']},
#   4: {'POS': 'N/A',
#    'examples': {'context 1': 'bộ nhớ chuyển dịch',
#     'context 2': 'chuyển sang',
#     'context 3': 'hệ số chuyển',
#     'context 4': 'mạch chuyển',
#     'context 5': 'sự chuyển qua',
#     'context 6': 'thời gian chuyển',
#     'context 7': 'tín hiệu chuyển ban đầu',
#     'nums context': 7,
#     'nums usage': 7,
#     'usage 1': ['carry storage'],
#     'usage 2': ['carry-over'],
#     'usage 3': ['carry-over factor'],
#     'usage 4': ['carry circuit'],
#     'usage 5': ['carry-over'],
#     'usage 6': ['carry time'],
#     'usage 7': ['carry initiating signal']},
#    'translation': ['carry']},
#   5: {'POS': 'N/A',
#    'examples': {'context 1': 'bộ chỉ báo lệnh chuyển hướng',
#     'context 10': 'ga chuyển khổ đường',
#     'context 11': 'ga chuyển tàu',
#     'context 12': 'giao thức chuyển hướng',
#     'context 13': 'giếng thăm nước thải chỗ chuyển dòng',
#     'context 14': 'hệ thống chuyển đổi',
#     'context 15': 'làn chuyển tốc',
#     'context 16': 'rơle chuyển đổi',
#     'context 17': 'sự chuyển hướng',
#     'context 18': 'sự chuyển sang dự phòng',
#     'context 19': 'sự chuyền đổi',
#     'context 2': 'bộ khống chế chuyển mạch',
#     'context 20': 'sự chuyển đổi chế độ',
#     'context 21': 'tệp chuyển tác',
#     'context 22': 'trạm chuyển xe',
#     'context 23': 'van chuyển dòng',
#     'context 24': 'van chuyển hướng',
#     'context 25': 'van điều tiết chuyển đổi',
#     'context 26': 'độ chuyển hóa',
#     'context 3': 'chuyển sang số hai hay số cao nhất',
#     'context 4': 'chuyển tiếp trạng thái',
#     'context 5': 'chuyển đổi',
#     'context 6': 'chuyển đổi',
#     'context 7': 'cơ cấu chuyển đổi',
#     'context 8': 'cửa chuyển đổi',
#     'context 9': 'di chuyển',
#     'nums context': 26,
#     'nums usage': 26,
#     'usage 1': ['change direction command indicator'],
#     'usage 10': ['change of gauge station'],
#     'usage 11': ['change station'],
#     'usage 12': ['change direction protocol'],
#     'usage 13': ['sewer manhole at change in line'],
#     'usage 14': ['change-over system'],
#     'usage 15': ['speed change lane'],
#     'usage 16': ['change-over relay'],
#     'usage 17': ['change of direction'],
#     'usage 18': ['change-over to stand-by'],
#     'usage 19': ['change-over'],
#     'usage 2': ['change-over switch controller'],
#     'usage 20': ['mode change'],
#     'usage 21': ['change file'],
#     'usage 22': ['change station'],
#     'usage 23': ['change-over valve'],
#     'usage 24': ['change-over valve'],
#     'usage 25': ['change-over damper'],
#     'usage 26': ['change ratio'],
#     'usage 3': ['to change into second or top'],
#     'usage 4': ['state change'],
#     'usage 5': ['to change'],
#     'usage 6': ['to change over'],
#     'usage 7': ['change-over mechanism'],
#     'usage 8': ['change-over gate'],
#     'usage 9': ['to change the position of']},
#    'translation': ['change']},
#   6: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['circulate']},
#   7: {'POS': 'N/A',
#    'examples': {'context 1': 'chuyển từ thủ công sang tự động',
#     'context 2': 'chuyển đổi',
#     'context 3': 'chuyển động thành động cơ điezen',
#     'nums context': 3,
#     'nums usage': 3,
#     'usage 1': ['convert from manual to automatic working'],
#     'usage 2': ['to convert'],
#     'usage 3': ['convert to diesel']},
#    'translation': ['convert']},
#   8: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['convey']},
#   9: {'POS': 'N/A',
#    'examples': {'context 1': 'chuyển giao rủi ro về hư hỏng công trình',
#     'context 2': 'chuyển tham số',
#     'context 3': 'chuyển đối số',
#     'context 4': 'giao diện chuyển tiếp tin báo',
#     'context 5': 'mạng vòng chuyển thẻ bài',
#     'context 6': 'sự chuyển tham số',
#     'context 7': 'sự chuyển thông báo',
#     'context 8': 'sự chuyển điều khiển',
#     'nums context': 8,
#     'nums usage': 8,
#     'usage 1': ['Damage to the Works', 'passing of risk'],
#     'usage 2': ['parameter passing'],
#     'usage 3': ['argument passing'],
#     'usage 4': ['Message Passing Interface (MPI)'],
#     'usage 5': ['token-passing ring network'],
#     'usage 6': ['parameter passing'],
#     'usage 7': ['message passing'],
#     'usage 8': ['passing of control']},
#    'translation': ['passing']},
#   'nums': 14},
#  'sang': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'sang sông',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['to cross a river']},
#    'translation': ['To cross']},
#   2: {'POS': 'N/A',
#    'examples': {'context 1': 'sang nhà tôi chơi',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['come to my place with me']},
#    'translation': ['To come to']},
#   3: {'POS': 'N/A',
#    'examples': 'N/A',
#    'translation': ['To hand over', 'to transfer']},
#   4: {'POS': 'N/A',
#    'examples': {'context 1': 'chuyển sang vấn đề khác',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['to go on to another problem']},
#    'translation': ['On', 'into', 'on to', 'aside']},
#   5: {'POS': 'N/A',
#    'examples': {'context 1': 'quần áo sang',
#     'context 2': 'vé hạng sang',
#     'nums context': 2,
#     'nums usage': 2,
#     'usage 1': ['luxurious clothes'],
#     'usage 2': ['first-rate ticket', 'first-class ticket']},
#    'translation': ['Expensive', 'luxurious']},
#   'nums': 5},
#  'tve': 'N/A',
#  'santseiya': 'N/A',
#  'ngày': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'làm việc suốt ngày',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['to work all day', '']},
#    'translation': ['Day', '']},
#   2: {'POS': 'N/A',
#    'examples': {'context 1': 'vào một ngày gần đây',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['at an early date', '']},
#    'translation': ['Date', '']},
#   'nums': 2},
#  'hoàn': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0, 'nums usage': 1, 'usage 1': ['pill']},
#    'translation': ['Danh từ']},
#   2: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 1,
#     'usage 1': ['to return', 'to give back', 'to restore']},
#    'translation': ['Động từ']},
#   'nums': 2},
#  'thành': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 3,
#     'usage 1': ['citadel', 'rampart'],
#     'usage 2': ['wall'],
#     'usage 3': ['town', 'city']},
#    'translation': ['Danh từ']},
#   2: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 2,
#     'usage 1': ["to achieve one's aim", "to gain (win) one's end"],
#     'usage 2': ['to turn into', 'to change into', 'to grow into', 'to make']},
#    'translation': ['Động từ']},
#   3: {'POS': 'N/A',
#    'examples': {'nums context': 0, 'nums usage': 1, 'usage 1': ['sincere']},
#    'translation': ['Tính từ']},
#   'nums': 3},
#  'nơi': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'khắp nơi',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['in all places', 'everywhere', '']},
#    'translation': ['Place', '']},
#   'nums': 1},
#  'hà': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 2,
#     'usage 1': ['shipworm teredo', 'borer'],
#     'usage 2': ['sweet potato weevil']},
#    'translation': ['Danh từ']},
#   2: {'POS': 'N/A',
#    'examples': {'context 1': 'sông Hồng Hà',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['The Red river']},
#    'translation': ['Rive']},
#   3: {'POS': 'N/A',
#    'examples': {'nums context': 0,
# ...
#   'nums': 2},
#  'mức': 'N/A',
#  'khắp': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'khắp nơi',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['everywhere', 'on all sides']},
#    'translation': ['All over']},
#   'nums': 1},
#  'grangđe': 'N/A',
#  'hầm': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'hầm rượu',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['wine-cellar']},
#    'translation': ['Trench', 'vault', 'cellar']},
#   2: {'POS': 'N/A',
#    'examples': {'context 1': 'hầm thịt bò',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['to stew beef']},
#    'translation': ['To stew', 'to braise', 'to simmer']},
#   3: {'POS': 'N/A',
#    'examples': {'context 1': 'hầm gạch',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['to bake bricks']},
#    'translation': ['To bake', 'to kiln']},
#   'nums': 3},
#  'khoái': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 1,
#     'usage 1': ['pleased', 'satisfied', 'joyful']},
#    'translation': ['Tính từ']},
#   'nums': 1},
#  'cảm': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'bị cảm nhẹ',
#     'context 2': 'bị cảm lạnh',
#     'context 3': 'bị cảm nắng',
#     'nums context': 3,
#     'nums usage': 3,
#     'usage 1': ['to catch a slight cold'],
#     'usage 2': ['to catch a chill'],
#     'usage 3': ['to get a sunstroke']},
#    'translation': ['To catch a cold',
#     'to be ill (because of a sudden change in the weather',
#     'too much sun',
#     '',
#     ')']},
#   2: {'POS': 'N/A',
#    'examples': {'context 1': 'cảm thấy đau ở tay',
#     'context 2': 'ở đây cũng cảm thấy thoải mái như ở nhà',
#     'nums context': 2,
#     'nums usage': 2,
#     'usage 1': ["to feel a pain in one's arm"],
#     'usage 2': ['to feel comfortable here as at home']},
#    'translation': ['To feel']},
#   3: {'POS': 'N/A',
#    'examples': {'context 1': 'điệu hát làm cảm được người nghe',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['the tune moved the audience']},
#    'translation': ['To be moved', 'to be affected']},
#   4: {'POS': 'N/A',
#    'examples': {'context 1': 'cảm lòng tốt của bạn',
#     'context 2': 'cảm cái đức của một cán bộ cách mạng',
#     'nums context': 2,
#     'nums usage': 2,
#     'usage 1': ["to appreciate one's friend's kindness"],
#     'usage 2': ["to appreciate a revolutionary militant's quality"]},
#    'translation': ['To appreciate']},
#   5: {'POS': 'N/A',
#    'examples': {'context 1': 'xem chừng hắn đã cảm cô ta từ lâu',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['he seems to have been sweet on her for long']},
#    'translation': ['To be sweet on']},
#   'nums': 5},
#  'bờ': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'đến bến lên bờ',
#     'context 2': 'thành phố trên bờ biển',
#     'nums context': 2,
#     'nums usage': 2,
#     'usage 1': ['to go ashore at port'],
#     'usage 2': ['a town on the seashore', 'a seaside town']},
#    'translation': ['Shore', 'bank']},
#   2: {'POS': 'N/A',
#    'examples': 'N/A',
#    'translation': ['Hedge', 'fence', 'wall']},
#   3: {'POS': 'N/A',
#    'examples': {'context 1': 'bờ xôi ruộng mật',
#     'context 2': 'bên ấy bờ xôi ruộng mật dễ đạt năng suất cao',
#     'nums context': 2,
#     'nums usage': 2,
#     'usage 1': ['fat and adequately watered fields'],
#     'usage 2': ['there are fat and adequately watered fields over there',
#      'so a high yield is no problem']},
#    'translation': ['Rim', 'edge']},
#   'nums': 3},
#  'bến': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 1,
#     'usage 1': ['Landing stage', 'wharf', 'station']},
#    'translation': ['Danh từ']},
#   'nums': 1},
#  'tiện': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 1,
#     'usage 1': ['convenient', 'proper']},
#    'translation': ['Tính từ']},
#   'nums': 1},
#  'lóng': {1: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 2,
#     'usage 1': ['internode'],
#     'usage 2': ['slang', 'cant']},
#    'translation': ['Danh từ']},
#   10: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['duh']},
#   11: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['housing']},
#   12: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['interlace']},
#   13: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['interleave']},
#   14: {'POS': 'N/A',
#    'examples': {'context 1': 'bình hóa lỏng ống chùm',
#     'context 2': 'bình hóa lỏng ống vỏ',
#     'context 3': 'lồng ống',
#     'context 4': 'máy trao đổi kiểu ống lồng',
#     'nums context': 4,
#     'nums usage': 4,
#     'usage 1': ['shell-and-tube liquefier'],
#     'usage 2': ['shell-and-tube liquefier'],
#     'usage 3': ['shell and tube condenser'],
#     'usage 4': ['shell tube exchanger']},
#    'translation': ['shell']},
#   15: {'POS': 'N/A',
#    'examples': {'context 1': 'cuộn dây lồng sóc',
#     'context 2': 'máy cân bằng có lồng sóc',
#     'context 3': 'mô tơ kiểu lồng sóc',
#     'context 4': 'phần ứng kiểu lồng sóc',
#     'context 5': 'rôto kiểu lồng sóc',
#     'context 6': 'rôto lồng sóc',
#     'context 7': 'động cơ ba pha lồng sóc',
#     'context 8': 'động cơ lồng sóc',
#     'context 9': 'động cơ lồng sóc kép',
#     'nums context': 9,
#     'nums usage': 9,
#     'usage 1': ['squirrel-cage winding'],
#     'usage 2': ['squirrel-cage balancing machine'],
#     'usage 3': ['squirrel cage motor'],
#     'usage 4': ['squirrel-cage armature'],
#     'usage 5': ['squirrel cage rotor'],
#     'usage 6': ['squirrel cage rotor'],
#     'usage 7': ['three-phase squirrel cage motor'],
#     'usage 8': ['squirrel cage motor'],
#     'usage 9': ['double-squirrel cage motor']},
#    'translation': ['squirrel cage']},
#   16: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['bad fit']},
#   17: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['fluid']},
#   18: {'POS': 'N/A',
#    'examples': {'context 1': 'bề mặt thoáng chất lỏng',
#     'context 2': 'bộ tách chất lỏng',
#     'context 3': 'lưu lượng trong lòng dẫn hở',
#     'context 4': 'mặt thoáng chất lỏng',
#     'context 5': 'mặt thoáng của chất lỏng',
#     'nums context': 5,
#     'nums usage': 5,
#     'usage 1': ['free liquid surface'],
#     'usage 2': ['free liquid knockout'],
#     'usage 3': ['free flow discharge'],
#     'usage 4': ['free surface of liquid'],
#     'usage 5': ['free surface of liquid']},
#    'translation': ['free']},
#   19: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['liquid']},
#   2: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['hair']},
#   20: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['loose']},
#   21: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['work loose']},
#   3: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['slang']},
#   4: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['pilus']},
#   5: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['basket']},
#   6: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['cage']},
#   7: {'POS': 'N/A',
#    'examples': {'context 1': 'lồng bao bọc sách',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['case in']},
#    'translation': ['case']},
#   8: {'POS': 'N/A',
#    'examples': {'context 1': 'lòng bao chắn',
#     'context 2': 'máy lồng bao bọc sách',
#     'context 3': 'móng bằng đá chất đầy lồng gỗ',
#     'context 4': 'ống chống nối lồng',
#     'nums context': 4,
#     'nums usage': 4,
#     'usage 1': ['casing cover'],
#     'usage 2': ['casing-in machine'],
#     'usage 3': ['foundation by timber casing'],
#     'usage 4': ['inserted joint casing']},
#    'translation': ['casing']},
#   9: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['crib']},
#   'nums': 21},
#  'lánh': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'lánh nạn',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['to shun danger', '']},
#    'translation': ['To avoid', 'to shun', '']},
#   'nums': 1},
#  'bọn': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'một bọn trẻ con chơi ngoài sân',
#     'context 2': 'đi thành từng bọn năm bảy người',
#     'context 3': 'bọn bán nước',
#     'context 4': 'bọn họ',
#     'context 5': 'bọn mình',
#     'nums context': 5,
#     'nums usage': 5,
#     'usage 1': ['a band of children was playing in the court-yard'],
#     'usage 2': ['to march in group of 5 to 7 people'],
#     'usage 3': ['traitors'],
#     'usage 4': ['they'],
#     'usage 5': ['we']},
#    'translation': ['Gang', 'band', 'group']},
#   'nums': 1},
#  'cơ': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'lá ách cơ',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['The ace of heart']},
#    'translation': ['Heart']},
#   2: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['Muscle']},
#   3: {'POS': 'N/A',
#    'examples': {'context 1': 'thừa cơ',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['To seize an opportunity']},
#    'translation': ['Occasion', 'possibility', 'opportunity']},
#   'nums': 3},
#  'trục': 'N/A',
#  'chơi': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'trẻ con chơi ngoài sân',
#     'context 2': 'dễ như chơi',
#     'context 3': 'chơi bài',
#     'context 4': 'chơi đàn piano',
#     'context 5': 'chơi bóng tròn',
#     'context 6': 'chơi cho một vố đau',
#     'context 7': 'chơi khăm',
#     'context 8': 'khách làng chơi',
#     'nums context': 8,
#     'nums usage': 8,
#     'usage 1': ['the children played in the yard'],
#     'usage 2': ["like child's play"],
#     'usage 3': ['to play cards'],
#     'usage 4': ['to play piano'],
#     'usage 5': ['to play football'],
#     'usage 6': ['to play a bad trick on someone'],
#     'usage 7': ['to play a nasty trick'],
#     'usage 8': ['play-boys']},
#    'translation': ['To play']},
#   2: {'POS': 'N/A',
#    'examples': {'context 1': 'chơi tem',
#     'context 2': 'chơi cá vàng',
#     'nums context': 2,
#     'nums usage': 2,
#     'usage 1': ['to collect stamps'],
#     'usage 2': ['to keep gold fish as a hobby']},
#    'translation': ['To collect', 'to keep as a hobby']},
#   3: {'POS': 'N/A',
#    'examples': {'context 1': 'chơi thân với nhau từ nhỏ',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['they have been good friends from children']},
#    'translation': ['To be friends with',
#     'to take company with',
#     'to frequent']},
#   4: {'POS': 'N/A',
#    'examples': {'context 1': 'nói chơi',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['to say (something) in play']},
#    'translation': ['To do something in play']},
#   5: {'POS': 'N/A',
#    'examples': {'context 1': 'chơi họ',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['to take part in a tontine']},
#    'translation': ['To take part in']},
#   6: {'POS': 'N/A',
#    'examples': {'context 1': 'chịu chơi không ốm như độ trước',
#     'context 2': 'chơi với lửa',
#     'nums context': 2,
#     'nums usage': 2,
#     'usage 1': ['baby is well', 'no longer sick like in these past months'],
#     'usage 2': ['to play with the fire']},
#    'translation': ['To be well']},
#   'nums': 6},
#  'lạc': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'kẹo lạc',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['peanut sweets', '']},
#    'translation': ['Peanut', 'ground-nut', '']},
#   2: {'POS': 'N/A',
#    'examples': {'context 1': 'đạn lạc',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['a stray bullet', '']},
#    'translation': ['To lose', 'to stray', '']},
#   3: {'POS': 'N/A',
#    'examples': {'context 1': 'lạc giọng',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['to be out of tune', '']},
#    'translation': ['To be out of', '']},
#   4: {'POS': 'N/A',
#    'examples': {'context 1': 'hay để lạc giấy tờ',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['to often mislay documents', '']},
#    'translation': ['To mislay', '']},
#   'nums': 4},
#  'máu': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'ngân hàng máu',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['blood bank', '']},
#    'translation': ['Blood', '']},
#   10: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['color', 'colour']},
#   11: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['colored']},
#   12: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['colour']},
#   13: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['coloured']},
#   14: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['dye']},
#   15: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['paint']},
#   16: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['knot']},
#   17: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['node']},
#   18: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['spike']},
#   19: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['stub']},
#   2: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['piece']},
#   20: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['tab']},
#   21: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['tit']},
#   22: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['check sample']},
#   23: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['crop']},
#   24: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['data-type']},
#   25: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['etalon']},
#   26: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['example']},
#   27: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['form']},
#   28: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['format']},
#   29: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['gauge']},
#   3: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['slab']},
#   30: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['instance']},
#   31: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['make']},
#   32: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['mock-up']},
#   33: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['model']},
#   34: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['mold']},
#   35: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['mould']},
#   36: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['norm']},
#   37: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['paragon']},
#   38: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['parcel']},
#   39: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['pattern']},
#   4: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['blood']},
#   40: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['piece']},
#   41: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['profile']},
#   42: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['reference']},
#   43: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['sample']},
#   44: {'POS': 'N/A',
#    'examples': 'N/A',
#    'translation': ['sample (in statistics)']},
#   45: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['sampled value']},
#   46: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['sampler']},
#   47: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['shape']},
#   48: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['shaped']},
#   49: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['specimen']},
#   5: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['annealing color']},
#   50: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['standard']},
#   51: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['stencil']},
#   52: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['style']},
#   53: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['sweep']},
#   54: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['template']},
#   55: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['templet']},
#   56: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['test']},
#   57: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['type']},
#   58: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['type sample']},
#   6: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['chroma']},
#   7: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['chromatic']},
#   8: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['colo (u) r']},
#   9: {'POS': 'N/A', 'examples': 'N/A', 'translation': ['color']},
#   'nums': 58},
#  'mê': {1: {'POS': 'N/A',
#    'examples': {'context 1': 'ngủ mê',
#     'nums context': 1,
#     'nums usage': 1,
#     'usage 1': ['to sleep roundly']},
#    'translation': ['To faint', 'to lose consciousness', '']},
#   2: {'POS': 'N/A',
#    'examples': {'nums context': 0,
#     'nums usage': 1,
#     'usage 1': ['to dote upon', 'to be carry about', '']},
#    'translation': ['Động từ', '']},
#   'nums': 2},
#  ...}

# %%
unknownPos
# Out:
# []

# %%
from google.colab import files
with open('soha VI-EN.json', 'w') as outfile:
    json.dump(dictionary, outfile)
files.download('soha VI-EN.json')

# %%
findTranslation("lm")
# Out:
# Finding translation for lm
# No translations found for lm
# 'N/A'
