# %%
import urllib.request 
from urllib.parse import quote 
from bs4 import BeautifulSoup
import json
import re
import time

# %%
with open('./wordList', 'r') as infile:
    wordList = infile.read()

# %%
wordList = wordList.split()

# %%
wordList
# Out:
# ['một',
#  'và',
#  'của',
#  'là',
#  'có',
#  'không',
#  'tôi',
#  'người',
#  'những',
#  'đã',
#  'ông',
#  'cho',
#  'như',
#  'ta',
#  'trong']

# %%
posDict = {} #a dictionary to translate POS words in Vietnamese to English
posDict["Động từ"] = "verb"
posDict["Danh từ"] = "noun"
posDict["Nghĩa chuyên ngành"] = "N/A"
posDict["*"] = "N/A"
posDict["Trạng ngữ"] = "adverb"
posDict["Cảm thán"] = "interjection"
posDict["Phó từ"] = "adverb"
posDict["Từ nối"] = "conjunction"
posDict["Từ đệm"] = "N/A"
posDict["Đại từ"] = "pronoun"

# %%
#The link format for soha Viet-Eng is: http://tratu.soha.vn/dict/vn_en/C%C3%B3

# %%
url = "http://tratu.soha.vn/dict/vn_en/" + quote("có") #resolving the IRI issue

try:
    source = urllib.request.urlopen(url)
except:
    print( "Link broken")
soup = BeautifulSoup(source, 'lxml')

# %%
groups = soup.findAll("div", class_ = "section-h3") #soha groups their translations by POS

# %%
groups[0].find("h3").find("span").string #getting the POS from each group
# Out:
# 'Động từ'

# %%
groups[0].findAll("div", class_ = "section-h5")[0] #translations in each group
# Out:
# <div class="section-h5" id="content-5"><h5> <span class="mw-headline">To be</span></h5>
# <dl><dd><dl><dd><strong class="selflink">có</strong> <a href="/dict/vn_en/Ai" title="Ai">ai</a> <a href="/dict/vn_en/H%E1%BB%8Fi" title="Hỏi">hỏi</a> <a href="/dict/vn_en/B%E1%BA%A3o" title="Bảo">bảo</a> <a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a> <a href="/dict/vn_en/%C4%90i" title="Đi">đi</a> <a href="/dict/vn_en/V%E1%BA%AFng" title="Vắng">vắng</a>
# </dd><dd>if there is anyone asking for me, tell him I am not at home
# </dd><dd><a href="/dict/vn_en/C%C6%A1" title="Cơ">cơ</a> <a href="/dict/vn_en/H%E1%BB%99i" title="Hội">hội</a> <a class="new" href="/index.php?title=Ngh%C3%ACn&amp;dict=vn_en&amp;action=edit" title="Nghìn">nghìn</a> <a href="/dict/vn_en/N%C4%83m" title="Năm">năm</a> <strong class="selflink">có</strong> <a href="/dict/vn_en/M%E1%BB%99t" title="Một">một</a>
# </dd><dd>there is such an opportunity once in a thousand years; once in a lifetime
# </dd><dd><a href="/dict/vn_en/Ch%C3%BAng" title="Chúng">chúng</a> <a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a> <a href="/dict/vn_en/Ch%E1%BB%89" title="Chỉ">chỉ</a> <strong class="selflink">có</strong> <a href="/dict/vn_en/Ba" title="Ba">ba</a> <a href="/dict/vn_en/Ng%C6%B0%E1%BB%9Di" title="Người">người</a> <a href="/dict/vn_en/T%E1%BA%A5t" title="Tất">tất</a> <a href="/dict/vn_en/C%E1%BA%A3" title="Cả">cả</a>
# </dd><dd>there are only three of us in all
# </dd><dd><a href="/dict/vn_en/L%C3%A1" title="Lá">lá</a> <strong class="selflink">có</strong> <a href="/dict/vn_en/M%C3%A0u" title="Màu">màu</a> <a href="/dict/vn_en/Xanh" title="Xanh">xanh</a>
# </dd><dd>leaves are green
# </dd><dd><strong class="selflink">có</strong> <a href="/dict/vn_en/Tu%E1%BB%95i" title="Tuổi">tuổi</a>
# </dd><dd>to be advanced in years
# </dd></dl>
# </dd></dl>
# <a name="To_have.2C_to_own"></a></div>

# %%
groups[0].findAll("div", class_ = "section-h5")[0].find("h5").find("span").string #getting one translation
# Out:
# 'To be'

# %%
groups[0].findAll("div", class_ = "section-h5")[0].find("dl").find("dd").find("dl").findAll("dd") #getting all examples
# Out:
# [<dd><strong class="selflink">có</strong> <a href="/dict/vn_en/Ai" title="Ai">ai</a> <a href="/dict/vn_en/H%E1%BB%8Fi" title="Hỏi">hỏi</a> <a href="/dict/vn_en/B%E1%BA%A3o" title="Bảo">bảo</a> <a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a> <a href="/dict/vn_en/%C4%90i" title="Đi">đi</a> <a href="/dict/vn_en/V%E1%BA%AFng" title="Vắng">vắng</a>
#  </dd>,
#  <dd>if there is anyone asking for me, tell him I am not at home
#  </dd>,
#  <dd><a href="/dict/vn_en/C%C6%A1" title="Cơ">cơ</a> <a href="/dict/vn_en/H%E1%BB%99i" title="Hội">hội</a> <a class="new" href="/index.php?title=Ngh%C3%ACn&amp;dict=vn_en&amp;action=edit" title="Nghìn">nghìn</a> <a href="/dict/vn_en/N%C4%83m" title="Năm">năm</a> <strong class="selflink">có</strong> <a href="/dict/vn_en/M%E1%BB%99t" title="Một">một</a>
#  </dd>,
#  <dd>there is such an opportunity once in a thousand years; once in a lifetime
#  </dd>,
#  <dd><a href="/dict/vn_en/Ch%C3%BAng" title="Chúng">chúng</a> <a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a> <a href="/dict/vn_en/Ch%E1%BB%89" title="Chỉ">chỉ</a> <strong class="selflink">có</strong> <a href="/dict/vn_en/Ba" title="Ba">ba</a> <a href="/dict/vn_en/Ng%C6%B0%E1%BB%9Di" title="Người">người</a> <a href="/dict/vn_en/T%E1%BA%A5t" title="Tất">tất</a> <a href="/dict/vn_en/C%E1%BA%A3" title="Cả">cả</a>
#  </dd>,
#  <dd>there are only three of us in all
#  </dd>,
#  <dd><a href="/dict/vn_en/L%C3%A1" title="Lá">lá</a> <strong class="selflink">có</strong> <a href="/dict/vn_en/M%C3%A0u" title="Màu">màu</a> <a href="/dict/vn_en/Xanh" title="Xanh">xanh</a>
#  </dd>,
#  <dd>leaves are green
#  </dd>,
#  <dd><strong class="selflink">có</strong> <a href="/dict/vn_en/Tu%E1%BB%95i" title="Tuổi">tuổi</a>
#  </dd>,
#  <dd>to be advanced in years
#  </dd>]

# %%
groups[0].findAll("div", class_ = "section-h5")[0].find("dl").find("dd").find("dl").findAll("dd")[0] #a context
# Out:
# <dd><strong class="selflink">có</strong> <a href="/dict/vn_en/Ai" title="Ai">ai</a> <a href="/dict/vn_en/H%E1%BB%8Fi" title="Hỏi">hỏi</a> <a href="/dict/vn_en/B%E1%BA%A3o" title="Bảo">bảo</a> <a href="/dict/vn_en/T%C3%B4i" title="Tôi">tôi</a> <a href="/dict/vn_en/%C4%90i" title="Đi">đi</a> <a href="/dict/vn_en/V%E1%BA%AFng" title="Vắng">vắng</a>
# </dd>

# %%
def extractContext(tag):
    parts = tag.findAll("a")
    parts = [part.contents[0] for part in parts]
    context = " ".join(parts)
    return context

# %%
extractContext(groups[0].findAll("div", class_ = "section-h5")[0].find("dl").find("dd").find("dl").findAll("dd")[0])
# Out:
# 'ai hỏi bảo tôi đi vắng'

# %%
groups[0].findAll("div", class_ = "section-h5")[0].find("dl").find("dd").find("dl").findAll("dd")[1].string.strip() #an usage
# Out:
# 'if there is anyone asking for me, tell him I am not at home'

# %%
def getPos(vietPos): #translating the POS in Viet to English
    vietPos = vietPos.strip(".")
    if (vietPos.find("(") != -1): #the vietPos contains the english equivalent
        return vietPos[vietPos.find("(")+1:vietPos.find(")")].strip()
    elif (vietPos in posDict):
        return posDict[vietPos]
    else:
        print("Can not determine POS: " + vietPos)
        return "N/A"

# %%
getPos("Động từ")
# Out:
# 'verb'

# %%
getPos("Phó từ ( affirmative particle)")
# Out:
# 'affirmative particle'

# %%
def findTranslation(word):
    url = "http://tratu.soha.vn/dict/vn_en/" + quote(word) #resolving the IRI issue

    try:
        source = urllib.request.urlopen(url)
    except:
        print( "Link broken")
    soup = BeautifulSoup(source, 'lxml')
    
    groups = soup.findAll("div", class_ = "section-h3") #soha groups their translations by POS
    
    translations = {}
    numTrans = 0
    
    for group in groups:
        groupPos = getPos(group.find("h3").find("span").string) #getting the POS for this group
        
        containers = group.findAll("div", class_ = "section-h5") #getting all the translations for this group
        
        for trans in containers: #for each translation in this group
            temp = {} #temp dict to store each translation of a word
            
            #getting the raw translation
            temp['translation'] = [item.strip() for item in re.split('[,;]', trans.find("h5").find("span").string)]
            temp['POS'] = groupPos
            
            try:
                #retrieving the examples and contexts of this translation
                clarifications = trans.find("dl").find("dd").find("dl").findAll("dd")
                temp2 = {} #another dict to store each examples of a translation
                numExamples = int(len(clarifications)/2) #each clarification has a context followed by its usage
                temp2["nums"] = numExamples
                
                for i in range(0, numExamples):
                    #if the index is even, then item is context. Otherwise, it is usage
                    temp2['context ' + str(i+1)] = extractContext(clarifications[2*i])
                    temp2['usage ' + str(i+1)] = clarifications[2*i+1].string.strip()
                
                temp['examples'] = temp2
            except:
                temp['examples'] = "N/A"
        
            translations[numTrans+1] = temp #adding the translation to the dictionary
            numTrans += 1
            
    #storing the number of translations
    translations['nums'] = numTrans
    return translations

# %%
findTranslation("có")
# Out:
# {1: {'translation': ['To be'],
#   'POS': 'verb',
#   'examples': {'nums': 5,
#    'context 1': 'ai hỏi bảo tôi đi vắng',
#    'usage 1': 'if there is anyone asking for me, tell him I am not at home',
#    'context 2': 'cơ hội nghìn năm một',
#    'usage 2': 'there is such an opportunity once in a thousand years; once in a lifetime',
#    'context 3': 'chúng tôi chỉ ba người tất cả',
#    'usage 3': 'there are only three of us in all',
#    'context 4': 'lá màu xanh',
#    'usage 4': 'leaves are green',
#    'context 5': 'tuổi',
#    'usage 5': 'to be advanced in years'}},
#  2: {'translation': ['To have', 'to own'],
#   'POS': 'verb',
#   'examples': {'nums': 11,
#    'context 1': 'người cày ruộng',
#    'usage 1': 'the tillet owns his own land',
#    'context 2': 'công dân quyền bầu cử ứng cử',
#    'usage 2': 'citizens have the right to vote and to stand for election',
#    'context 3': 'nhà',
#    'usage 3': 'a "have" family',
#    'context 4': 'sách ba chương',
#    'usage 4': 'the book has three chapters',
#    'context 5': 'gan nói lên sự thật',
#    'usage 5': 'to have enough courage to tell the truth',
#    'context 6': 'một nền nghệ thuật truyền thống lâu đời',
#    'usage 6': 'an art having an age-old tradition',
#    'context 7': 'hai con',
#    'usage 7': 'to have two children',
#    'context 8': 'nhau',
#    'usage 8': 'to have one another (as allies, friends...)',
#    'context 9': 'chí thì nên nên',
#    'usage 9': 'nên',
#    'context 10': 'da thịt',
#    'usage 10': 'to put on flesh (nói về người vốn gầy gò)',
#    'context 11': 'tật giật mình',
#    'usage 11': 'A guilty conscience needs no accuser; Truest jets sound worst in guilty ears'}},
#  3: {'translation': ['Tình hình có khác the situation is different'],
#   'POS': 'affirmative particle',
#   'examples': {'nums': 5,
#    'context 1': 'tôi gặp anh ta',
#    'usage 1': 'I did meet him',
#    'context 2': 'ngày mai thư viện mở cửa',
#    'usage 2': 'tomorrow, the library will be open',
#    'context 3': 'chăng chỉ anhta biết',
#    'usage 3': "if anyone knows, it's him",
#    'context 4': 'xa không',
#    'usage 4': "quite far, isn't it\xa0?",
#    'context 5': 'ăn nhai nói nghĩ',
#    'usage 5': 'do chew when eating, do think when speaking'}},
#  4: {'translation': ['Nó chỉ ăn có một bát cơm he ate only one bowl of rice'],
#   'POS': 'emphatic particle',
#   'examples': {'nums': 5,
#    'context 1': 'đông đến vài trăm người',
#    'usage 1': 'there was a crowd of at least some hundreds of people',
#    'context 2': 'anh đi thì tôi chờ',
#    'usage 2': "if you want to come, I'll wait for you",
#    'context 3': 'chớ nói dối',
#    'usage 3': "don't ever lie",
#    'context 4': 'anh đừng nghĩ như thế',
#    'usage 4': 'do not think like that',
#    'context 5': 'tôi biết đâu việc ấy',
#    'usage 5': "I don't know anything at all about that"}},
#  'nums': 4}

# %%
findTranslation("tôi")
# Out:
# {1: {'translation': ['Cur', 'ass', 'donkey'],
#   'POS': 'noun',
#   'examples': {'nums': 2,
#    'context 1': 'đồ',
#    'usage 1': 'what a cur you are!',
#    'context 2': 'ngu như',
#    'usage 2': 'what an ass!'}},
#  2: {'translation': ['Dog'],
#   'POS': 'noun',
#   'examples': {'nums': 6,
#    'context 1': 'già giữ xương',
#    'usage 1': 'to be a dog in the manger',
#    'context 2': 'treo đầu dê bán thịt',
#    'usage 2': 'he cries wine and sells vinegar',
#    'context 3': 'cắn áo rách',
#    'usage 3': 'hardships never come alone',
#    'context 4': 'cùng rứt giậu',
#    'usage 4': 'beast at bay bites hard',
#    'context 5': 'ngáp phải ruồi',
#    'usage 5': 'to get a godsend',
#    'context 6': 'như với mèo',
#    'usage 6': 'to agree like cats and dogs'}},
#  'nums': 2}

# %%
dictionary = {}
start_time = time.time()
for word in wordList:
    dictionary[word] = findTranslation(word)
    time.sleep(1) #wait for 1 sec between each query
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 23.94894790649414 seconds ---

# %%
dictionary
# Out:
# {'một': {'nums': 0},
#  'và': {'nums': 0},
#  'của': {1: {'translation': ['Property', 'belongings', 'given kind of food'],
#    'POS': 'noun',
#    'examples': {'nums': 1,
#     'context 1': 'bảo vệ công',
#     'usage 1': 'to protect public property'}},
#   2: {'translation': ['Of', 'belong to', 'from'],
#    'POS': 'adverb',
#    'examples': {'nums': 1,
#     'context 1': 'cô ta là bạn tôi',
#     'usage 1': 'A girl friend of mine'}},
#   'nums': 2},
#  'là': {1: {'translation': ['To be.'],
#    'POS': 'verb',
#    'examples': {'nums': 1,
#     'context 1': 'thì giờ tiền bạc',
#     'usage 1': 'Time is money.'}},
#   2: {'translation': ['Trạng ngữ.'], 'POS': 'verb', 'examples': {'nums': 0}},
#   3: {'translation': ['How.'],
#    'POS': 'interjection',
#    'examples': {'nums': 1,
#     'context 1': 'đẹp đẹp',
#     'usage 1': 'how beautiful!'}},
#   4: {'translation': ['To press iron.'],
#    'POS': 'verb',
#    'examples': {'nums': 1, 'context 1': 'bàn', 'usage 1': 'an iron.'}},
#   'nums': 4},
#  'có': {1: {'translation': ['To be'],
#    'POS': 'verb',
#    'examples': {'nums': 5,
#     'context 1': 'ai hỏi bảo tôi đi vắng',
#     'usage 1': 'if there is anyone asking for me, tell him I am not at home',
#     'context 2': 'cơ hội nghìn năm một',
#     'usage 2': 'there is such an opportunity once in a thousand years; once in a lifetime',
#     'context 3': 'chúng tôi chỉ ba người tất cả',
#     'usage 3': 'there are only three of us in all',
#     'context 4': 'lá màu xanh',
#     'usage 4': 'leaves are green',
#     'context 5': 'tuổi',
#     'usage 5': 'to be advanced in years'}},
#   2: {'translation': ['To have', 'to own'],
#    'POS': 'verb',
#    'examples': {'nums': 11,
#     'context 1': 'người cày ruộng',
#     'usage 1': 'the tillet owns his own land',
#     'context 2': 'công dân quyền bầu cử ứng cử',
#     'usage 2': 'citizens have the right to vote and to stand for election',
#     'context 3': 'nhà',
#     'usage 3': 'a "have" family',
#     'context 4': 'sách ba chương',
#     'usage 4': 'the book has three chapters',
#     'context 5': 'gan nói lên sự thật',
#     'usage 5': 'to have enough courage to tell the truth',
#     'context 6': 'một nền nghệ thuật truyền thống lâu đời',
#     'usage 6': 'an art having an age-old tradition',
#     'context 7': 'hai con',
#     'usage 7': 'to have two children',
#     'context 8': 'nhau',
#     'usage 8': 'to have one another (as allies, friends...)',
#     'context 9': 'chí thì nên nên',
#     'usage 9': 'nên',
#     'context 10': 'da thịt',
#     'usage 10': 'to put on flesh (nói về người vốn gầy gò)',
#     'context 11': 'tật giật mình',
#     'usage 11': 'A guilty conscience needs no accuser; Truest jets sound worst in guilty ears'}},
#   3: {'translation': ['Tình hình có khác the situation is different'],
#    'POS': 'affirmative particle',
#    'examples': {'nums': 5,
#     'context 1': 'tôi gặp anh ta',
#     'usage 1': 'I did meet him',
#     'context 2': 'ngày mai thư viện mở cửa',
#     'usage 2': 'tomorrow, the library will be open',
#     'context 3': 'chăng chỉ anhta biết',
#     'usage 3': "if anyone knows, it's him",
#     'context 4': 'xa không',
#     'usage 4': "quite far, isn't it\xa0?",
#     'context 5': 'ăn nhai nói nghĩ',
#     'usage 5': 'do chew when eating, do think when speaking'}},
#   4: {'translation': ['Nó chỉ ăn có một bát cơm he ate only one bowl of rice'],
#    'POS': 'emphatic particle',
#    'examples': {'nums': 5,
#     'context 1': 'đông đến vài trăm người',
#     'usage 1': 'there was a crowd of at least some hundreds of people',
#     'context 2': 'anh đi thì tôi chờ',
#     'usage 2': "if you want to come, I'll wait for you",
#     'context 3': 'chớ nói dối',
#     'usage 3': "don't ever lie",
#     'context 4': 'anh đừng nghĩ như thế',
#     'usage 4': 'do not think like that',
#     'context 5': 'tôi biết đâu việc ấy',
#     'usage 5': "I don't know anything at all about that"}},
#   'nums': 4},
#  'không': {1: {'translation': ['Not', 'nothing', 'without'],
#    'POS': 'N/A',
#    'examples': {'nums': 1,
#     'context 1': 'anh có thấy nó Tôi trả lời',
#     'usage 1': 'Have you seen him? My answer is no'}},
#   2: {'translation': ['Empty'],
#    'POS': 'N/A',
#    'examples': {'nums': 1, 'context 1': 'tay', 'usage 1': 'empty handed'}},
#   3: {'translation': ['Bare'],
#    'POS': 'N/A',
#    'examples': {'nums': 1, 'context 1': 'chân', 'usage 1': 'bare legs'}},
#   4: {'translation': ['Air'],
#    'POS': 'noun',
#    'examples': {'nums': 1,
#     'context 1': 'bay lượn trên',
#     'usage 1': 'to float about in the air'}},
#   5: {'translation': ['no'], 'POS': 'N/A', 'examples': 'N/A'},
#   6: {'translation': ['not'], 'POS': 'N/A', 'examples': 'N/A'},
#   7: {'translation': ['zero'], 'POS': 'N/A', 'examples': 'N/A'},
#   'nums': 7},
#  'tôi': {1: {'translation': ['bad'], 'POS': 'N/A', 'examples': 'N/A'},
#   2: {'translation': ['friable'], 'POS': 'N/A', 'examples': 'N/A'},
#   3: {'translation': ['chilling'], 'POS': 'N/A', 'examples': 'N/A'},
#   4: {'translation': ['cure'], 'POS': 'N/A', 'examples': 'N/A'},
#   5: {'translation': ['dip'], 'POS': 'N/A', 'examples': 'N/A'},
#   6: {'translation': ['thoriveitite'], 'POS': 'N/A', 'examples': 'N/A'},
#   7: {'translation': ['advent'], 'POS': 'N/A', 'examples': 'N/A'},
#   8: {'translation': ['arrival'], 'POS': 'N/A', 'examples': 'N/A'},
#   9: {'translation': ['arrive'], 'POS': 'N/A', 'examples': 'N/A'},
#   10: {'translation': ['ingoing'], 'POS': 'N/A', 'examples': 'N/A'},
#   11: {'translation': ['capstan'], 'POS': 'N/A', 'examples': 'N/A'},
#   12: {'translation': ['drawwork'], 'POS': 'N/A', 'examples': 'N/A'},
#   13: {'translation': ['gin'], 'POS': 'N/A', 'examples': 'N/A'},
#   14: {'translation': ['hauler'], 'POS': 'N/A', 'examples': 'N/A'},
#   15: {'translation': ['jack up'], 'POS': 'N/A', 'examples': 'N/A'},
#   16: {'translation': ['purchase'], 'POS': 'N/A', 'examples': 'N/A'},
#   17: {'translation': ['sheave'], 'POS': 'N/A', 'examples': 'N/A'},
#   18: {'translation': ['winch capstan'], 'POS': 'N/A', 'examples': 'N/A'},
#   19: {'translation': ['winding engine'], 'POS': 'N/A', 'examples': 'N/A'},
#   20: {'translation': ['defective'], 'POS': 'N/A', 'examples': 'N/A'},
#   21: {'translation': ['foul'], 'POS': 'N/A', 'examples': 'N/A'},
#   22: {'translation': ['garlicky'], 'POS': 'N/A', 'examples': 'N/A'},
#   23: {'translation': ['crumbly'], 'POS': 'N/A', 'examples': 'N/A'},
#   24: {'translation': ['friable'], 'POS': 'N/A', 'examples': 'N/A'},
#   25: {'translation': ['windlass'], 'POS': 'N/A', 'examples': 'N/A'},
#   26: {'translation': ['wrong'], 'POS': 'N/A', 'examples': 'N/A'},
#   'nums': 26},
#  'người': {1: {'translation': ['Man', 'person', 'people', 'individual.'],
#    'POS': 'noun',
#    'examples': {'nums': 1, 'context 1': 'mọi', 'usage 1': 'every man.'}},
#   'nums': 1},
#  'những': {'nums': 0},
#  'đã': {1: {'translation': ['Already'],
#    'POS': 'adverb',
#    'examples': {'nums': 1,
#     'context 1': 'trưa rồi',
#     'usage 1': "It's already late"}},
#   2: {'translation': ['First'],
#    'POS': 'adverb',
#    'examples': {'nums': 1,
#     'context 1': 'chúng ta hãy học',
#     'usage 1': "Let's learn first"}},
#   3: {'translation': ['As', 'since'], 'POS': 'adverb', 'examples': 'N/A'},
#   'nums': 3},
#  'ông': {1: {'translation': ['Grandfather.'],
#    'POS': 'noun',
#    'examples': {'nums': 1,
#     'context 1': 'nội',
#     'usage 1': 'paternal grandfather.'}},
#   2: {'translation': ['Gentleman.'],
#    'POS': 'noun',
#    'examples': {'nums': 1,
#     'context 1': 'mời ấy vào',
#     'usage 1': 'Ask the gentleman to come in.'}},
#   3: {'translation': ['You mister', 'you sir.'],
#    'POS': 'noun',
#    'examples': 'N/A'},
#   4: {'translation': ['canal'], 'POS': 'N/A', 'examples': 'N/A'},
#   5: {'translation': ['mister'], 'POS': 'N/A', 'examples': 'N/A'},
#   6: {'translation': ['adjutage'], 'POS': 'N/A', 'examples': 'N/A'},
#   7: {'translation': ['alveus'], 'POS': 'N/A', 'examples': 'N/A'},
#   8: {'translation': ['barrel'], 'POS': 'N/A', 'examples': 'N/A'},
#   9: {'translation': ['blowpipe'], 'POS': 'N/A', 'examples': 'N/A'},
#   10: {'translation': ['box spanner'], 'POS': 'N/A', 'examples': 'N/A'},
#   11: {'translation': ['bush'], 'POS': 'N/A', 'examples': 'N/A'},
#   12: {'translation': ['bushing'], 'POS': 'N/A', 'examples': 'N/A'},
#   13: {'translation': ['bypass'], 'POS': 'N/A', 'examples': 'N/A'},
#   14: {'translation': ['cartridge'], 'POS': 'N/A', 'examples': 'N/A'},
#   15: {'translation': ['cellular'], 'POS': 'N/A', 'examples': 'N/A'},
#   16: {'translation': ['channel'], 'POS': 'N/A', 'examples': 'N/A'},
#   17: {'translation': ['collar'], 'POS': 'N/A', 'examples': 'N/A'},
#   18: {'translation': ['communication pipe'], 'POS': 'N/A', 'examples': 'N/A'},
#   19: {'translation': ['conduit'], 'POS': 'N/A', 'examples': 'N/A'},
#   20: {'translation': ['course'], 'POS': 'N/A', 'examples': 'N/A'},
#   21: {'translation': ['duct'], 'POS': 'N/A', 'examples': 'N/A'},
#   22: {'translation': ['duet'], 'POS': 'N/A', 'examples': 'N/A'},
#   23: {'translation': ['flexible pipe'], 'POS': 'N/A', 'examples': 'N/A'},
#   24: {'translation': ['flexible tube'], 'POS': 'N/A', 'examples': 'N/A'},
#   25: {'translation': ['flexible tubing'], 'POS': 'N/A', 'examples': 'N/A'},
#   26: {'translation': ['hose'], 'POS': 'N/A', 'examples': 'N/A'},
#   27: {'translation': ['lamp'], 'POS': 'N/A', 'examples': 'N/A'},
#   28: {'translation': ['manifold'], 'POS': 'N/A', 'examples': 'N/A'},
#   29: {'translation': ['mantle'], 'POS': 'N/A', 'examples': 'N/A'},
#   30: {'translation': ['muff'], 'POS': 'N/A', 'examples': 'N/A'},
#   31: {'translation': ['nozzle'], 'POS': 'N/A', 'examples': 'N/A'},
#   32: {'translation': ['pin'], 'POS': 'N/A', 'examples': 'N/A'},
#   33: {'translation': ['pipe'], 'POS': 'N/A', 'examples': 'N/A'},
#   34: {'translation': ['pipe', 'conduit and duct'],
#    'POS': 'N/A',
#    'examples': 'N/A'},
#   35: {'translation': ['pipeline'], 'POS': 'N/A', 'examples': 'N/A'},
#   36: {'translation': ['quill'], 'POS': 'N/A', 'examples': 'N/A'},
#   37: {'translation': ['rigid pipe'], 'POS': 'N/A', 'examples': 'N/A'},
#   38: {'translation': ['sewer pipe'], 'POS': 'N/A', 'examples': 'N/A'},
#   39: {'translation': ['shell'], 'POS': 'N/A', 'examples': 'N/A'},
#   40: {'translation': ['shoot'], 'POS': 'N/A', 'examples': 'N/A'},
#   41: {'translation': ['sleeve'], 'POS': 'N/A', 'examples': 'N/A'},
#   42: {'translation': ['thimble'], 'POS': 'N/A', 'examples': 'N/A'},
#   43: {'translation': ['transverse drain'], 'POS': 'N/A', 'examples': 'N/A'},
#   44: {'translation': ['trunk'], 'POS': 'N/A', 'examples': 'N/A'},
#   45: {'translation': ['tube'], 'POS': 'N/A', 'examples': 'N/A'},
#   46: {'translation': ['tubing'], 'POS': 'N/A', 'examples': 'N/A'},
#   47: {'translation': ['tunnel'], 'POS': 'N/A', 'examples': 'N/A'},
#   48: {'translation': ['vessel'], 'POS': 'N/A', 'examples': 'N/A'},
#   49: {'translation': ['channel'], 'POS': 'N/A', 'examples': 'N/A'},
#   50: {'translation': ['duct'], 'POS': 'N/A', 'examples': 'N/A'},
#   51: {'translation': ['flask'], 'POS': 'N/A', 'examples': 'N/A'},
#   52: {'translation': ['rack'], 'POS': 'N/A', 'examples': 'N/A'},
#   53: {'translation': ['tube'], 'POS': 'N/A', 'examples': 'N/A'},
#   54: {'translation': ['vessel'], 'POS': 'N/A', 'examples': 'N/A'},
#   'nums': 54},
#  'cho': {1: {'translation': ['To give'],
#    'POS': 'verb',
#    'examples': {'nums': 11,
#     'context 1': 'anh ta tôi chiếc đồng hồ',
#     'usage 1': 'he gave me a watch',
#     'context 2': 'quà',
#     'usage 2': 'to give presents',
#     'context 3': 'không không bán',
#     'usage 3': 'to give (something) free of charge, not to sell it',
#     'context 4': 'thầy thuốc đơn',
#     'usage 4': 'doctors give prescriptions',
#     'context 5': 'bài này đáng năm điểm',
#     'usage 5': 'this task deserves to be given mark 5',
#     'context 6': 'anh ta một tuần lễ để chuẩn bị',
#     'usage 6': 'he was given a week to prepare',
#     'context 7': 'kinh nghiệm lịch sử ta nhiều bài học quý',
#     'usage 7': 'history has given us many valuable lessons',
#     'context 8': 'hắn một cái tát',
#     'usage 8': 'give him a slap',
#     'context 9': 'bú',
#     'usage 9': 'to give suck',
#     'context 10': 'chủ toạ ai nói',
#     'usage 10': 'the chairman gave the floor to someone',
#     'context 11': 'phép nghỉ',
#     'usage 11': 'to give (someone) leave of absence'}},
#   2: {'translation': ['To let', 'to make'],
#    'POS': 'verb',
#    'examples': {'nums': 4,
#     'context 1': 'công nhân máy chạy',
#     'usage 1': 'the worker made the machine work',
#     'context 2': 'bò đi ăn cỏ',
#     'usage 2': 'to make (let) cows go and eat grass, to graze cows',
#     'context 3': 'vấn đề này có thể qua',
#     'usage 3': 'this matter can be let pass',
#     'context 4': 'người đi tìm',
#     'usage 4': 'to make a person go and look for (someone...), to send a person on the search for (someone..)'}},
#   3: {'translation': ['To put'],
#    'POS': 'verb',
#    'examples': {'nums': 4,
#     'context 1': 'than vào lò',
#     'usage 1': 'to put coal in the oven',
#     'context 2': 'hàng hoá đã cả lên tàu',
#     'usage 2': 'all the goods have been put on board, all the goods have been loaded',
#     'context 3': 'canh hơi nhạt cần thêm muối',
#     'usage 3': 'the soup is not seasoned enough, some more salt must be put in it (added to it)',
#     'context 4': 'ảnh treo cao quá cần thấp xuống một chút',
#     'usage 4': 'the picture is hung too high, it must be put a bit lower'}},
#   4: {'translation': ['To consider', 'to think', 'to put down'],
#    'POS': 'verb',
#    'examples': {'nums': 5,
#     'context 1': 'đừng vội rằng việc làm ám muội ấy không ai biết',
#     'usage 1': "don't think too soon that such a shady deed is not known by anyone",
#     'context 2': 'ai cũng thế là phải',
#     'usage 2': 'everyone thinks that right',
#     'context 3': 'kém nhưng lại mình là đủ khả năng',
#     'usage 3': 'though not capable, he considers himself fully qualified',
#     'context 4': 'là nó có tài một mình nó cũng chẳng làm gì được',
#     'usage 4': 'supposing he is talented, he cannot do anything about it alone',
#     'context 5': 'chúng tôi nó là người khờ dại',
#     'usage 5': 'we put him down as a fool'}},
#   5: {'translation': ['Please give', 'please let'],
#    'POS': 'verb',
#    'examples': {'nums': 2,
#     'context 1': 'anh tôi chiếc mũ ở kia',
#     'usage 1': 'please give me that hat over there',
#     'context 2': 'chị tôi mười đồng phong bì',
#     'usage 2': 'please give ten dongs worth of envelopes'}},
#   6: {'translation': ['For', 'to'],
#    'POS': 'conjunction',
#    'examples': {'nums': 10,
#     'context 1': 'gửi ai một bức thư',
#     'usage 1': 'to send a letter to someone',
#     'context 2': 'bán khách hàng',
#     'usage 2': 'to sell to customers',
#     'context 3': 'mừng anh chị',
#     'usage 3': 'congratulations to you both',
#     'context 4': 'anh ở nhà để tôi đi',
#     'usage 4': 'stay at home, let me go for you',
#     'context 5': 'mong anh giúp',
#     'usage 5': "I hope for your help for me, I hope you'll help me",
#     'context 6': 'sách thiếu nhi',
#     'usage 6': 'books for children',
#     'context 7': 'tất cả tiền tuyến tất cả để chiến thắng',
#     'usage 7': 'all for the front, all for our victory',
#     'context 8': 'buổi nói chuyện bổ ích nhiều người',
#     'usage 8': 'the talk was useful to many people',
#     'context 9': 'sai lầm có hại công tác',
#     'usage 9': "a mistake harmful to one's work",
#     'context 10': 'không may anh ta',
#     'usage 10': 'unfortunately for him'}},
#   7: {'translation': ['Until', 'till'],
#    'POS': 'conjunction',
#    'examples': {'nums': 3,
#     'context 1': 'học giỏi',
#     'usage 1': 'to study hard until proficiency is achieved',
#     'context 2': 'làm cố xong việc gì',
#     'usage 2': 'to try hard until some job is finished',
#     'context 3': 'chúng ta hãy chờ mọi người đến đông đủ',
#     'usage 3': "let's wait until everybody has come"}},
#   8: {'translation': ['Therefore', 'hence', 'that'],
#    'POS': 'conjunction',
#    'examples': {'nums': 2,
#     'context 1': 'Vì ta lụy đến người',
#     'usage 1': 'it is because of me that he found himself in such a predicament',
#     'context 2': 'vênh cái mặt người ta ghét',
#     'usage 2': 'he put on airs, hence they did not like him'}},
#   9: {'translation': ['Mặc cho mưa gió',
#     'anh ta vẫn cứ đi in spite of the rain and wind',
#     'he set off all the same'],
#    'POS': 'N/A',
#    'examples': {'nums': 2,
#     'context 1': 'dù nó có sống nó cũng bị què',
#     'usage 1': 'even if he lived, he would be a crippled',
#     'context 2': 'vở kịch không hay gì lắm',
#     'usage 2': 'the play was not so good'}},
#   10: {'translation': ['give'], 'POS': 'N/A', 'examples': 'N/A'},
#   11: {'translation': ['position'], 'POS': 'N/A', 'examples': 'N/A'},
#   12: {'translation': ['room'], 'POS': 'N/A', 'examples': 'N/A'},
#   13: {'translation': ['space'], 'POS': 'N/A', 'examples': 'N/A'},
#   14: {'translation': ['pending'], 'POS': 'N/A', 'examples': 'N/A'},
#   15: {'translation': ['carry'], 'POS': 'N/A', 'examples': 'N/A'},
#   16: {'translation': ['bazaar'], 'POS': 'N/A', 'examples': 'N/A'},
#   17: {'translation': ['local market'], 'POS': 'N/A', 'examples': 'N/A'},
#   18: {'translation': ['allow'], 'POS': 'N/A', 'examples': 'N/A'},
#   19: {'translation': ['award'], 'POS': 'N/A', 'examples': 'N/A'},
#   20: {'translation': ['place'], 'POS': 'N/A', 'examples': 'N/A'},
#   21: {'translation': ['site'], 'POS': 'N/A', 'examples': 'N/A'},
#   22: {'translation': ['situation'], 'POS': 'N/A', 'examples': 'N/A'},
#   23: {'translation': ['carry'], 'POS': 'N/A', 'examples': 'N/A'},
#   24: {'translation': ['load'], 'POS': 'N/A', 'examples': 'N/A'},
#   25: {'translation': ['emporium'], 'POS': 'N/A', 'examples': 'N/A'},
#   26: {'translation': ['market'], 'POS': 'N/A', 'examples': 'N/A'},
#   27: {'translation': ['market place (marketplace)'],
#    'POS': 'N/A',
#    'examples': 'N/A'},
#   'nums': 27},
#  'như': {'nums': 0},
#  'ta': {1: {'translation': ['I', 'me', 'my.'],
#    'POS': 'pronoun',
#    'examples': {'nums': 1,
#     'context 1': 'cũng nghĩ thế',
#     'usage 1': 'I think so, too.'}},
#   2: {'translation': ['We', 'our', 'us.'],
#    'POS': 'pronoun',
#    'examples': {'nums': 1, 'context 1': 'đi thôi', 'usage 1': "let's go."}},
#   'nums': 2},
#  'trong': {1: {'translation': ['intrinsic'],
#    'POS': 'N/A',
#    'examples': {'nums': 2,
#     'context 1': 'hiệu ứng quang điện',
#     'usage 1': 'intrinsic photo effect',
#     'context 2': 'tính chất bên',
#     'usage 2': 'intrinsic property'}},
#   2: {'translation': ['blank'],
#    'POS': 'N/A',
#    'examples': {'nums': 31,
#     'context 1': 'bản ghi để trống',
#     'usage 1': 'blank record',
#     'context 2': 'bảng kê để trống',
#     'usage 2': 'blank table',
#     'context 3': 'băng trống',
#     'usage 3': 'blank tape',
#     'context 4': 'băng từ trống',
#     'usage 4': 'blank magnetic tape',
#     'context 5': 'bối thư trống',
#     'usage 5': 'blank endorsement',
#     'context 6': 'cơ sở dữ liệu trống',
#     'usage 6': 'blank database',
#     'context 7': 'cột trống',
#     'usage 7': 'blank column',
#     'context 8': 'cửa mái để trống',
#     'usage 8': 'blank skylight',
#     'context 9': 'cửa sổ trí',
#     'usage 9': 'blank window',
#     'context 10': 'dòng trống',
#     'usage 10': 'blank line',
#     'context 11': 'dòng trống',
#     'usage 11': 'blank lines',
#     'context 12': 'khoảng trống',
#     'usage 12': 'blank gap',
#     'context 13': 'khoảng trống',
#     'usage 13': 'blank space',
#     'context 14': 'khoảng trống giữa các từ',
#     'usage 14': 'inter-word blank',
#     'context 15': 'khoảng trống không được nhúng',
#     'usage 15': 'embedded blank',
#     'context 16': 'khoảng trống được nhúng',
#     'usage 16': 'embedded blank',
#     'context 17': 'khuôn trống',
#     'usage 17': 'blank form',
#     'context 18': 'ký tự trống',
#     'usage 18': 'blank character',
#     'context 19': 'lờ đi khoảng trống',
#     'usage 19': 'ignore blank',
#     'context 20': 'mẫu biểu trống',
#     'usage 20': 'blank form',
#     'context 21': 'môi trường trống',
#     'usage 21': 'blank medium',
#     'context 22': 'mức trống',
#     'usage 22': 'blank level',
#     'context 23': 'ô trống',
#     'usage 23': 'blank cell',
#     'context 24': 'phát hiện cột trống',
#     'usage 24': 'blank column detection',
#     'context 25': 'phiếu trống',
#     'usage 25': 'blank ticket',
#     'context 26': 'phương tiện trống',
#     'usage 26': 'blank medium',
#     'context 27': 'rãnh trống',
#     'usage 27': 'blank groove',
#     'context 28': 'thông báo trống rỗng-chùm khối',
#     'usage 28': 'blank-and-burst message',
#     'context 29': 'trang web trống',
#     'usage 29': 'blank web page',
#     'context 30': 'vật trữ tin trống',
#     'usage 30': 'blank medium',
#     'context 31': 'đĩa mềm trống',
#     'usage 31': 'blank diskette'}},
#   3: {'translation': ['blank space'], 'POS': 'N/A', 'examples': 'N/A'},
#   4: {'translation': ['blind'],
#    'POS': 'N/A',
#    'examples': {'nums': 1,
#     'context 1': 'đất bỏ trống',
#     'usage 1': 'blind area'}},
#   5: {'translation': ['clear'],
#    'POS': 'N/A',
#    'examples': {'nums': 33,
#     'context 1': 'bầu trời sáng',
#     'usage 1': 'clear air',
#     'context 2': 'bể chứa nước',
#     'usage 2': 'clear-water reservoir',
#     'context 3': 'bể làm',
#     'usage 3': 'clear pond',
#     'context 4': 'bộ nhớ trống',
#     'usage 4': 'clear memory',
#     'context 5': 'bộ nhớ trống',
#     'usage 5': 'clear storage',
#     'context 6': 'giếng làm',
#     'usage 6': 'clear well',
#     'context 7': 'khẩu độ trống',
#     'usage 7': 'clear span',
#     'context 8': 'khoảng cách mép',
#     'usage 8': 'clear distance',
#     'context 9': 'khoảng cách trống nhịp trống',
#     'usage 9': 'clear span',
#     'context 10': 'khoảng trống',
#     'usage 10': 'clear spacing',
#     'context 11': 'kính',
#     'usage 11': 'clear glass',
#     'context 12': 'màn hình trống',
#     'usage 12': 'clear display',
#     'context 13': 'màn suốt',
#     'usage 13': 'Clear Screen (CLS)',
#     'context 14': 'màng',
#     'usage 14': 'clear film',
#     'context 15': 'máy làm nước đá suốt',
#     'usage 15': 'clear ice generator',
#     'context 16': 'máy làm nước đá suốt',
#     'usage 16': 'clear ice generator [machine',
#     'context 17': 'máy làm nước đá suốt',
#     'usage 17': 'clear ice machine',
#     'context 18': 'máy làm nước đá suốt',
#     'usage 18': 'clear ice maker',
#     'context 19': 'máy làm nước đá suốt',
#     'usage 19': 'clear ice making machine',
#     'context 20': 'men',
#     'usage 20': 'clear glaze',
#     'context 21': 'nước',
#     'usage 21': 'clear water',
#     'context 22': 'nước đá suốt',
#     'usage 22': 'clear ice',
#     'context 23': 'nước được làm',
#     'usage 23': 'clear water',
#     'context 24': 'quãng trống',
#     'usage 24': 'clear spacing',
#     'context 25': 'sơn suốt',
#     'usage 25': 'clear varnish',
#     'context 26': 'thời tiết sáng',
#     'usage 26': 'clear air',
#     'context 27': 'trạm nước đá suốt',
#     'usage 27': 'clear ice making plant',
#     'context 28': 'vách kính suốt',
#     'usage 28': 'clear stained-glass window',
#     'context 29': 'vécni',
#     'usage 29': 'clear varnish',
#     'context 30': 'vécni suốt',
#     'usage 30': 'clear varnish',
#     'context 31': 'vết',
#     'usage 31': 'clear spot',
#     'context 32': 'vùng trống',
#     'usage 32': 'clear area',
#     'context 33': 'vùng trống',
#     'usage 33': 'clear zone'}},
#   6: {'translation': ['empty'],
#    'POS': 'N/A',
#    'examples': {'nums': 23,
#     'context 1': 'ánh xạ trống',
#     'usage 1': 'empty map',
#     'context 2': 'bộ báo hiệu trống',
#     'usage 2': 'empty signal unit-ESU',
#     'context 3': 'chuỗi trống',
#     'usage 3': 'empty string',
#     'context 4': 'chuỗi trống',
#     'usage 4': 'empty string (nullstring)',
#     'context 5': 'danh sách trống',
#     'usage 5': 'empty list',
#     'context 6': 'hàm trống',
#     'usage 6': 'empty function',
#     'context 7': 'khe thời gian trống',
#     'usage 7': 'empty time slot',
#     'context 8': 'khe trống',
#     'usage 8': 'empty slot',
#     'context 9': 'khoảng trống',
#     'usage 9': 'empty space',
#     'context 10': 'không trống',
#     'usage 10': 'non-empty',
#     'context 11': 'lớp trống',
#     'usage 11': 'empty class',
#     'context 12': 'mối trường trống',
#     'usage 12': 'empty medium',
#     'context 13': 'phông trống',
#     'usage 13': 'empty font',
#     'context 14': 'phương tiện tải tin trống',
#     'usage 14': 'empty medium',
#     'context 15': 'phương tiện trống',
#     'usage 15': 'empty medium',
#     'context 16': 'tải trọng rỗng',
#     'usage 16': 'empty weight',
#     'context 17': 'tập hợp trống',
#     'usage 17': 'empty set',
#     'context 18': 'tập trống',
#     'usage 18': 'empty set',
#     'context 19': 'tập trống',
#     'usage 19': 'void set, empty set',
#     'context 20': 'thư mục trống',
#     'usage 20': 'empty directory',
#     'context 21': 'trọng lượng xe không tải',
#     'usage 21': 'empty weight',
#     'context 22': 'vận tốc ánh sáng chân không',
#     'usage 22': 'speed of light in empty space',
#     'context 23': 'vật trữ tin trống',
#     'usage 23': 'empty medium'}},
#   7: {'translation': ['hollow'],
#    'POS': 'N/A',
#    'examples': {'nums': 2,
#     'context 1': 'kết cấu gỗ rỗng bên',
#     'usage 1': 'hollow wood construction',
#     'context 2': 'tường trống rỗng giữa',
#     'usage 2': 'hollow burning'}},
#   8: {'translation': ['inward'], 'POS': 'N/A', 'examples': 'N/A'},
#   9: {'translation': ['null (a-no)'], 'POS': 'N/A', 'examples': 'N/A'},
#   10: {'translation': ['null (NUL)'], 'POS': 'N/A', 'examples': 'N/A'},
#   11: {'translation': ['space'],
#    'POS': 'N/A',
#    'examples': {'nums': 67,
#     'context 1': 'ăng ten không gian',
#     'usage 1': 'space-erectable antenna',
#     'context 2': 'chuyển động không gian',
#     'usage 2': 'motion in a space',
#     'context 3': 'dây trời không gian',
#     'usage 3': 'space-erectable antenna',
#     'context 4': 'giàn lạnh phòng',
#     'usage 4': 'space air cooler',
#     'context 5': 'giới hạn không gian tôpô',
#     'usage 5': 'limit (intopological space)',
#     'context 6': 'góc nghiêng của đường thẳng không gian',
#     'usage 6': 'inclination of a line in the space',
#     'context 7': 'hành lang ra chơi trường học',
#     'usage 7': 'recreation space',
#     'context 8': 'khoảng trống',
#     'usage 8': 'air space',
#     'context 9': 'khoảng trống',
#     'usage 9': 'blank space',
#     'context 10': 'khoảng trống',
#     'usage 10': 'empty space',
#     'context 11': 'khoảng trống',
#     'usage 11': 'inter-space',
#     'context 12': 'khoảng trống',
#     'usage 12': 'void space',
#     'context 13': 'khoảng trống',
#     'usage 13': 'white space',
#     'context 14': 'khoảng trống bảng',
#     'usage 14': 'table space',
#     'context 15': 'khoảng trống cần có',
#     'usage 15': 'required space',
#     'context 16': 'khoảng trống có hại',
#     'usage 16': 'dead space',
#     'context 17': 'khoảng trống có hại',
#     'usage 17': 'idle space',
#     'context 18': 'khoảng trống có hại',
#     'usage 18': 'noxious space',
#     'context 19': 'khoảng trống giữa các khung',
#     'usage 19': 'Inter-Frame Space (IFS)',
#     'context 20': 'khoảng trống giữa hai ký tự',
#     'usage 20': 'space between characters',
#     'context 21': 'khoảng trống giữa hai đoạn văn',
#     'usage 21': 'space between paragraphs',
#     'context 22': 'khoảng trống không gian',
#     'usage 22': 'space vacuum',
#     'context 23': 'khoảng trống tính trạng',
#     'usage 23': 'state space',
#     'context 24': 'khoảng trống đen',
#     'usage 24': 'black space',
#     'context 25': 'không gian bên',
#     'usage 25': 'interior space',
#     'context 26': 'không gian trống',
#     'usage 26': 'free space (ona disk)',
#     'context 27': 'không khí nhà',
#     'usage 27': 'space air',
#     'context 28': 'không khí phòng',
#     'usage 28': 'space air',
#     'context 29': 'kiểu SPACE ngôn ngữ Pascal',
#     'usage 29': 'SPACE type',
#     'context 30': 'ký tự khoảng trống bằng không',
#     'usage 30': 'NSP (numberedspace character)',
#     'context 31': 'ký tự khoảng trống bằng số',
#     'usage 31': 'numeric space character',
#     'context 32': 'ký tự khoảng trống cần có',
#     'usage 32': 'required space character',
#     'context 33': 'ký tự khoảng trống cần có',
#     'usage 33': 'RSP (requiredspace character)',
#     'context 34': 'ký tự khoảng trống theo yêu cầu',
#     'usage 34': 'RSP (requiredspace character)',
#     'context 35': 'ký tự trống',
#     'usage 35': 'space character',
#     'context 36': 'lò sưởi phòng',
#     'usage 36': 'space heater',
#     'context 37': 'mặt lắp kính cửa sổ',
#     'usage 37': 'window space',
#     'context 38': 'mô phỏng điều kiện vũ trụ',
#     'usage 38': 'space simulation',
#     'context 39': 'nhiệt độ nhà',
#     'usage 39': 'space temperature',
#     'context 40': 'phân cách bằng ký tự trống',
#     'usage 40': 'white space delimiter',
#     'context 41': 'phép đối xạ không gian',
#     'usage 41': 'correlation in space',
#     'context 42': 'sự chuyển động không gian',
#     'usage 42': 'motion in a space',
#     'context 43': 'sự mô phỏng điều kiện vũ trụ',
#     'usage 43': 'space simulation',
#     'context 44': 'sự sưởi nhà',
#     'usage 44': 'space heating',
#     'context 45': 'sự thông gió nhà',
#     'usage 45': 'space air distribution',
#     'context 46': 'sự tiết kiệm khoảng trống',
#     'usage 46': 'economy of space',
#     'context 47': 'suy hao không gian tự do',
#     'usage 47': 'Free Space Loss (FSL)',
#     'context 48': 'tệp được phân cách bằng khoảng trống',
#     'usage 48': 'Space Delimited File (SDF)',
#     'context 49': 'thể tích',
#     'usage 49': 'space inside',
#     'context 50': 'thể tích không gian pha',
#     'usage 50': 'volume in phase space',
#     'context 51': 'thiết bị sưởi nhà',
#     'usage 51': 'space heater',
#     'context 52': 'thiết bị sưởi nhà',
#     'usage 52': 'space heating appliance',
#     'context 53': 'Thử nghiệm công nghệ Lidar vũ trụ',
#     'usage 53': 'Lidar In-space Technology Experiment (LITE)',
#     'context 54': 'tốc độ dòng chảy không gian',
#     'usage 54': 'space velocity',
#     'context 55': 'tỷ lệ dấu và trống',
#     'usage 55': 'mark-space ratio',
#     'context 56': 'vạch dấu không gian',
#     'usage 56': 'space marking',
#     'context 57': 'vận tốc ánh sáng chân không',
#     'usage 57': 'speed of light in empty space',
#     'context 58': 'vật thể không gian',
#     'usage 58': 'body in space',
#     'context 59': 'vật thể vũ trụ',
#     'usage 59': 'body in space',
#     'context 60': 'vật thể vũ trụ',
#     'usage 60': 'object in space',
#     'context 61': 'vi khí hậu nhà',
#     'usage 61': 'space microclimate',
#     'context 62': 'vị trí không gian',
#     'usage 62': 'location in space',
#     'context 63': 'vị trí không gian',
#     'usage 63': 'space position',
#     'context 64': 'vùng trống phân phối',
#     'usage 64': 'distributed free space',
#     'context 65': 'độ xoắn đường cong không gian tại một điểm',
#     'usage 65': 'torsion of a space curve at a point',
#     'context 66': 'đối tượng không gian',
#     'usage 66': 'space object',
#     'context 67': 'đường cong không gian',
#     'usage 67': 'curve in space'}},
#   12: {'translation': ['tambour'], 'POS': 'N/A', 'examples': 'N/A'},
#   13: {'translation': ['unoccupied'], 'POS': 'N/A', 'examples': 'N/A'},
#   14: {'translation': ['vacuum'],
#    'POS': 'N/A',
#    'examples': {'nums': 37,
#     'context 1': 'bay hơi chân không',
#     'usage 1': 'vacuum evaporation',
#     'context 2': 'bệ chân không máy sao chụp',
#     'usage 2': 'vacuum bed',
#     'context 3': 'bộ điều khiển không',
#     'usage 3': 'vacuum control unit',
#     'context 4': 'bùng cháy chân không',
#     'usage 4': 'vacuum flashing',
#     'context 5': 'buồng áp thấp delco',
#     'usage 5': 'vacuum capsule or chamber',
#     'context 6': 'cách điện chân không',
#     'usage 6': 'vacuum insulation',
#     'context 7': 'chuyển mạch chân không',
#     'usage 7': 'vacuum switch',
#     'context 8': 'dẫn điện chân không',
#     'usage 8': 'vacuum conduction',
#     'context 9': 'giá đỡ tấm chân không',
#     'usage 9': 'vacuum plate holder',
#     'context 10': 'hệ thống kết đông chân không',
#     'usage 10': 'vacuum freezer',
#     'context 11': 'hệ thống kết đông chân không',
#     'usage 11': 'vacuum freezing plant',
#     'context 12': 'hệ thống kết đông chân không',
#     'usage 12': 'vacuum freezing system',
#     'context 13': 'hệ thống kết đông chân không',
#     'usage 13': 'vacuum froster',
#     'context 14': 'hệ vận chuyển màng chân không',
#     'usage 14': 'vacuum film transport system',
#     'context 15': 'hồ quang chân không',
#     'usage 15': 'vacuum arc',
#     'context 16': 'hóa hơi chân không',
#     'usage 16': 'evaporation under vacuum',
#     'context 17': 'kết đông chân không',
#     'usage 17': 'vacuum freezing',
#     'context 18': 'khoảng trống không gian',
#     'usage 18': 'space vacuum',
#     'context 19': 'làm lạnh chân không',
#     'usage 19': 'vacuum cooling',
#     'context 20': 'làm nguội chân không',
#     'usage 20': 'vacuum cooling',
#     'context 21': 'lực đẩy chân không',
#     'usage 21': 'vacuum thrust',
#     'context 22': 'máy kết đông chân không',
#     'usage 22': 'vacuum freezing system',
#     'context 23': 'máy nạp đầy chân không',
#     'usage 23': 'vacuum filling machine',
#     'context 24': 'máy đóng kín chân không',
#     'usage 24': 'vacuum closing machine',
#     'context 25': 'muối được tạo ra môi trưòng chân không',
#     'usage 25': 'vacuum pan salt',
#     'context 26': 'phép thử chân không',
#     'usage 26': 'vacuum test',
#     'context 27': 'sự cán bằng lực chân không',
#     'usage 27': 'vacuum-pressure rolling',
#     'context 28': 'sự tẩm chân không',
#     'usage 28': 'vacuum impregnation',
#     'context 29': 'sự tạo chân không bê tông',
#     'usage 29': 'vacuum treatment of concrete',
#     'context 30': 'sự thổi thủy tinh chân không',
#     'usage 30': 'vacuum blowing',
#     'context 31': 'sự thổi chân không',
#     'usage 31': 'vacuum bubble',
#     'context 32': 'sự đúc chân khong',
#     'usage 32': 'vacuum casting',
#     'context 33': 'sự đúc chân không',
#     'usage 33': 'vacuum casting',
#     'context 34': 'sự đúc chân không',
#     'usage 34': 'vacuum molding',
#     'context 35': 'ủ môi trường chân không',
#     'usage 35': 'annealed in vacuum',
#     'context 36': 'đóng gói chân không',
#     'usage 36': 'vacuum packaging',
#     'context 37': 'đóng gói chân không',
#     'usage 37': 'vacuum packing'}},
#   15: {'translation': ['tubular'], 'POS': 'N/A', 'examples': 'N/A'},
#   16: {'translation': ['vacant'],
#    'POS': 'N/A',
#    'examples': {'nums': 1,
#     'context 1': 'cần tuyển cụm từ mục quảng cáo tìm người làm',
#     'usage 1': 'situations vacant'}},
#   17: {'translation': ['void'], 'POS': 'N/A', 'examples': 'N/A'},
#   18: {'translation': ['rear'], 'POS': 'N/A', 'examples': 'N/A'},
#   'nums': 18}}

# %%
with open('soha VI-EN.json', 'w') as outfile:
    json.dump(dictionary, outfile)
