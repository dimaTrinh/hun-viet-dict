# %%
import nltk

# %%
link = "./Converted/The Little Prince - Antoine de Saint-Exupery - Viet.txt"

# %%
with open(link, 'r') as infile:
    test = infile.read()

# %%
#Source: https://kite.com/python/answers/how-to-split-text-into-sentences-in-python

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/dima/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
sentences = nltk.tokenize.sent_tokenize(test)

# %%
for i in range(0, len(sentences)):
    print("Line " + str(i) + ": " + sentences[i])
# Out:
# Line 0: Xuất bản theo Hợp đồng sử dụng tác phẩm dịch giữa Chủ sỡ hữu và Nhà xuất bản Kim Đồng, 8/2/2012
#
# Vẽ bìa: NHÓM CỎ BỐN LÁ
#
# Trình bày bìa: TÔ HỒNG THỦY
#
# Ebook miễn phí tại : www.Sachvui.Com
#
#
#
#
#
# Tặng Léon Werth
#
#
# Anh xin lỗi các em nhỏ vì đã đem tặng sách này cho một người lớn.
# Line 1: Anh có một lẽ đáng kể: ông người lớn này là người bạn tốt nhất của anh trên đời.
# Line 2: Anh cố thêm một lẽ nữa: ông người lớn này cái gì cũng hiểu được, cả sách viết cho trẻ em.
# Line 3: Anh cố một lẽ thứ ba: ông người lớn này là người nước Pháp, ở đây ông ta đói và rét.
# Line 4: Ông ta cần được an ủi.
# Line 5: Nếu mà các lẽ ấy vẫn không đủ, anh xin tặng sách này cho em bé là ông người lớn đó trước kia.
# Line 6: Tất cả mọi người lớn đều từng là trẻ con (nhưng ít các ông ấy lại nhớ được như thế).
# Line 7: Vậy anh chữa lại câu đề tặng của anh:
#
# Tặng Léon Werth ngày ông còn là cậu bé
#
#
#
#
#
# MỤC LỤC
#
#
#
#
# Tặng Léon Werth
#
# I
#
# II
#
# III
#
# IV
#
# V
#
# ...

# %%
write_path = "./Cleaned/The Little Prince - Antoine de Saint-Exupery - Viet.txt"

# %%
import os
with open(write_path, 'w') as outfile:
    outfile.write("\n".join(str(item) for item in sentences))
