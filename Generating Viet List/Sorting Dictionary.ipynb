# %%
import json

# %%
with open('./bigFreqList.json') as infile:
    freqList = json.load(infile)

# %%
sortedList = sorted(freqList.items(), key=lambda x: x[1], reverse=True)

# %%
sortedList[6000:]
# Out:
# [('svđ', 6780),
#  ('state', 6778),
#  ('skincare', 6777),
#  ('asanzo', 6776),
#  ('trấu', 6772),
#  ('lpg', 6770),
#  ('dnnvv', 6769),
#  ('iu', 6767),
#  ('guồng', 6766),
#  ('tucson', 6764),
#  ('miết', 6763),
#  ('elizabeth', 6762),
#  ('bp', 6757),
#  ('rapper', 6755),
#  ('thuât', 6749),
#  ('ken', 6744),
#  ('phuket', 6739),
#  ('db', 6738),
#  ('wan', 6734),
#  ('chóc', 6730),
#  ('bbt', 6730),
#  ('talent', 6727),
#  ('valley', 6726),
#  ('xẩy', 6722),
#  ('cbre', 6721),
#  ('dấp', 6718),
#  ('ðức', 6714),
#  ('tpđà', 6714),
#  ('7m', 6711),
#  ('ttc', 6708),
#  ('var', 6708),
#  ('kid', 6707),
#  ('nhòm', 6704),
#  ('ed', 6695),
#  ('săm', 6691),
#  ('lhp', 6689),
#  ('ag', 6688),
#  ('ana', 6688),
#  ('nịnh', 6686),
#  ('tuộc', 6683),
#  ('htthích', 6681),
#  ('hasaki', 6679),
#  ('hz', 6675),
#  ('tuông', 6674),
#  ('bậy', 6674),
#  ('đút', 6673),
#  ('éo', 6673),
#  ('bida', 6673),
#  ('vầng', 6670),
#  ('epa', 6670),
#  ('veo', 6670),
#  ('viva', 6668),
#  ('token', 6668),
#  ('lukaku', 6664),
#  ('thẹn', 6664),
#  ('treble', 6658),
#  ('khem', 6655),
#  ('cebu', 6653),
#  ('hsbc', 6652),
#  ('loto', 6651),
#  ('story', 6651),
#  ('hến', 6648),
#  ('tree', 6646),
#  ('public', 6645),
#  ('elle', 6645),
#  ('trươc', 6644),
#  ('lẹ', 6640),
#  ('victor', 6639),
#  ('nớt', 6637),
#  ('trợn', 6637),
#  ('horea', 6633),
#  ('skii', 6633),
#  ('friday', 6631),
#  ('cannes', 6628),
#  ('rap', 6624),
#  ('bảnh', 6617),
#  ('imperia', 6616),
#  ('oct', 6616),
#  ('chipset', 6614),
#  ('dũ', 6609),
#  ('room', 6609),
#  ('low', 6605),
#  ('work', 6605),
#  ('thớ', 6603),
#  ('nỡ', 6603),
#  ('lự', 6603),
#  ('championship', 6602),
#  ('phoenix', 6601),
#  ('pen', 6601),
#  ('ndđt', 6592),
#  ('ktnn', 6591),
#  ('nín', 6589),
#  ('tuôn', 6587),
#  ('chiu', 6587),
#  ('basic', 6584),
#  ('future', 6580),
#  ('otp', 6573),
#  ('lố', 6568),
#  ('steroid', 6565),
#  ('giở', 6563),
#  ('hilux', 6558),
#  ('sủng', 6556),
#  ('masteri', 6553),
#  ('lag', 6552),
#  ('xl', 6550),
#  ('gôn', 6550),
#  ('salah', 6549),
#  ('cache', 6540),
#  ('ariston', 6534),
#  ('g2', 6534),
#  ('én', 6531),
#  ('streamer', 6531),
#  ('16h30', 6524),
#  ('tth', 6523),
#  ('anti', 6521),
#  ('tips', 6518),
#  ('mixer', 6518),
#  ('deluxe', 6514),
#  ('fans', 6510),
#  ('hách', 6510),
#  ('hiu', 6506),
#  ('thuy', 6506),
#  ('subaru', 6505),
#  ('wat', 6502),
#  ('dề', 6502),
#  ('bonsai', 6499),
#  ('energy', 6496),
#  ('gem', 6495),
#  ('delhi', 6494),
#  ('backdrop', 6489),
#  ('s3', 6485),
#  ('mống', 6482),
#  ('mass', 6481),
#  ('giẻ', 6480),
#  ('lâp', 6479),
#  ('usbc', 6472),
#  ('nịt', 6468),
#  ('hích', 6468),
#  ('ngớ', 6468),
#  ('end', 6466),
#  ('kawasaki', 6465),
#  ('lọn', 6464),
#  ('diêu', 6464),
#  ('mbappe', 6463),
#  ('musk', 6462),
#  ('war', 6458),
#  ('jeff', 6457),
#  ('ngổn', 6454),
#  ('motors', 6453),
#  ('aha', 6452),
#  ('kona', 6451),
#  ('80m2', 6451),
#  ('rmit', 6451),
#  ('ferguson', 6450),
#  ('ace', 6450),
#  ('cật', 6448),
#  ('ice', 6447),
#  ('a7', 6443),
#  ('kane', 6438),
#  ('pastel', 6437),
#  ('nhm', 6437),
#  ('20km', 6434),
#  ('hub', 6433),
#  ('xắt', 6432),
#  ('formosa', 6428),
#  ('palestine', 6427),
#  ('phnom', 6426),
#  ('rẩy', 6426),
#  ('sk', 6425),
#  ('bôn', 6414),
#  ('dry', 6413),
#  ('tiêt', 6410),
#  ('campus', 6410),
#  ('cmos', 6407),
#  ('silva', 6402),
#  ('eur', 6402),
#  ('đhqghcm', 6401),
#  ('pentax', 6400),
#  ('xéo', 6400),
#  ('danang', 6399),
#  ('andrew', 6398),
#  ('rụt', 6397),
#  ('tét', 6395),
#  ('chạc', 6393),
#  ('hq', 6389),
#  ('đượm', 6384),
#  ('date', 6383),
#  ('b5', 6379),
#  ('base', 6376),
#  ('will', 6375),
#  ('cỏi', 6374),
#  ('p1', 6368),
#  ('nấp', 6362),
#  ('tikivn', 6362),
#  ('imei', 6359),
#  ('lioa', 6356),
#  ('topik', 6355),
#  ('safe', 6354),
#  ('đhsp', 6351),
#  ('eh', 6349),
#  ('nganh', 6346),
#  ('cót', 6344),
#  ('machine', 6344),
#  ('nhen', 6343),
#  ('transino', 6342),
#  ('joong', 6341),
#  ('2gb', 6341),
#  ('uruguay', 6340),
#  ('image', 6338),
#  ('cocacola', 6337),
#  ('tể', 6332),
#  ('guardian', 6332),
#  ('vani', 6332),
#  ('electric', 6329),
#  ('quoc', 6327),
#  ('bvđk', 6322),
#  ('marketer', 6322),
#  ('stephen', 6321),
#  ('blđ', 6321),
#  ('framework', 6316),
#  ('giuộc', 6310),
#  ('ngượng', 6298),
#  ('sound', 6294),
#  ('sớ', 6291),
#  ('chau', 6288),
#  ('road', 6285),
#  ('vichy', 6284),
#  ('bulgaria', 6283),
#  ('npk', 6272),
#  ('nọc', 6271),
#  ('mary', 6268),
#  ('bctc', 6265),
#  ('pano', 6263),
#  ('retina', 6262),
#  ('bấp', 6258),
#  ('cat', 6257),
#  ('way', 6257),
#  ('pci', 6253),
#  ('vertu', 6252),
#  ('tăn', 6252),
#  ('usdnăm', 6250),
#  ('nhe', 6248),
#  ('diode', 6246),
#  ('steam', 6245),
#  ('kicm', 6245),
#  ('vhtt', 6243),
#  ('ùa', 6242),
#  ('tiêng', 6241),
#  ('cọng', 6236),
#  ('study', 6236),
#  ('warren', 6234),
#  ('petersburg', 6234),
#  ('q5', 6234),
#  ('uva', 6229),
#  ('matte', 6228),
#  ('angel', 6227),
#  ('jolie', 6224),
#  ('3s', 6223),
#  ('20cm', 6223),
#  ('cuả', 6221),
#  ('navara', 6218),
#  ('paradise', 6216),
#  ('slam', 6215),
#  ('rầu', 6213),
#  ('glutathione', 6212),
#  ('i7', 6207),
#  ('gôm', 6206),
#  ('universal', 6204),
#  ('range', 6200),
#  ('uế', 6199),
#  ('lavender', 6194),
#  ('uzbekistan', 6193),
#  ('vlog', 6190),
#  ('xps', 6189),
#  ('họat', 6187),
#  ('qđnd', 6184),
#  ('upcom', 6183),
#  ('tvc', 6182),
#  ('catwalk', 6181),
#  ('nguời', 6180),
#  ('dow', 6176),
#  ('chớm', 6176),
#  ('sake', 6169),
#  ('philippe', 6168),
#  ('oc', 6162),
#  ('12h00', 6161),
#  ('a9', 6160),
#  ('khàn', 6160),
#  ('qúa', 6158),
#  ('lady', 6157),
#  ('saponin', 6157),
#  ('offroad', 6156),
#  ('duterte', 6155),
#  ('plo', 6155),
#  ('zingvn', 6150),
#  ('buffett', 6148),
#  ('coco', 6147),
#  ('arab', 6145),
#  ('rịavũng', 6145),
#  ('kbnn', 6142),
#  ('rating', 6139),
#  ('3g4g', 6138),
#  ('mytour', 6138),
#  ('qs', 6136),
#  ('tiktok', 6134),
#  ('korean', 6133),
#  ('loáng', 6131),
#  ('vinyl', 6130),
#  ('eric', 6129),
#  ('electronics', 6129),
#  ('apollo', 6124),
#  ('mfc', 6124),
#  ('au', 6123),
#  ('tong', 6120),
#  ('vè', 6116),
#  ('signature', 6112),
#  ('hotgirl', 6106),
#  ('bella', 6105),
#  ('gaal', 6105),
#  ('asen', 6104),
#  ('channel', 6102),
#  ('hsg', 6100),
#  ('roger', 6095),
#  ('precision', 6093),
#  ('kìa', 6093),
#  ('hơ', 6092),
#  ('sà', 6091),
#  ('nhâp', 6091),
#  ('solution', 6089),
#  ('calcium', 6080),
#  ('visual', 6080),
#  ('mst', 6079),
#  ('kynavn', 6079),
#  ('yemen', 6077),
#  ('40m', 6071),
#  ('glc', 6069),
#  ('dó', 6069),
#  ('pctn', 6068),
#  ('vtv3', 6066),
#  ('cõng', 6065),
#  ('vât', 6061),
#  ('sg', 6061),
#  ('shinzo', 6057),
#  ('ns', 6054),
#  ('bẹp', 6052),
#  ('triêu', 6050),
#  ('liềm', 6050),
#  ('trập', 6048),
#  ('cr7', 6048),
#  ('thiến', 6047),
#  ('ncs', 6046),
#  ('not', 6043),
#  ('bậttắt', 6042),
#  ('velvet', 6042),
#  ('dk', 6040),
#  ('lòa', 6040),
#  ('boost', 6038),
#  ('chatbot', 6035),
#  ('bât', 6033),
#  ('kd', 6033),
#  ('thads', 6033),
#  ('sm', 6032),
#  ('writing', 6031),
#  ('đọa', 6029),
#  ('esl', 6029),
#  ('đuốc', 6026),
#  ('llvt', 6017),
#  ('xp', 6015),
#  ('viêng', 6013),
#  ('30cm', 6013),
#  ('prudential', 6009),
#  ('hòe', 6008),
#  ('fujie', 6006),
#  ('boxing', 6006),
#  ('huê', 6004),
#  ('hỉnh', 6001),
#  ('sodium', 6000),
#  ('kayak', 6000),
#  ('yangon', 5998),
#  ('corolla', 5998),
#  ('juve', 5995),
#  ('ethanol', 5990),
#  ('ocb', 5988),
#  ('laneige', 5985),
#  ('kiev', 5983),
#  ('hóng', 5982),
#  ('mhz', 5980),
#  ('lụi', 5979),
#  ('ket', 5978),
#  ('andy', 5978),
#  ('dslr', 5978),
#  ('đảnh', 5976),
#  ('belarus', 5976),
#  ('gả', 5975),
#  ('institute', 5975),
#  ('200m2', 5975),
#  ('gea', 5973),
#  ('rắt', 5963),
#  ('cacao', 5961),
#  ('phùn', 5961),
#  ('13h30', 5958),
#  ('weibo', 5957),
#  ('flavonoid', 5948),
#  ('yoo', 5947),
#  ('giêsu', 5947),
#  ('ir', 5946),
#  ('liquid', 5944),
#  ('part', 5942),
#  ('nph', 5941),
#  ('nukeviet', 5937),
#  ('abbott', 5936),
#  ('12mm', 5935),
#  ('thui', 5934),
#  ('blds', 5932),
#  ('qủa', 5924),
#  ('vector', 5919),
#  ('lavabo', 5918),
#  ('núp', 5915),
#  ('penh', 5913),
#  ('diva', 5910),
#  ('technologies', 5909),
#  ('cỗi', 5908),
#  ('ubmttqvn', 5904),
#  ('zombie', 5904),
#  ('garage', 5896),
#  ('giắc', 5895),
#  ('bentley', 5894),
#  ('steven', 5890),
#  ('sergio', 5887),
#  ('dỗi', 5886),
#  ('đk', 5886),
#  ('meghan', 5885),
#  ('lactic', 5884),
#  ('lc', 5883),
#  ('ak', 5882),
#  ('lả', 5879),
#  ('batdongsancomvn', 5878),
#  ('nhơ', 5877),
#  ('tran', 5874),
#  ('rượt', 5873),
#  ('uvb', 5871),
#  ('calci', 5868),
#  ('gá', 5866),
#  ('ria', 5866),
#  ('uể', 5865),
#  ('williams', 5864),
#  ('rollsroyce', 5863),
#  ('firmware', 5860),
#  ('vacxin', 5858),
#  ('sensor', 5857),
#  ('ăng', 5856),
#  ('tsbs', 5856),
#  ('hud', 5855),
#  ('manhattan', 5855),
#  ('thanks', 5855),
#  ('đhđcđ', 5854),
#  ('abu', 5853),
#  ('iốt', 5852),
#  ('marc', 5850),
#  ('bập', 5848),
#  ('3a', 5847),
#  ('stop', 5847),
#  ('bốt', 5842),
#  ('empire', 5841),
#  ('vpcp', 5841),
#  ('volume', 5839),
#  ('tags', 5837),
#  ('place', 5835),
#  ('griezmann', 5835),
#  ('biotin', 5833),
#  ('rack', 5832),
#  ('dộng', 5831),
#  ('đep', 5831),
#  ('edu', 5825),
#  ('lừ', 5824),
#  ('sala', 5820),
#  ('thỏm', 5817),
#  ('steel', 5815),
#  ('wax', 5815),
#  ('dip', 5808),
#  ('siri', 5804),
#  ('lâng', 5801),
#  ('goi', 5797),
#  ('vằn', 5795),
#  ('vec', 5793),
#  ('pl', 5791),
#  ('ngước', 5783),
#  ('pink', 5783),
#  ('xxi', 5783),
#  ('lài', 5782),
#  ('unica', 5779),
#  ('intercontinental', 5777),
#  ('quậnhuyện', 5773),
#  ('gcn', 5771),
#  ('terra', 5770),
#  ('jae', 5770),
#  ('duty', 5770),
#  ('hèm', 5769),
#  ('blazer', 5769),
#  ('256gb', 5769),
#  ('cơi', 5769),
#  ('ole', 5764),
#  ('wyndham', 5762),
#  ('matcha', 5758),
#  ('hẻo', 5755),
#  ('zone', 5755),
#  ('2a', 5755),
#  ('moskva', 5754),
#  ('lion', 5753),
#  ('cqđt', 5753),
#  ('yokohama', 5753),
#  ('nết', 5751),
#  ('noo', 5748),
#  ('atiso', 5748),
#  ('fernandes', 5747),
#  ('chun', 5746),
#  ('quick', 5745),
#  ('crôm', 5739),
#  ('nice', 5739),
#  ('nhíp', 5738),
#  ('lõng', 5738),
#  ('48h', 5737),
#  ('nồm', 5736),
#  ('sing', 5736),
#  ('last', 5735),
#  ('lincoln', 5731),
#  ('massachusetts', 5731),
#  ('scb', 5730),
#  ('tửu', 5728),
#  ('đẫy', 5728),
#  ('đồngusd', 5726),
#  ('kiếng', 5721),
#  ('khuân', 5719),
#  ('vesak', 5719),
#  ('ðiện', 5718),
#  ('dùi', 5717),
#  ('macro', 5715),
#  ('vhnt', 5714),
#  ('enter', 5712),
#  ('standee', 5711),
#  ('f5', 5711),
#  ('ngớt', 5710),
#  ('qg', 5710),
#  ('hepa', 5708),
#  ('xbox', 5702),
#  ('dpi', 5702),
#  ('yaris', 5700),
#  ('wikihow', 5700),
#  ('southampton', 5696),
#  ('hí', 5695),
#  ('inspiron', 5691),
#  ('aura', 5691),
#  ('s2', 5689),
#  ('sevilla', 5688),
#  ('aoe', 5686),
#  ('10cm', 5685),
#  ('giảo', 5684),
#  ('smartwatch', 5682),
#  ('oceanbank', 5679),
#  ('movenpick', 5678),
#  ('d2', 5678),
#  ('finance', 5676),
#  ('xiêu', 5674),
#  ('testo', 5674),
#  ('khè', 5671),
#  ('niken', 5670),
#  ('hcb', 5670),
#  ('ui', 5669),
#  ('apply', 5667),
#  ('marie', 5666),
#  ('bahrain', 5664),
#  ('microphone', 5664),
#  ('links', 5659),
#  ('nhăm', 5659),
#  ('brussels', 5658),
#  ('thò', 5651),
#  ('gis', 5651),
#  ('save', 5647),
#  ('amg', 5646),
#  ('kraft', 5645),
#  ('cuội', 5644),
#  ('duplex', 5643),
#  ('19h00', 5642),
#  ('keeng', 5640),
#  ('yoon', 5632),
#  ('award', 5632),
#  ('ciputra', 5628),
#  ('hom', 5627),
#  ('ligue', 5625),
#  ('thoang', 5624),
#  ('4s', 5622),
#  ('vinatech', 5618),
#  ('10mm', 5617),
#  ('giùm', 5617),
#  ('thethaovanhoavn', 5617),
#  ('tâng', 5615),
#  ('fagor', 5613),
#  ('túm', 5613),
#  ('nhộng', 5613),
#  ('gap', 5613),
#  ('lổ', 5611),
#  ('mascot', 5610),
#  ('gáo', 5608),
#  ('bướng', 5607),
#  ('17h30', 5607),
#  ('nghêu', 5606),
#  ('nhíu', 5606),
#  ('hì', 5603),
#  ('prix', 5602),
#  ('outlander', 5600),
#  ('kiềng', 5600),
#  ('dụm', 5599),
#  ('ngoặc', 5597),
#  ('cuôc', 5596),
#  ('boris', 5595),
#  ('mri', 5595),
#  ('venus', 5593),
#  ('teaser', 5592),
#  ('fonecare', 5590),
#  ('dả', 5590),
#  ('stereo', 5589),
#  ('kurd', 5584),
#  ('viênngày', 5584),
#  ('100km', 5581),
#  ('simon', 5580),
#  ('automatic', 5578),
#  ('oánh', 5574),
#  ('crown', 5573),
#  ('tươm', 5572),
#  ('hởi', 5570),
#  ('zika', 5568),
#  ('bẹn', 5568),
#  ('juan', 5567),
#  ('gtx', 5567),
#  ('cnlđ', 5566),
#  ('776gp', 5564),
#  ('anfield', 5562),
#  ('100k', 5562),
#  ('retail', 5560),
#  ('niêu', 5554),
#  ('piaggio', 5552),
#  ('60m2', 5550),
#  ('kobe', 5545),
#  ('30m2', 5545),
#  ('thánglần', 5543),
#  ('bẹ', 5542),
#  ('wigo', 5542),
#  ('martial', 5541),
#  ('gpa', 5541),
#  ('23h', 5540),
#  ('north', 5532),
#  ('khểnh', 5527),
#  ('serbia', 5527),
#  ('coc', 5523),
#  ('bêtông', 5522),
#  ('bsr', 5520),
#  ('concert', 5520),
#  ('chuân', 5519),
#  ('sigma', 5518),
#  ('filter', 5518),
#  ('ebola', 5518),
#  ('haccp', 5516),
#  ('chiềng', 5515),
#  ('áthái', 5513),
#  ('20g', 5512),
#  ('gear', 5509),
#  ('nhạn', 5509),
#  ('triton', 5504),
#  ('kremlin', 5504),
#  ('lằn', 5502),
#  ('nhác', 5501),
#  ('protected', 5500),
#  ('door', 5498),
#  ('jet', 5496),
#  ('đăt', 5495),
#  ('layout', 5495),
#  ('líu', 5491),
#  ('đat', 5491),
#  ('beer', 5485),
#  ('jackson', 5481),
#  ('mpv', 5480),
#  ('giỡn', 5480),
#  ('ngốn', 5479),
#  ('300m2', 5478),
#  ('đung', 5477),
#  ('rươi', 5476),
#  ('500k', 5476),
#  ('16m', 5473),
#  ('mả', 5471),
#  ('robusta', 5470),
#  ('miu', 5470),
#  ('mipec', 5465),
#  ('70m2', 5465),
#  ('stanford', 5465),
#  ('financial', 5462),
#  ('talk', 5462),
#  ('avenue', 5460),
#  ('joy', 5456),
#  ('rashford', 5454),
#  ('toanh', 5452),
#  ('leader', 5451),
#  ('arabica', 5450),
#  ('xsmn', 5449),
#  ('12mp', 5448),
#  ('seattle', 5448),
#  ('diet', 5448),
#  ('cleansing', 5447),
#  ('nc', 5447),
#  ('onplaza', 5446),
#  ('uổng', 5446),
#  ('koh', 5445),
#  ('m3ngày', 5444),
#  ('dìm', 5442),
#  ('thuân', 5437),
#  ('carlos', 5435),
#  ('30km', 5435),
#  ('ipo', 5434),
#  ('hutech', 5428),
#  ('flagold', 5425),
#  ('lưa', 5424),
#  ('adoor', 5424),
#  ('thím', 5423),
#  ('mún', 5422),
#  ('centre', 5421),
#  ('copa', 5421),
#  ('iron', 5421),
#  ('shipper', 5421),
#  ('hâu', 5418),
#  ('basel', 5416),
#  ('extract', 5414),
#  ('trét', 5410),
#  ('ebay', 5407),
#  ('10g', 5405),
#  ('maldives', 5403),
#  ('erdogan', 5402),
#  ('0px', 5401),
#  ('ebara', 5394),
#  ('iris', 5394),
#  ('diệc', 5391),
#  ('nu', 5390),
#  ('héc', 5386),
#  ('bezos', 5383),
#  ('đồngngườitháng', 5381),
#  ('gẫy', 5378),
#  ('rog', 5378),
#  ('luyenvietchudepchonguoilonvagiaovien', 5377),
#  ('serial', 5377),
#  ('paypal', 5374),
#  ('oneplus', 5373),
#  ('attt', 5371),
#  ('dôi', 5370),
#  ('aaa', 5366),
#  ('jica', 5366),
#  ('hafele', 5365),
#  ('bân', 5365),
#  ('vnm', 5363),
#  ('expo', 5362),
#  ('development', 5362),
#  ('thúng', 5360),
#  ('xuýt', 5359),
#  ('cms', 5359),
#  ('ufc', 5359),
#  ('kn', 5358),
#  ('dốt', 5358),
#  ('austdoor', 5357),
#  ('sirius', 5357),
#  ('lucky', 5356),
#  ('zen', 5354),
#  ('professional', 5350),
#  ('lợ', 5348),
#  ('lactose', 5345),
#  ('lấm', 5343),
#  ('charlie', 5342),
#  ('lb', 5336),
#  ('lavie', 5336),
#  ('cruiser', 5334),
#  ('soft', 5333),
#  ('buddha', 5332),
#  ('hcđ', 5331),
#  ('kttv', 5331),
#  ('bmi', 5330),
#  ('performance', 5327),
#  ('fbi', 5326),
#  ('ivan', 5325),
#  ('diết', 5325),
#  ('tts', 5323),
#  ('hmông', 5320),
#  ('asiana', 5318),
#  ('bìu', 5318),
#  ('nippon', 5317),
#  ('hỡi', 5316),
#  ('cói', 5315),
#  ('lóe', 5312),
#  ('et', 5309),
#  ('macron', 5307),
#  ('ngăm', 5307),
#  ('biếm', 5307),
#  ('nưa', 5306),
#  ('rệp', 5299),
#  ('yves', 5298),
#  ('1000m2', 5297),
#  ('qbđt', 5297),
#  ('mỉa', 5296),
#  ('nanh', 5295),
#  ('yen', 5295),
#  ('nđ', 5289),
#  ('sol', 5289),
#  ('av', 5284),
#  ('brother', 5283),
#  ('nua', 5281),
#  ('bsc', 5279),
#  ('jesus', 5277),
#  ('metavn', 5274),
#  ('zaloviber', 5273),
#  ('selen', 5271),
#  ('amiăng', 5270),
#  ('pk', 5270),
#  ('houston', 5269),
#  ('poly', 5267),
#  ('raptor', 5264),
#  ('latin', 5263),
#  ('tcn', 5263),
#  ('coca', 5262),
#  ('răm', 5262),
#  ('lòi', 5261),
#  ('j7', 5260),
#  ('cảo', 5260),
#  ('nicolas', 5259),
#  ('bện', 5257),
#  ('dùm', 5254),
#  ('mat', 5253),
#  ('nhuế', 5252),
#  ('that', 5251),
#  ('nép', 5250),
#  ('chình', 5247),
#  ('fontsize', 5246),
#  ('ramos', 5245),
#  ('coin', 5244),
#  ('airline', 5243),
#  ('smarthome', 5243),
#  ('week', 5242),
#  ('lẳng', 5241),
#  ('liberty', 5240),
#  ('phẩy', 5240),
#  ('sticker', 5238),
#  ('864gpbtttt', 5238),
#  ('iec', 5236),
#  ('um', 5235),
#  ('neon', 5235),
#  ('rànglỗi', 5232),
#  ('denim', 5231),
#  ('miami', 5231),
#  ('trưc', 5231),
#  ('cabinet', 5230),
#  ('thoắt', 5225),
#  ('mần', 5222),
#  ('peel', 5220),
#  ('silk', 5219),
#  ('enterprise', 5218),
#  ('lịm', 5218),
#  ('hóm', 5217),
#  ('mountain', 5216),
#  ('typec', 5213),
#  ('thình', 5213),
#  ('nộm', 5213),
#  ('catalan', 5212),
#  ('vtv1', 5212),
#  ('420ma', 5210),
#  ('nicotine', 5206),
#  ('jackpot', 5203),
#  ('shock', 5203),
#  ('a8', 5197),
#  ('southern', 5196),
#  ('python', 5193),
#  ('newton', 5190),
#  ('electron', 5190),
#  ('vuitton', 5188),
#  ('garena', 5188),
#  ('medical', 5185),
#  ('pedro', 5185),
#  ('bhutan', 5185),
#  ('czech', 5185),
#  ('thướt', 5184),
#  ('screen', 5183),
#  ('ốt', 5183),
#  ('pct', 5180),
#  ('sata', 5178),
#  ('chiền', 5175),
#  ('sứa', 5171),
#  ('kanji', 5171),
#  ('kkt', 5171),
#  ('platform', 5170),
#  ('logitech', 5169),
#  ('hugo', 5169),
#  ('background', 5167),
#  ('giễu', 5165),
#  ('console', 5160),
#  ('olympia', 5159),
#  ('liếm', 5159),
#  ('avengers', 5159),
#  ('macos', 5156),
#  ('u18', 5155),
#  ('rượi', 5155),
#  ('g3', 5154),
#  ('rục', 5153),
#  ('keyword', 5152),
#  ('bto', 5152),
#  ('gallery', 5147),
#  ('sap', 5146),
#  ('hững', 5145),
#  ('illustrator', 5137),
#  ('trề', 5136),
#  ('2pn', 5136),
#  ('uniqlo', 5135),
#  ('fusion', 5134),
#  ('nfc', 5134),
#  ('retro', 5132),
#  ('des', 5131),
#  ('50mm', 5131),
#  ('bống', 5129),
#  ('ems', 5129),
#  ('penalty', 5124),
#  ('flip', 5123),
#  ('ổng', 5122),
#  ('academic', 5122),
#  ('sính', 5121),
#  ('rush', 5119),
#  ('18h30', 5119),
#  ('eq', 5114),
#  ('tấnha', 5112),
#  ('10kg', 5108),
#  ('echo', 5108),
#  ('etihad', 5106),
#  ('đôc', 5104),
#  ('ontario', 5102),
#  ('miura', 5099),
#  ('gareth', 5099),
#  ('ló', 5098),
#  ('sos', 5098),
#  ('joo', 5095),
#  ('manga', 5092),
#  ('schengen', 5092),
#  ('unilever', 5090),
#  ('msb', 5089),
#  ('nishino', 5089),
#  ('saffron', 5089),
#  ('emerald', 5084),
#  ('investment', 5084),
#  ('solid', 5084),
#  ('summit', 5083),
#  ('motion', 5081),
#  ('lupus', 5081),
#  ('htv', 5080),
#  ('bủa', 5080),
#  ('núc', 5080),
#  ('cmt', 5080),
#  ('fold', 5078),
#  ('gon', 5072),
#  ('watford', 5071),
#  ('swing', 5070),
#  ('đồngngày', 5070),
#  ('ðiều', 5069),
#  ('penthouse', 5069),
#  ('es', 5067),
#  ('private', 5067),
#  ('thor', 5067),
#  ('pompeo', 5065),
#  ('thía', 5064),
#  ('nguôn', 5059),
#  ('sẳn', 5058),
#  ('chịt', 5058),
#  ('gáp', 5055),
#  ('bl', 5054),
#  ('developer', 5054),
#  ('jr', 5053),
#  ('mk', 5049),
#  ('phuy', 5047),
#  ('charge', 5043),
#  ('jo', 5039),
#  ('vozforums', 5039),
#  ('gamuda', 5035),
#  ('geyser', 5032),
#  ('images', 5032),
#  ('thiet', 5028),
#  ('acoustic', 5028),
#  ('đtm', 5025),
#  ('trồi', 5023),
#  ('discovery', 5018),
#  ('phiếm', 5018),
#  ('build', 5018),
#  ('kỉnh', 5016),
#  ('nhè', 5015),
#  ('daewoo', 5014),
#  ('extra', 5013),
#  ('đênh', 5012),
#  ('standa', 5012),
#  ('chiakivn', 5012),
#  ('hđh', 5011),
#  ('akira', 5008),
#  ('m1', 5005),
#  ...]

# %%
dictionary = {}
dictionary['data'] = sortedList

# %%
with open('./sortedFreqList.json', 'w') as outfile:
    json.dump(dictionary, outfile)
